# %% [markdown]
# # Initialization

# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset02/'
vitaldbpath = 'vitaldb_tiva/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt
import pickle

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 513, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 513 (delta 22), reused 46 (delta 20), pack-reused 461
# Receiving objects: 100% (513/513), 83.94 MiB | 29.07 MiB/s, done.
# Resolving deltas: 100% (226/226), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl.metadata (520 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.31.0)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.8 MB/s eta 0:00:00
# Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %% [markdown]
# # Data loading

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolrate.name = 'Propofol Rate'
    propofolrate.tracks = ['Orchestra/PPF20_RATE']
    propofolrate.filterON = False
    propofolrate.generateDataset(normalization=md.NormNone)
    propofolrate.save('03_propofol_rate.npz')

    remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    remifentanilrate.name = 'Remifentanil Rate'
    remifentanilrate.tracks = ['Orchestra/RFTN20_RATE']
    remifentanilrate.filterON = False
    remifentanilrate.generateDataset(normalization=md.NormNone)
    remifentanilrate.save('03_remifentanil_rate.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolrate.load('03_propofol_rate.npz')

remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
remifentanilrate.load('03_remifentanil_rate.npz')

train_index, val_index, test_index = bis.split(np.array(bis.index))

# %% [markdown]
# # Model creation

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### Blood Pressure Input
input_bp = Input(shape=(None, bloodpressure.train_dataset.shape[2]))
bp_layer = Masking(mask_value=0.0)(input_bp)

bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=128, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=16, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=16, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = Dense(units=16, activation='linear')(bp_layer)

### etCO2 Input
input_co2 = Input(shape=(None, etCO2.train_dataset.shape[2]))

co2_layer = LSTM(units=64, return_sequences=True)(input_co2)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=64, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=64, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=16, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=8, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = Dense(units=8, activation='linear')(co2_layer)

### spo2 Input
input_spo2 = Input(shape=(None, spO2.train_dataset.shape[2]))

spo2_layer = LSTM(units=64, return_sequences=True)(input_spo2)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=64, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=64, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=16, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=8, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = Dense(units=8, activation='linear')(spo2_layer)

# Prpofol layers
input_propofol = Input(shape=(None, propofolrate.train_dataset.shape[2]))
propofol_layer = BatchNormalization()(input_propofol)
propofol_layer = LSTM(units=64, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=64, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=64, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=64, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=128, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=64, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=16, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=16, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = Dense(units=16, activation='linear')(propofol_layer)

### INFO layers
input_info = Input(shape=(info.train_dataset.shape[1],))
info_layer = RepeatVector(bloodpressure.train_dataset.shape[1])(input_info)
info_layer = Dense(units=16, activation='linear')(info_layer)
info_layer = Dense(units=16, activation='sigmoid')(info_layer)


## Concatenate the Propofol output with the info layer
comb_layer = Concatenate()([bp_layer, co2_layer, spo2_layer, propofol_layer, info_layer])
comb_layer = Dense(units=64, activation='linear')(comb_layer)
comb_layer = Dense(units=64, activation='relu')(comb_layer)
comb_layer = Dense(units=64, activation='relu')(comb_layer)
comb_layer = Dense(units=32, activation='relu')(comb_layer)
comb_layer = Dense(units=16, activation='relu')(comb_layer)
comb_layer = Dense(units=1, activation='relu')(comb_layer)
output = Lambda(lambda x: x * 100)(comb_layer)

# Define the model
model = Model(inputs=[input_bp, input_co2, input_spo2, input_propofol, input_info], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.0005)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 3)]            0         []
#
#  input_4 (InputLayer)        [(None, None, 1)]            0         []
#
#  masking (Masking)           (None, None, 3)              0         ['input_1[0][0]']
#
#  batch_normalization_18 (Ba  (None, None, 1)              4         ['input_4[0][0]']
#  tchNormalization)
#
#  lstm (LSTM)                 (None, None, 64)             17408     ['masking[0][0]']
#
#  lstm_18 (LSTM)              (None, None, 64)             16896     ['batch_normalization_18[0][0]
#                                                                     ']
#
#  batch_normalization (Batch  (None, None, 64)             256       ['lstm[0][0]']
#  Normalization)
#
#  batch_normalization_19 (Ba  (None, None, 64)             256       ['lstm_18[0][0]']
#  tchNormalization)
#
#  lstm_1 (LSTM)               (None, None, 64)             33024     ['batch_normalization[0][0]']
#
#  lstm_19 (LSTM)              (None, None, 64)             33024     ['batch_normalization_19[0][0]
#                                                                     ']
#
#  batch_normalization_1 (Bat  (None, None, 64)             256       ['lstm_1[0][0]']
#  chNormalization)
#
#  batch_normalization_20 (Ba  (None, None, 64)             256       ['lstm_19[0][0]']
#  tchNormalization)
#
#  lstm_2 (LSTM)               (None, None, 64)             33024     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  lstm_20 (LSTM)              (None, None, 64)             33024     ['batch_normalization_20[0][0]
#                                                                     ']
#
#  batch_normalization_2 (Bat  (None, None, 64)             256       ['lstm_2[0][0]']
#  chNormalization)
#
#  input_2 (InputLayer)        [(None, None, 1)]            0         []
#
#  input_3 (InputLayer)        [(None, None, 1)]            0         []
#
#  batch_normalization_21 (Ba  (None, None, 64)             256       ['lstm_20[0][0]']
#  tchNormalization)
#
#  lstm_3 (LSTM)               (None, None, 64)             33024     ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  lstm_8 (LSTM)               (None, None, 64)             16896     ['input_2[0][0]']
#
#  lstm_13 (LSTM)              (None, None, 64)             16896     ['input_3[0][0]']
#
#  lstm_21 (LSTM)              (None, None, 64)             33024     ['batch_normalization_21[0][0]
#                                                                     ']
#
#  batch_normalization_3 (Bat  (None, None, 64)             256       ['lstm_3[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, None, 64)             256       ['lstm_8[0][0]']
#  chNormalization)
#
#  batch_normalization_13 (Ba  (None, None, 64)             256       ['lstm_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, None, 64)             256       ['lstm_21[0][0]']
#  tchNormalization)
#
#  lstm_4 (LSTM)               (None, None, 128)            98816     ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  lstm_9 (LSTM)               (None, None, 64)             33024     ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  lstm_14 (LSTM)              (None, None, 64)             33024     ['batch_normalization_13[0][0]
#                                                                     ']
#
#  lstm_22 (LSTM)              (None, None, 128)            98816     ['batch_normalization_22[0][0]
#                                                                     ']
#
#  batch_normalization_4 (Bat  (None, None, 128)            512       ['lstm_4[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, None, 64)             256       ['lstm_9[0][0]']
#  chNormalization)
#
#  batch_normalization_14 (Ba  (None, None, 64)             256       ['lstm_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, None, 128)            512       ['lstm_22[0][0]']
#  tchNormalization)
#
#  lstm_5 (LSTM)               (None, None, 64)             49408     ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  lstm_10 (LSTM)              (None, None, 64)             33024     ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  lstm_15 (LSTM)              (None, None, 64)             33024     ['batch_normalization_14[0][0]
#                                                                     ']
#
#  lstm_23 (LSTM)              (None, None, 64)             49408     ['batch_normalization_23[0][0]
#                                                                     ']
#
#  batch_normalization_5 (Bat  (None, None, 64)             256       ['lstm_5[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, None, 64)             256       ['lstm_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, None, 64)             256       ['lstm_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, None, 64)             256       ['lstm_23[0][0]']
#  tchNormalization)
#
#  lstm_6 (LSTM)               (None, None, 16)             5184      ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  lstm_11 (LSTM)              (None, None, 16)             5184      ['batch_normalization_10[0][0]
#                                                                     ']
#
#  lstm_16 (LSTM)              (None, None, 16)             5184      ['batch_normalization_15[0][0]
#                                                                     ']
#
#  lstm_24 (LSTM)              (None, None, 16)             5184      ['batch_normalization_24[0][0]
#                                                                     ']
#
#  batch_normalization_6 (Bat  (None, None, 16)             64        ['lstm_6[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, None, 16)             64        ['lstm_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, None, 16)             64        ['lstm_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, None, 16)             64        ['lstm_24[0][0]']
#  tchNormalization)
#
#  input_5 (InputLayer)        [(None, 5)]                  0         []
#
#  lstm_7 (LSTM)               (None, None, 16)             2112      ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  lstm_12 (LSTM)              (None, None, 8)              800       ['batch_normalization_11[0][0]
#                                                                     ']
#
#  lstm_17 (LSTM)              (None, None, 8)              800       ['batch_normalization_16[0][0]
#                                                                     ']
#
#  lstm_25 (LSTM)              (None, None, 16)             2112      ['batch_normalization_25[0][0]
#                                                                     ']
#
#  repeat_vector (RepeatVecto  (None, 3680, 5)              0         ['input_5[0][0]']
#  r)
#
#  batch_normalization_7 (Bat  (None, None, 16)             64        ['lstm_7[0][0]']
#  chNormalization)
#
#  batch_normalization_12 (Ba  (None, None, 8)              32        ['lstm_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, None, 8)              32        ['lstm_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, None, 16)             64        ['lstm_25[0][0]']
#  tchNormalization)
#
#  dense_4 (Dense)             (None, 3680, 16)             96        ['repeat_vector[0][0]']
#
#  dense (Dense)               (None, None, 16)             272       ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dense_1 (Dense)             (None, None, 8)              72        ['batch_normalization_12[0][0]
#                                                                     ']
#
#  dense_2 (Dense)             (None, None, 8)              72        ['batch_normalization_17[0][0]
#                                                                     ']
#
#  dense_3 (Dense)             (None, None, 16)             272       ['batch_normalization_26[0][0]
#                                                                     ']
#
#  dense_5 (Dense)             (None, 3680, 16)             272       ['dense_4[0][0]']
#
#  concatenate (Concatenate)   (None, 3680, 64)             0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 3680, 64)             4160      ['concatenate[0][0]']
#
#  dense_7 (Dense)             (None, 3680, 64)             4160      ['dense_6[0][0]']
#
#  dense_8 (Dense)             (None, 3680, 64)             4160      ['dense_7[0][0]']
#
#  dense_9 (Dense)             (None, 3680, 32)             2080      ['dense_8[0][0]']
#
#  dense_10 (Dense)            (None, 3680, 16)             528       ['dense_9[0][0]']
#
#  dense_11 (Dense)            (None, 3680, 1)              17        ['dense_10[0][0]']
#
#  lambda (Lambda)             (None, 3680, 1)              0         ['dense_11[0][0]']
#
# ==================================================================================================
# Total params: 743077 (2.83 MB)
# Trainable params: 740291 (2.82 MB)
# Non-trainable params: 2786 (10.88 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %%
# Rolling mean on BIS data
y = pd.DataFrame(bis.train_dataset[:,:,0].T).rolling(min_periods=1,window=3, center=True).mean().to_numpy().T[:,:,np.newaxis]

# Define training stop criteria
class StopTrainingCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(StopTrainingCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_loss') is not None:
            if logs.get('val_loss') < self.threshold:
                print(f"\nValidation loss is below {self.threshold}, stopping training.")
                self.model.stop_training = True

stop_training_callback = StopTrainingCallback(threshold = 35)



# Train the model
history = model.fit([bloodpressure.train_dataset, etCO2.train_dataset, spO2.train_dataset, propofolrate.train_dataset, info.train_dataset],
                    y,
                    validation_data=([bloodpressure.validation_dataset, etCO2.validation_dataset, spO2.validation_dataset, propofolrate.validation_dataset , info.validation_dataset], bis.validation_dataset),
                    epochs=150,
                    callbacks=[stop_training_callback],
                    batch_size=4
                    )

train_score = history.history

if in_google_colab():
    # Save the model
    model.save('download/model.keras')

    # Save the training history
    with open('download/train_score.pkl', 'wb') as f:
        pickle.dump(train_score, f)
# Out:
# Epoch 1/150
# 28/28 [==============================] - 150s 3s/step - loss: 336.2950 - mean_squared_error: 336.2950 - mean_absolute_error: 10.6770 - root_mean_squared_error: 18.3383 - val_loss: 505.7501 - val_mean_squared_error: 505.7501 - val_mean_absolute_error: 18.5423 - val_root_mean_squared_error: 22.4889
# Epoch 2/150
# 28/28 [==============================] - 57s 2s/step - loss: 123.4459 - mean_squared_error: 123.4459 - mean_absolute_error: 6.0072 - root_mean_squared_error: 11.1106 - val_loss: 445.6801 - val_mean_squared_error: 445.6801 - val_mean_absolute_error: 19.2050 - val_root_mean_squared_error: 21.1111
# Epoch 3/150
# 28/28 [==============================] - 57s 2s/step - loss: 87.4125 - mean_squared_error: 87.4125 - mean_absolute_error: 4.6865 - root_mean_squared_error: 9.3495 - val_loss: 471.3511 - val_mean_squared_error: 471.3511 - val_mean_absolute_error: 19.8389 - val_root_mean_squared_error: 21.7106
# Epoch 4/150
# 28/28 [==============================] - 57s 2s/step - loss: 75.1383 - mean_squared_error: 75.1383 - mean_absolute_error: 4.3288 - root_mean_squared_error: 8.6682 - val_loss: 452.6413 - val_mean_squared_error: 452.6413 - val_mean_absolute_error: 19.4347 - val_root_mean_squared_error: 21.2754
# Epoch 5/150
# 28/28 [==============================] - 58s 2s/step - loss: 63.8072 - mean_squared_error: 63.8071 - mean_absolute_error: 4.0071 - root_mean_squared_error: 7.9879 - val_loss: 409.0477 - val_mean_squared_error: 409.0477 - val_mean_absolute_error: 18.3419 - val_root_mean_squared_error: 20.2249
# Epoch 6/150
# 28/28 [==============================] - 59s 2s/step - loss: 58.6103 - mean_squared_error: 58.6103 - mean_absolute_error: 3.8533 - root_mean_squared_error: 7.6557 - val_loss: 406.5074 - val_mean_squared_error: 406.5074 - val_mean_absolute_error: 18.2426 - val_root_mean_squared_error: 20.1620
# Epoch 7/150
# 28/28 [==============================] - 58s 2s/step - loss: 57.7518 - mean_squared_error: 57.7518 - mean_absolute_error: 3.7945 - root_mean_squared_error: 7.5995 - val_loss: 420.7705 - val_mean_squared_error: 420.7705 - val_mean_absolute_error: 18.3820 - val_root_mean_squared_error: 20.5127
# Epoch 8/150
# 28/28 [==============================] - 58s 2s/step - loss: 54.6798 - mean_squared_error: 54.6798 - mean_absolute_error: 3.7118 - root_mean_squared_error: 7.3946 - val_loss: 455.5279 - val_mean_squared_error: 455.5279 - val_mean_absolute_error: 19.0064 - val_root_mean_squared_error: 21.3431
# Epoch 9/150
# 28/28 [==============================] - 58s 2s/step - loss: 51.1864 - mean_squared_error: 51.1864 - mean_absolute_error: 3.5922 - root_mean_squared_error: 7.1545 - val_loss: 547.0573 - val_mean_squared_error: 547.0572 - val_mean_absolute_error: 20.7452 - val_root_mean_squared_error: 23.3893
# Epoch 10/150
# 28/28 [==============================] - 59s 2s/step - loss: 51.0406 - mean_squared_error: 51.0406 - mean_absolute_error: 3.6216 - root_mean_squared_error: 7.1443 - val_loss: 588.0597 - val_mean_squared_error: 588.0596 - val_mean_absolute_error: 21.4377 - val_root_mean_squared_error: 24.2499
# Epoch 11/150
# 28/28 [==============================] - 58s 2s/step - loss: 48.7656 - mean_squared_error: 48.7656 - mean_absolute_error: 3.4838 - root_mean_squared_error: 6.9832 - val_loss: 758.4973 - val_mean_squared_error: 758.4974 - val_mean_absolute_error: 24.0590 - val_root_mean_squared_error: 27.5408
# Epoch 12/150
# 28/28 [==============================] - 57s 2s/step - loss: 45.8878 - mean_squared_error: 45.8878 - mean_absolute_error: 3.4157 - root_mean_squared_error: 6.7741 - val_loss: 741.5934 - val_mean_squared_error: 741.5934 - val_mean_absolute_error: 23.8898 - val_root_mean_squared_error: 27.2322
# Epoch 13/150
# 28/28 [==============================] - 58s 2s/step - loss: 42.8916 - mean_squared_error: 42.8916 - mean_absolute_error: 3.3661 - root_mean_squared_error: 6.5492 - val_loss: 658.5154 - val_mean_squared_error: 658.5154 - val_mean_absolute_error: 22.7093 - val_root_mean_squared_error: 25.6616
# Epoch 14/150
# 28/28 [==============================] - 58s 2s/step - loss: 43.6220 - mean_squared_error: 43.6221 - mean_absolute_error: 3.3241 - root_mean_squared_error: 6.6047 - val_loss: 574.5397 - val_mean_squared_error: 574.5397 - val_mean_absolute_error: 21.2215 - val_root_mean_squared_error: 23.9696
# Epoch 15/150
# 28/28 [==============================] - 57s 2s/step - loss: 43.2430 - mean_squared_error: 43.2430 - mean_absolute_error: 3.3268 - root_mean_squared_error: 6.5759 - val_loss: 784.1245 - val_mean_squared_error: 784.1245 - val_mean_absolute_error: 24.4328 - val_root_mean_squared_error: 28.0022
# Epoch 16/150
# 28/28 [==============================] - 58s 2s/step - loss: 46.2401 - mean_squared_error: 46.2401 - mean_absolute_error: 3.4647 - root_mean_squared_error: 6.8000 - val_loss: 861.3344 - val_mean_squared_error: 861.3343 - val_mean_absolute_error: 25.5910 - val_root_mean_squared_error: 29.3485
# Epoch 17/150
# 28/28 [==============================] - 58s 2s/step - loss: 44.8588 - mean_squared_error: 44.8588 - mean_absolute_error: 3.4055 - root_mean_squared_error: 6.6977 - val_loss: 930.1307 - val_mean_squared_error: 930.1307 - val_mean_absolute_error: 26.2893 - val_root_mean_squared_error: 30.4980
# Epoch 18/150
# 28/28 [==============================] - 58s 2s/step - loss: 43.0851 - mean_squared_error: 43.0851 - mean_absolute_error: 3.3230 - root_mean_squared_error: 6.5639 - val_loss: 973.4458 - val_mean_squared_error: 973.4459 - val_mean_absolute_error: 26.9161 - val_root_mean_squared_error: 31.2001
# Epoch 19/150
# 28/28 [==============================] - 59s 2s/step - loss: 41.4165 - mean_squared_error: 41.4165 - mean_absolute_error: 3.2663 - root_mean_squared_error: 6.4356 - val_loss: 992.1175 - val_mean_squared_error: 992.1175 - val_mean_absolute_error: 27.1100 - val_root_mean_squared_error: 31.4979
# Epoch 20/150
# 28/28 [==============================] - 58s 2s/step - loss: 40.6747 - mean_squared_error: 40.6747 - mean_absolute_error: 3.2314 - root_mean_squared_error: 6.3777 - val_loss: 994.0516 - val_mean_squared_error: 994.0515 - val_mean_absolute_error: 27.1583 - val_root_mean_squared_error: 31.5286
# Epoch 21/150
# 28/28 [==============================] - 58s 2s/step - loss: 44.3019 - mean_squared_error: 44.3019 - mean_absolute_error: 3.4369 - root_mean_squared_error: 6.6560 - val_loss: 654.3727 - val_mean_squared_error: 654.3727 - val_mean_absolute_error: 22.4473 - val_root_mean_squared_error: 25.5807
# Epoch 22/150
# 28/28 [==============================] - 58s 2s/step - loss: 39.8741 - mean_squared_error: 39.8741 - mean_absolute_error: 3.2022 - root_mean_squared_error: 6.3146 - val_loss: 681.7936 - val_mean_squared_error: 681.7935 - val_mean_absolute_error: 22.8190 - val_root_mean_squared_error: 26.1112
# Epoch 23/150
# 28/28 [==============================] - 58s 2s/step - loss: 40.5607 - mean_squared_error: 40.5607 - mean_absolute_error: 3.2434 - root_mean_squared_error: 6.3687 - val_loss: 401.0495 - val_mean_squared_error: 401.0495 - val_mean_absolute_error: 17.8562 - val_root_mean_squared_error: 20.0262
# Epoch 24/150
# 28/28 [==============================] - 58s 2s/step - loss: 39.2002 - mean_squared_error: 39.2002 - mean_absolute_error: 3.1782 - root_mean_squared_error: 6.2610 - val_loss: 105.5287 - val_mean_squared_error: 105.5287 - val_mean_absolute_error: 9.0684 - val_root_mean_squared_error: 10.2727
# Epoch 25/150
# 28/28 [==============================] - 57s 2s/step - loss: 37.6789 - mean_squared_error: 37.6789 - mean_absolute_error: 3.0987 - root_mean_squared_error: 6.1383 - val_loss: 313.1532 - val_mean_squared_error: 313.1532 - val_mean_absolute_error: 15.8172 - val_root_mean_squared_error: 17.6961
# Epoch 26/150
# 28/28 [==============================] - 57s 2s/step - loss: 38.2996 - mean_squared_error: 38.2996 - mean_absolute_error: 3.1576 - root_mean_squared_error: 6.1887 - val_loss: 79.7160 - val_mean_squared_error: 79.7160 - val_mean_absolute_error: 7.5287 - val_root_mean_squared_error: 8.9284
# Epoch 27/150
# 28/28 [==============================] - 58s 2s/step - loss: 39.3079 - mean_squared_error: 39.3079 - mean_absolute_error: 3.1702 - root_mean_squared_error: 6.2696 - val_loss: 112.9769 - val_mean_squared_error: 112.9768 - val_mean_absolute_error: 9.5325 - val_root_mean_squared_error: 10.6291
# Epoch 28/150
# 28/28 [==============================] - 59s 2s/step - loss: 36.3624 - mean_squared_error: 36.3624 - mean_absolute_error: 3.0617 - root_mean_squared_error: 6.0301 - val_loss: 100.1093 - val_mean_squared_error: 100.1093 - val_mean_absolute_error: 8.9898 - val_root_mean_squared_error: 10.0055
# Epoch 29/150
# 28/28 [==============================] - 58s 2s/step - loss: 37.1640 - mean_squared_error: 37.1640 - mean_absolute_error: 3.0930 - root_mean_squared_error: 6.0962 - val_loss: 44.0397 - val_mean_squared_error: 44.0397 - val_mean_absolute_error: 3.3102 - val_root_mean_squared_error: 6.6362
# Epoch 30/150
# 28/28 [==============================] - 58s 2s/step - loss: 37.5818 - mean_squared_error: 37.5818 - mean_absolute_error: 3.1234 - root_mean_squared_error: 6.1304 - val_loss: 53.8614 - val_mean_squared_error: 53.8614 - val_mean_absolute_error: 5.5924 - val_root_mean_squared_error: 7.3390
# Epoch 31/150
# 28/28 [==============================] - 57s 2s/step - loss: 36.8118 - mean_squared_error: 36.8118 - mean_absolute_error: 3.0966 - root_mean_squared_error: 6.0673 - val_loss: 49.6392 - val_mean_squared_error: 49.6392 - val_mean_absolute_error: 3.5813 - val_root_mean_squared_error: 7.0455
# Epoch 32/150
# 28/28 [==============================] - 58s 2s/step - loss: 38.5092 - mean_squared_error: 38.5092 - mean_absolute_error: 3.1739 - root_mean_squared_error: 6.2056 - val_loss: 198.5425 - val_mean_squared_error: 198.5425 - val_mean_absolute_error: 12.8400 - val_root_mean_squared_error: 14.0905
# Epoch 33/150
# 28/28 [==============================] - 60s 2s/step - loss: 35.9314 - mean_squared_error: 35.9314 - mean_absolute_error: 3.0371 - root_mean_squared_error: 5.9943 - val_loss: 42.2874 - val_mean_squared_error: 42.2874 - val_mean_absolute_error: 3.2094 - val_root_mean_squared_error: 6.5029
# Epoch 34/150
# 28/28 [==============================] - 58s 2s/step - loss: 34.7422 - mean_squared_error: 34.7422 - mean_absolute_error: 2.9902 - root_mean_squared_error: 5.8943 - val_loss: 43.0240 - val_mean_squared_error: 43.0240 - val_mean_absolute_error: 3.2733 - val_root_mean_squared_error: 6.5593
# Epoch 35/150
# 28/28 [==============================] - 58s 2s/step - loss: 35.3806 - mean_squared_error: 35.3806 - mean_absolute_error: 3.0217 - root_mean_squared_error: 5.9482 - val_loss: 41.4072 - val_mean_squared_error: 41.4072 - val_mean_absolute_error: 3.2036 - val_root_mean_squared_error: 6.4348
# Epoch 36/150
# 28/28 [==============================] - 58s 2s/step - loss: 35.6218 - mean_squared_error: 35.6218 - mean_absolute_error: 3.0231 - root_mean_squared_error: 5.9684 - val_loss: 182.4560 - val_mean_squared_error: 182.4560 - val_mean_absolute_error: 12.2971 - val_root_mean_squared_error: 13.5076
# Epoch 37/150
# 28/28 [==============================] - 59s 2s/step - loss: 36.2132 - mean_squared_error: 36.2132 - mean_absolute_error: 3.0870 - root_mean_squared_error: 6.0177 - val_loss: 78.2939 - val_mean_squared_error: 78.2939 - val_mean_absolute_error: 7.6114 - val_root_mean_squared_error: 8.8484
# Epoch 38/150
# 28/28 [==============================] - 58s 2s/step - loss: 34.0645 - mean_squared_error: 34.0645 - mean_absolute_error: 2.9912 - root_mean_squared_error: 5.8365 - val_loss: 41.7408 - val_mean_squared_error: 41.7408 - val_mean_absolute_error: 3.2045 - val_root_mean_squared_error: 6.4607
# Epoch 39/150
# 28/28 [==============================] - 58s 2s/step - loss: 32.8279 - mean_squared_error: 32.8279 - mean_absolute_error: 2.9184 - root_mean_squared_error: 5.7296 - val_loss: 48.2032 - val_mean_squared_error: 48.2032 - val_mean_absolute_error: 4.6632 - val_root_mean_squared_error: 6.9429
# Epoch 40/150
# 28/28 [==============================] - 58s 2s/step - loss: 35.3170 - mean_squared_error: 35.3170 - mean_absolute_error: 3.0461 - root_mean_squared_error: 5.9428 - val_loss: 42.0366 - val_mean_squared_error: 42.0366 - val_mean_absolute_error: 3.2488 - val_root_mean_squared_error: 6.4836
# Epoch 41/150
# 28/28 [==============================] - 58s 2s/step - loss: 34.2638 - mean_squared_error: 34.2638 - mean_absolute_error: 2.9922 - root_mean_squared_error: 5.8535 - val_loss: 46.8432 - val_mean_squared_error: 46.8432 - val_mean_absolute_error: 3.4492 - val_root_mean_squared_error: 6.8442
# Epoch 42/150
# 28/28 [==============================] - 59s 2s/step - loss: 34.0100 - mean_squared_error: 34.0100 - mean_absolute_error: 2.9566 - root_mean_squared_error: 5.8318 - val_loss: 657.3480 - val_mean_squared_error: 657.3480 - val_mean_absolute_error: 22.4533 - val_root_mean_squared_error: 25.6388
# Epoch 43/150
# 28/28 [==============================] - 58s 2s/step - loss: 35.0138 - mean_squared_error: 35.0138 - mean_absolute_error: 3.0059 - root_mean_squared_error: 5.9172 - val_loss: 75.0060 - val_mean_squared_error: 75.0060 - val_mean_absolute_error: 7.4732 - val_root_mean_squared_error: 8.6606
# Epoch 44/150
# 28/28 [==============================] - 58s 2s/step - loss: 40.5884 - mean_squared_error: 40.5884 - mean_absolute_error: 3.3923 - root_mean_squared_error: 6.3709 - val_loss: 44.9037 - val_mean_squared_error: 44.9037 - val_mean_absolute_error: 3.3366 - val_root_mean_squared_error: 6.7010
# Epoch 45/150
# 28/28 [==============================] - 58s 2s/step - loss: 36.1830 - mean_squared_error: 36.1830 - mean_absolute_error: 3.0311 - root_mean_squared_error: 6.0152 - val_loss: 51.5163 - val_mean_squared_error: 51.5163 - val_mean_absolute_error: 5.2275 - val_root_mean_squared_error: 7.1775
# Epoch 46/150
# 28/28 [==============================] - 59s 2s/step - loss: 35.3290 - mean_squared_error: 35.3290 - mean_absolute_error: 2.9876 - root_mean_squared_error: 5.9438 - val_loss: 163.5445 - val_mean_squared_error: 163.5445 - val_mean_absolute_error: 11.6205 - val_root_mean_squared_error: 12.7885
# Epoch 47/150
# 28/28 [==============================] - 58s 2s/step - loss: 35.6181 - mean_squared_error: 35.6181 - mean_absolute_error: 3.0683 - root_mean_squared_error: 5.9681 - val_loss: 44.1006 - val_mean_squared_error: 44.1006 - val_mean_absolute_error: 3.3148 - val_root_mean_squared_error: 6.6408
# Epoch 48/150
# 28/28 [==============================] - 58s 2s/step - loss: 34.2962 - mean_squared_error: 34.2962 - mean_absolute_error: 2.9641 - root_mean_squared_error: 5.8563 - val_loss: 371.9442 - val_mean_squared_error: 371.9442 - val_mean_absolute_error: 17.2778 - val_root_mean_squared_error: 19.2859
# Epoch 49/150
# 28/28 [==============================] - 58s 2s/step - loss: 34.9291 - mean_squared_error: 34.9291 - mean_absolute_error: 3.0063 - root_mean_squared_error: 5.9101 - val_loss: 42.1469 - val_mean_squared_error: 42.1469 - val_mean_absolute_error: 3.2406 - val_root_mean_squared_error: 6.4921
# Epoch 50/150
# 28/28 [==============================] - 58s 2s/step - loss: 34.5801 - mean_squared_error: 34.5801 - mean_absolute_error: 3.0026 - root_mean_squared_error: 5.8805 - val_loss: 42.0110 - val_mean_squared_error: 42.0110 - val_mean_absolute_error: 3.2361 - val_root_mean_squared_error: 6.4816
# Epoch 51/150
# 28/28 [==============================] - 59s 2s/step - loss: 35.6947 - mean_squared_error: 35.6947 - mean_absolute_error: 3.0436 - root_mean_squared_error: 5.9745 - val_loss: 42.4780 - val_mean_squared_error: 42.4780 - val_mean_absolute_error: 3.2489 - val_root_mean_squared_error: 6.5175
# Epoch 52/150
# 28/28 [==============================] - 57s 2s/step - loss: 35.3716 - mean_squared_error: 35.3716 - mean_absolute_error: 3.0188 - root_mean_squared_error: 5.9474 - val_loss: 42.2176 - val_mean_squared_error: 42.2176 - val_mean_absolute_error: 3.2648 - val_root_mean_squared_error: 6.4975
# Epoch 53/150
# 28/28 [==============================] - 57s 2s/step - loss: 33.3142 - mean_squared_error: 33.3142 - mean_absolute_error: 2.9380 - root_mean_squared_error: 5.7718 - val_loss: 40.9110 - val_mean_squared_error: 40.9110 - val_mean_absolute_error: 3.1769 - val_root_mean_squared_error: 6.3962
# Epoch 54/150
# 28/28 [==============================] - 58s 2s/step - loss: 33.9654 - mean_squared_error: 33.9653 - mean_absolute_error: 2.9638 - root_mean_squared_error: 5.8280 - val_loss: 46.3848 - val_mean_squared_error: 46.3848 - val_mean_absolute_error: 3.4745 - val_root_mean_squared_error: 6.8106
# Epoch 55/150
# 28/28 [==============================] - 58s 2s/step - loss: 34.7472 - mean_squared_error: 34.7472 - mean_absolute_error: 3.0049 - root_mean_squared_error: 5.8947 - val_loss: 42.2836 - val_mean_squared_error: 42.2836 - val_mean_absolute_error: 3.2647 - val_root_mean_squared_error: 6.5026
# Epoch 56/150
# 28/28 [==============================] - 57s 2s/step - loss: 32.2497 - mean_squared_error: 32.2497 - mean_absolute_error: 2.9302 - root_mean_squared_error: 5.6789 - val_loss: 47.0100 - val_mean_squared_error: 47.0100 - val_mean_absolute_error: 3.4502 - val_root_mean_squared_error: 6.8564
# Epoch 57/150
# 28/28 [==============================] - 57s 2s/step - loss: 32.5635 - mean_squared_error: 32.5635 - mean_absolute_error: 2.9217 - root_mean_squared_error: 5.7064 - val_loss: 44.3618 - val_mean_squared_error: 44.3618 - val_mean_absolute_error: 3.3334 - val_root_mean_squared_error: 6.6605
# Epoch 58/150
# 28/28 [==============================] - 58s 2s/step - loss: 32.0878 - mean_squared_error: 32.0878 - mean_absolute_error: 2.9012 - root_mean_squared_error: 5.6646 - val_loss: 50.4254 - val_mean_squared_error: 50.4254 - val_mean_absolute_error: 3.6013 - val_root_mean_squared_error: 7.1011
# Epoch 59/150
# 28/28 [==============================] - 64s 2s/step - loss: 32.9324 - mean_squared_error: 32.9324 - mean_absolute_error: 2.9587 - root_mean_squared_error: 5.7387 - val_loss: 41.5333 - val_mean_squared_error: 41.5333 - val_mean_absolute_error: 3.2220 - val_root_mean_squared_error: 6.4446
# Epoch 60/150
# 28/28 [==============================] - 58s 2s/step - loss: 31.5471 - mean_squared_error: 31.5471 - mean_absolute_error: 2.8358 - root_mean_squared_error: 5.6167 - val_loss: 44.6454 - val_mean_squared_error: 44.6454 - val_mean_absolute_error: 3.3840 - val_root_mean_squared_error: 6.6817
# Epoch 61/150
# 28/28 [==============================] - 58s 2s/step - loss: 33.8927 - mean_squared_error: 33.8927 - mean_absolute_error: 2.9934 - root_mean_squared_error: 5.8217 - val_loss: 42.7054 - val_mean_squared_error: 42.7054 - val_mean_absolute_error: 3.2421 - val_root_mean_squared_error: 6.5349
# Epoch 62/150
# 28/28 [==============================] - 58s 2s/step - loss: 33.2607 - mean_squared_error: 33.2607 - mean_absolute_error: 2.9063 - root_mean_squared_error: 5.7672 - val_loss: 128.2742 - val_mean_squared_error: 128.2742 - val_mean_absolute_error: 10.3802 - val_root_mean_squared_error: 11.3258
# Epoch 63/150
# 28/28 [==============================] - 57s 2s/step - loss: 32.6495 - mean_squared_error: 32.6495 - mean_absolute_error: 2.9254 - root_mean_squared_error: 5.7140 - val_loss: 42.0142 - val_mean_squared_error: 42.0142 - val_mean_absolute_error: 3.2305 - val_root_mean_squared_error: 6.4818
# Epoch 64/150
# 28/28 [==============================] - 59s 2s/step - loss: 31.2041 - mean_squared_error: 31.2041 - mean_absolute_error: 2.8467 - root_mean_squared_error: 5.5861 - val_loss: 40.0063 - val_mean_squared_error: 40.0063 - val_mean_absolute_error: 3.1661 - val_root_mean_squared_error: 6.3251
# Epoch 65/150
# 28/28 [==============================] - 58s 2s/step - loss: 30.7638 - mean_squared_error: 30.7638 - mean_absolute_error: 2.8129 - root_mean_squared_error: 5.5465 - val_loss: 51.2597 - val_mean_squared_error: 51.2597 - val_mean_absolute_error: 5.6187 - val_root_mean_squared_error: 7.1596
# Epoch 66/150
# 28/28 [==============================] - 58s 2s/step - loss: 31.3077 - mean_squared_error: 31.3077 - mean_absolute_error: 2.8236 - root_mean_squared_error: 5.5953 - val_loss: 49.3857 - val_mean_squared_error: 49.3857 - val_mean_absolute_error: 3.5339 - val_root_mean_squared_error: 7.0275
# Epoch 67/150
# 28/28 [==============================] - 58s 2s/step - loss: 34.8753 - mean_squared_error: 34.8753 - mean_absolute_error: 3.0056 - root_mean_squared_error: 5.9055 - val_loss: 209.7812 - val_mean_squared_error: 209.7812 - val_mean_absolute_error: 13.3453 - val_root_mean_squared_error: 14.4838
# Epoch 68/150
# 28/28 [==============================] - 59s 2s/step - loss: 32.7666 - mean_squared_error: 32.7666 - mean_absolute_error: 2.9293 - root_mean_squared_error: 5.7242 - val_loss: 42.8329 - val_mean_squared_error: 42.8329 - val_mean_absolute_error: 3.2641 - val_root_mean_squared_error: 6.5447
# Epoch 69/150
# 28/28 [==============================] - 58s 2s/step - loss: 31.0608 - mean_squared_error: 31.0608 - mean_absolute_error: 2.8330 - root_mean_squared_error: 5.5732 - val_loss: 38.5062 - val_mean_squared_error: 38.5062 - val_mean_absolute_error: 3.0526 - val_root_mean_squared_error: 6.2053
# Epoch 70/150
# 28/28 [==============================] - 57s 2s/step - loss: 31.4400 - mean_squared_error: 31.4400 - mean_absolute_error: 2.8472 - root_mean_squared_error: 5.6071 - val_loss: 42.1592 - val_mean_squared_error: 42.1592 - val_mean_absolute_error: 3.2758 - val_root_mean_squared_error: 6.4930
# Epoch 71/150
# 28/28 [==============================] - 57s 2s/step - loss: 30.9728 - mean_squared_error: 30.9728 - mean_absolute_error: 2.8342 - root_mean_squared_error: 5.5653 - val_loss: 39.3345 - val_mean_squared_error: 39.3345 - val_mean_absolute_error: 3.1235 - val_root_mean_squared_error: 6.2717
# Epoch 72/150
# 28/28 [==============================] - 58s 2s/step - loss: 33.1653 - mean_squared_error: 33.1653 - mean_absolute_error: 2.9490 - root_mean_squared_error: 5.7589 - val_loss: 45.1153 - val_mean_squared_error: 45.1153 - val_mean_absolute_error: 3.3517 - val_root_mean_squared_error: 6.7168
# Epoch 73/150
# 28/28 [==============================] - 57s 2s/step - loss: 32.8755 - mean_squared_error: 32.8755 - mean_absolute_error: 2.9118 - root_mean_squared_error: 5.7337 - val_loss: 44.8712 - val_mean_squared_error: 44.8712 - val_mean_absolute_error: 3.3568 - val_root_mean_squared_error: 6.6986
# Epoch 74/150
# 28/28 [==============================] - 58s 2s/step - loss: 30.3747 - mean_squared_error: 30.3747 - mean_absolute_error: 2.8020 - root_mean_squared_error: 5.5113 - val_loss: 51.0296 - val_mean_squared_error: 51.0296 - val_mean_absolute_error: 5.5067 - val_root_mean_squared_error: 7.1435
# Epoch 75/150
# 28/28 [==============================] - 60s 2s/step - loss: 29.8253 - mean_squared_error: 29.8253 - mean_absolute_error: 2.7852 - root_mean_squared_error: 5.4613 - val_loss: 40.9052 - val_mean_squared_error: 40.9052 - val_mean_absolute_error: 3.2034 - val_root_mean_squared_error: 6.3957
# Epoch 76/150
# 28/28 [==============================] - 57s 2s/step - loss: 30.9186 - mean_squared_error: 30.9186 - mean_absolute_error: 2.8478 - root_mean_squared_error: 5.5605 - val_loss: 627.6277 - val_mean_squared_error: 627.6277 - val_mean_absolute_error: 21.7489 - val_root_mean_squared_error: 25.0525
# Epoch 77/150
# 28/28 [==============================] - 59s 2s/step - loss: 29.0149 - mean_squared_error: 29.0149 - mean_absolute_error: 2.7218 - root_mean_squared_error: 5.3865 - val_loss: 45.5162 - val_mean_squared_error: 45.5162 - val_mean_absolute_error: 3.4048 - val_root_mean_squared_error: 6.7466
# Epoch 78/150
# 28/28 [==============================] - 57s 2s/step - loss: 29.5984 - mean_squared_error: 29.5984 - mean_absolute_error: 2.7704 - root_mean_squared_error: 5.4404 - val_loss: 43.7932 - val_mean_squared_error: 43.7932 - val_mean_absolute_error: 3.2937 - val_root_mean_squared_error: 6.6176
# Epoch 79/150
# 28/28 [==============================] - 57s 2s/step - loss: 30.7250 - mean_squared_error: 30.7250 - mean_absolute_error: 2.8000 - root_mean_squared_error: 5.5430 - val_loss: 73.9697 - val_mean_squared_error: 73.9697 - val_mean_absolute_error: 7.3608 - val_root_mean_squared_error: 8.6006
# Epoch 80/150
# 28/28 [==============================] - 59s 2s/step - loss: 30.5866 - mean_squared_error: 30.5866 - mean_absolute_error: 2.8214 - root_mean_squared_error: 5.5305 - val_loss: 211.2391 - val_mean_squared_error: 211.2391 - val_mean_absolute_error: 13.1486 - val_root_mean_squared_error: 14.5341
# Epoch 81/150
# 28/28 [==============================] - 59s 2s/step - loss: 31.6367 - mean_squared_error: 31.6367 - mean_absolute_error: 2.8650 - root_mean_squared_error: 5.6247 - val_loss: 64.6152 - val_mean_squared_error: 64.6152 - val_mean_absolute_error: 6.7399 - val_root_mean_squared_error: 8.0384
# Epoch 82/150
# 28/28 [==============================] - 58s 2s/step - loss: 31.8004 - mean_squared_error: 31.8004 - mean_absolute_error: 2.8924 - root_mean_squared_error: 5.6392 - val_loss: 39.0279 - val_mean_squared_error: 39.0279 - val_mean_absolute_error: 3.1251 - val_root_mean_squared_error: 6.2472
# Epoch 83/150
# 28/28 [==============================] - 58s 2s/step - loss: 30.2046 - mean_squared_error: 30.2046 - mean_absolute_error: 2.8112 - root_mean_squared_error: 5.4959 - val_loss: 104.4397 - val_mean_squared_error: 104.4397 - val_mean_absolute_error: 9.2600 - val_root_mean_squared_error: 10.2196
# Epoch 84/150
# 28/28 [==============================] - 58s 2s/step - loss: 30.9572 - mean_squared_error: 30.9572 - mean_absolute_error: 2.8558 - root_mean_squared_error: 5.5639 - val_loss: 42.3638 - val_mean_squared_error: 42.3638 - val_mean_absolute_error: 3.2523 - val_root_mean_squared_error: 6.5087
# Epoch 85/150
# 28/28 [==============================] - 58s 2s/step - loss: 29.7979 - mean_squared_error: 29.7979 - mean_absolute_error: 2.7676 - root_mean_squared_error: 5.4587 - val_loss: 124.3053 - val_mean_squared_error: 124.3053 - val_mean_absolute_error: 10.1369 - val_root_mean_squared_error: 11.1492
# Epoch 86/150
# 28/28 [==============================] - 57s 2s/step - loss: 29.8742 - mean_squared_error: 29.8742 - mean_absolute_error: 2.7886 - root_mean_squared_error: 5.4657 - val_loss: 40.1032 - val_mean_squared_error: 40.1032 - val_mean_absolute_error: 3.1543 - val_root_mean_squared_error: 6.3327
# Epoch 87/150
# 28/28 [==============================] - 58s 2s/step - loss: 30.0718 - mean_squared_error: 30.0718 - mean_absolute_error: 2.7949 - root_mean_squared_error: 5.4838 - val_loss: 121.4178 - val_mean_squared_error: 121.4178 - val_mean_absolute_error: 10.0808 - val_root_mean_squared_error: 11.0190
# Epoch 88/150
# 28/28 [==============================] - 58s 2s/step - loss: 29.2555 - mean_squared_error: 29.2555 - mean_absolute_error: 2.7743 - root_mean_squared_error: 5.4088 - val_loss: 177.5665 - val_mean_squared_error: 177.5665 - val_mean_absolute_error: 12.1938 - val_root_mean_squared_error: 13.3254
# Epoch 89/150
# 28/28 [==============================] - 59s 2s/step - loss: 28.4305 - mean_squared_error: 28.4305 - mean_absolute_error: 2.7037 - root_mean_squared_error: 5.3320 - val_loss: 42.5411 - val_mean_squared_error: 42.5411 - val_mean_absolute_error: 3.2971 - val_root_mean_squared_error: 6.5224
# Epoch 90/150
# 28/28 [==============================] - 58s 2s/step - loss: 29.8573 - mean_squared_error: 29.8573 - mean_absolute_error: 2.8005 - root_mean_squared_error: 5.4642 - val_loss: 39.5180 - val_mean_squared_error: 39.5180 - val_mean_absolute_error: 3.0952 - val_root_mean_squared_error: 6.2863
# Epoch 91/150
# 28/28 [==============================] - 57s 2s/step - loss: 28.6324 - mean_squared_error: 28.6324 - mean_absolute_error: 2.7114 - root_mean_squared_error: 5.3509 - val_loss: 40.8749 - val_mean_squared_error: 40.8749 - val_mean_absolute_error: 3.1889 - val_root_mean_squared_error: 6.3933
# Epoch 92/150
# 28/28 [==============================] - 58s 2s/step - loss: 28.7099 - mean_squared_error: 28.7099 - mean_absolute_error: 2.7372 - root_mean_squared_error: 5.3582 - val_loss: 39.6967 - val_mean_squared_error: 39.6967 - val_mean_absolute_error: 3.1484 - val_root_mean_squared_error: 6.3005
# Epoch 93/150
# 28/28 [==============================] - 57s 2s/step - loss: 28.3388 - mean_squared_error: 28.3388 - mean_absolute_error: 2.6970 - root_mean_squared_error: 5.3234 - val_loss: 39.7310 - val_mean_squared_error: 39.7310 - val_mean_absolute_error: 3.1722 - val_root_mean_squared_error: 6.3033
# Epoch 94/150
# 28/28 [==============================] - 59s 2s/step - loss: 28.6712 - mean_squared_error: 28.6712 - mean_absolute_error: 2.6980 - root_mean_squared_error: 5.3545 - val_loss: 39.1364 - val_mean_squared_error: 39.1364 - val_mean_absolute_error: 3.1069 - val_root_mean_squared_error: 6.2559
# Epoch 95/150
# 28/28 [==============================] - 57s 2s/step - loss: 27.9436 - mean_squared_error: 27.9436 - mean_absolute_error: 2.6819 - root_mean_squared_error: 5.2862 - val_loss: 40.9198 - val_mean_squared_error: 40.9198 - val_mean_absolute_error: 3.1704 - val_root_mean_squared_error: 6.3969
# Epoch 96/150
# 28/28 [==============================] - 58s 2s/step - loss: 28.5977 - mean_squared_error: 28.5977 - mean_absolute_error: 2.7155 - root_mean_squared_error: 5.3477 - val_loss: 40.2823 - val_mean_squared_error: 40.2823 - val_mean_absolute_error: 3.1691 - val_root_mean_squared_error: 6.3468
# Epoch 97/150
# 28/28 [==============================] - 58s 2s/step - loss: 28.1203 - mean_squared_error: 28.1203 - mean_absolute_error: 2.7123 - root_mean_squared_error: 5.3029 - val_loss: 260.5862 - val_mean_squared_error: 260.5862 - val_mean_absolute_error: 14.5059 - val_root_mean_squared_error: 16.1427
# Epoch 98/150
# 28/28 [==============================] - 59s 2s/step - loss: 28.2538 - mean_squared_error: 28.2538 - mean_absolute_error: 2.6919 - root_mean_squared_error: 5.3154 - val_loss: 41.2166 - val_mean_squared_error: 41.2166 - val_mean_absolute_error: 3.1780 - val_root_mean_squared_error: 6.4200
# Epoch 99/150
# 28/28 [==============================] - 57s 2s/step - loss: 30.8555 - mean_squared_error: 30.8555 - mean_absolute_error: 2.8248 - root_mean_squared_error: 5.5548 - val_loss: 48.2382 - val_mean_squared_error: 48.2382 - val_mean_absolute_error: 3.5206 - val_root_mean_squared_error: 6.9454
# Epoch 100/150
# 28/28 [==============================] - 58s 2s/step - loss: 30.7782 - mean_squared_error: 30.7783 - mean_absolute_error: 2.8253 - root_mean_squared_error: 5.5478 - val_loss: 42.1071 - val_mean_squared_error: 42.1071 - val_mean_absolute_error: 3.3053 - val_root_mean_squared_error: 6.4890
# Epoch 101/150
# 28/28 [==============================] - 58s 2s/step - loss: 27.8015 - mean_squared_error: 27.8015 - mean_absolute_error: 2.6919 - root_mean_squared_error: 5.2727 - val_loss: 40.2084 - val_mean_squared_error: 40.2084 - val_mean_absolute_error: 3.1156 - val_root_mean_squared_error: 6.3410
# Epoch 102/150
# 28/28 [==============================] - 58s 2s/step - loss: 29.2511 - mean_squared_error: 29.2511 - mean_absolute_error: 2.7591 - root_mean_squared_error: 5.4084 - val_loss: 51.2629 - val_mean_squared_error: 51.2629 - val_mean_absolute_error: 5.2663 - val_root_mean_squared_error: 7.1598
# Epoch 103/150
# 28/28 [==============================] - 58s 2s/step - loss: 28.7393 - mean_squared_error: 28.7393 - mean_absolute_error: 2.7268 - root_mean_squared_error: 5.3609 - val_loss: 38.9746 - val_mean_squared_error: 38.9746 - val_mean_absolute_error: 3.1443 - val_root_mean_squared_error: 6.2430
# Epoch 104/150
# 28/28 [==============================] - 57s 2s/step - loss: 28.4426 - mean_squared_error: 28.4426 - mean_absolute_error: 2.7173 - root_mean_squared_error: 5.3332 - val_loss: 38.8182 - val_mean_squared_error: 38.8182 - val_mean_absolute_error: 3.1300 - val_root_mean_squared_error: 6.2304
# Epoch 105/150
# 28/28 [==============================] - 58s 2s/step - loss: 27.3202 - mean_squared_error: 27.3202 - mean_absolute_error: 2.6398 - root_mean_squared_error: 5.2269 - val_loss: 39.3358 - val_mean_squared_error: 39.3358 - val_mean_absolute_error: 3.1555 - val_root_mean_squared_error: 6.2718
# Epoch 106/150
# 28/28 [==============================] - 56s 2s/step - loss: 27.8042 - mean_squared_error: 27.8042 - mean_absolute_error: 2.6897 - root_mean_squared_error: 5.2730 - val_loss: 101.9244 - val_mean_squared_error: 101.9244 - val_mean_absolute_error: 9.1412 - val_root_mean_squared_error: 10.0958
# Epoch 107/150
# 28/28 [==============================] - 59s 2s/step - loss: 29.8181 - mean_squared_error: 29.8181 - mean_absolute_error: 2.7984 - root_mean_squared_error: 5.4606 - val_loss: 452.3873 - val_mean_squared_error: 452.3873 - val_mean_absolute_error: 18.9094 - val_root_mean_squared_error: 21.2694
# Epoch 108/150
# 28/28 [==============================] - 58s 2s/step - loss: 29.8259 - mean_squared_error: 29.8259 - mean_absolute_error: 2.7553 - root_mean_squared_error: 5.4613 - val_loss: 763.7488 - val_mean_squared_error: 763.7488 - val_mean_absolute_error: 23.9871 - val_root_mean_squared_error: 27.6360
# Epoch 109/150
# 28/28 [==============================] - 58s 2s/step - loss: 28.3226 - mean_squared_error: 28.3226 - mean_absolute_error: 2.6972 - root_mean_squared_error: 5.3219 - val_loss: 80.1997 - val_mean_squared_error: 80.1997 - val_mean_absolute_error: 7.7714 - val_root_mean_squared_error: 8.9554
# Epoch 110/150
# 28/28 [==============================] - 58s 2s/step - loss: 29.8557 - mean_squared_error: 29.8556 - mean_absolute_error: 2.7987 - root_mean_squared_error: 5.4640 - val_loss: 36.8907 - val_mean_squared_error: 36.8907 - val_mean_absolute_error: 3.0045 - val_root_mean_squared_error: 6.0738
# Epoch 111/150
# 28/28 [==============================] - 59s 2s/step - loss: 27.0957 - mean_squared_error: 27.0956 - mean_absolute_error: 2.6381 - root_mean_squared_error: 5.2053 - val_loss: 43.5614 - val_mean_squared_error: 43.5614 - val_mean_absolute_error: 3.3257 - val_root_mean_squared_error: 6.6001
# Epoch 112/150
# 28/28 [==============================] - 58s 2s/step - loss: 27.5320 - mean_squared_error: 27.5320 - mean_absolute_error: 2.6525 - root_mean_squared_error: 5.2471 - val_loss: 41.6603 - val_mean_squared_error: 41.6603 - val_mean_absolute_error: 3.2540 - val_root_mean_squared_error: 6.4545
# Epoch 113/150
# 28/28 [==============================] - 58s 2s/step - loss: 27.2281 - mean_squared_error: 27.2281 - mean_absolute_error: 2.6407 - root_mean_squared_error: 5.2181 - val_loss: 52.8710 - val_mean_squared_error: 52.8710 - val_mean_absolute_error: 5.7684 - val_root_mean_squared_error: 7.2712
# Epoch 114/150
# 28/28 [==============================] - 58s 2s/step - loss: 27.1471 - mean_squared_error: 27.1471 - mean_absolute_error: 2.6289 - root_mean_squared_error: 5.2103 - val_loss: 40.8092 - val_mean_squared_error: 40.8091 - val_mean_absolute_error: 3.2120 - val_root_mean_squared_error: 6.3882
# Epoch 115/150
# 28/28 [==============================] - 58s 2s/step - loss: 29.1617 - mean_squared_error: 29.1617 - mean_absolute_error: 2.7630 - root_mean_squared_error: 5.4002 - val_loss: 40.4704 - val_mean_squared_error: 40.4704 - val_mean_absolute_error: 3.1744 - val_root_mean_squared_error: 6.3616
# Epoch 116/150
# 28/28 [==============================] - 57s 2s/step - loss: 28.5266 - mean_squared_error: 28.5266 - mean_absolute_error: 2.7139 - root_mean_squared_error: 5.3410 - val_loss: 249.5255 - val_mean_squared_error: 249.5255 - val_mean_absolute_error: 14.2885 - val_root_mean_squared_error: 15.7964
# Epoch 117/150
# 28/28 [==============================] - 58s 2s/step - loss: 28.1126 - mean_squared_error: 28.1126 - mean_absolute_error: 2.7008 - root_mean_squared_error: 5.3021 - val_loss: 58.7441 - val_mean_squared_error: 58.7441 - val_mean_absolute_error: 6.3601 - val_root_mean_squared_error: 7.6645
# Epoch 118/150
# 28/28 [==============================] - 58s 2s/step - loss: 27.0827 - mean_squared_error: 27.0827 - mean_absolute_error: 2.6573 - root_mean_squared_error: 5.2041 - val_loss: 45.0059 - val_mean_squared_error: 45.0059 - val_mean_absolute_error: 3.9032 - val_root_mean_squared_error: 6.7086
# Epoch 119/150
# 28/28 [==============================] - 58s 2s/step - loss: 29.1009 - mean_squared_error: 29.1009 - mean_absolute_error: 2.7480 - root_mean_squared_error: 5.3945 - val_loss: 383.2438 - val_mean_squared_error: 383.2438 - val_mean_absolute_error: 17.5586 - val_root_mean_squared_error: 19.5766
# Epoch 120/150
# 28/28 [==============================] - 58s 2s/step - loss: 28.9125 - mean_squared_error: 28.9125 - mean_absolute_error: 2.7289 - root_mean_squared_error: 5.3770 - val_loss: 203.3887 - val_mean_squared_error: 203.3887 - val_mean_absolute_error: 12.9411 - val_root_mean_squared_error: 14.2614
# Epoch 121/150
# 28/28 [==============================] - 58s 2s/step - loss: 29.3137 - mean_squared_error: 29.3137 - mean_absolute_error: 2.7662 - root_mean_squared_error: 5.4142 - val_loss: 279.2411 - val_mean_squared_error: 279.2411 - val_mean_absolute_error: 14.8239 - val_root_mean_squared_error: 16.7105
# Epoch 122/150
# 28/28 [==============================] - 58s 2s/step - loss: 28.5027 - mean_squared_error: 28.5027 - mean_absolute_error: 2.7261 - root_mean_squared_error: 5.3388 - val_loss: 230.6574 - val_mean_squared_error: 230.6574 - val_mean_absolute_error: 13.6341 - val_root_mean_squared_error: 15.1874
# Epoch 123/150
# 28/28 [==============================] - 57s 2s/step - loss: 26.3276 - mean_squared_error: 26.3276 - mean_absolute_error: 2.6195 - root_mean_squared_error: 5.1310 - val_loss: 42.1945 - val_mean_squared_error: 42.1946 - val_mean_absolute_error: 3.2676 - val_root_mean_squared_error: 6.4957
# Epoch 124/150
# 28/28 [==============================] - 59s 2s/step - loss: 26.7459 - mean_squared_error: 26.7459 - mean_absolute_error: 2.6173 - root_mean_squared_error: 5.1716 - val_loss: 40.2888 - val_mean_squared_error: 40.2888 - val_mean_absolute_error: 3.1896 - val_root_mean_squared_error: 6.3473
# Epoch 125/150
# 28/28 [==============================] - 57s 2s/step - loss: 27.7091 - mean_squared_error: 27.7091 - mean_absolute_error: 2.6691 - root_mean_squared_error: 5.2639 - val_loss: 39.4928 - val_mean_squared_error: 39.4928 - val_mean_absolute_error: 3.1214 - val_root_mean_squared_error: 6.2843
# Epoch 126/150
# 28/28 [==============================] - 57s 2s/step - loss: 25.8941 - mean_squared_error: 25.8941 - mean_absolute_error: 2.5669 - root_mean_squared_error: 5.0886 - val_loss: 41.9506 - val_mean_squared_error: 41.9506 - val_mean_absolute_error: 3.2188 - val_root_mean_squared_error: 6.4769
# Epoch 127/150
# 28/28 [==============================] - 58s 2s/step - loss: 27.7200 - mean_squared_error: 27.7200 - mean_absolute_error: 2.6839 - root_mean_squared_error: 5.2650 - val_loss: 212.4668 - val_mean_squared_error: 212.4668 - val_mean_absolute_error: 13.2050 - val_root_mean_squared_error: 14.5762
# Epoch 128/150
# 28/28 [==============================] - 59s 2s/step - loss: 28.0975 - mean_squared_error: 28.0975 - mean_absolute_error: 2.6909 - root_mean_squared_error: 5.3007 - val_loss: 42.4620 - val_mean_squared_error: 42.4620 - val_mean_absolute_error: 3.2734 - val_root_mean_squared_error: 6.5163
# Epoch 129/150
# 28/28 [==============================] - 57s 2s/step - loss: 27.5224 - mean_squared_error: 27.5224 - mean_absolute_error: 2.6497 - root_mean_squared_error: 5.2462 - val_loss: 481.4909 - val_mean_squared_error: 481.4909 - val_mean_absolute_error: 19.3379 - val_root_mean_squared_error: 21.9429
# Epoch 130/150
# 28/28 [==============================] - 56s 2s/step - loss: 26.6908 - mean_squared_error: 26.6908 - mean_absolute_error: 2.6104 - root_mean_squared_error: 5.1663 - val_loss: 44.1251 - val_mean_squared_error: 44.1251 - val_mean_absolute_error: 3.3080 - val_root_mean_squared_error: 6.6427
# Epoch 131/150
# 28/28 [==============================] - 58s 2s/step - loss: 26.6089 - mean_squared_error: 26.6089 - mean_absolute_error: 2.6116 - root_mean_squared_error: 5.1584 - val_loss: 44.2445 - val_mean_squared_error: 44.2445 - val_mean_absolute_error: 3.3376 - val_root_mean_squared_error: 6.6517
# Epoch 132/150
# 28/28 [==============================] - 58s 2s/step - loss: 26.6288 - mean_squared_error: 26.6288 - mean_absolute_error: 2.6206 - root_mean_squared_error: 5.1603 - val_loss: 39.0163 - val_mean_squared_error: 39.0163 - val_mean_absolute_error: 3.1171 - val_root_mean_squared_error: 6.2463
# Epoch 133/150
# 28/28 [==============================] - 59s 2s/step - loss: 27.4227 - mean_squared_error: 27.4227 - mean_absolute_error: 2.6570 - root_mean_squared_error: 5.2367 - val_loss: 46.4300 - val_mean_squared_error: 46.4300 - val_mean_absolute_error: 3.4302 - val_root_mean_squared_error: 6.8140
# Epoch 134/150
# 28/28 [==============================] - 60s 2s/step - loss: 26.4905 - mean_squared_error: 26.4905 - mean_absolute_error: 2.6125 - root_mean_squared_error: 5.1469 - val_loss: 41.5812 - val_mean_squared_error: 41.5812 - val_mean_absolute_error: 3.2354 - val_root_mean_squared_error: 6.4483
# Epoch 135/150
# 28/28 [==============================] - 60s 2s/step - loss: 27.1155 - mean_squared_error: 27.1155 - mean_absolute_error: 2.6617 - root_mean_squared_error: 5.2073 - val_loss: 39.9049 - val_mean_squared_error: 39.9049 - val_mean_absolute_error: 3.1449 - val_root_mean_squared_error: 6.3170
# Epoch 136/150
# 28/28 [==============================] - 59s 2s/step - loss: 26.2579 - mean_squared_error: 26.2579 - mean_absolute_error: 2.6128 - root_mean_squared_error: 5.1242 - val_loss: 86.1745 - val_mean_squared_error: 86.1745 - val_mean_absolute_error: 8.2103 - val_root_mean_squared_error: 9.2830
# Epoch 137/150
# 28/28 [==============================] - 59s 2s/step - loss: 25.5515 - mean_squared_error: 25.5515 - mean_absolute_error: 2.5636 - root_mean_squared_error: 5.0548 - val_loss: 48.9471 - val_mean_squared_error: 48.9471 - val_mean_absolute_error: 3.5578 - val_root_mean_squared_error: 6.9962
# Epoch 138/150
# 28/28 [==============================] - 57s 2s/step - loss: 28.6878 - mean_squared_error: 28.6878 - mean_absolute_error: 2.7467 - root_mean_squared_error: 5.3561 - val_loss: 40.0151 - val_mean_squared_error: 40.0151 - val_mean_absolute_error: 3.1421 - val_root_mean_squared_error: 6.3257
# Epoch 139/150
# 28/28 [==============================] - 58s 2s/step - loss: 26.4188 - mean_squared_error: 26.4188 - mean_absolute_error: 2.5887 - root_mean_squared_error: 5.1399 - val_loss: 338.4797 - val_mean_squared_error: 338.4797 - val_mean_absolute_error: 16.4326 - val_root_mean_squared_error: 18.3978
# Epoch 140/150
# 28/28 [==============================] - 58s 2s/step - loss: 25.8658 - mean_squared_error: 25.8658 - mean_absolute_error: 2.5742 - root_mean_squared_error: 5.0858 - val_loss: 40.0726 - val_mean_squared_error: 40.0726 - val_mean_absolute_error: 3.1708 - val_root_mean_squared_error: 6.3303
# Epoch 141/150
# 28/28 [==============================] - 59s 2s/step - loss: 25.4736 - mean_squared_error: 25.4736 - mean_absolute_error: 2.5551 - root_mean_squared_error: 5.0471 - val_loss: 40.3996 - val_mean_squared_error: 40.3996 - val_mean_absolute_error: 3.1584 - val_root_mean_squared_error: 6.3561
# Epoch 142/150
# 28/28 [==============================] - 58s 2s/step - loss: 26.6450 - mean_squared_error: 26.6450 - mean_absolute_error: 2.5972 - root_mean_squared_error: 5.1619 - val_loss: 193.1294 - val_mean_squared_error: 193.1294 - val_mean_absolute_error: 12.5019 - val_root_mean_squared_error: 13.8971
# Epoch 143/150
# 28/28 [==============================] - 58s 2s/step - loss: 26.1791 - mean_squared_error: 26.1790 - mean_absolute_error: 2.6115 - root_mean_squared_error: 5.1165 - val_loss: 41.7210 - val_mean_squared_error: 41.7210 - val_mean_absolute_error: 3.2435 - val_root_mean_squared_error: 6.4592
# Epoch 144/150
# 28/28 [==============================] - 58s 2s/step - loss: 25.4980 - mean_squared_error: 25.4980 - mean_absolute_error: 2.5657 - root_mean_squared_error: 5.0496 - val_loss: 42.2263 - val_mean_squared_error: 42.2263 - val_mean_absolute_error: 3.2762 - val_root_mean_squared_error: 6.4982
# Epoch 145/150
# 28/28 [==============================] - 59s 2s/step - loss: 26.6574 - mean_squared_error: 26.6574 - mean_absolute_error: 2.6155 - root_mean_squared_error: 5.1631 - val_loss: 277.4702 - val_mean_squared_error: 277.4702 - val_mean_absolute_error: 14.9922 - val_root_mean_squared_error: 16.6574
# Epoch 146/150
# 28/28 [==============================] - 58s 2s/step - loss: 26.3178 - mean_squared_error: 26.3178 - mean_absolute_error: 2.6125 - root_mean_squared_error: 5.1301 - val_loss: 39.6106 - val_mean_squared_error: 39.6106 - val_mean_absolute_error: 3.1097 - val_root_mean_squared_error: 6.2937
# Epoch 147/150
# 28/28 [==============================] - 59s 2s/step - loss: 25.8559 - mean_squared_error: 25.8559 - mean_absolute_error: 2.6039 - root_mean_squared_error: 5.0849 - val_loss: 41.6893 - val_mean_squared_error: 41.6893 - val_mean_absolute_error: 3.2479 - val_root_mean_squared_error: 6.4567
# Epoch 148/150
# 28/28 [==============================] - 59s 2s/step - loss: 25.7834 - mean_squared_error: 25.7834 - mean_absolute_error: 2.5668 - root_mean_squared_error: 5.0777 - val_loss: 79.8899 - val_mean_squared_error: 79.8899 - val_mean_absolute_error: 7.8781 - val_root_mean_squared_error: 8.9381
# Epoch 149/150
# 28/28 [==============================] - 58s 2s/step - loss: 25.2705 - mean_squared_error: 25.2705 - mean_absolute_error: 2.5536 - root_mean_squared_error: 5.0270 - val_loss: 224.0153 - val_mean_squared_error: 224.0153 - val_mean_absolute_error: 13.5551 - val_root_mean_squared_error: 14.9671
# Epoch 150/150
# 28/28 [==============================] - 60s 2s/step - loss: 26.2001 - mean_squared_error: 26.2001 - mean_absolute_error: 2.5929 - root_mean_squared_error: 5.1186 - val_loss: 40.0125 - val_mean_squared_error: 40.0125 - val_mean_absolute_error: 3.1694 - val_root_mean_squared_error: 6.3255

# %% [markdown]
# # Training results

# %%
from utils.plotting import training_loss_plot

if not in_google_colab():
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

plot = training_loss_plot(train_score, filename='download/training_loss.pdf')
plot.show()

# %% [markdown]
# # Testing

# %%
### Predict on the test set
from utils.evaluation import phases_report, phases_report_std

if in_google_colab():
    y_pred =  model.predict([bloodpressure.test_dataset,etCO2.test_dataset, spO2.test_dataset, propofolrate.test_dataset, info.test_dataset], verbose=0)
    with open('download/prediction.pkl', 'wb') as f:
        pickle.dump(y_pred, f)
else:
    with open('prediction.pkl', 'rb') as f:
        y_pred = pickle.load(f)

print('Testmetriken:')

report = phases_report(y_pred, bis.test_dataset, propofolrate.test_dataset)
report
# Out:
# Testmetriken:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                  76.92       139.87           6.64         7.55
# Induction           151.21       637.60           9.63        18.34
# Maintenance          61.74        60.90           6.05         5.68
# Recovery            129.17       361.57           8.53        13.46
#
#             Prediction RMSE Baseline RMSE
# All                    8.77         11.83
# Induction             12.30         25.25
# Maintenance            7.86          7.80
# Recovery              11.37         19.02

# %%
phases_report_std(report, y_pred, bis.test_dataset, propofolrate.test_dataset)
# Out:
# All      	min: 	 15 	max: 	 6
# Induction 	min: 	 23 	max: 	 10
# Maintenance 	min: 	 13 	max: 	 6
# Recovery 	min: 	 19 	max: 	 22
#              Prediction MSE  Baseline MSE  Prediction MAE  Baseline MAE  \
# All                   46.15         82.42            1.96          2.54
# Induction             97.25        403.81            3.30          8.45
# Maintenance           37.83         43.11            2.03          2.15
# Recovery             104.42        185.95            3.96          6.28
#
#              Prediction RMSE  Baseline RMSE
# All                     2.34           3.31
# Induction               3.61           7.29
# Maintenance             2.29           2.51
# Recovery                4.47           6.47

# %%
from utils.plotting import full_histogramm_plot

plot = full_histogramm_plot(groundtruth = bis.test_dataset, prediction = y_pred, filename='download/histogramm.pdf')
plot.show()

# %%
from utils.plotting import single_prediction_plot

for case in test_index:
    single_prediction_plot(
        case = case,
        index = test_index,
        groundtruth = bis.test_dataset,
        prediction = y_pred,
        infusion = propofolrate.test_dataset,
        error = 'Prediction RMSE',
        filename = 'download/' + str(case) + '.pdf')

print('Finished')
# Out:
# /content/utils/plotting.py:79: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(12/2.54, 6/2.54))
# Finished

# %%
from utils.plotting import full_prediction_plot

full_prediction_plot(index = test_index, groundtruth = bis.test_dataset, prediction = y_pred, infusion = propofolrate.test_dataset)
