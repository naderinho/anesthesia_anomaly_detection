# %% [markdown]
# # Initialization

# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset02/'
vitaldbpath = 'vitaldb_tiva/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt
import pickle

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 600, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 600 (delta 73), reused 129 (delta 67), pack-reused 461
# Receiving objects: 100% (600/600), 109.32 MiB | 13.48 MiB/s, done.
# Resolving deltas: 100% (277/277), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl.metadata (520 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.31.0)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.8 MB/s eta 0:00:00
# Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 11.7 MB/s eta 0:00:00
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %% [markdown]
# # Data loading

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolrate.name = 'Propofol Rate'
    propofolrate.tracks = ['Orchestra/PPF20_RATE']
    propofolrate.filterON = False
    propofolrate.generateDataset(normalization=md.NormNone)
    propofolrate.save('03_propofol_rate.npz')

    remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    remifentanilrate.name = 'Remifentanil Rate'
    remifentanilrate.tracks = ['Orchestra/RFTN20_RATE']
    remifentanilrate.filterON = False
    remifentanilrate.generateDataset(normalization=md.NormNone)
    remifentanilrate.save('03_remifentanil_rate.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolrate.load('03_propofol_rate.npz')

remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
remifentanilrate.load('03_remifentanil_rate.npz')

train_index, val_index, test_index = bis.split(np.array(bis.index))

# %% [markdown]
# # Model creation

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### Blood Pressure Input
input_bp = Input(shape=(None, bloodpressure.train_dataset.shape[2]))
bp_layer = Masking(mask_value=0.0)(input_bp)

bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=128, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=16, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=16, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = Dense(units=16, activation='linear')(bp_layer)

### etCO2 Input
input_co2 = Input(shape=(None, etCO2.train_dataset.shape[2]))

co2_layer = LSTM(units=64, return_sequences=True)(input_co2)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=64, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=64, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=16, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=8, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = Dense(units=8, activation='linear')(co2_layer)

### spo2 Input
input_spo2 = Input(shape=(None, spO2.train_dataset.shape[2]))

spo2_layer = LSTM(units=64, return_sequences=True)(input_spo2)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=64, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=64, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=16, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=8, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = Dense(units=8, activation='linear')(spo2_layer)


### INFO layers
input_info = Input(shape=(info.train_dataset.shape[1],))
info_layer = RepeatVector(bloodpressure.train_dataset.shape[1])(input_info)
info_layer = Dense(units=16, activation='linear')(info_layer)
info_layer = Dense(units=16, activation='sigmoid')(info_layer)


## Concatenate the Propofol output with the info layer
comb_layer = Concatenate()([bp_layer, co2_layer, spo2_layer, info_layer])
comb_layer = Dense(units=64, activation='linear')(comb_layer)
comb_layer = Dense(units=64, activation='relu')(comb_layer)
comb_layer = Dense(units=64, activation='relu')(comb_layer)
comb_layer = Dense(units=32, activation='relu')(comb_layer)
comb_layer = Dense(units=16, activation='relu')(comb_layer)
comb_layer = Dense(units=1, activation='relu')(comb_layer)
output = Lambda(lambda x: x * 100)(comb_layer)

# Define the model
model = Model(inputs=[input_bp, input_co2, input_spo2, input_info], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.0005)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 3)]            0         []
#
#  masking (Masking)           (None, None, 3)              0         ['input_1[0][0]']
#
#  lstm (LSTM)                 (None, None, 64)             17408     ['masking[0][0]']
#
#  batch_normalization (Batch  (None, None, 64)             256       ['lstm[0][0]']
#  Normalization)
#
#  lstm_1 (LSTM)               (None, None, 64)             33024     ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, None, 64)             256       ['lstm_1[0][0]']
#  chNormalization)
#
#  lstm_2 (LSTM)               (None, None, 64)             33024     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, None, 64)             256       ['lstm_2[0][0]']
#  chNormalization)
#
#  input_2 (InputLayer)        [(None, None, 1)]            0         []
#
#  input_3 (InputLayer)        [(None, None, 1)]            0         []
#
#  lstm_3 (LSTM)               (None, None, 64)             33024     ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  lstm_8 (LSTM)               (None, None, 64)             16896     ['input_2[0][0]']
#
#  lstm_13 (LSTM)              (None, None, 64)             16896     ['input_3[0][0]']
#
#  batch_normalization_3 (Bat  (None, None, 64)             256       ['lstm_3[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, None, 64)             256       ['lstm_8[0][0]']
#  chNormalization)
#
#  batch_normalization_13 (Ba  (None, None, 64)             256       ['lstm_13[0][0]']
#  tchNormalization)
#
#  lstm_4 (LSTM)               (None, None, 128)            98816     ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  lstm_9 (LSTM)               (None, None, 64)             33024     ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  lstm_14 (LSTM)              (None, None, 64)             33024     ['batch_normalization_13[0][0]
#                                                                     ']
#
#  batch_normalization_4 (Bat  (None, None, 128)            512       ['lstm_4[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, None, 64)             256       ['lstm_9[0][0]']
#  chNormalization)
#
#  batch_normalization_14 (Ba  (None, None, 64)             256       ['lstm_14[0][0]']
#  tchNormalization)
#
#  lstm_5 (LSTM)               (None, None, 64)             49408     ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  lstm_10 (LSTM)              (None, None, 64)             33024     ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  lstm_15 (LSTM)              (None, None, 64)             33024     ['batch_normalization_14[0][0]
#                                                                     ']
#
#  batch_normalization_5 (Bat  (None, None, 64)             256       ['lstm_5[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, None, 64)             256       ['lstm_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, None, 64)             256       ['lstm_15[0][0]']
#  tchNormalization)
#
#  lstm_6 (LSTM)               (None, None, 16)             5184      ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  lstm_11 (LSTM)              (None, None, 16)             5184      ['batch_normalization_10[0][0]
#                                                                     ']
#
#  lstm_16 (LSTM)              (None, None, 16)             5184      ['batch_normalization_15[0][0]
#                                                                     ']
#
#  batch_normalization_6 (Bat  (None, None, 16)             64        ['lstm_6[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, None, 16)             64        ['lstm_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, None, 16)             64        ['lstm_16[0][0]']
#  tchNormalization)
#
#  input_4 (InputLayer)        [(None, 5)]                  0         []
#
#  lstm_7 (LSTM)               (None, None, 16)             2112      ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  lstm_12 (LSTM)              (None, None, 8)              800       ['batch_normalization_11[0][0]
#                                                                     ']
#
#  lstm_17 (LSTM)              (None, None, 8)              800       ['batch_normalization_16[0][0]
#                                                                     ']
#
#  repeat_vector (RepeatVecto  (None, 3680, 5)              0         ['input_4[0][0]']
#  r)
#
#  batch_normalization_7 (Bat  (None, None, 16)             64        ['lstm_7[0][0]']
#  chNormalization)
#
#  batch_normalization_12 (Ba  (None, None, 8)              32        ['lstm_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, None, 8)              32        ['lstm_17[0][0]']
#  tchNormalization)
#
#  dense_3 (Dense)             (None, 3680, 16)             96        ['repeat_vector[0][0]']
#
#  dense (Dense)               (None, None, 16)             272       ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dense_1 (Dense)             (None, None, 8)              72        ['batch_normalization_12[0][0]
#                                                                     ']
#
#  dense_2 (Dense)             (None, None, 8)              72        ['batch_normalization_17[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 3680, 16)             272       ['dense_3[0][0]']
#
#  concatenate (Concatenate)   (None, 3680, 48)             0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 3680, 64)             3136      ['concatenate[0][0]']
#
#  dense_6 (Dense)             (None, 3680, 64)             4160      ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 3680, 64)             4160      ['dense_6[0][0]']
#
#  dense_8 (Dense)             (None, 3680, 32)             2080      ['dense_7[0][0]']
#
#  dense_9 (Dense)             (None, 3680, 16)             528       ['dense_8[0][0]']
#
#  dense_10 (Dense)            (None, 3680, 1)              17        ['dense_9[0][0]']
#
#  lambda (Lambda)             (None, 3680, 1)              0         ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 468369 (1.79 MB)
# Trainable params: 466545 (1.78 MB)
# Non-trainable params: 1824 (7.12 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %%
# Rolling mean on BIS data
y = pd.DataFrame(bis.train_dataset[:,:,0].T).rolling(min_periods=1,window=3, center=True).mean().to_numpy().T[:,:,np.newaxis]

# Define training stop criteria
class StopTrainingCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(StopTrainingCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_loss') is not None:
            if logs.get('val_loss') < self.threshold:
                print(f"\nValidation loss is below {self.threshold}, stopping training.")
                self.model.stop_training = True

stop_training_callback = StopTrainingCallback(threshold = 35)


if in_google_colab():
    # Train the model
    history = model.fit([bloodpressure.train_dataset, etCO2.train_dataset, spO2.train_dataset, info.train_dataset],
                        y,
                        validation_data=([bloodpressure.validation_dataset, etCO2.validation_dataset, spO2.validation_dataset, info.validation_dataset], bis.validation_dataset),
                        epochs=150,
                        callbacks=[stop_training_callback],
                        batch_size=4
                        )

    train_score = history.history

    # Save the model
    model.save('download/model.keras')

    # Save the training history
    with open('download/train_score.pkl', 'wb') as f:
        pickle.dump(train_score, f)

    # Save the prediction
    y_pred = model.predict([bloodpressure.test_dataset, etCO2.test_dataset, spO2.test_dataset, info.test_dataset], verbose=0)
    with open('download/prediction.pkl', 'wb') as f:
        pickle.dump(y_pred, f)

else:
    # Load train score data
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

    # Load test prediction data
    with open('prediction.pkl', 'rb') as f:
        y_pred = pickle.load(f)
# Out:
# Epoch 1/150
# 28/28 [==============================] - 115s 2s/step - loss: 258.6093 - mean_squared_error: 258.6093 - mean_absolute_error: 8.2153 - root_mean_squared_error: 16.0813 - val_loss: 498.6062 - val_mean_squared_error: 498.6062 - val_mean_absolute_error: 17.0628 - val_root_mean_squared_error: 22.3295
# Epoch 2/150
# 28/28 [==============================] - 39s 1s/step - loss: 95.7052 - mean_squared_error: 95.7052 - mean_absolute_error: 5.0604 - root_mean_squared_error: 9.7829 - val_loss: 258.7547 - val_mean_squared_error: 258.7547 - val_mean_absolute_error: 12.2951 - val_root_mean_squared_error: 16.0859
# Epoch 3/150
# 28/28 [==============================] - 37s 1s/step - loss: 77.5375 - mean_squared_error: 77.5375 - mean_absolute_error: 4.3513 - root_mean_squared_error: 8.8055 - val_loss: 216.1261 - val_mean_squared_error: 216.1261 - val_mean_absolute_error: 10.9357 - val_root_mean_squared_error: 14.7012
# Epoch 4/150
# 28/28 [==============================] - 39s 1s/step - loss: 72.3062 - mean_squared_error: 72.3062 - mean_absolute_error: 4.2406 - root_mean_squared_error: 8.5033 - val_loss: 213.0409 - val_mean_squared_error: 213.0409 - val_mean_absolute_error: 10.7446 - val_root_mean_squared_error: 14.5959
# Epoch 5/150
# 28/28 [==============================] - 39s 1s/step - loss: 72.9353 - mean_squared_error: 72.9353 - mean_absolute_error: 4.2607 - root_mean_squared_error: 8.5402 - val_loss: 169.4399 - val_mean_squared_error: 169.4399 - val_mean_absolute_error: 9.3360 - val_root_mean_squared_error: 13.0169
# Epoch 6/150
# 28/28 [==============================] - 39s 1s/step - loss: 66.8104 - mean_squared_error: 66.8104 - mean_absolute_error: 4.0599 - root_mean_squared_error: 8.1738 - val_loss: 139.8027 - val_mean_squared_error: 139.8027 - val_mean_absolute_error: 8.6676 - val_root_mean_squared_error: 11.8238
# Epoch 7/150
# 28/28 [==============================] - 39s 1s/step - loss: 66.0198 - mean_squared_error: 66.0198 - mean_absolute_error: 4.0662 - root_mean_squared_error: 8.1253 - val_loss: 136.9238 - val_mean_squared_error: 136.9238 - val_mean_absolute_error: 8.2303 - val_root_mean_squared_error: 11.7014
# Epoch 8/150
# 28/28 [==============================] - 39s 1s/step - loss: 63.4602 - mean_squared_error: 63.4602 - mean_absolute_error: 3.9821 - root_mean_squared_error: 7.9662 - val_loss: 119.9237 - val_mean_squared_error: 119.9237 - val_mean_absolute_error: 4.8538 - val_root_mean_squared_error: 10.9510
# Epoch 9/150
# 28/28 [==============================] - 40s 1s/step - loss: 61.3507 - mean_squared_error: 61.3507 - mean_absolute_error: 3.8542 - root_mean_squared_error: 7.8327 - val_loss: 90.4593 - val_mean_squared_error: 90.4593 - val_mean_absolute_error: 4.2099 - val_root_mean_squared_error: 9.5110
# Epoch 10/150
# 28/28 [==============================] - 38s 1s/step - loss: 60.2238 - mean_squared_error: 60.2238 - mean_absolute_error: 3.8508 - root_mean_squared_error: 7.7604 - val_loss: 87.5318 - val_mean_squared_error: 87.5318 - val_mean_absolute_error: 4.1328 - val_root_mean_squared_error: 9.3558
# Epoch 11/150
# 28/28 [==============================] - 39s 1s/step - loss: 58.4118 - mean_squared_error: 58.4118 - mean_absolute_error: 3.7767 - root_mean_squared_error: 7.6428 - val_loss: 81.3378 - val_mean_squared_error: 81.3378 - val_mean_absolute_error: 4.0403 - val_root_mean_squared_error: 9.0187
# Epoch 12/150
# 28/28 [==============================] - 39s 1s/step - loss: 56.7406 - mean_squared_error: 56.7406 - mean_absolute_error: 3.7192 - root_mean_squared_error: 7.5326 - val_loss: 73.9329 - val_mean_squared_error: 73.9329 - val_mean_absolute_error: 3.9064 - val_root_mean_squared_error: 8.5984
# Epoch 13/150
# 28/28 [==============================] - 40s 1s/step - loss: 60.3957 - mean_squared_error: 60.3957 - mean_absolute_error: 3.8155 - root_mean_squared_error: 7.7715 - val_loss: 70.7982 - val_mean_squared_error: 70.7982 - val_mean_absolute_error: 3.8228 - val_root_mean_squared_error: 8.4142
# Epoch 14/150
# 28/28 [==============================] - 38s 1s/step - loss: 56.9253 - mean_squared_error: 56.9252 - mean_absolute_error: 3.6953 - root_mean_squared_error: 7.5449 - val_loss: 69.9553 - val_mean_squared_error: 69.9553 - val_mean_absolute_error: 3.8184 - val_root_mean_squared_error: 8.3639
# Epoch 15/150
# 28/28 [==============================] - 39s 1s/step - loss: 54.7238 - mean_squared_error: 54.7238 - mean_absolute_error: 3.6387 - root_mean_squared_error: 7.3976 - val_loss: 69.4702 - val_mean_squared_error: 69.4702 - val_mean_absolute_error: 3.8280 - val_root_mean_squared_error: 8.3349
# Epoch 16/150
# 28/28 [==============================] - 38s 1s/step - loss: 55.0332 - mean_squared_error: 55.0332 - mean_absolute_error: 3.6998 - root_mean_squared_error: 7.4184 - val_loss: 75.5155 - val_mean_squared_error: 75.5155 - val_mean_absolute_error: 4.0233 - val_root_mean_squared_error: 8.6900
# Epoch 17/150
# 28/28 [==============================] - 39s 1s/step - loss: 55.1403 - mean_squared_error: 55.1403 - mean_absolute_error: 3.6750 - root_mean_squared_error: 7.4257 - val_loss: 64.6564 - val_mean_squared_error: 64.6564 - val_mean_absolute_error: 3.7479 - val_root_mean_squared_error: 8.0409
# Epoch 18/150
# 28/28 [==============================] - 39s 1s/step - loss: 53.1766 - mean_squared_error: 53.1766 - mean_absolute_error: 3.6174 - root_mean_squared_error: 7.2922 - val_loss: 65.5201 - val_mean_squared_error: 65.5201 - val_mean_absolute_error: 3.7481 - val_root_mean_squared_error: 8.0944
# Epoch 19/150
# 28/28 [==============================] - 39s 1s/step - loss: 52.6913 - mean_squared_error: 52.6913 - mean_absolute_error: 3.5883 - root_mean_squared_error: 7.2589 - val_loss: 66.9948 - val_mean_squared_error: 66.9948 - val_mean_absolute_error: 3.7619 - val_root_mean_squared_error: 8.1850
# Epoch 20/150
# 28/28 [==============================] - 37s 1s/step - loss: 53.2433 - mean_squared_error: 53.2433 - mean_absolute_error: 3.6116 - root_mean_squared_error: 7.2968 - val_loss: 66.9109 - val_mean_squared_error: 66.9109 - val_mean_absolute_error: 3.8141 - val_root_mean_squared_error: 8.1799
# Epoch 21/150
# 28/28 [==============================] - 37s 1s/step - loss: 50.9807 - mean_squared_error: 50.9807 - mean_absolute_error: 3.5141 - root_mean_squared_error: 7.1401 - val_loss: 72.2107 - val_mean_squared_error: 72.2107 - val_mean_absolute_error: 3.9712 - val_root_mean_squared_error: 8.4977
# Epoch 22/150
# 28/28 [==============================] - 37s 1s/step - loss: 50.7300 - mean_squared_error: 50.7300 - mean_absolute_error: 3.4933 - root_mean_squared_error: 7.1225 - val_loss: 66.0921 - val_mean_squared_error: 66.0921 - val_mean_absolute_error: 3.7700 - val_root_mean_squared_error: 8.1297
# Epoch 23/150
# 28/28 [==============================] - 37s 1s/step - loss: 51.6918 - mean_squared_error: 51.6918 - mean_absolute_error: 3.5401 - root_mean_squared_error: 7.1897 - val_loss: 65.6347 - val_mean_squared_error: 65.6346 - val_mean_absolute_error: 3.8685 - val_root_mean_squared_error: 8.1015
# Epoch 24/150
# 28/28 [==============================] - 37s 1s/step - loss: 51.7100 - mean_squared_error: 51.7099 - mean_absolute_error: 3.5536 - root_mean_squared_error: 7.1910 - val_loss: 64.7944 - val_mean_squared_error: 64.7944 - val_mean_absolute_error: 3.7787 - val_root_mean_squared_error: 8.0495
# Epoch 25/150
# 28/28 [==============================] - 37s 1s/step - loss: 51.2902 - mean_squared_error: 51.2902 - mean_absolute_error: 3.5651 - root_mean_squared_error: 7.1617 - val_loss: 64.2102 - val_mean_squared_error: 64.2102 - val_mean_absolute_error: 3.9231 - val_root_mean_squared_error: 8.0131
# Epoch 26/150
# 28/28 [==============================] - 40s 1s/step - loss: 48.8532 - mean_squared_error: 48.8532 - mean_absolute_error: 3.4444 - root_mean_squared_error: 6.9895 - val_loss: 64.5834 - val_mean_squared_error: 64.5834 - val_mean_absolute_error: 3.9482 - val_root_mean_squared_error: 8.0364
# Epoch 27/150
# 28/28 [==============================] - 37s 1s/step - loss: 50.5433 - mean_squared_error: 50.5433 - mean_absolute_error: 3.4951 - root_mean_squared_error: 7.1094 - val_loss: 65.4732 - val_mean_squared_error: 65.4732 - val_mean_absolute_error: 3.9462 - val_root_mean_squared_error: 8.0915
# Epoch 28/150
# 28/28 [==============================] - 38s 1s/step - loss: 48.5677 - mean_squared_error: 48.5677 - mean_absolute_error: 3.4622 - root_mean_squared_error: 6.9691 - val_loss: 68.0614 - val_mean_squared_error: 68.0614 - val_mean_absolute_error: 3.9021 - val_root_mean_squared_error: 8.2499
# Epoch 29/150
# 28/28 [==============================] - 37s 1s/step - loss: 50.5850 - mean_squared_error: 50.5850 - mean_absolute_error: 3.5147 - root_mean_squared_error: 7.1123 - val_loss: 65.3447 - val_mean_squared_error: 65.3447 - val_mean_absolute_error: 3.7566 - val_root_mean_squared_error: 8.0836
# Epoch 30/150
# 28/28 [==============================] - 39s 1s/step - loss: 48.9276 - mean_squared_error: 48.9276 - mean_absolute_error: 3.4333 - root_mean_squared_error: 6.9948 - val_loss: 64.3180 - val_mean_squared_error: 64.3180 - val_mean_absolute_error: 3.8649 - val_root_mean_squared_error: 8.0199
# Epoch 31/150
# 28/28 [==============================] - 39s 1s/step - loss: 48.2005 - mean_squared_error: 48.2005 - mean_absolute_error: 3.4278 - root_mean_squared_error: 6.9427 - val_loss: 67.3071 - val_mean_squared_error: 67.3071 - val_mean_absolute_error: 3.9964 - val_root_mean_squared_error: 8.2041
# Epoch 32/150
# 28/28 [==============================] - 39s 1s/step - loss: 49.8930 - mean_squared_error: 49.8930 - mean_absolute_error: 3.5131 - root_mean_squared_error: 7.0635 - val_loss: 67.4134 - val_mean_squared_error: 67.4134 - val_mean_absolute_error: 4.0113 - val_root_mean_squared_error: 8.2106
# Epoch 33/150
# 28/28 [==============================] - 40s 1s/step - loss: 50.8495 - mean_squared_error: 50.8495 - mean_absolute_error: 3.4623 - root_mean_squared_error: 7.1309 - val_loss: 64.7074 - val_mean_squared_error: 64.7074 - val_mean_absolute_error: 3.9759 - val_root_mean_squared_error: 8.0441
# Epoch 34/150
# 28/28 [==============================] - 39s 1s/step - loss: 50.0588 - mean_squared_error: 50.0588 - mean_absolute_error: 3.5125 - root_mean_squared_error: 7.0752 - val_loss: 64.0068 - val_mean_squared_error: 64.0068 - val_mean_absolute_error: 3.9478 - val_root_mean_squared_error: 8.0004
# Epoch 35/150
# 28/28 [==============================] - 38s 1s/step - loss: 48.9967 - mean_squared_error: 48.9967 - mean_absolute_error: 3.4580 - root_mean_squared_error: 6.9998 - val_loss: 63.6134 - val_mean_squared_error: 63.6134 - val_mean_absolute_error: 3.8582 - val_root_mean_squared_error: 7.9758
# Epoch 36/150
# 28/28 [==============================] - 39s 1s/step - loss: 49.5565 - mean_squared_error: 49.5565 - mean_absolute_error: 3.4842 - root_mean_squared_error: 7.0396 - val_loss: 66.2710 - val_mean_squared_error: 66.2710 - val_mean_absolute_error: 3.8900 - val_root_mean_squared_error: 8.1407
# Epoch 37/150
# 28/28 [==============================] - 39s 1s/step - loss: 47.5701 - mean_squared_error: 47.5701 - mean_absolute_error: 3.4144 - root_mean_squared_error: 6.8971 - val_loss: 64.9436 - val_mean_squared_error: 64.9436 - val_mean_absolute_error: 3.8043 - val_root_mean_squared_error: 8.0588
# Epoch 38/150
# 28/28 [==============================] - 40s 1s/step - loss: 47.9713 - mean_squared_error: 47.9713 - mean_absolute_error: 3.4049 - root_mean_squared_error: 6.9261 - val_loss: 66.0958 - val_mean_squared_error: 66.0958 - val_mean_absolute_error: 3.8240 - val_root_mean_squared_error: 8.1299
# Epoch 39/150
# 28/28 [==============================] - 37s 1s/step - loss: 48.3822 - mean_squared_error: 48.3822 - mean_absolute_error: 3.4646 - root_mean_squared_error: 6.9557 - val_loss: 65.2662 - val_mean_squared_error: 65.2662 - val_mean_absolute_error: 3.9124 - val_root_mean_squared_error: 8.0787
# Epoch 40/150
# 28/28 [==============================] - 39s 1s/step - loss: 48.8648 - mean_squared_error: 48.8648 - mean_absolute_error: 3.4786 - root_mean_squared_error: 6.9903 - val_loss: 65.3445 - val_mean_squared_error: 65.3445 - val_mean_absolute_error: 3.9097 - val_root_mean_squared_error: 8.0836
# Epoch 41/150
# 28/28 [==============================] - 39s 1s/step - loss: 48.6720 - mean_squared_error: 48.6720 - mean_absolute_error: 3.4630 - root_mean_squared_error: 6.9765 - val_loss: 72.0547 - val_mean_squared_error: 72.0547 - val_mean_absolute_error: 4.0032 - val_root_mean_squared_error: 8.4885
# Epoch 42/150
# 28/28 [==============================] - 37s 1s/step - loss: 48.8186 - mean_squared_error: 48.8186 - mean_absolute_error: 3.4622 - root_mean_squared_error: 6.9870 - val_loss: 65.3545 - val_mean_squared_error: 65.3545 - val_mean_absolute_error: 3.8954 - val_root_mean_squared_error: 8.0842
# Epoch 43/150
# 28/28 [==============================] - 37s 1s/step - loss: 47.3847 - mean_squared_error: 47.3847 - mean_absolute_error: 3.3890 - root_mean_squared_error: 6.8837 - val_loss: 64.6089 - val_mean_squared_error: 64.6089 - val_mean_absolute_error: 3.8943 - val_root_mean_squared_error: 8.0380
# Epoch 44/150
# 28/28 [==============================] - 39s 1s/step - loss: 46.9052 - mean_squared_error: 46.9052 - mean_absolute_error: 3.3717 - root_mean_squared_error: 6.8487 - val_loss: 65.6890 - val_mean_squared_error: 65.6890 - val_mean_absolute_error: 3.9596 - val_root_mean_squared_error: 8.1049
# Epoch 45/150
# 28/28 [==============================] - 38s 1s/step - loss: 47.4189 - mean_squared_error: 47.4189 - mean_absolute_error: 3.3971 - root_mean_squared_error: 6.8861 - val_loss: 65.1286 - val_mean_squared_error: 65.1286 - val_mean_absolute_error: 3.8586 - val_root_mean_squared_error: 8.0702
# Epoch 46/150
# 28/28 [==============================] - 38s 1s/step - loss: 47.6257 - mean_squared_error: 47.6257 - mean_absolute_error: 3.4307 - root_mean_squared_error: 6.9011 - val_loss: 73.2535 - val_mean_squared_error: 73.2535 - val_mean_absolute_error: 4.1959 - val_root_mean_squared_error: 8.5588
# Epoch 47/150
# 28/28 [==============================] - 39s 1s/step - loss: 49.1093 - mean_squared_error: 49.1093 - mean_absolute_error: 3.4847 - root_mean_squared_error: 7.0078 - val_loss: 67.5339 - val_mean_squared_error: 67.5339 - val_mean_absolute_error: 4.0822 - val_root_mean_squared_error: 8.2179
# Epoch 48/150
# 28/28 [==============================] - 39s 1s/step - loss: 47.6616 - mean_squared_error: 47.6616 - mean_absolute_error: 3.4103 - root_mean_squared_error: 6.9037 - val_loss: 74.7193 - val_mean_squared_error: 74.7194 - val_mean_absolute_error: 4.1905 - val_root_mean_squared_error: 8.6440
# Epoch 49/150
# 28/28 [==============================] - 38s 1s/step - loss: 48.3679 - mean_squared_error: 48.3679 - mean_absolute_error: 3.4481 - root_mean_squared_error: 6.9547 - val_loss: 61.0863 - val_mean_squared_error: 61.0863 - val_mean_absolute_error: 3.8302 - val_root_mean_squared_error: 7.8158
# Epoch 50/150
# 28/28 [==============================] - 38s 1s/step - loss: 48.4994 - mean_squared_error: 48.4994 - mean_absolute_error: 3.4579 - root_mean_squared_error: 6.9642 - val_loss: 60.4365 - val_mean_squared_error: 60.4365 - val_mean_absolute_error: 3.7191 - val_root_mean_squared_error: 7.7741
# Epoch 51/150
# 28/28 [==============================] - 39s 1s/step - loss: 46.4586 - mean_squared_error: 46.4586 - mean_absolute_error: 3.3837 - root_mean_squared_error: 6.8161 - val_loss: 61.1236 - val_mean_squared_error: 61.1236 - val_mean_absolute_error: 3.8187 - val_root_mean_squared_error: 7.8182
# Epoch 52/150
# 28/28 [==============================] - 38s 1s/step - loss: 46.9339 - mean_squared_error: 46.9339 - mean_absolute_error: 3.4273 - root_mean_squared_error: 6.8508 - val_loss: 62.0505 - val_mean_squared_error: 62.0505 - val_mean_absolute_error: 3.8426 - val_root_mean_squared_error: 7.8772
# Epoch 53/150
# 28/28 [==============================] - 38s 1s/step - loss: 46.6624 - mean_squared_error: 46.6624 - mean_absolute_error: 3.3893 - root_mean_squared_error: 6.8310 - val_loss: 67.8640 - val_mean_squared_error: 67.8640 - val_mean_absolute_error: 4.0556 - val_root_mean_squared_error: 8.2380
# Epoch 54/150
# 28/28 [==============================] - 38s 1s/step - loss: 46.1924 - mean_squared_error: 46.1924 - mean_absolute_error: 3.3632 - root_mean_squared_error: 6.7965 - val_loss: 73.8798 - val_mean_squared_error: 73.8798 - val_mean_absolute_error: 4.2667 - val_root_mean_squared_error: 8.5953
# Epoch 55/150
# 28/28 [==============================] - 38s 1s/step - loss: 45.9198 - mean_squared_error: 45.9198 - mean_absolute_error: 3.3542 - root_mean_squared_error: 6.7764 - val_loss: 64.7374 - val_mean_squared_error: 64.7374 - val_mean_absolute_error: 3.9708 - val_root_mean_squared_error: 8.0460
# Epoch 56/150
# 28/28 [==============================] - 39s 1s/step - loss: 44.5962 - mean_squared_error: 44.5962 - mean_absolute_error: 3.3264 - root_mean_squared_error: 6.6780 - val_loss: 61.2917 - val_mean_squared_error: 61.2917 - val_mean_absolute_error: 3.7435 - val_root_mean_squared_error: 7.8289
# Epoch 57/150
# 28/28 [==============================] - 39s 1s/step - loss: 45.4065 - mean_squared_error: 45.4065 - mean_absolute_error: 3.2951 - root_mean_squared_error: 6.7384 - val_loss: 72.6661 - val_mean_squared_error: 72.6660 - val_mean_absolute_error: 4.2491 - val_root_mean_squared_error: 8.5244
# Epoch 58/150
# 28/28 [==============================] - 39s 1s/step - loss: 45.2995 - mean_squared_error: 45.2995 - mean_absolute_error: 3.3449 - root_mean_squared_error: 6.7305 - val_loss: 69.9454 - val_mean_squared_error: 69.9454 - val_mean_absolute_error: 4.0262 - val_root_mean_squared_error: 8.3633
# Epoch 59/150
# 28/28 [==============================] - 39s 1s/step - loss: 44.7497 - mean_squared_error: 44.7497 - mean_absolute_error: 3.3084 - root_mean_squared_error: 6.6895 - val_loss: 71.5668 - val_mean_squared_error: 71.5669 - val_mean_absolute_error: 4.1633 - val_root_mean_squared_error: 8.4597
# Epoch 60/150
# 28/28 [==============================] - 39s 1s/step - loss: 44.3244 - mean_squared_error: 44.3244 - mean_absolute_error: 3.2939 - root_mean_squared_error: 6.6577 - val_loss: 64.0882 - val_mean_squared_error: 64.0883 - val_mean_absolute_error: 3.8623 - val_root_mean_squared_error: 8.0055
# Epoch 61/150
# 28/28 [==============================] - 39s 1s/step - loss: 43.7378 - mean_squared_error: 43.7378 - mean_absolute_error: 3.2992 - root_mean_squared_error: 6.6135 - val_loss: 70.3162 - val_mean_squared_error: 70.3162 - val_mean_absolute_error: 4.0657 - val_root_mean_squared_error: 8.3855
# Epoch 62/150
# 28/28 [==============================] - 39s 1s/step - loss: 45.1374 - mean_squared_error: 45.1374 - mean_absolute_error: 3.3304 - root_mean_squared_error: 6.7184 - val_loss: 62.8787 - val_mean_squared_error: 62.8787 - val_mean_absolute_error: 3.7654 - val_root_mean_squared_error: 7.9296
# Epoch 63/150
# 28/28 [==============================] - 40s 1s/step - loss: 45.7967 - mean_squared_error: 45.7967 - mean_absolute_error: 3.3596 - root_mean_squared_error: 6.7673 - val_loss: 69.0110 - val_mean_squared_error: 69.0110 - val_mean_absolute_error: 4.0815 - val_root_mean_squared_error: 8.3073
# Epoch 64/150
# 28/28 [==============================] - 38s 1s/step - loss: 47.1655 - mean_squared_error: 47.1655 - mean_absolute_error: 3.3999 - root_mean_squared_error: 6.8677 - val_loss: 70.3011 - val_mean_squared_error: 70.3011 - val_mean_absolute_error: 3.9951 - val_root_mean_squared_error: 8.3846
# Epoch 65/150
# 28/28 [==============================] - 40s 1s/step - loss: 46.3202 - mean_squared_error: 46.3202 - mean_absolute_error: 3.3758 - root_mean_squared_error: 6.8059 - val_loss: 55.6430 - val_mean_squared_error: 55.6430 - val_mean_absolute_error: 3.5828 - val_root_mean_squared_error: 7.4594
# Epoch 66/150
# 28/28 [==============================] - 39s 1s/step - loss: 44.9660 - mean_squared_error: 44.9660 - mean_absolute_error: 3.3316 - root_mean_squared_error: 6.7057 - val_loss: 65.2890 - val_mean_squared_error: 65.2890 - val_mean_absolute_error: 3.8715 - val_root_mean_squared_error: 8.0802
# Epoch 67/150
# 28/28 [==============================] - 37s 1s/step - loss: 43.2902 - mean_squared_error: 43.2902 - mean_absolute_error: 3.2723 - root_mean_squared_error: 6.5795 - val_loss: 60.2855 - val_mean_squared_error: 60.2855 - val_mean_absolute_error: 3.6900 - val_root_mean_squared_error: 7.7644
# Epoch 68/150
# 28/28 [==============================] - 38s 1s/step - loss: 43.1465 - mean_squared_error: 43.1465 - mean_absolute_error: 3.2510 - root_mean_squared_error: 6.5686 - val_loss: 67.3759 - val_mean_squared_error: 67.3759 - val_mean_absolute_error: 3.9810 - val_root_mean_squared_error: 8.2083
# Epoch 69/150
# 28/28 [==============================] - 39s 1s/step - loss: 43.1136 - mean_squared_error: 43.1136 - mean_absolute_error: 3.2300 - root_mean_squared_error: 6.5661 - val_loss: 69.6544 - val_mean_squared_error: 69.6544 - val_mean_absolute_error: 3.9822 - val_root_mean_squared_error: 8.3459
# Epoch 70/150
# 28/28 [==============================] - 38s 1s/step - loss: 42.8207 - mean_squared_error: 42.8207 - mean_absolute_error: 3.2316 - root_mean_squared_error: 6.5438 - val_loss: 66.6749 - val_mean_squared_error: 66.6749 - val_mean_absolute_error: 3.9575 - val_root_mean_squared_error: 8.1655
# Epoch 71/150
# 28/28 [==============================] - 38s 1s/step - loss: 45.8763 - mean_squared_error: 45.8763 - mean_absolute_error: 3.3764 - root_mean_squared_error: 6.7732 - val_loss: 64.7462 - val_mean_squared_error: 64.7462 - val_mean_absolute_error: 3.7652 - val_root_mean_squared_error: 8.0465
# Epoch 72/150
# 28/28 [==============================] - 38s 1s/step - loss: 43.7868 - mean_squared_error: 43.7868 - mean_absolute_error: 3.2888 - root_mean_squared_error: 6.6172 - val_loss: 67.1116 - val_mean_squared_error: 67.1116 - val_mean_absolute_error: 4.0331 - val_root_mean_squared_error: 8.1922
# Epoch 73/150
# 28/28 [==============================] - 37s 1s/step - loss: 41.8775 - mean_squared_error: 41.8775 - mean_absolute_error: 3.1848 - root_mean_squared_error: 6.4713 - val_loss: 75.7825 - val_mean_squared_error: 75.7825 - val_mean_absolute_error: 4.3088 - val_root_mean_squared_error: 8.7053
# Epoch 74/150
# 28/28 [==============================] - 36s 1s/step - loss: 43.8382 - mean_squared_error: 43.8382 - mean_absolute_error: 3.2696 - root_mean_squared_error: 6.6210 - val_loss: 69.5384 - val_mean_squared_error: 69.5384 - val_mean_absolute_error: 4.1312 - val_root_mean_squared_error: 8.3390
# Epoch 75/150
# 28/28 [==============================] - 40s 1s/step - loss: 43.7804 - mean_squared_error: 43.7804 - mean_absolute_error: 3.2824 - root_mean_squared_error: 6.6167 - val_loss: 66.9070 - val_mean_squared_error: 66.9070 - val_mean_absolute_error: 3.9076 - val_root_mean_squared_error: 8.1797
# Epoch 76/150
# 28/28 [==============================] - 37s 1s/step - loss: 44.2346 - mean_squared_error: 44.2346 - mean_absolute_error: 3.3020 - root_mean_squared_error: 6.6509 - val_loss: 63.8854 - val_mean_squared_error: 63.8854 - val_mean_absolute_error: 3.7998 - val_root_mean_squared_error: 7.9928
# Epoch 77/150
# 28/28 [==============================] - 37s 1s/step - loss: 43.8545 - mean_squared_error: 43.8545 - mean_absolute_error: 3.2653 - root_mean_squared_error: 6.6223 - val_loss: 58.3913 - val_mean_squared_error: 58.3913 - val_mean_absolute_error: 3.6464 - val_root_mean_squared_error: 7.6414
# Epoch 78/150
# 28/28 [==============================] - 37s 1s/step - loss: 44.0242 - mean_squared_error: 44.0242 - mean_absolute_error: 3.2897 - root_mean_squared_error: 6.6351 - val_loss: 61.6819 - val_mean_squared_error: 61.6819 - val_mean_absolute_error: 3.7876 - val_root_mean_squared_error: 7.8538
# Epoch 79/150
# 28/28 [==============================] - 38s 1s/step - loss: 42.5690 - mean_squared_error: 42.5690 - mean_absolute_error: 3.2187 - root_mean_squared_error: 6.5245 - val_loss: 77.0226 - val_mean_squared_error: 77.0227 - val_mean_absolute_error: 4.2370 - val_root_mean_squared_error: 8.7763
# Epoch 80/150
# 28/28 [==============================] - 39s 1s/step - loss: 44.2006 - mean_squared_error: 44.2006 - mean_absolute_error: 3.3333 - root_mean_squared_error: 6.6484 - val_loss: 63.6702 - val_mean_squared_error: 63.6702 - val_mean_absolute_error: 3.8260 - val_root_mean_squared_error: 7.9794
# Epoch 81/150
# 28/28 [==============================] - 40s 1s/step - loss: 43.0585 - mean_squared_error: 43.0585 - mean_absolute_error: 3.2620 - root_mean_squared_error: 6.5619 - val_loss: 66.9574 - val_mean_squared_error: 66.9574 - val_mean_absolute_error: 4.0844 - val_root_mean_squared_error: 8.1827
# Epoch 82/150
# 28/28 [==============================] - 38s 1s/step - loss: 41.4877 - mean_squared_error: 41.4877 - mean_absolute_error: 3.1757 - root_mean_squared_error: 6.4411 - val_loss: 66.1941 - val_mean_squared_error: 66.1941 - val_mean_absolute_error: 3.9663 - val_root_mean_squared_error: 8.1360
# Epoch 83/150
# 28/28 [==============================] - 37s 1s/step - loss: 42.3636 - mean_squared_error: 42.3636 - mean_absolute_error: 3.1784 - root_mean_squared_error: 6.5087 - val_loss: 61.8362 - val_mean_squared_error: 61.8362 - val_mean_absolute_error: 3.8349 - val_root_mean_squared_error: 7.8636
# Epoch 84/150
# 28/28 [==============================] - 40s 1s/step - loss: 41.5609 - mean_squared_error: 41.5609 - mean_absolute_error: 3.1686 - root_mean_squared_error: 6.4468 - val_loss: 58.6654 - val_mean_squared_error: 58.6654 - val_mean_absolute_error: 3.6556 - val_root_mean_squared_error: 7.6593
# Epoch 85/150
# 28/28 [==============================] - 40s 1s/step - loss: 41.5118 - mean_squared_error: 41.5118 - mean_absolute_error: 3.1590 - root_mean_squared_error: 6.4430 - val_loss: 62.2300 - val_mean_squared_error: 62.2300 - val_mean_absolute_error: 3.7574 - val_root_mean_squared_error: 7.8886
# Epoch 86/150
# 28/28 [==============================] - 37s 1s/step - loss: 40.8446 - mean_squared_error: 40.8446 - mean_absolute_error: 3.1501 - root_mean_squared_error: 6.3910 - val_loss: 63.3030 - val_mean_squared_error: 63.3030 - val_mean_absolute_error: 3.8971 - val_root_mean_squared_error: 7.9563
# Epoch 87/150
# 28/28 [==============================] - 40s 1s/step - loss: 43.2653 - mean_squared_error: 43.2653 - mean_absolute_error: 3.2294 - root_mean_squared_error: 6.5776 - val_loss: 98.2246 - val_mean_squared_error: 98.2246 - val_mean_absolute_error: 4.8592 - val_root_mean_squared_error: 9.9108
# Epoch 88/150
# 28/28 [==============================] - 38s 1s/step - loss: 44.4572 - mean_squared_error: 44.4572 - mean_absolute_error: 3.3238 - root_mean_squared_error: 6.6676 - val_loss: 78.5568 - val_mean_squared_error: 78.5568 - val_mean_absolute_error: 4.5242 - val_root_mean_squared_error: 8.8632
# Epoch 89/150
# 28/28 [==============================] - 39s 1s/step - loss: 41.7822 - mean_squared_error: 41.7822 - mean_absolute_error: 3.1866 - root_mean_squared_error: 6.4639 - val_loss: 60.7767 - val_mean_squared_error: 60.7767 - val_mean_absolute_error: 3.8580 - val_root_mean_squared_error: 7.7959
# Epoch 90/150
# 28/28 [==============================] - 37s 1s/step - loss: 41.4772 - mean_squared_error: 41.4772 - mean_absolute_error: 3.1841 - root_mean_squared_error: 6.4403 - val_loss: 70.7891 - val_mean_squared_error: 70.7891 - val_mean_absolute_error: 4.0996 - val_root_mean_squared_error: 8.4136
# Epoch 91/150
# 28/28 [==============================] - 37s 1s/step - loss: 42.1579 - mean_squared_error: 42.1579 - mean_absolute_error: 3.1964 - root_mean_squared_error: 6.4929 - val_loss: 74.2249 - val_mean_squared_error: 74.2248 - val_mean_absolute_error: 4.3019 - val_root_mean_squared_error: 8.6154
# Epoch 92/150
# 28/28 [==============================] - 40s 1s/step - loss: 42.9813 - mean_squared_error: 42.9813 - mean_absolute_error: 3.2555 - root_mean_squared_error: 6.5560 - val_loss: 64.1339 - val_mean_squared_error: 64.1339 - val_mean_absolute_error: 3.8623 - val_root_mean_squared_error: 8.0084
# Epoch 93/150
# 28/28 [==============================] - 38s 1s/step - loss: 43.1195 - mean_squared_error: 43.1195 - mean_absolute_error: 3.2491 - root_mean_squared_error: 6.5665 - val_loss: 66.1318 - val_mean_squared_error: 66.1318 - val_mean_absolute_error: 3.8951 - val_root_mean_squared_error: 8.1321
# Epoch 94/150
# 28/28 [==============================] - 40s 1s/step - loss: 43.8978 - mean_squared_error: 43.8978 - mean_absolute_error: 3.2841 - root_mean_squared_error: 6.6255 - val_loss: 74.6712 - val_mean_squared_error: 74.6712 - val_mean_absolute_error: 4.4137 - val_root_mean_squared_error: 8.6413
# Epoch 95/150
# 28/28 [==============================] - 40s 1s/step - loss: 44.4807 - mean_squared_error: 44.4807 - mean_absolute_error: 3.3186 - root_mean_squared_error: 6.6694 - val_loss: 62.4261 - val_mean_squared_error: 62.4261 - val_mean_absolute_error: 3.8446 - val_root_mean_squared_error: 7.9010
# Epoch 96/150
# 28/28 [==============================] - 40s 1s/step - loss: 43.5020 - mean_squared_error: 43.5020 - mean_absolute_error: 3.2605 - root_mean_squared_error: 6.5956 - val_loss: 62.5858 - val_mean_squared_error: 62.5858 - val_mean_absolute_error: 3.8134 - val_root_mean_squared_error: 7.9111
# Epoch 97/150
# 28/28 [==============================] - 38s 1s/step - loss: 42.9616 - mean_squared_error: 42.9616 - mean_absolute_error: 3.2226 - root_mean_squared_error: 6.5545 - val_loss: 71.3070 - val_mean_squared_error: 71.3070 - val_mean_absolute_error: 3.9990 - val_root_mean_squared_error: 8.4443
# Epoch 98/150
# 28/28 [==============================] - 38s 1s/step - loss: 43.4373 - mean_squared_error: 43.4373 - mean_absolute_error: 3.2531 - root_mean_squared_error: 6.5907 - val_loss: 64.7141 - val_mean_squared_error: 64.7141 - val_mean_absolute_error: 3.8570 - val_root_mean_squared_error: 8.0445
# Epoch 99/150
# 28/28 [==============================] - 41s 1s/step - loss: 42.8338 - mean_squared_error: 42.8338 - mean_absolute_error: 3.2186 - root_mean_squared_error: 6.5448 - val_loss: 65.0094 - val_mean_squared_error: 65.0094 - val_mean_absolute_error: 3.9281 - val_root_mean_squared_error: 8.0628
# Epoch 100/150
# 28/28 [==============================] - 38s 1s/step - loss: 42.1794 - mean_squared_error: 42.1794 - mean_absolute_error: 3.2139 - root_mean_squared_error: 6.4946 - val_loss: 68.6295 - val_mean_squared_error: 68.6295 - val_mean_absolute_error: 4.0230 - val_root_mean_squared_error: 8.2843
# Epoch 101/150
# 28/28 [==============================] - 38s 1s/step - loss: 42.7659 - mean_squared_error: 42.7659 - mean_absolute_error: 3.2221 - root_mean_squared_error: 6.5396 - val_loss: 64.8624 - val_mean_squared_error: 64.8624 - val_mean_absolute_error: 3.9761 - val_root_mean_squared_error: 8.0537
# Epoch 102/150
# 28/28 [==============================] - 38s 1s/step - loss: 43.7290 - mean_squared_error: 43.7290 - mean_absolute_error: 3.2882 - root_mean_squared_error: 6.6128 - val_loss: 62.3644 - val_mean_squared_error: 62.3644 - val_mean_absolute_error: 3.7983 - val_root_mean_squared_error: 7.8971
# Epoch 103/150
# 28/28 [==============================] - 41s 1s/step - loss: 43.9072 - mean_squared_error: 43.9072 - mean_absolute_error: 3.2428 - root_mean_squared_error: 6.6262 - val_loss: 64.1551 - val_mean_squared_error: 64.1551 - val_mean_absolute_error: 3.9753 - val_root_mean_squared_error: 8.0097
# Epoch 104/150
# 28/28 [==============================] - 38s 1s/step - loss: 42.6225 - mean_squared_error: 42.6225 - mean_absolute_error: 3.2529 - root_mean_squared_error: 6.5286 - val_loss: 59.9116 - val_mean_squared_error: 59.9116 - val_mean_absolute_error: 3.7748 - val_root_mean_squared_error: 7.7403
# Epoch 105/150
# 28/28 [==============================] - 37s 1s/step - loss: 43.2134 - mean_squared_error: 43.2134 - mean_absolute_error: 3.2526 - root_mean_squared_error: 6.5737 - val_loss: 60.1798 - val_mean_squared_error: 60.1798 - val_mean_absolute_error: 3.6959 - val_root_mean_squared_error: 7.7576
# Epoch 106/150
# 28/28 [==============================] - 36s 1s/step - loss: 41.4230 - mean_squared_error: 41.4230 - mean_absolute_error: 3.1925 - root_mean_squared_error: 6.4361 - val_loss: 57.9922 - val_mean_squared_error: 57.9922 - val_mean_absolute_error: 3.6892 - val_root_mean_squared_error: 7.6153
# Epoch 107/150
# 28/28 [==============================] - 39s 1s/step - loss: 41.3002 - mean_squared_error: 41.3002 - mean_absolute_error: 3.1814 - root_mean_squared_error: 6.4265 - val_loss: 70.2014 - val_mean_squared_error: 70.2014 - val_mean_absolute_error: 4.1863 - val_root_mean_squared_error: 8.3786
# Epoch 108/150
# 28/28 [==============================] - 40s 1s/step - loss: 41.4121 - mean_squared_error: 41.4121 - mean_absolute_error: 3.1831 - root_mean_squared_error: 6.4352 - val_loss: 58.2795 - val_mean_squared_error: 58.2795 - val_mean_absolute_error: 3.6047 - val_root_mean_squared_error: 7.6341
# Epoch 109/150
# 28/28 [==============================] - 38s 1s/step - loss: 41.2837 - mean_squared_error: 41.2837 - mean_absolute_error: 3.1968 - root_mean_squared_error: 6.4252 - val_loss: 63.9936 - val_mean_squared_error: 63.9936 - val_mean_absolute_error: 3.9354 - val_root_mean_squared_error: 7.9996
# Epoch 110/150
# 28/28 [==============================] - 38s 1s/step - loss: 40.9297 - mean_squared_error: 40.9297 - mean_absolute_error: 3.1774 - root_mean_squared_error: 6.3976 - val_loss: 59.8619 - val_mean_squared_error: 59.8619 - val_mean_absolute_error: 3.6586 - val_root_mean_squared_error: 7.7370
# Epoch 111/150
# 28/28 [==============================] - 40s 1s/step - loss: 40.8072 - mean_squared_error: 40.8072 - mean_absolute_error: 3.1596 - root_mean_squared_error: 6.3881 - val_loss: 62.9706 - val_mean_squared_error: 62.9706 - val_mean_absolute_error: 3.7999 - val_root_mean_squared_error: 7.9354
# Epoch 112/150
# 28/28 [==============================] - 37s 1s/step - loss: 40.3859 - mean_squared_error: 40.3859 - mean_absolute_error: 3.1349 - root_mean_squared_error: 6.3550 - val_loss: 60.7050 - val_mean_squared_error: 60.7050 - val_mean_absolute_error: 3.7862 - val_root_mean_squared_error: 7.7913
# Epoch 113/150
# 28/28 [==============================] - 40s 1s/step - loss: 40.6936 - mean_squared_error: 40.6936 - mean_absolute_error: 3.1496 - root_mean_squared_error: 6.3792 - val_loss: 67.2505 - val_mean_squared_error: 67.2505 - val_mean_absolute_error: 4.0210 - val_root_mean_squared_error: 8.2006
# Epoch 114/150
# 28/28 [==============================] - 37s 1s/step - loss: 40.4740 - mean_squared_error: 40.4740 - mean_absolute_error: 3.1653 - root_mean_squared_error: 6.3619 - val_loss: 67.3932 - val_mean_squared_error: 67.3933 - val_mean_absolute_error: 3.9093 - val_root_mean_squared_error: 8.2093
# Epoch 115/150
# 28/28 [==============================] - 37s 1s/step - loss: 40.5983 - mean_squared_error: 40.5983 - mean_absolute_error: 3.1357 - root_mean_squared_error: 6.3717 - val_loss: 72.9467 - val_mean_squared_error: 72.9467 - val_mean_absolute_error: 4.1527 - val_root_mean_squared_error: 8.5409
# Epoch 116/150
# 28/28 [==============================] - 37s 1s/step - loss: 38.6994 - mean_squared_error: 38.6994 - mean_absolute_error: 3.0577 - root_mean_squared_error: 6.2209 - val_loss: 66.8629 - val_mean_squared_error: 66.8629 - val_mean_absolute_error: 3.9921 - val_root_mean_squared_error: 8.1770
# Epoch 117/150
# 28/28 [==============================] - 39s 1s/step - loss: 39.1986 - mean_squared_error: 39.1986 - mean_absolute_error: 3.0948 - root_mean_squared_error: 6.2609 - val_loss: 60.6018 - val_mean_squared_error: 60.6019 - val_mean_absolute_error: 3.7565 - val_root_mean_squared_error: 7.7847
# Epoch 118/150
# 28/28 [==============================] - 40s 1s/step - loss: 39.5997 - mean_squared_error: 39.5997 - mean_absolute_error: 3.1069 - root_mean_squared_error: 6.2928 - val_loss: 64.5338 - val_mean_squared_error: 64.5338 - val_mean_absolute_error: 3.7648 - val_root_mean_squared_error: 8.0333
# Epoch 119/150
# 28/28 [==============================] - 40s 1s/step - loss: 40.4715 - mean_squared_error: 40.4715 - mean_absolute_error: 3.1498 - root_mean_squared_error: 6.3617 - val_loss: 63.9522 - val_mean_squared_error: 63.9522 - val_mean_absolute_error: 3.8024 - val_root_mean_squared_error: 7.9970
# Epoch 120/150
# 28/28 [==============================] - 37s 1s/step - loss: 39.0981 - mean_squared_error: 39.0981 - mean_absolute_error: 3.1088 - root_mean_squared_error: 6.2529 - val_loss: 69.9426 - val_mean_squared_error: 69.9426 - val_mean_absolute_error: 3.9334 - val_root_mean_squared_error: 8.3632
# Epoch 121/150
# 28/28 [==============================] - 40s 1s/step - loss: 39.1138 - mean_squared_error: 39.1138 - mean_absolute_error: 3.0888 - root_mean_squared_error: 6.2541 - val_loss: 61.9240 - val_mean_squared_error: 61.9240 - val_mean_absolute_error: 3.7728 - val_root_mean_squared_error: 7.8692
# Epoch 122/150
# 28/28 [==============================] - 41s 1s/step - loss: 38.7079 - mean_squared_error: 38.7079 - mean_absolute_error: 3.0788 - root_mean_squared_error: 6.2216 - val_loss: 67.1335 - val_mean_squared_error: 67.1335 - val_mean_absolute_error: 3.8449 - val_root_mean_squared_error: 8.1935
# Epoch 123/150
# 28/28 [==============================] - 42s 1s/step - loss: 39.2684 - mean_squared_error: 39.2684 - mean_absolute_error: 3.0987 - root_mean_squared_error: 6.2665 - val_loss: 66.0136 - val_mean_squared_error: 66.0136 - val_mean_absolute_error: 3.8321 - val_root_mean_squared_error: 8.1249
# Epoch 124/150
# 28/28 [==============================] - 41s 1s/step - loss: 38.0615 - mean_squared_error: 38.0615 - mean_absolute_error: 3.0055 - root_mean_squared_error: 6.1694 - val_loss: 63.0841 - val_mean_squared_error: 63.0841 - val_mean_absolute_error: 3.7382 - val_root_mean_squared_error: 7.9425
# Epoch 125/150
# 28/28 [==============================] - 39s 1s/step - loss: 39.6955 - mean_squared_error: 39.6955 - mean_absolute_error: 3.1216 - root_mean_squared_error: 6.3004 - val_loss: 66.9250 - val_mean_squared_error: 66.9250 - val_mean_absolute_error: 3.9465 - val_root_mean_squared_error: 8.1808
# Epoch 126/150
# 28/28 [==============================] - 39s 1s/step - loss: 38.8833 - mean_squared_error: 38.8833 - mean_absolute_error: 3.0833 - root_mean_squared_error: 6.2357 - val_loss: 62.9161 - val_mean_squared_error: 62.9161 - val_mean_absolute_error: 3.8230 - val_root_mean_squared_error: 7.9320
# Epoch 127/150
# 28/28 [==============================] - 40s 1s/step - loss: 39.8047 - mean_squared_error: 39.8047 - mean_absolute_error: 3.0949 - root_mean_squared_error: 6.3091 - val_loss: 58.3815 - val_mean_squared_error: 58.3815 - val_mean_absolute_error: 3.7693 - val_root_mean_squared_error: 7.6408
# Epoch 128/150
# 28/28 [==============================] - 41s 1s/step - loss: 38.1462 - mean_squared_error: 38.1462 - mean_absolute_error: 3.0414 - root_mean_squared_error: 6.1763 - val_loss: 66.6188 - val_mean_squared_error: 66.6188 - val_mean_absolute_error: 3.9591 - val_root_mean_squared_error: 8.1620
# Epoch 129/150
# 28/28 [==============================] - 38s 1s/step - loss: 39.2332 - mean_squared_error: 39.2332 - mean_absolute_error: 3.0964 - root_mean_squared_error: 6.2636 - val_loss: 65.3298 - val_mean_squared_error: 65.3298 - val_mean_absolute_error: 3.8836 - val_root_mean_squared_error: 8.0827
# Epoch 130/150
# 28/28 [==============================] - 38s 1s/step - loss: 40.0127 - mean_squared_error: 40.0127 - mean_absolute_error: 3.1191 - root_mean_squared_error: 6.3256 - val_loss: 74.4535 - val_mean_squared_error: 74.4535 - val_mean_absolute_error: 4.1799 - val_root_mean_squared_error: 8.6286
# Epoch 131/150
# 28/28 [==============================] - 38s 1s/step - loss: 40.8132 - mean_squared_error: 40.8132 - mean_absolute_error: 3.1809 - root_mean_squared_error: 6.3885 - val_loss: 67.9769 - val_mean_squared_error: 67.9769 - val_mean_absolute_error: 4.0285 - val_root_mean_squared_error: 8.2448
# Epoch 132/150
# 28/28 [==============================] - 40s 1s/step - loss: 40.2840 - mean_squared_error: 40.2840 - mean_absolute_error: 3.1291 - root_mean_squared_error: 6.3470 - val_loss: 66.9507 - val_mean_squared_error: 66.9507 - val_mean_absolute_error: 4.1001 - val_root_mean_squared_error: 8.1823
# Epoch 133/150
# 28/28 [==============================] - 40s 1s/step - loss: 39.7868 - mean_squared_error: 39.7868 - mean_absolute_error: 3.1159 - root_mean_squared_error: 6.3077 - val_loss: 59.2065 - val_mean_squared_error: 59.2065 - val_mean_absolute_error: 3.7317 - val_root_mean_squared_error: 7.6946
# Epoch 134/150
# 28/28 [==============================] - 41s 1s/step - loss: 38.2125 - mean_squared_error: 38.2125 - mean_absolute_error: 3.0525 - root_mean_squared_error: 6.1816 - val_loss: 66.1903 - val_mean_squared_error: 66.1903 - val_mean_absolute_error: 3.9790 - val_root_mean_squared_error: 8.1357
# Epoch 135/150
# 28/28 [==============================] - 40s 1s/step - loss: 37.6195 - mean_squared_error: 37.6195 - mean_absolute_error: 3.0308 - root_mean_squared_error: 6.1335 - val_loss: 62.5696 - val_mean_squared_error: 62.5696 - val_mean_absolute_error: 3.7538 - val_root_mean_squared_error: 7.9101
# Epoch 136/150
# 28/28 [==============================] - 40s 1s/step - loss: 38.6718 - mean_squared_error: 38.6717 - mean_absolute_error: 3.0936 - root_mean_squared_error: 6.2187 - val_loss: 68.9026 - val_mean_squared_error: 68.9026 - val_mean_absolute_error: 3.9948 - val_root_mean_squared_error: 8.3008
# Epoch 137/150
# 28/28 [==============================] - 37s 1s/step - loss: 37.5877 - mean_squared_error: 37.5877 - mean_absolute_error: 3.0393 - root_mean_squared_error: 6.1309 - val_loss: 65.3823 - val_mean_squared_error: 65.3823 - val_mean_absolute_error: 3.9793 - val_root_mean_squared_error: 8.0859
# Epoch 138/150
# 28/28 [==============================] - 39s 1s/step - loss: 36.8948 - mean_squared_error: 36.8948 - mean_absolute_error: 3.0051 - root_mean_squared_error: 6.0741 - val_loss: 66.0957 - val_mean_squared_error: 66.0957 - val_mean_absolute_error: 3.9326 - val_root_mean_squared_error: 8.1299
# Epoch 139/150
# 28/28 [==============================] - 39s 1s/step - loss: 37.4917 - mean_squared_error: 37.4917 - mean_absolute_error: 3.0290 - root_mean_squared_error: 6.1230 - val_loss: 60.0658 - val_mean_squared_error: 60.0658 - val_mean_absolute_error: 3.7147 - val_root_mean_squared_error: 7.7502
# Epoch 140/150
# 28/28 [==============================] - 39s 1s/step - loss: 37.1693 - mean_squared_error: 37.1693 - mean_absolute_error: 2.9996 - root_mean_squared_error: 6.0967 - val_loss: 70.5823 - val_mean_squared_error: 70.5823 - val_mean_absolute_error: 4.1028 - val_root_mean_squared_error: 8.4013
# Epoch 141/150
# 28/28 [==============================] - 39s 1s/step - loss: 37.1333 - mean_squared_error: 37.1333 - mean_absolute_error: 3.0111 - root_mean_squared_error: 6.0937 - val_loss: 70.8775 - val_mean_squared_error: 70.8775 - val_mean_absolute_error: 4.0498 - val_root_mean_squared_error: 8.4189
# Epoch 142/150
# 28/28 [==============================] - 40s 1s/step - loss: 37.6544 - mean_squared_error: 37.6544 - mean_absolute_error: 3.0313 - root_mean_squared_error: 6.1363 - val_loss: 66.6058 - val_mean_squared_error: 66.6058 - val_mean_absolute_error: 3.8475 - val_root_mean_squared_error: 8.1612
# Epoch 143/150
# 28/28 [==============================] - 40s 1s/step - loss: 37.6545 - mean_squared_error: 37.6545 - mean_absolute_error: 3.0135 - root_mean_squared_error: 6.1363 - val_loss: 64.7317 - val_mean_squared_error: 64.7317 - val_mean_absolute_error: 3.8100 - val_root_mean_squared_error: 8.0456
# Epoch 144/150
# 28/28 [==============================] - 38s 1s/step - loss: 37.9202 - mean_squared_error: 37.9202 - mean_absolute_error: 3.0481 - root_mean_squared_error: 6.1579 - val_loss: 71.8859 - val_mean_squared_error: 71.8859 - val_mean_absolute_error: 4.1156 - val_root_mean_squared_error: 8.4786
# Epoch 145/150
# 28/28 [==============================] - 37s 1s/step - loss: 36.6869 - mean_squared_error: 36.6869 - mean_absolute_error: 2.9551 - root_mean_squared_error: 6.0570 - val_loss: 63.2293 - val_mean_squared_error: 63.2293 - val_mean_absolute_error: 3.8327 - val_root_mean_squared_error: 7.9517
# Epoch 146/150
# 28/28 [==============================] - 39s 1s/step - loss: 36.7952 - mean_squared_error: 36.7952 - mean_absolute_error: 3.0214 - root_mean_squared_error: 6.0659 - val_loss: 69.3901 - val_mean_squared_error: 69.3901 - val_mean_absolute_error: 4.0090 - val_root_mean_squared_error: 8.3301
# Epoch 147/150
# 28/28 [==============================] - 38s 1s/step - loss: 38.7946 - mean_squared_error: 38.7946 - mean_absolute_error: 3.0705 - root_mean_squared_error: 6.2285 - val_loss: 60.9776 - val_mean_squared_error: 60.9776 - val_mean_absolute_error: 3.7607 - val_root_mean_squared_error: 7.8088
# Epoch 148/150
# 28/28 [==============================] - 40s 1s/step - loss: 38.2820 - mean_squared_error: 38.2820 - mean_absolute_error: 3.0776 - root_mean_squared_error: 6.1872 - val_loss: 62.2398 - val_mean_squared_error: 62.2398 - val_mean_absolute_error: 3.8031 - val_root_mean_squared_error: 7.8892
# Epoch 149/150
# 28/28 [==============================] - 38s 1s/step - loss: 38.7913 - mean_squared_error: 38.7913 - mean_absolute_error: 3.0458 - root_mean_squared_error: 6.2283 - val_loss: 68.6991 - val_mean_squared_error: 68.6991 - val_mean_absolute_error: 3.9672 - val_root_mean_squared_error: 8.2885
# Epoch 150/150
# 28/28 [==============================] - 37s 1s/step - loss: 39.0764 - mean_squared_error: 39.0764 - mean_absolute_error: 3.1337 - root_mean_squared_error: 6.2511 - val_loss: 61.6527 - val_mean_squared_error: 61.6528 - val_mean_absolute_error: 3.7820 - val_root_mean_squared_error: 7.8519

# %% [markdown]
# # Training results

# %%
from utils.plotting import training_loss_plot

plot = training_loss_plot(train_score, filename='download/training_loss.pdf')
plot.show()

# %% [markdown]
# # Testing

# %%
### Predict on the test set
from utils.evaluation import phases_report, phases_report_std

print('Testmetriken:')

report = phases_report(y_pred, bis.test_dataset, propofolrate.test_dataset)
report
# Out:
# Testmetriken:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                  94.38       139.87           7.08         7.55
# Induction           217.37       637.60          10.94        18.34
# Maintenance          65.71        60.90           6.20         5.68
# Recovery            206.94       361.57          10.41        13.46
#
#             Prediction RMSE Baseline RMSE
# All                    9.71         11.83
# Induction             14.74         25.25
# Maintenance            8.11          7.80
# Recovery              14.39         19.02

# %%
phases_report_std(report, y_pred, bis.test_dataset, propofolrate.test_dataset)
# Out:
# All      	min: 	 15 	max: 	 6
# Induction 	min: 	 23 	max: 	 10
# Maintenance 	min: 	 13 	max: 	 6
# Recovery 	min: 	 19 	max: 	 22
#              Prediction MSE  Baseline MSE  Prediction MAE  Baseline MAE  \
# All                   48.14         82.42            1.96          2.54
# Induction            148.36        403.81            4.17          8.45
# Maintenance           36.37         43.11            1.78          2.15
# Recovery             144.25        185.95            5.25          6.28
#
#              Prediction RMSE  Baseline RMSE
# All                     2.33           3.31
# Induction               4.87           7.29
# Maintenance             2.00           2.51
# Recovery                6.07           6.47

# %%
from utils.plotting import full_histogramm_plot

plot = full_histogramm_plot(groundtruth = bis.test_dataset, prediction = y_pred, filename='download/histogramm.pdf')
plot.show()

# %%
from utils.plotting import single_prediction_plot

for case in test_index:
    single_prediction_plot(
        case = case,
        index = test_index,
        groundtruth = bis.test_dataset,
        prediction = y_pred,
        infusion = propofolrate.test_dataset,
        error = 'Prediction RMSE',
        filename = 'download/' + str(case) + '.pdf')

print('Finished')
# Out:
# /content/utils/plotting.py:79: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(12/2.54, 6/2.54))
# Finished

# %%
from utils.plotting import full_prediction_plot

full_prediction_plot(index = test_index, groundtruth = bis.test_dataset, prediction = y_pred, infusion = propofolrate.test_dataset)
