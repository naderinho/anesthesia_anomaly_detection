# %% [markdown]
# # Initialization

# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset02/'
vitaldbpath = 'vitaldb_tiva/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt
import pickle

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 467, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 467 (delta 1), reused 4 (delta 1), pack-reused 461
# Receiving objects: 100% (467/467), 79.91 MiB | 17.16 MiB/s, done.
# Resolving deltas: 100% (205/205), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.31.0)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %% [markdown]
# # Data loading

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolrate.name = 'Propofol Rate'
    propofolrate.tracks = ['Orchestra/PPF20_RATE']
    propofolrate.filterON = False
    propofolrate.generateDataset(normalization=md.NormNone)
    propofolrate.save('03_propofol_rate.npz')

    remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    remifentanilrate.name = 'Remifentanil Rate'
    remifentanilrate.tracks = ['Orchestra/RFTN20_RATE']
    remifentanilrate.filterON = False
    remifentanilrate.generateDataset(normalization=md.NormNone)
    remifentanilrate.save('03_remifentanil_rate.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolrate.load('03_propofol_rate.npz')

remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
remifentanilrate.load('03_remifentanil_rate.npz')

train_index, val_index, test_index = bis.split(np.array(bis.index))

# %% [markdown]
# # Model creation

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### LSTM layers for the blood pressure data

### Combine the vital data
vital_train = np.concatenate([bloodpressure.train_dataset, etCO2.train_dataset, spO2.train_dataset, hr.train_dataset], axis=2)
vital_validation = np.concatenate([bloodpressure.validation_dataset, etCO2.validation_dataset, spO2.validation_dataset, hr.validation_dataset], axis=2)
vital_test = np.concatenate([bloodpressure.test_dataset, etCO2.test_dataset, spO2.test_dataset, hr.test_dataset], axis=2)

### LSTM layers for the vital data
input_vital = Input(shape=(None, vital_train.shape[2]))
vital_layer = Masking(mask_value=0.0)(input_vital)

### INFO layers
input_info = Input(shape=(info.train_dataset.shape[1],))
info_layer = RepeatVector(vital_train.shape[1])(input_info)

## Concatenate the LSTM output with the info layer
comb_layer = Concatenate()([vital_layer, info_layer])
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=128, activation='relu')(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=32, activation='relu')(comb_layer)
comb_layer = BatchNormalization()(comb_layer)


output = Dense(units=1, activation='sigmoid')(comb_layer)
output = Lambda(lambda x: x * 100)(output)

# Define the model
model = Model(inputs=[input_vital, input_info], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 6)]            0         []
#
#  input_2 (InputLayer)        [(None, 5)]                  0         []
#
#  masking (Masking)           (None, None, 6)              0         ['input_1[0][0]']
#
#  repeat_vector (RepeatVecto  (None, 3680, 5)              0         ['input_2[0][0]']
#  r)
#
#  concatenate (Concatenate)   (None, 3680, 11)             0         ['masking[0][0]',
#                                                                      'repeat_vector[0][0]']
#
#  lstm (LSTM)                 (None, 3680, 32)             5632      ['concatenate[0][0]']
#
#  batch_normalization (Batch  (None, 3680, 32)             128       ['lstm[0][0]']
#  Normalization)
#
#  lstm_1 (LSTM)               (None, 3680, 32)             8320      ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 3680, 32)             128       ['lstm_1[0][0]']
#  chNormalization)
#
#  lstm_2 (LSTM)               (None, 3680, 32)             8320      ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, 3680, 32)             128       ['lstm_2[0][0]']
#  chNormalization)
#
#  dense (Dense)               (None, 3680, 128)            4224      ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  batch_normalization_3 (Bat  (None, 3680, 128)            512       ['dense[0][0]']
#  chNormalization)
#
#  dense_1 (Dense)             (None, 3680, 32)             4128      ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  batch_normalization_4 (Bat  (None, 3680, 32)             128       ['dense_1[0][0]']
#  chNormalization)
#
#  dense_2 (Dense)             (None, 3680, 1)              33        ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  lambda (Lambda)             (None, 3680, 1)              0         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 31681 (123.75 KB)
# Trainable params: 31169 (121.75 KB)
# Non-trainable params: 512 (2.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %%
# Rolling mean on BIS data
y = pd.DataFrame(bis.train_dataset[:,:,0].T).rolling(min_periods=1,window=20, center=True).mean().to_numpy().T[:,:,np.newaxis]

# Define training stop criteria
class StopTrainingCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(StopTrainingCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_loss') is not None:
            if logs.get('val_loss') < self.threshold:
                print(f"\nValidation loss is below {self.threshold}, stopping training.")
                self.model.stop_training = True

stop_training_callback = StopTrainingCallback(threshold = 35)



# Train the model
history = model.fit([vital_train, info.train_dataset],
                    y,
                    validation_data=([vital_validation, info.validation_dataset], bis.validation_dataset),
                    epochs=50,
                    batch_size=4,
                    callbacks=[stop_training_callback]
                    )

# Save the model
model.save('model.keras')

# Save the training history
train_score = history.history

with open('train_score.pkl', 'wb') as f:
    pickle.dump(train_score, f)
# Out:
# Epoch 1/50
# 28/28 [==============================] - 31s 302ms/step - loss: 279.4178 - mean_squared_error: 279.4178 - mean_absolute_error: 10.1351 - root_mean_squared_error: 16.7158 - val_loss: 956.6629 - val_mean_squared_error: 956.6628 - val_mean_absolute_error: 26.6232 - val_root_mean_squared_error: 30.9300
# Epoch 2/50
# 28/28 [==============================] - 5s 173ms/step - loss: 127.4816 - mean_squared_error: 127.4816 - mean_absolute_error: 6.7198 - root_mean_squared_error: 11.2908 - val_loss: 580.1650 - val_mean_squared_error: 580.1650 - val_mean_absolute_error: 21.1749 - val_root_mean_squared_error: 24.0866
# Epoch 3/50
# 28/28 [==============================] - 6s 203ms/step - loss: 98.3587 - mean_squared_error: 98.3587 - mean_absolute_error: 5.9859 - root_mean_squared_error: 9.9176 - val_loss: 378.2819 - val_mean_squared_error: 378.2819 - val_mean_absolute_error: 17.4185 - val_root_mean_squared_error: 19.4495
# Epoch 4/50
# 28/28 [==============================] - 5s 169ms/step - loss: 81.9891 - mean_squared_error: 81.9891 - mean_absolute_error: 5.5974 - root_mean_squared_error: 9.0548 - val_loss: 269.5227 - val_mean_squared_error: 269.5227 - val_mean_absolute_error: 14.4733 - val_root_mean_squared_error: 16.4171
# Epoch 5/50
# 28/28 [==============================] - 5s 170ms/step - loss: 73.8077 - mean_squared_error: 73.8077 - mean_absolute_error: 5.1157 - root_mean_squared_error: 8.5911 - val_loss: 201.7832 - val_mean_squared_error: 201.7832 - val_mean_absolute_error: 11.8828 - val_root_mean_squared_error: 14.2050
# Epoch 6/50
# 28/28 [==============================] - 5s 183ms/step - loss: 69.1617 - mean_squared_error: 69.1617 - mean_absolute_error: 5.0985 - root_mean_squared_error: 8.3164 - val_loss: 161.8376 - val_mean_squared_error: 161.8376 - val_mean_absolute_error: 9.8791 - val_root_mean_squared_error: 12.7215
# Epoch 7/50
# 28/28 [==============================] - 5s 168ms/step - loss: 64.4565 - mean_squared_error: 64.4565 - mean_absolute_error: 4.8087 - root_mean_squared_error: 8.0285 - val_loss: 139.5779 - val_mean_squared_error: 139.5779 - val_mean_absolute_error: 8.3795 - val_root_mean_squared_error: 11.8143
# Epoch 8/50
# 28/28 [==============================] - 6s 208ms/step - loss: 63.5800 - mean_squared_error: 63.5800 - mean_absolute_error: 4.7641 - root_mean_squared_error: 7.9737 - val_loss: 118.0863 - val_mean_squared_error: 118.0863 - val_mean_absolute_error: 7.1051 - val_root_mean_squared_error: 10.8668
# Epoch 9/50
# 28/28 [==============================] - 5s 164ms/step - loss: 60.7671 - mean_squared_error: 60.7671 - mean_absolute_error: 4.5879 - root_mean_squared_error: 7.7953 - val_loss: 104.5193 - val_mean_squared_error: 104.5193 - val_mean_absolute_error: 6.1869 - val_root_mean_squared_error: 10.2235
# Epoch 10/50
# 28/28 [==============================] - 5s 174ms/step - loss: 56.8236 - mean_squared_error: 56.8236 - mean_absolute_error: 4.4791 - root_mean_squared_error: 7.5381 - val_loss: 93.5792 - val_mean_squared_error: 93.5792 - val_mean_absolute_error: 5.6555 - val_root_mean_squared_error: 9.6736
# Epoch 11/50
# 28/28 [==============================] - 5s 191ms/step - loss: 58.3659 - mean_squared_error: 58.3659 - mean_absolute_error: 4.4766 - root_mean_squared_error: 7.6398 - val_loss: 88.7234 - val_mean_squared_error: 88.7234 - val_mean_absolute_error: 5.4169 - val_root_mean_squared_error: 9.4193
# Epoch 12/50
# 28/28 [==============================] - 5s 166ms/step - loss: 53.1774 - mean_squared_error: 53.1774 - mean_absolute_error: 4.2501 - root_mean_squared_error: 7.2923 - val_loss: 81.7856 - val_mean_squared_error: 81.7856 - val_mean_absolute_error: 4.9676 - val_root_mean_squared_error: 9.0435
# Epoch 13/50
# 28/28 [==============================] - 6s 223ms/step - loss: 53.5800 - mean_squared_error: 53.5800 - mean_absolute_error: 4.3578 - root_mean_squared_error: 7.3198 - val_loss: 75.5428 - val_mean_squared_error: 75.5428 - val_mean_absolute_error: 4.7769 - val_root_mean_squared_error: 8.6915
# Epoch 14/50
# 28/28 [==============================] - 5s 168ms/step - loss: 53.6875 - mean_squared_error: 53.6875 - mean_absolute_error: 4.2641 - root_mean_squared_error: 7.3272 - val_loss: 80.3515 - val_mean_squared_error: 80.3515 - val_mean_absolute_error: 4.9174 - val_root_mean_squared_error: 8.9639
# Epoch 15/50
# 28/28 [==============================] - 5s 170ms/step - loss: 51.4739 - mean_squared_error: 51.4739 - mean_absolute_error: 4.1379 - root_mean_squared_error: 7.1745 - val_loss: 75.3890 - val_mean_squared_error: 75.3890 - val_mean_absolute_error: 4.6438 - val_root_mean_squared_error: 8.6827
# Epoch 16/50
# 28/28 [==============================] - 6s 199ms/step - loss: 50.7540 - mean_squared_error: 50.7540 - mean_absolute_error: 4.0902 - root_mean_squared_error: 7.1242 - val_loss: 79.5481 - val_mean_squared_error: 79.5481 - val_mean_absolute_error: 4.8617 - val_root_mean_squared_error: 8.9190
# Epoch 17/50
# 28/28 [==============================] - 5s 176ms/step - loss: 51.4850 - mean_squared_error: 51.4850 - mean_absolute_error: 4.1318 - root_mean_squared_error: 7.1753 - val_loss: 75.3856 - val_mean_squared_error: 75.3856 - val_mean_absolute_error: 4.6944 - val_root_mean_squared_error: 8.6825
# Epoch 18/50
# 28/28 [==============================] - 6s 226ms/step - loss: 51.6374 - mean_squared_error: 51.6374 - mean_absolute_error: 4.1298 - root_mean_squared_error: 7.1859 - val_loss: 71.4791 - val_mean_squared_error: 71.4791 - val_mean_absolute_error: 4.4416 - val_root_mean_squared_error: 8.4545
# Epoch 19/50
# 28/28 [==============================] - 5s 174ms/step - loss: 49.9908 - mean_squared_error: 49.9908 - mean_absolute_error: 4.0339 - root_mean_squared_error: 7.0704 - val_loss: 76.8883 - val_mean_squared_error: 76.8883 - val_mean_absolute_error: 4.5972 - val_root_mean_squared_error: 8.7686
# Epoch 20/50
# 28/28 [==============================] - 5s 173ms/step - loss: 48.4002 - mean_squared_error: 48.4002 - mean_absolute_error: 3.9629 - root_mean_squared_error: 6.9570 - val_loss: 81.2177 - val_mean_squared_error: 81.2177 - val_mean_absolute_error: 4.6708 - val_root_mean_squared_error: 9.0121
# Epoch 21/50
# 28/28 [==============================] - 5s 188ms/step - loss: 48.1339 - mean_squared_error: 48.1339 - mean_absolute_error: 3.9181 - root_mean_squared_error: 6.9379 - val_loss: 80.5105 - val_mean_squared_error: 80.5105 - val_mean_absolute_error: 4.6430 - val_root_mean_squared_error: 8.9728
# Epoch 22/50
# 28/28 [==============================] - 5s 174ms/step - loss: 47.1494 - mean_squared_error: 47.1494 - mean_absolute_error: 3.9051 - root_mean_squared_error: 6.8665 - val_loss: 78.2535 - val_mean_squared_error: 78.2534 - val_mean_absolute_error: 4.4814 - val_root_mean_squared_error: 8.8461
# Epoch 23/50
# 28/28 [==============================] - 6s 203ms/step - loss: 45.9677 - mean_squared_error: 45.9677 - mean_absolute_error: 3.8220 - root_mean_squared_error: 6.7799 - val_loss: 81.3745 - val_mean_squared_error: 81.3745 - val_mean_absolute_error: 4.6868 - val_root_mean_squared_error: 9.0208
# Epoch 24/50
# 28/28 [==============================] - 5s 184ms/step - loss: 44.9289 - mean_squared_error: 44.9289 - mean_absolute_error: 3.7873 - root_mean_squared_error: 6.7029 - val_loss: 81.9336 - val_mean_squared_error: 81.9336 - val_mean_absolute_error: 4.6153 - val_root_mean_squared_error: 9.0517
# Epoch 25/50
# 28/28 [==============================] - 5s 169ms/step - loss: 45.2964 - mean_squared_error: 45.2964 - mean_absolute_error: 3.7328 - root_mean_squared_error: 6.7303 - val_loss: 77.3607 - val_mean_squared_error: 77.3607 - val_mean_absolute_error: 4.4593 - val_root_mean_squared_error: 8.7955
# Epoch 26/50
# 28/28 [==============================] - 6s 210ms/step - loss: 45.4051 - mean_squared_error: 45.4051 - mean_absolute_error: 3.7881 - root_mean_squared_error: 6.7383 - val_loss: 76.7517 - val_mean_squared_error: 76.7517 - val_mean_absolute_error: 4.4664 - val_root_mean_squared_error: 8.7608
# Epoch 27/50
# 28/28 [==============================] - 5s 164ms/step - loss: 45.2290 - mean_squared_error: 45.2290 - mean_absolute_error: 3.8114 - root_mean_squared_error: 6.7252 - val_loss: 82.2247 - val_mean_squared_error: 82.2247 - val_mean_absolute_error: 4.6459 - val_root_mean_squared_error: 9.0678
# Epoch 28/50
# 28/28 [==============================] - 6s 212ms/step - loss: 44.3821 - mean_squared_error: 44.3821 - mean_absolute_error: 3.6863 - root_mean_squared_error: 6.6620 - val_loss: 81.6064 - val_mean_squared_error: 81.6064 - val_mean_absolute_error: 4.6620 - val_root_mean_squared_error: 9.0336
# Epoch 29/50
# 28/28 [==============================] - 5s 173ms/step - loss: 45.3362 - mean_squared_error: 45.3362 - mean_absolute_error: 3.7686 - root_mean_squared_error: 6.7332 - val_loss: 80.6424 - val_mean_squared_error: 80.6424 - val_mean_absolute_error: 4.6649 - val_root_mean_squared_error: 8.9801
# Epoch 30/50
# 28/28 [==============================] - 5s 164ms/step - loss: 44.4095 - mean_squared_error: 44.4095 - mean_absolute_error: 3.7407 - root_mean_squared_error: 6.6640 - val_loss: 77.0903 - val_mean_squared_error: 77.0903 - val_mean_absolute_error: 4.5557 - val_root_mean_squared_error: 8.7801
# Epoch 31/50
# 28/28 [==============================] - 6s 206ms/step - loss: 45.8718 - mean_squared_error: 45.8718 - mean_absolute_error: 3.7478 - root_mean_squared_error: 6.7729 - val_loss: 76.2533 - val_mean_squared_error: 76.2533 - val_mean_absolute_error: 4.6265 - val_root_mean_squared_error: 8.7323
# Epoch 32/50
# 28/28 [==============================] - 5s 182ms/step - loss: 44.6546 - mean_squared_error: 44.6546 - mean_absolute_error: 3.7506 - root_mean_squared_error: 6.6824 - val_loss: 76.2619 - val_mean_squared_error: 76.2619 - val_mean_absolute_error: 4.4259 - val_root_mean_squared_error: 8.7328
# Epoch 33/50
# 28/28 [==============================] - 6s 198ms/step - loss: 44.9796 - mean_squared_error: 44.9796 - mean_absolute_error: 3.7129 - root_mean_squared_error: 6.7067 - val_loss: 76.2452 - val_mean_squared_error: 76.2452 - val_mean_absolute_error: 4.6648 - val_root_mean_squared_error: 8.7319
# Epoch 34/50
# 28/28 [==============================] - 5s 163ms/step - loss: 42.8219 - mean_squared_error: 42.8219 - mean_absolute_error: 3.6785 - root_mean_squared_error: 6.5438 - val_loss: 83.2537 - val_mean_squared_error: 83.2537 - val_mean_absolute_error: 4.5662 - val_root_mean_squared_error: 9.1243
# Epoch 35/50
# 28/28 [==============================] - 5s 178ms/step - loss: 43.1850 - mean_squared_error: 43.1850 - mean_absolute_error: 3.6203 - root_mean_squared_error: 6.5715 - val_loss: 79.1398 - val_mean_squared_error: 79.1398 - val_mean_absolute_error: 4.6667 - val_root_mean_squared_error: 8.8961
# Epoch 36/50
# 28/28 [==============================] - 5s 191ms/step - loss: 43.5444 - mean_squared_error: 43.5444 - mean_absolute_error: 3.6412 - root_mean_squared_error: 6.5988 - val_loss: 68.7070 - val_mean_squared_error: 68.7070 - val_mean_absolute_error: 4.3624 - val_root_mean_squared_error: 8.2890
# Epoch 37/50
# 28/28 [==============================] - 5s 171ms/step - loss: 42.1314 - mean_squared_error: 42.1314 - mean_absolute_error: 3.6562 - root_mean_squared_error: 6.4909 - val_loss: 68.3543 - val_mean_squared_error: 68.3543 - val_mean_absolute_error: 4.3275 - val_root_mean_squared_error: 8.2677
# Epoch 38/50
# 28/28 [==============================] - 6s 210ms/step - loss: 42.1235 - mean_squared_error: 42.1235 - mean_absolute_error: 3.5898 - root_mean_squared_error: 6.4903 - val_loss: 68.1378 - val_mean_squared_error: 68.1378 - val_mean_absolute_error: 4.2544 - val_root_mean_squared_error: 8.2546
# Epoch 39/50
# 28/28 [==============================] - 5s 175ms/step - loss: 42.3360 - mean_squared_error: 42.3360 - mean_absolute_error: 3.5535 - root_mean_squared_error: 6.5066 - val_loss: 67.7374 - val_mean_squared_error: 67.7374 - val_mean_absolute_error: 4.2892 - val_root_mean_squared_error: 8.2303
# Epoch 40/50
# 28/28 [==============================] - 5s 165ms/step - loss: 41.6969 - mean_squared_error: 41.6969 - mean_absolute_error: 3.5363 - root_mean_squared_error: 6.4573 - val_loss: 70.6880 - val_mean_squared_error: 70.6880 - val_mean_absolute_error: 4.3925 - val_root_mean_squared_error: 8.4076
# Epoch 41/50
# 28/28 [==============================] - 6s 207ms/step - loss: 40.8272 - mean_squared_error: 40.8272 - mean_absolute_error: 3.5355 - root_mean_squared_error: 6.3896 - val_loss: 77.9218 - val_mean_squared_error: 77.9218 - val_mean_absolute_error: 4.5968 - val_root_mean_squared_error: 8.8273
# Epoch 42/50
# 28/28 [==============================] - 5s 163ms/step - loss: 42.4406 - mean_squared_error: 42.4406 - mean_absolute_error: 3.5564 - root_mean_squared_error: 6.5146 - val_loss: 71.3107 - val_mean_squared_error: 71.3107 - val_mean_absolute_error: 4.3740 - val_root_mean_squared_error: 8.4446
# Epoch 43/50
# 28/28 [==============================] - 5s 185ms/step - loss: 41.5966 - mean_squared_error: 41.5966 - mean_absolute_error: 3.5662 - root_mean_squared_error: 6.4495 - val_loss: 74.6993 - val_mean_squared_error: 74.6993 - val_mean_absolute_error: 4.5155 - val_root_mean_squared_error: 8.6429
# Epoch 44/50
# 28/28 [==============================] - 5s 184ms/step - loss: 41.3514 - mean_squared_error: 41.3514 - mean_absolute_error: 3.5551 - root_mean_squared_error: 6.4305 - val_loss: 71.8849 - val_mean_squared_error: 71.8849 - val_mean_absolute_error: 4.3414 - val_root_mean_squared_error: 8.4785
# Epoch 45/50
# 28/28 [==============================] - 5s 164ms/step - loss: 42.6455 - mean_squared_error: 42.6455 - mean_absolute_error: 3.6562 - root_mean_squared_error: 6.5303 - val_loss: 78.6124 - val_mean_squared_error: 78.6124 - val_mean_absolute_error: 4.6305 - val_root_mean_squared_error: 8.8664
# Epoch 46/50
# 28/28 [==============================] - 6s 209ms/step - loss: 40.9002 - mean_squared_error: 40.9002 - mean_absolute_error: 3.5291 - root_mean_squared_error: 6.3953 - val_loss: 80.9786 - val_mean_squared_error: 80.9786 - val_mean_absolute_error: 4.5732 - val_root_mean_squared_error: 8.9988
# Epoch 47/50
# 28/28 [==============================] - 5s 176ms/step - loss: 40.5270 - mean_squared_error: 40.5270 - mean_absolute_error: 3.4724 - root_mean_squared_error: 6.3661 - val_loss: 73.6664 - val_mean_squared_error: 73.6664 - val_mean_absolute_error: 4.4316 - val_root_mean_squared_error: 8.5829
# Epoch 48/50
# 28/28 [==============================] - 5s 191ms/step - loss: 40.7595 - mean_squared_error: 40.7595 - mean_absolute_error: 3.5204 - root_mean_squared_error: 6.3843 - val_loss: 79.7844 - val_mean_squared_error: 79.7844 - val_mean_absolute_error: 4.4403 - val_root_mean_squared_error: 8.9322
# Epoch 49/50
# 28/28 [==============================] - 5s 184ms/step - loss: 42.0843 - mean_squared_error: 42.0843 - mean_absolute_error: 3.5816 - root_mean_squared_error: 6.4872 - val_loss: 73.4330 - val_mean_squared_error: 73.4330 - val_mean_absolute_error: 4.3196 - val_root_mean_squared_error: 8.5693
# Epoch 50/50
# 28/28 [==============================] - 5s 165ms/step - loss: 39.5001 - mean_squared_error: 39.5001 - mean_absolute_error: 3.4083 - root_mean_squared_error: 6.2849 - val_loss: 71.1879 - val_mean_squared_error: 71.1879 - val_mean_absolute_error: 4.3578 - val_root_mean_squared_error: 8.4373

# %% [markdown]
# # Training results

# %%
from utils.plotting import training_loss_plot

with open('train_score.pkl', 'rb') as f:
    train_score = pickle.load(f)

plot = training_loss_plot(train_score)
plot.show()

# %% [markdown]
# # Testing

# %%
### Predict on the test set
from utils.evaluation import phases_report, phases_report_std

y_pred = model.predict([vital_test, info.test_dataset], verbose=0)

print('Testmetriken:')

report = phases_report(y_pred, bis.test_dataset, propofolrate.test_dataset)
report
# Out:
# Testmetriken:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                 110.09       139.87           7.67         7.55
# Induction           287.78       637.60          12.93        18.34
# Maintenance          73.24        60.90           6.59         5.68
# Recovery            240.28       361.57          11.32        13.46
#
#             Prediction RMSE Baseline RMSE
# All                   10.49         11.83
# Induction             16.96         25.25
# Maintenance            8.56          7.80
# Recovery              15.50         19.02

# %%
phases_report_std(report, y_pred, bis.test_dataset, propofolrate.test_dataset)
# Out:
#              Prediction MSE  Baseline MSE  Prediction MAE  Baseline MAE  \
# All                   55.11         82.42            1.83          2.54
# Induction            287.44        403.81            6.28          8.45
# Maintenance           30.91         43.11            1.68          2.15
# Recovery             125.09        185.95            4.37          6.28
#
#              Prediction RMSE  Baseline RMSE
# All                     2.41           3.31
# Induction               6.65           7.29
# Maintenance             1.80           2.51
# Recovery                5.28           6.47

# %%
from utils.plotting import full_histogramm_plot

plot = full_histogramm_plot(groundtruth = bis.test_dataset, prediction = y_pred)
plot.show()

# %%
from utils.plotting import single_prediction_plot

plot = single_prediction_plot(
    case = 3270,
    index = test_index,
    groundtruth = bis.test_dataset,
    prediction = y_pred,
    infusion = propofolrate.test_dataset,
    error = 'Prediction RMSE',
    filename = None)

plot.show()

# %%
from utils.plotting import full_prediction_plot

full_prediction_plot(index = test_index, groundtruth = bis.test_dataset, prediction = y_pred, infusion = propofolrate.test_dataset)
