# %% [markdown]
# # Initialization

# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset02/'
vitaldbpath = 'vitaldb_tiva/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt
import pickle

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 630, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 630 (delta 87), reused 169 (delta 87), pack-reused 461
# Receiving objects: 100% (630/630), 124.94 MiB | 27.31 MiB/s, done.
# Resolving deltas: 100% (291/291), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl.metadata (520 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.31.0)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.2 MB/s eta 0:00:00
# Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 8.4 MB/s eta 0:00:00
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %% [markdown]
# # Data loading

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolrate.name = 'Propofol Rate'
    propofolrate.tracks = ['Orchestra/PPF20_RATE']
    propofolrate.filterON = False
    propofolrate.generateDataset(normalization=md.NormNone)
    propofolrate.save('03_propofol_rate.npz')

    remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    remifentanilrate.name = 'Remifentanil Rate'
    remifentanilrate.tracks = ['Orchestra/RFTN20_RATE']
    remifentanilrate.filterON = False
    remifentanilrate.generateDataset(normalization=md.NormNone)
    remifentanilrate.save('03_remifentanil_rate.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolrate.load('03_propofol_rate.npz')

remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
remifentanilrate.load('03_remifentanil_rate.npz')

train_index, val_index, test_index = bis.split(np.array(bis.index))

# %% [markdown]
# # Model creation

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### LSTM layers for the blood pressure data

### Combine the vital data
vital_train = np.concatenate([bloodpressure.train_dataset, etCO2.train_dataset, spO2.train_dataset, hr.train_dataset], axis=2)
vital_validation = np.concatenate([bloodpressure.validation_dataset, etCO2.validation_dataset, spO2.validation_dataset, hr.validation_dataset], axis=2)
vital_test = np.concatenate([bloodpressure.test_dataset, etCO2.test_dataset, spO2.test_dataset, hr.test_dataset], axis=2)

### LSTM layers for the vital data
input_vital = Input(shape=(None, vital_train.shape[2]))
vital_layer = Masking(mask_value=0.0)(input_vital)

### INFO layers
input_info = Input(shape=(info.train_dataset.shape[1],))
info_layer = RepeatVector(vital_train.shape[1])(input_info)

## Concatenate the LSTM output with the info layer
comb_layer = Concatenate()([vital_layer, info_layer])
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=128, activation='relu')(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=32, activation='relu')(comb_layer)
comb_layer = BatchNormalization()(comb_layer)


output = Dense(units=1, activation=ReLU(max_value=1.0))(comb_layer)
output = Lambda(lambda x: x * 100)(output)

# Define the model
model = Model(inputs=[input_vital, input_info], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 6)]            0         []
#
#  input_2 (InputLayer)        [(None, 5)]                  0         []
#
#  masking (Masking)           (None, None, 6)              0         ['input_1[0][0]']
#
#  repeat_vector (RepeatVecto  (None, 3680, 5)              0         ['input_2[0][0]']
#  r)
#
#  concatenate (Concatenate)   (None, 3680, 11)             0         ['masking[0][0]',
#                                                                      'repeat_vector[0][0]']
#
#  lstm (LSTM)                 (None, 3680, 32)             5632      ['concatenate[0][0]']
#
#  batch_normalization (Batch  (None, 3680, 32)             128       ['lstm[0][0]']
#  Normalization)
#
#  lstm_1 (LSTM)               (None, 3680, 32)             8320      ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 3680, 32)             128       ['lstm_1[0][0]']
#  chNormalization)
#
#  lstm_2 (LSTM)               (None, 3680, 32)             8320      ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, 3680, 32)             128       ['lstm_2[0][0]']
#  chNormalization)
#
#  dense (Dense)               (None, 3680, 128)            4224      ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  batch_normalization_3 (Bat  (None, 3680, 128)            512       ['dense[0][0]']
#  chNormalization)
#
#  dense_1 (Dense)             (None, 3680, 32)             4128      ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  batch_normalization_4 (Bat  (None, 3680, 32)             128       ['dense_1[0][0]']
#  chNormalization)
#
#  dense_2 (Dense)             (None, 3680, 1)              33        ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  lambda (Lambda)             (None, 3680, 1)              0         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 31681 (123.75 KB)
# Trainable params: 31169 (121.75 KB)
# Non-trainable params: 512 (2.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %%
# Rolling mean on BIS data
y = pd.DataFrame(bis.train_dataset[:,:,0].T).rolling(min_periods=1,window=20, center=True).mean().to_numpy().T[:,:,np.newaxis]

# Define training stop criteria
class StopTrainingCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(StopTrainingCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_loss') is not None:
            if logs.get('val_loss') < self.threshold:
                print(f"\nValidation loss is below {self.threshold}, stopping training.")
                self.model.stop_training = True

stop_training_callback = StopTrainingCallback(threshold = 35)


if in_google_colab():
    # Train the model
    history = model.fit([vital_train, info.train_dataset],
                        y,
                        validation_data=([vital_validation, info.validation_dataset], bis.validation_dataset),
                        epochs=100,
                        batch_size=4,
                        callbacks=[stop_training_callback]
                        )

    train_score = history.history

    # Save the model
    model.save('download/model.keras')

    # Save the training history
    with open('download/train_score.pkl', 'wb') as f:
        pickle.dump(train_score, f)

    # Save the prediction
    y_pred = model.predict([vital_test, info.test_dataset], verbose=0)
    with open('download/prediction.pkl', 'wb') as f:
        pickle.dump(y_pred, f)

else:
    # Load train score data
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

    # Load test prediction data
    with open('prediction.pkl', 'rb') as f:
        y_pred = pickle.load(f)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 30s 325ms/step - loss: 793.1434 - mean_squared_error: 793.1433 - mean_absolute_error: 17.2591 - root_mean_squared_error: 28.1628 - val_loss: 836.7848 - val_mean_squared_error: 836.7849 - val_mean_absolute_error: 17.6631 - val_root_mean_squared_error: 28.9272
# Epoch 2/100
# 28/28 [==============================] - 6s 202ms/step - loss: 692.3365 - mean_squared_error: 692.3364 - mean_absolute_error: 15.5965 - root_mean_squared_error: 26.3123 - val_loss: 836.7848 - val_mean_squared_error: 836.7849 - val_mean_absolute_error: 17.6631 - val_root_mean_squared_error: 28.9272
# Epoch 3/100
# 28/28 [==============================] - 6s 228ms/step - loss: 619.9357 - mean_squared_error: 619.9358 - mean_absolute_error: 14.5890 - root_mean_squared_error: 24.8985 - val_loss: 836.7848 - val_mean_squared_error: 836.7849 - val_mean_absolute_error: 17.6631 - val_root_mean_squared_error: 28.9272
# Epoch 4/100
# 28/28 [==============================] - 5s 197ms/step - loss: 493.2975 - mean_squared_error: 493.2975 - mean_absolute_error: 12.4364 - root_mean_squared_error: 22.2103 - val_loss: 836.7848 - val_mean_squared_error: 836.7849 - val_mean_absolute_error: 17.6631 - val_root_mean_squared_error: 28.9272
# Epoch 5/100
# 28/28 [==============================] - 6s 229ms/step - loss: 350.9054 - mean_squared_error: 350.9055 - mean_absolute_error: 9.9232 - root_mean_squared_error: 18.7325 - val_loss: 829.7163 - val_mean_squared_error: 829.7163 - val_mean_absolute_error: 17.5682 - val_root_mean_squared_error: 28.8048
# Epoch 6/100
# 28/28 [==============================] - 5s 185ms/step - loss: 221.7103 - mean_squared_error: 221.7103 - mean_absolute_error: 7.4837 - root_mean_squared_error: 14.8899 - val_loss: 668.4480 - val_mean_squared_error: 668.4480 - val_mean_absolute_error: 15.2305 - val_root_mean_squared_error: 25.8544
# Epoch 7/100
# 28/28 [==============================] - 6s 208ms/step - loss: 177.4941 - mean_squared_error: 177.4941 - mean_absolute_error: 6.9240 - root_mean_squared_error: 13.3227 - val_loss: 476.1876 - val_mean_squared_error: 476.1876 - val_mean_absolute_error: 12.0871 - val_root_mean_squared_error: 21.8217
# Epoch 8/100
# 28/28 [==============================] - 6s 209ms/step - loss: 152.1656 - mean_squared_error: 152.1656 - mean_absolute_error: 6.0497 - root_mean_squared_error: 12.3355 - val_loss: 350.9902 - val_mean_squared_error: 350.9902 - val_mean_absolute_error: 9.9016 - val_root_mean_squared_error: 18.7347
# Epoch 9/100
# 28/28 [==============================] - 5s 198ms/step - loss: 121.3825 - mean_squared_error: 121.3825 - mean_absolute_error: 5.4516 - root_mean_squared_error: 11.0174 - val_loss: 212.6222 - val_mean_squared_error: 212.6222 - val_mean_absolute_error: 7.0100 - val_root_mean_squared_error: 14.5816
# Epoch 10/100
# 28/28 [==============================] - 6s 223ms/step - loss: 106.1372 - mean_squared_error: 106.1372 - mean_absolute_error: 5.1502 - root_mean_squared_error: 10.3023 - val_loss: 153.7789 - val_mean_squared_error: 153.7789 - val_mean_absolute_error: 5.6884 - val_root_mean_squared_error: 12.4008
# Epoch 11/100
# 28/28 [==============================] - 5s 197ms/step - loss: 103.7803 - mean_squared_error: 103.7803 - mean_absolute_error: 5.2464 - root_mean_squared_error: 10.1873 - val_loss: 124.4847 - val_mean_squared_error: 124.4847 - val_mean_absolute_error: 5.2675 - val_root_mean_squared_error: 11.1573
# Epoch 12/100
# 28/28 [==============================] - 6s 218ms/step - loss: 93.4175 - mean_squared_error: 93.4175 - mean_absolute_error: 4.7885 - root_mean_squared_error: 9.6653 - val_loss: 109.9225 - val_mean_squared_error: 109.9225 - val_mean_absolute_error: 4.8075 - val_root_mean_squared_error: 10.4844
# Epoch 13/100
# 28/28 [==============================] - 5s 187ms/step - loss: 83.9108 - mean_squared_error: 83.9108 - mean_absolute_error: 4.5534 - root_mean_squared_error: 9.1603 - val_loss: 89.9458 - val_mean_squared_error: 89.9458 - val_mean_absolute_error: 4.3983 - val_root_mean_squared_error: 9.4840
# Epoch 14/100
# 28/28 [==============================] - 6s 226ms/step - loss: 71.3124 - mean_squared_error: 71.3124 - mean_absolute_error: 4.1624 - root_mean_squared_error: 8.4447 - val_loss: 85.2278 - val_mean_squared_error: 85.2278 - val_mean_absolute_error: 4.2568 - val_root_mean_squared_error: 9.2319
# Epoch 15/100
# 28/28 [==============================] - 5s 187ms/step - loss: 69.6168 - mean_squared_error: 69.6168 - mean_absolute_error: 4.1803 - root_mean_squared_error: 8.3437 - val_loss: 84.9821 - val_mean_squared_error: 84.9821 - val_mean_absolute_error: 4.3916 - val_root_mean_squared_error: 9.2186
# Epoch 16/100
# 28/28 [==============================] - 6s 230ms/step - loss: 72.2509 - mean_squared_error: 72.2509 - mean_absolute_error: 4.2691 - root_mean_squared_error: 8.5000 - val_loss: 96.8628 - val_mean_squared_error: 96.8628 - val_mean_absolute_error: 4.6399 - val_root_mean_squared_error: 9.8419
# Epoch 17/100
# 28/28 [==============================] - 5s 190ms/step - loss: 64.1627 - mean_squared_error: 64.1627 - mean_absolute_error: 3.9998 - root_mean_squared_error: 8.0102 - val_loss: 80.9483 - val_mean_squared_error: 80.9483 - val_mean_absolute_error: 4.3125 - val_root_mean_squared_error: 8.9971
# Epoch 18/100
# 28/28 [==============================] - 8s 273ms/step - loss: 70.3478 - mean_squared_error: 70.3478 - mean_absolute_error: 4.2490 - root_mean_squared_error: 8.3874 - val_loss: 88.7006 - val_mean_squared_error: 88.7006 - val_mean_absolute_error: 4.6250 - val_root_mean_squared_error: 9.4181
# Epoch 19/100
# 28/28 [==============================] - 6s 204ms/step - loss: 65.6799 - mean_squared_error: 65.6799 - mean_absolute_error: 4.0461 - root_mean_squared_error: 8.1043 - val_loss: 79.2780 - val_mean_squared_error: 79.2780 - val_mean_absolute_error: 4.2769 - val_root_mean_squared_error: 8.9038
# Epoch 20/100
# 28/28 [==============================] - 6s 221ms/step - loss: 61.5161 - mean_squared_error: 61.5161 - mean_absolute_error: 3.8447 - root_mean_squared_error: 7.8432 - val_loss: 74.8734 - val_mean_squared_error: 74.8734 - val_mean_absolute_error: 4.1204 - val_root_mean_squared_error: 8.6529
# Epoch 21/100
# 28/28 [==============================] - 6s 204ms/step - loss: 60.0964 - mean_squared_error: 60.0964 - mean_absolute_error: 3.8497 - root_mean_squared_error: 7.7522 - val_loss: 79.5790 - val_mean_squared_error: 79.5790 - val_mean_absolute_error: 4.2562 - val_root_mean_squared_error: 8.9207
# Epoch 22/100
# 28/28 [==============================] - 5s 188ms/step - loss: 60.7926 - mean_squared_error: 60.7926 - mean_absolute_error: 3.9464 - root_mean_squared_error: 7.7970 - val_loss: 77.0735 - val_mean_squared_error: 77.0735 - val_mean_absolute_error: 4.2984 - val_root_mean_squared_error: 8.7792
# Epoch 23/100
# 28/28 [==============================] - 6s 231ms/step - loss: 59.7641 - mean_squared_error: 59.7641 - mean_absolute_error: 3.8683 - root_mean_squared_error: 7.7307 - val_loss: 74.0247 - val_mean_squared_error: 74.0248 - val_mean_absolute_error: 4.1949 - val_root_mean_squared_error: 8.6038
# Epoch 24/100
# 28/28 [==============================] - 6s 200ms/step - loss: 57.6413 - mean_squared_error: 57.6413 - mean_absolute_error: 3.7830 - root_mean_squared_error: 7.5922 - val_loss: 81.2301 - val_mean_squared_error: 81.2301 - val_mean_absolute_error: 4.4383 - val_root_mean_squared_error: 9.0128
# Epoch 25/100
# 28/28 [==============================] - 6s 225ms/step - loss: 58.3151 - mean_squared_error: 58.3150 - mean_absolute_error: 3.7495 - root_mean_squared_error: 7.6364 - val_loss: 78.7318 - val_mean_squared_error: 78.7318 - val_mean_absolute_error: 4.3679 - val_root_mean_squared_error: 8.8731
# Epoch 26/100
# 28/28 [==============================] - 5s 189ms/step - loss: 55.7266 - mean_squared_error: 55.7266 - mean_absolute_error: 3.6819 - root_mean_squared_error: 7.4650 - val_loss: 76.7689 - val_mean_squared_error: 76.7689 - val_mean_absolute_error: 4.2367 - val_root_mean_squared_error: 8.7618
# Epoch 27/100
# 28/28 [==============================] - 6s 222ms/step - loss: 55.1678 - mean_squared_error: 55.1678 - mean_absolute_error: 3.6651 - root_mean_squared_error: 7.4275 - val_loss: 71.3007 - val_mean_squared_error: 71.3007 - val_mean_absolute_error: 4.0523 - val_root_mean_squared_error: 8.4440
# Epoch 28/100
# 28/28 [==============================] - 5s 187ms/step - loss: 53.4870 - mean_squared_error: 53.4870 - mean_absolute_error: 3.5878 - root_mean_squared_error: 7.3135 - val_loss: 81.1163 - val_mean_squared_error: 81.1163 - val_mean_absolute_error: 4.3214 - val_root_mean_squared_error: 9.0065
# Epoch 29/100
# 28/28 [==============================] - 6s 213ms/step - loss: 54.4574 - mean_squared_error: 54.4574 - mean_absolute_error: 3.6467 - root_mean_squared_error: 7.3795 - val_loss: 72.9692 - val_mean_squared_error: 72.9692 - val_mean_absolute_error: 4.1489 - val_root_mean_squared_error: 8.5422
# Epoch 30/100
# 28/28 [==============================] - 6s 194ms/step - loss: 51.4730 - mean_squared_error: 51.4730 - mean_absolute_error: 3.5254 - root_mean_squared_error: 7.1745 - val_loss: 80.0862 - val_mean_squared_error: 80.0862 - val_mean_absolute_error: 4.4360 - val_root_mean_squared_error: 8.9491
# Epoch 31/100
# 28/28 [==============================] - 5s 193ms/step - loss: 53.2743 - mean_squared_error: 53.2743 - mean_absolute_error: 3.6165 - root_mean_squared_error: 7.2989 - val_loss: 77.0800 - val_mean_squared_error: 77.0800 - val_mean_absolute_error: 4.2948 - val_root_mean_squared_error: 8.7795
# Epoch 32/100
# 28/28 [==============================] - 6s 217ms/step - loss: 53.0699 - mean_squared_error: 53.0699 - mean_absolute_error: 3.6036 - root_mean_squared_error: 7.2849 - val_loss: 86.5027 - val_mean_squared_error: 86.5027 - val_mean_absolute_error: 4.5300 - val_root_mean_squared_error: 9.3007
# Epoch 33/100
# 28/28 [==============================] - 6s 201ms/step - loss: 52.2571 - mean_squared_error: 52.2571 - mean_absolute_error: 3.6025 - root_mean_squared_error: 7.2289 - val_loss: 75.1041 - val_mean_squared_error: 75.1041 - val_mean_absolute_error: 4.1047 - val_root_mean_squared_error: 8.6663
# Epoch 34/100
# 28/28 [==============================] - 6s 227ms/step - loss: 54.9451 - mean_squared_error: 54.9451 - mean_absolute_error: 3.6964 - root_mean_squared_error: 7.4125 - val_loss: 73.0193 - val_mean_squared_error: 73.0193 - val_mean_absolute_error: 3.9876 - val_root_mean_squared_error: 8.5451
# Epoch 35/100
# 28/28 [==============================] - 5s 188ms/step - loss: 51.9413 - mean_squared_error: 51.9413 - mean_absolute_error: 3.5559 - root_mean_squared_error: 7.2070 - val_loss: 76.3361 - val_mean_squared_error: 76.3361 - val_mean_absolute_error: 4.1233 - val_root_mean_squared_error: 8.7371
# Epoch 36/100
# 28/28 [==============================] - 6s 221ms/step - loss: 52.5188 - mean_squared_error: 52.5188 - mean_absolute_error: 3.6063 - root_mean_squared_error: 7.2470 - val_loss: 68.3730 - val_mean_squared_error: 68.3730 - val_mean_absolute_error: 3.9441 - val_root_mean_squared_error: 8.2688
# Epoch 37/100
# 28/28 [==============================] - 5s 197ms/step - loss: 50.0236 - mean_squared_error: 50.0236 - mean_absolute_error: 3.5286 - root_mean_squared_error: 7.0727 - val_loss: 73.2663 - val_mean_squared_error: 73.2663 - val_mean_absolute_error: 4.1551 - val_root_mean_squared_error: 8.5596
# Epoch 38/100
# 28/28 [==============================] - 6s 222ms/step - loss: 51.3803 - mean_squared_error: 51.3803 - mean_absolute_error: 3.4654 - root_mean_squared_error: 7.1680 - val_loss: 71.9654 - val_mean_squared_error: 71.9654 - val_mean_absolute_error: 4.0910 - val_root_mean_squared_error: 8.4832
# Epoch 39/100
# 28/28 [==============================] - 5s 198ms/step - loss: 50.9682 - mean_squared_error: 50.9682 - mean_absolute_error: 3.4834 - root_mean_squared_error: 7.1392 - val_loss: 76.9171 - val_mean_squared_error: 76.9171 - val_mean_absolute_error: 4.2985 - val_root_mean_squared_error: 8.7702
# Epoch 40/100
# 28/28 [==============================] - 6s 207ms/step - loss: 52.0012 - mean_squared_error: 52.0012 - mean_absolute_error: 3.6172 - root_mean_squared_error: 7.2112 - val_loss: 64.7629 - val_mean_squared_error: 64.7629 - val_mean_absolute_error: 3.8296 - val_root_mean_squared_error: 8.0475
# Epoch 41/100
# 28/28 [==============================] - 7s 245ms/step - loss: 51.5197 - mean_squared_error: 51.5197 - mean_absolute_error: 3.5830 - root_mean_squared_error: 7.1777 - val_loss: 69.7514 - val_mean_squared_error: 69.7514 - val_mean_absolute_error: 4.0370 - val_root_mean_squared_error: 8.3517
# Epoch 42/100
# 28/28 [==============================] - 5s 187ms/step - loss: 57.3323 - mean_squared_error: 57.3323 - mean_absolute_error: 3.8217 - root_mean_squared_error: 7.5718 - val_loss: 72.9632 - val_mean_squared_error: 72.9632 - val_mean_absolute_error: 4.2709 - val_root_mean_squared_error: 8.5419
# Epoch 43/100
# 28/28 [==============================] - 6s 225ms/step - loss: 53.7160 - mean_squared_error: 53.7160 - mean_absolute_error: 3.6372 - root_mean_squared_error: 7.3291 - val_loss: 71.9320 - val_mean_squared_error: 71.9320 - val_mean_absolute_error: 4.1550 - val_root_mean_squared_error: 8.4813
# Epoch 44/100
# 28/28 [==============================] - 6s 199ms/step - loss: 50.5069 - mean_squared_error: 50.5069 - mean_absolute_error: 3.5042 - root_mean_squared_error: 7.1068 - val_loss: 70.0204 - val_mean_squared_error: 70.0204 - val_mean_absolute_error: 4.0209 - val_root_mean_squared_error: 8.3678
# Epoch 45/100
# 28/28 [==============================] - 6s 233ms/step - loss: 49.9516 - mean_squared_error: 49.9516 - mean_absolute_error: 3.4845 - root_mean_squared_error: 7.0676 - val_loss: 80.5366 - val_mean_squared_error: 80.5366 - val_mean_absolute_error: 4.3725 - val_root_mean_squared_error: 8.9742
# Epoch 46/100
# 28/28 [==============================] - 5s 189ms/step - loss: 50.3222 - mean_squared_error: 50.3222 - mean_absolute_error: 3.4987 - root_mean_squared_error: 7.0938 - val_loss: 68.9269 - val_mean_squared_error: 68.9269 - val_mean_absolute_error: 4.0357 - val_root_mean_squared_error: 8.3022
# Epoch 47/100
# 28/28 [==============================] - 6s 219ms/step - loss: 47.7632 - mean_squared_error: 47.7632 - mean_absolute_error: 3.4212 - root_mean_squared_error: 6.9111 - val_loss: 68.5319 - val_mean_squared_error: 68.5319 - val_mean_absolute_error: 3.8585 - val_root_mean_squared_error: 8.2784
# Epoch 48/100
# 28/28 [==============================] - 6s 197ms/step - loss: 48.0356 - mean_squared_error: 48.0356 - mean_absolute_error: 3.4206 - root_mean_squared_error: 6.9308 - val_loss: 70.6029 - val_mean_squared_error: 70.6030 - val_mean_absolute_error: 4.0837 - val_root_mean_squared_error: 8.4026
# Epoch 49/100
# 28/28 [==============================] - 6s 219ms/step - loss: 48.4812 - mean_squared_error: 48.4812 - mean_absolute_error: 3.4559 - root_mean_squared_error: 6.9628 - val_loss: 74.1289 - val_mean_squared_error: 74.1289 - val_mean_absolute_error: 4.1577 - val_root_mean_squared_error: 8.6098
# Epoch 50/100
# 28/28 [==============================] - 5s 191ms/step - loss: 47.8138 - mean_squared_error: 47.8138 - mean_absolute_error: 3.4056 - root_mean_squared_error: 6.9148 - val_loss: 85.0226 - val_mean_squared_error: 85.0227 - val_mean_absolute_error: 4.4860 - val_root_mean_squared_error: 9.2208
# Epoch 51/100
# 28/28 [==============================] - 6s 212ms/step - loss: 48.5328 - mean_squared_error: 48.5328 - mean_absolute_error: 3.4510 - root_mean_squared_error: 6.9665 - val_loss: 69.2106 - val_mean_squared_error: 69.2106 - val_mean_absolute_error: 4.0432 - val_root_mean_squared_error: 8.3193
# Epoch 52/100
# 28/28 [==============================] - 6s 208ms/step - loss: 45.8726 - mean_squared_error: 45.8726 - mean_absolute_error: 3.3829 - root_mean_squared_error: 6.7729 - val_loss: 72.1955 - val_mean_squared_error: 72.1955 - val_mean_absolute_error: 4.1719 - val_root_mean_squared_error: 8.4968
# Epoch 53/100
# 28/28 [==============================] - 5s 185ms/step - loss: 46.6633 - mean_squared_error: 46.6633 - mean_absolute_error: 3.3470 - root_mean_squared_error: 6.8311 - val_loss: 72.3988 - val_mean_squared_error: 72.3988 - val_mean_absolute_error: 4.1078 - val_root_mean_squared_error: 8.5087
# Epoch 54/100
# 28/28 [==============================] - 6s 222ms/step - loss: 47.9811 - mean_squared_error: 47.9811 - mean_absolute_error: 3.5155 - root_mean_squared_error: 6.9268 - val_loss: 78.3072 - val_mean_squared_error: 78.3072 - val_mean_absolute_error: 4.2587 - val_root_mean_squared_error: 8.8491
# Epoch 55/100
# 28/28 [==============================] - 6s 199ms/step - loss: 50.1670 - mean_squared_error: 50.1670 - mean_absolute_error: 3.5295 - root_mean_squared_error: 7.0829 - val_loss: 71.9657 - val_mean_squared_error: 71.9657 - val_mean_absolute_error: 3.9734 - val_root_mean_squared_error: 8.4833
# Epoch 56/100
# 28/28 [==============================] - 6s 218ms/step - loss: 48.4619 - mean_squared_error: 48.4619 - mean_absolute_error: 3.4562 - root_mean_squared_error: 6.9615 - val_loss: 71.1242 - val_mean_squared_error: 71.1242 - val_mean_absolute_error: 4.1912 - val_root_mean_squared_error: 8.4335
# Epoch 57/100
# 28/28 [==============================] - 5s 191ms/step - loss: 49.2554 - mean_squared_error: 49.2554 - mean_absolute_error: 3.4816 - root_mean_squared_error: 7.0182 - val_loss: 72.1938 - val_mean_squared_error: 72.1938 - val_mean_absolute_error: 4.1459 - val_root_mean_squared_error: 8.4967
# Epoch 58/100
# 28/28 [==============================] - 6s 220ms/step - loss: 48.3447 - mean_squared_error: 48.3447 - mean_absolute_error: 3.4659 - root_mean_squared_error: 6.9530 - val_loss: 78.1257 - val_mean_squared_error: 78.1256 - val_mean_absolute_error: 4.3560 - val_root_mean_squared_error: 8.8389
# Epoch 59/100
# 28/28 [==============================] - 5s 196ms/step - loss: 47.7950 - mean_squared_error: 47.7950 - mean_absolute_error: 3.4410 - root_mean_squared_error: 6.9134 - val_loss: 70.8009 - val_mean_squared_error: 70.8009 - val_mean_absolute_error: 4.0946 - val_root_mean_squared_error: 8.4143
# Epoch 60/100
# 28/28 [==============================] - 6s 214ms/step - loss: 46.5916 - mean_squared_error: 46.5916 - mean_absolute_error: 3.3597 - root_mean_squared_error: 6.8258 - val_loss: 70.0943 - val_mean_squared_error: 70.0943 - val_mean_absolute_error: 4.0968 - val_root_mean_squared_error: 8.3722
# Epoch 61/100
# 28/28 [==============================] - 6s 202ms/step - loss: 43.7382 - mean_squared_error: 43.7382 - mean_absolute_error: 3.2400 - root_mean_squared_error: 6.6135 - val_loss: 69.1001 - val_mean_squared_error: 69.1001 - val_mean_absolute_error: 4.0481 - val_root_mean_squared_error: 8.3126
# Epoch 62/100
# 28/28 [==============================] - 5s 191ms/step - loss: 45.4939 - mean_squared_error: 45.4940 - mean_absolute_error: 3.3401 - root_mean_squared_error: 6.7449 - val_loss: 70.1114 - val_mean_squared_error: 70.1114 - val_mean_absolute_error: 4.1188 - val_root_mean_squared_error: 8.3733
# Epoch 63/100
# 28/28 [==============================] - 6s 221ms/step - loss: 45.0666 - mean_squared_error: 45.0666 - mean_absolute_error: 3.3154 - root_mean_squared_error: 6.7132 - val_loss: 71.7198 - val_mean_squared_error: 71.7198 - val_mean_absolute_error: 4.1846 - val_root_mean_squared_error: 8.4688
# Epoch 64/100
# 28/28 [==============================] - 5s 192ms/step - loss: 45.8281 - mean_squared_error: 45.8281 - mean_absolute_error: 3.3285 - root_mean_squared_error: 6.7696 - val_loss: 73.7127 - val_mean_squared_error: 73.7127 - val_mean_absolute_error: 4.1371 - val_root_mean_squared_error: 8.5856
# Epoch 65/100
# 28/28 [==============================] - 6s 226ms/step - loss: 49.7237 - mean_squared_error: 49.7237 - mean_absolute_error: 3.5314 - root_mean_squared_error: 7.0515 - val_loss: 77.4814 - val_mean_squared_error: 77.4814 - val_mean_absolute_error: 4.2265 - val_root_mean_squared_error: 8.8024
# Epoch 66/100
# 28/28 [==============================] - 6s 202ms/step - loss: 46.5852 - mean_squared_error: 46.5852 - mean_absolute_error: 3.3799 - root_mean_squared_error: 6.8253 - val_loss: 76.6702 - val_mean_squared_error: 76.6702 - val_mean_absolute_error: 4.2870 - val_root_mean_squared_error: 8.7562
# Epoch 67/100
# 28/28 [==============================] - 6s 223ms/step - loss: 44.1435 - mean_squared_error: 44.1435 - mean_absolute_error: 3.2819 - root_mean_squared_error: 6.6441 - val_loss: 68.9154 - val_mean_squared_error: 68.9154 - val_mean_absolute_error: 3.9685 - val_root_mean_squared_error: 8.3015
# Epoch 68/100
# 28/28 [==============================] - 6s 199ms/step - loss: 46.3202 - mean_squared_error: 46.3202 - mean_absolute_error: 3.3705 - root_mean_squared_error: 6.8059 - val_loss: 69.1005 - val_mean_squared_error: 69.1005 - val_mean_absolute_error: 4.0913 - val_root_mean_squared_error: 8.3127
# Epoch 69/100
# 28/28 [==============================] - 6s 232ms/step - loss: 45.4619 - mean_squared_error: 45.4619 - mean_absolute_error: 3.3538 - root_mean_squared_error: 6.7425 - val_loss: 67.2996 - val_mean_squared_error: 67.2996 - val_mean_absolute_error: 3.9436 - val_root_mean_squared_error: 8.2036
# Epoch 70/100
# 28/28 [==============================] - 6s 200ms/step - loss: 46.0453 - mean_squared_error: 46.0453 - mean_absolute_error: 3.3632 - root_mean_squared_error: 6.7857 - val_loss: 68.8029 - val_mean_squared_error: 68.8029 - val_mean_absolute_error: 4.0222 - val_root_mean_squared_error: 8.2948
# Epoch 71/100
# 28/28 [==============================] - 6s 221ms/step - loss: 44.7811 - mean_squared_error: 44.7811 - mean_absolute_error: 3.2729 - root_mean_squared_error: 6.6919 - val_loss: 78.6320 - val_mean_squared_error: 78.6320 - val_mean_absolute_error: 4.2746 - val_root_mean_squared_error: 8.8675
# Epoch 72/100
# 28/28 [==============================] - 6s 204ms/step - loss: 45.4459 - mean_squared_error: 45.4459 - mean_absolute_error: 3.3422 - root_mean_squared_error: 6.7414 - val_loss: 67.2190 - val_mean_squared_error: 67.2190 - val_mean_absolute_error: 3.9797 - val_root_mean_squared_error: 8.1987
# Epoch 73/100
# 28/28 [==============================] - 6s 210ms/step - loss: 44.3982 - mean_squared_error: 44.3982 - mean_absolute_error: 3.2923 - root_mean_squared_error: 6.6632 - val_loss: 71.9383 - val_mean_squared_error: 71.9383 - val_mean_absolute_error: 4.0881 - val_root_mean_squared_error: 8.4816
# Epoch 74/100
# 28/28 [==============================] - 6s 218ms/step - loss: 44.6909 - mean_squared_error: 44.6909 - mean_absolute_error: 3.2769 - root_mean_squared_error: 6.6851 - val_loss: 71.6560 - val_mean_squared_error: 71.6560 - val_mean_absolute_error: 4.1824 - val_root_mean_squared_error: 8.4650
# Epoch 75/100
# 28/28 [==============================] - 5s 196ms/step - loss: 43.9719 - mean_squared_error: 43.9719 - mean_absolute_error: 3.3089 - root_mean_squared_error: 6.6311 - val_loss: 74.8583 - val_mean_squared_error: 74.8583 - val_mean_absolute_error: 4.3354 - val_root_mean_squared_error: 8.6521
# Epoch 76/100
# 28/28 [==============================] - 7s 235ms/step - loss: 44.0773 - mean_squared_error: 44.0773 - mean_absolute_error: 3.3435 - root_mean_squared_error: 6.6391 - val_loss: 66.9581 - val_mean_squared_error: 66.9581 - val_mean_absolute_error: 4.0188 - val_root_mean_squared_error: 8.1828
# Epoch 77/100
# 28/28 [==============================] - 5s 189ms/step - loss: 47.0916 - mean_squared_error: 47.0916 - mean_absolute_error: 3.3706 - root_mean_squared_error: 6.8623 - val_loss: 75.8886 - val_mean_squared_error: 75.8886 - val_mean_absolute_error: 4.2457 - val_root_mean_squared_error: 8.7114
# Epoch 78/100
# 28/28 [==============================] - 6s 231ms/step - loss: 45.1222 - mean_squared_error: 45.1222 - mean_absolute_error: 3.3476 - root_mean_squared_error: 6.7173 - val_loss: 74.6856 - val_mean_squared_error: 74.6856 - val_mean_absolute_error: 4.3325 - val_root_mean_squared_error: 8.6421
# Epoch 79/100
# 28/28 [==============================] - 5s 196ms/step - loss: 47.1906 - mean_squared_error: 47.1906 - mean_absolute_error: 3.3900 - root_mean_squared_error: 6.8695 - val_loss: 78.4411 - val_mean_squared_error: 78.4411 - val_mean_absolute_error: 4.3660 - val_root_mean_squared_error: 8.8567
# Epoch 80/100
# 28/28 [==============================] - 6s 220ms/step - loss: 43.5371 - mean_squared_error: 43.5371 - mean_absolute_error: 3.3001 - root_mean_squared_error: 6.5983 - val_loss: 66.4877 - val_mean_squared_error: 66.4877 - val_mean_absolute_error: 3.9785 - val_root_mean_squared_error: 8.1540
# Epoch 81/100
# 28/28 [==============================] - 5s 197ms/step - loss: 43.0883 - mean_squared_error: 43.0883 - mean_absolute_error: 3.2787 - root_mean_squared_error: 6.5642 - val_loss: 72.4031 - val_mean_squared_error: 72.4031 - val_mean_absolute_error: 4.1505 - val_root_mean_squared_error: 8.5090
# Epoch 82/100
# 28/28 [==============================] - 7s 273ms/step - loss: 46.2399 - mean_squared_error: 46.2399 - mean_absolute_error: 3.3913 - root_mean_squared_error: 6.8000 - val_loss: 70.1551 - val_mean_squared_error: 70.1551 - val_mean_absolute_error: 4.2371 - val_root_mean_squared_error: 8.3759
# Epoch 83/100
# 28/28 [==============================] - 5s 194ms/step - loss: 45.1609 - mean_squared_error: 45.1609 - mean_absolute_error: 3.3735 - root_mean_squared_error: 6.7202 - val_loss: 70.1898 - val_mean_squared_error: 70.1898 - val_mean_absolute_error: 4.0684 - val_root_mean_squared_error: 8.3779
# Epoch 84/100
# 28/28 [==============================] - 6s 228ms/step - loss: 44.3546 - mean_squared_error: 44.3546 - mean_absolute_error: 3.3234 - root_mean_squared_error: 6.6599 - val_loss: 71.6180 - val_mean_squared_error: 71.6180 - val_mean_absolute_error: 4.2086 - val_root_mean_squared_error: 8.4627
# Epoch 85/100
# 28/28 [==============================] - 6s 202ms/step - loss: 42.5285 - mean_squared_error: 42.5285 - mean_absolute_error: 3.2343 - root_mean_squared_error: 6.5214 - val_loss: 63.7774 - val_mean_squared_error: 63.7774 - val_mean_absolute_error: 3.9173 - val_root_mean_squared_error: 7.9861
# Epoch 86/100
# 28/28 [==============================] - 6s 213ms/step - loss: 42.8737 - mean_squared_error: 42.8737 - mean_absolute_error: 3.2722 - root_mean_squared_error: 6.5478 - val_loss: 70.7391 - val_mean_squared_error: 70.7391 - val_mean_absolute_error: 4.1766 - val_root_mean_squared_error: 8.4107
# Epoch 87/100
# 28/28 [==============================] - 6s 205ms/step - loss: 44.0498 - mean_squared_error: 44.0498 - mean_absolute_error: 3.2847 - root_mean_squared_error: 6.6370 - val_loss: 64.9070 - val_mean_squared_error: 64.9070 - val_mean_absolute_error: 3.9481 - val_root_mean_squared_error: 8.0565
# Epoch 88/100
# 28/28 [==============================] - 6s 203ms/step - loss: 44.5745 - mean_squared_error: 44.5744 - mean_absolute_error: 3.3031 - root_mean_squared_error: 6.6764 - val_loss: 67.8061 - val_mean_squared_error: 67.8061 - val_mean_absolute_error: 3.9617 - val_root_mean_squared_error: 8.2344
# Epoch 89/100
# 28/28 [==============================] - 6s 209ms/step - loss: 41.8388 - mean_squared_error: 41.8388 - mean_absolute_error: 3.1641 - root_mean_squared_error: 6.4683 - val_loss: 68.6120 - val_mean_squared_error: 68.6120 - val_mean_absolute_error: 3.9948 - val_root_mean_squared_error: 8.2832
# Epoch 90/100
# 28/28 [==============================] - 6s 203ms/step - loss: 43.0119 - mean_squared_error: 43.0119 - mean_absolute_error: 3.2499 - root_mean_squared_error: 6.5583 - val_loss: 74.1594 - val_mean_squared_error: 74.1594 - val_mean_absolute_error: 4.2307 - val_root_mean_squared_error: 8.6116
# Epoch 91/100
# 28/28 [==============================] - 6s 233ms/step - loss: 42.7940 - mean_squared_error: 42.7940 - mean_absolute_error: 3.2393 - root_mean_squared_error: 6.5417 - val_loss: 73.7208 - val_mean_squared_error: 73.7208 - val_mean_absolute_error: 4.3093 - val_root_mean_squared_error: 8.5861
# Epoch 92/100
# 28/28 [==============================] - 5s 190ms/step - loss: 43.6237 - mean_squared_error: 43.6237 - mean_absolute_error: 3.2789 - root_mean_squared_error: 6.6048 - val_loss: 66.2852 - val_mean_squared_error: 66.2852 - val_mean_absolute_error: 3.9739 - val_root_mean_squared_error: 8.1416
# Epoch 93/100
# 28/28 [==============================] - 6s 232ms/step - loss: 41.7927 - mean_squared_error: 41.7927 - mean_absolute_error: 3.2175 - root_mean_squared_error: 6.4647 - val_loss: 67.7812 - val_mean_squared_error: 67.7812 - val_mean_absolute_error: 4.0462 - val_root_mean_squared_error: 8.2329
# Epoch 94/100
# 28/28 [==============================] - 6s 204ms/step - loss: 43.1913 - mean_squared_error: 43.1913 - mean_absolute_error: 3.2569 - root_mean_squared_error: 6.5720 - val_loss: 68.1623 - val_mean_squared_error: 68.1623 - val_mean_absolute_error: 4.0556 - val_root_mean_squared_error: 8.2560
# Epoch 95/100
# 28/28 [==============================] - 7s 240ms/step - loss: 42.1638 - mean_squared_error: 42.1638 - mean_absolute_error: 3.2715 - root_mean_squared_error: 6.4934 - val_loss: 66.9108 - val_mean_squared_error: 66.9108 - val_mean_absolute_error: 3.9977 - val_root_mean_squared_error: 8.1799
# Epoch 96/100
# 28/28 [==============================] - 5s 189ms/step - loss: 43.1630 - mean_squared_error: 43.1630 - mean_absolute_error: 3.2527 - root_mean_squared_error: 6.5699 - val_loss: 65.8725 - val_mean_squared_error: 65.8725 - val_mean_absolute_error: 4.0397 - val_root_mean_squared_error: 8.1162
# Epoch 97/100
# 28/28 [==============================] - 6s 222ms/step - loss: 40.1976 - mean_squared_error: 40.1976 - mean_absolute_error: 3.1121 - root_mean_squared_error: 6.3402 - val_loss: 66.6492 - val_mean_squared_error: 66.6492 - val_mean_absolute_error: 4.0151 - val_root_mean_squared_error: 8.1639
# Epoch 98/100
# 28/28 [==============================] - 6s 201ms/step - loss: 44.3017 - mean_squared_error: 44.3017 - mean_absolute_error: 3.3193 - root_mean_squared_error: 6.6559 - val_loss: 68.4126 - val_mean_squared_error: 68.4126 - val_mean_absolute_error: 4.0718 - val_root_mean_squared_error: 8.2712
# Epoch 99/100
# 28/28 [==============================] - 6s 198ms/step - loss: 41.4236 - mean_squared_error: 41.4236 - mean_absolute_error: 3.1913 - root_mean_squared_error: 6.4361 - val_loss: 67.4706 - val_mean_squared_error: 67.4706 - val_mean_absolute_error: 4.0232 - val_root_mean_squared_error: 8.2140
# Epoch 100/100
# 28/28 [==============================] - 6s 210ms/step - loss: 40.5412 - mean_squared_error: 40.5413 - mean_absolute_error: 3.1570 - root_mean_squared_error: 6.3672 - val_loss: 67.4102 - val_mean_squared_error: 67.4102 - val_mean_absolute_error: 3.9286 - val_root_mean_squared_error: 8.2104

# %% [markdown]
# # Training results

# %%
from utils.plotting import training_loss_plot

if not in_google_colab():
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

plot = training_loss_plot(train_score, filename='download/training_loss.pdf')
plot.show()

# %% [markdown]
# # Testing

# %%
### Predict on the test set
from utils.evaluation import phases_report, phases_report_std

print('Testmetriken:')

report = phases_report(y_pred, bis.test_dataset, propofolrate.test_dataset)
report
# Out:
# Testmetriken:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                 109.23       139.87           7.45         7.55
# Induction           282.50       637.60          12.78        18.34
# Maintenance          66.63        60.90           6.15         5.68
# Recovery            284.13       361.57          12.68        13.46
#
#             Prediction RMSE Baseline RMSE
# All                   10.45         11.83
# Induction             16.81         25.25
# Maintenance            8.16          7.80
# Recovery              16.86         19.02

# %%
phases_report_std(report, y_pred, bis.test_dataset, propofolrate.test_dataset)
# Out:
# All      	min: 	 15 	max: 	 6
# Induction 	min: 	 23 	max: 	 10
# Maintenance 	min: 	 13 	max: 	 6
# Recovery 	min: 	 19 	max: 	 22
#              Prediction MSE  Baseline MSE  Prediction MAE  Baseline MAE  \
# All                   57.54         82.42            2.04          2.54
# Induction            255.16        403.81            5.30          8.45
# Maintenance           41.52         43.11            1.99          2.15
# Recovery             151.61        185.95            5.06          6.28
#
#              Prediction RMSE  Baseline RMSE
# All                     2.57           3.31
# Induction               5.71           7.29
# Maintenance             2.29           2.51
# Recovery                5.82           6.47

# %%
from utils.plotting import full_histogramm_plot

plot = full_histogramm_plot(groundtruth = bis.test_dataset, prediction = y_pred, filename='download/histogramm.pdf')
plot.show()

# %%
from utils.plotting import single_prediction_plot

for case in test_index:
    single_prediction_plot(
        case = case,
        index = test_index,
        groundtruth = bis.test_dataset,
        prediction = y_pred,
        infusion = propofolrate.test_dataset,
        error = 'Prediction RMSE',
        filename = 'download/' + str(case) + '.pdf')

print('Finished')
# Out:
# /content/utils/plotting.py:79: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(12/2.54, 6/2.54))
# Finished

# %%
from utils.plotting import full_prediction_plot

full_prediction_plot(index = test_index, groundtruth = bis.test_dataset, prediction = y_pred, infusion = propofolrate.test_dataset)
