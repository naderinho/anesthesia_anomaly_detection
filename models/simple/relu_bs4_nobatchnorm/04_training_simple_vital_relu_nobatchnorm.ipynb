# %% [markdown]
# # Initialization

# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset02/'
vitaldbpath = 'vitaldb_tiva/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt
import pickle

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 630, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 630 (delta 87), reused 169 (delta 87), pack-reused 461
# Receiving objects: 100% (630/630), 124.94 MiB | 25.08 MiB/s, done.
# Resolving deltas: 100% (291/291), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl.metadata (520 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.31.0)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.5 MB/s eta 0:00:00
# Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %% [markdown]
# # Data loading

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolrate.name = 'Propofol Rate'
    propofolrate.tracks = ['Orchestra/PPF20_RATE']
    propofolrate.filterON = False
    propofolrate.generateDataset(normalization=md.NormNone)
    propofolrate.save('03_propofol_rate.npz')

    remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    remifentanilrate.name = 'Remifentanil Rate'
    remifentanilrate.tracks = ['Orchestra/RFTN20_RATE']
    remifentanilrate.filterON = False
    remifentanilrate.generateDataset(normalization=md.NormNone)
    remifentanilrate.save('03_remifentanil_rate.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolrate.load('03_propofol_rate.npz')

remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
remifentanilrate.load('03_remifentanil_rate.npz')

train_index, val_index, test_index = bis.split(np.array(bis.index))

# %% [markdown]
# # Model creation

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### LSTM layers for the blood pressure data

### Combine the vital data
vital_train = np.concatenate([bloodpressure.train_dataset, etCO2.train_dataset, spO2.train_dataset, hr.train_dataset], axis=2)
vital_validation = np.concatenate([bloodpressure.validation_dataset, etCO2.validation_dataset, spO2.validation_dataset, hr.validation_dataset], axis=2)
vital_test = np.concatenate([bloodpressure.test_dataset, etCO2.test_dataset, spO2.test_dataset, hr.test_dataset], axis=2)

### LSTM layers for the vital data
input_vital = Input(shape=(None, vital_train.shape[2]))
vital_layer = Masking(mask_value=0.0)(input_vital)

### INFO layers
input_info = Input(shape=(info.train_dataset.shape[1],))
info_layer = RepeatVector(vital_train.shape[1])(input_info)

## Concatenate the LSTM output with the info layer
comb_layer = Concatenate()([vital_layer, info_layer])
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=128, activation='relu')(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=32, activation='relu')(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)


output = Dense(units=1, activation=ReLU(max_value=1.0))(comb_layer)
output = Lambda(lambda x: x * 100)(output)

# Define the model
model = Model(inputs=[input_vital, input_info], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 6)]            0         []
#
#  input_2 (InputLayer)        [(None, 5)]                  0         []
#
#  masking (Masking)           (None, None, 6)              0         ['input_1[0][0]']
#
#  repeat_vector (RepeatVecto  (None, 3680, 5)              0         ['input_2[0][0]']
#  r)
#
#  concatenate (Concatenate)   (None, 3680, 11)             0         ['masking[0][0]',
#                                                                      'repeat_vector[0][0]']
#
#  lstm (LSTM)                 (None, 3680, 32)             5632      ['concatenate[0][0]']
#
#  lstm_1 (LSTM)               (None, 3680, 32)             8320      ['lstm[0][0]']
#
#  lstm_2 (LSTM)               (None, 3680, 32)             8320      ['lstm_1[0][0]']
#
#  dense (Dense)               (None, 3680, 128)            4224      ['lstm_2[0][0]']
#
#  dense_1 (Dense)             (None, 3680, 32)             4128      ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 3680, 1)              33        ['dense_1[0][0]']
#
#  lambda (Lambda)             (None, 3680, 1)              0         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 30657 (119.75 KB)
# Trainable params: 30657 (119.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %%
# Rolling mean on BIS data
y = pd.DataFrame(bis.train_dataset[:,:,0].T).rolling(min_periods=1,window=20, center=True).mean().to_numpy().T[:,:,np.newaxis]

# Define training stop criteria
class StopTrainingCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(StopTrainingCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_loss') is not None:
            if logs.get('val_loss') < self.threshold:
                print(f"\nValidation loss is below {self.threshold}, stopping training.")
                self.model.stop_training = True

stop_training_callback = StopTrainingCallback(threshold = 35)


if in_google_colab():
    # Train the model
    history = model.fit([vital_train, info.train_dataset],
                        y,
                        validation_data=([vital_validation, info.validation_dataset], bis.validation_dataset),
                        epochs=100,
                        batch_size=4,
                        callbacks=[stop_training_callback]
                        )

    train_score = history.history

    # Save the model
    model.save('download/model.keras')

    # Save the training history
    with open('download/train_score.pkl', 'wb') as f:
        pickle.dump(train_score, f)

    # Save the prediction
    y_pred = model.predict([vital_test, info.test_dataset], verbose=0)
    with open('download/prediction.pkl', 'wb') as f:
        pickle.dump(y_pred, f)

else:
    # Load train score data
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

    # Load test prediction data
    with open('prediction.pkl', 'rb') as f:
        y_pred = pickle.load(f)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 33s 331ms/step - loss: 181.8390 - mean_squared_error: 181.8390 - mean_absolute_error: 8.2055 - root_mean_squared_error: 13.4848 - val_loss: 92.8639 - val_mean_squared_error: 92.8639 - val_mean_absolute_error: 5.0309 - val_root_mean_squared_error: 9.6366
# Epoch 2/100
# 28/28 [==============================] - 5s 187ms/step - loss: 77.2562 - mean_squared_error: 77.2562 - mean_absolute_error: 4.4321 - root_mean_squared_error: 8.7896 - val_loss: 91.5836 - val_mean_squared_error: 91.5835 - val_mean_absolute_error: 4.4918 - val_root_mean_squared_error: 9.5699
# Epoch 3/100
# 28/28 [==============================] - 6s 205ms/step - loss: 70.6781 - mean_squared_error: 70.6781 - mean_absolute_error: 4.1375 - root_mean_squared_error: 8.4070 - val_loss: 88.1660 - val_mean_squared_error: 88.1660 - val_mean_absolute_error: 4.2481 - val_root_mean_squared_error: 9.3897
# Epoch 4/100
# 28/28 [==============================] - 5s 184ms/step - loss: 69.1382 - mean_squared_error: 69.1382 - mean_absolute_error: 4.0123 - root_mean_squared_error: 8.3149 - val_loss: 86.8979 - val_mean_squared_error: 86.8979 - val_mean_absolute_error: 4.5669 - val_root_mean_squared_error: 9.3219
# Epoch 5/100
# 28/28 [==============================] - 6s 227ms/step - loss: 62.9072 - mean_squared_error: 62.9072 - mean_absolute_error: 3.7813 - root_mean_squared_error: 7.9314 - val_loss: 89.3660 - val_mean_squared_error: 89.3660 - val_mean_absolute_error: 4.3764 - val_root_mean_squared_error: 9.4534
# Epoch 6/100
# 28/28 [==============================] - 6s 202ms/step - loss: 62.3876 - mean_squared_error: 62.3876 - mean_absolute_error: 3.7493 - root_mean_squared_error: 7.8986 - val_loss: 86.0262 - val_mean_squared_error: 86.0262 - val_mean_absolute_error: 4.2768 - val_root_mean_squared_error: 9.2750
# Epoch 7/100
# 28/28 [==============================] - 6s 220ms/step - loss: 59.7790 - mean_squared_error: 59.7790 - mean_absolute_error: 3.6885 - root_mean_squared_error: 7.7317 - val_loss: 87.0413 - val_mean_squared_error: 87.0413 - val_mean_absolute_error: 4.6357 - val_root_mean_squared_error: 9.3296
# Epoch 8/100
# 28/28 [==============================] - 5s 175ms/step - loss: 60.1229 - mean_squared_error: 60.1229 - mean_absolute_error: 3.6685 - root_mean_squared_error: 7.7539 - val_loss: 82.0564 - val_mean_squared_error: 82.0564 - val_mean_absolute_error: 4.1470 - val_root_mean_squared_error: 9.0585
# Epoch 9/100
# 28/28 [==============================] - 5s 179ms/step - loss: 60.3853 - mean_squared_error: 60.3853 - mean_absolute_error: 3.7897 - root_mean_squared_error: 7.7708 - val_loss: 84.0674 - val_mean_squared_error: 84.0674 - val_mean_absolute_error: 4.4002 - val_root_mean_squared_error: 9.1688
# Epoch 10/100
# 28/28 [==============================] - 6s 202ms/step - loss: 57.0049 - mean_squared_error: 57.0049 - mean_absolute_error: 3.6674 - root_mean_squared_error: 7.5502 - val_loss: 79.7653 - val_mean_squared_error: 79.7653 - val_mean_absolute_error: 4.2914 - val_root_mean_squared_error: 8.9311
# Epoch 11/100
# 28/28 [==============================] - 5s 177ms/step - loss: 56.3250 - mean_squared_error: 56.3251 - mean_absolute_error: 3.6060 - root_mean_squared_error: 7.5050 - val_loss: 85.5679 - val_mean_squared_error: 85.5679 - val_mean_absolute_error: 4.9397 - val_root_mean_squared_error: 9.2503
# Epoch 12/100
# 28/28 [==============================] - 6s 218ms/step - loss: 57.4507 - mean_squared_error: 57.4507 - mean_absolute_error: 3.7158 - root_mean_squared_error: 7.5796 - val_loss: 75.3332 - val_mean_squared_error: 75.3332 - val_mean_absolute_error: 4.0952 - val_root_mean_squared_error: 8.6795
# Epoch 13/100
# 28/28 [==============================] - 5s 165ms/step - loss: 53.9857 - mean_squared_error: 53.9857 - mean_absolute_error: 3.6163 - root_mean_squared_error: 7.3475 - val_loss: 82.6938 - val_mean_squared_error: 82.6938 - val_mean_absolute_error: 4.2925 - val_root_mean_squared_error: 9.0936
# Epoch 14/100
# 28/28 [==============================] - 5s 181ms/step - loss: 52.3427 - mean_squared_error: 52.3428 - mean_absolute_error: 3.5484 - root_mean_squared_error: 7.2348 - val_loss: 74.2663 - val_mean_squared_error: 74.2663 - val_mean_absolute_error: 4.2989 - val_root_mean_squared_error: 8.6178
# Epoch 15/100
# 28/28 [==============================] - 6s 200ms/step - loss: 50.7273 - mean_squared_error: 50.7273 - mean_absolute_error: 3.4634 - root_mean_squared_error: 7.1223 - val_loss: 69.9921 - val_mean_squared_error: 69.9921 - val_mean_absolute_error: 4.2116 - val_root_mean_squared_error: 8.3661
# Epoch 16/100
# 28/28 [==============================] - 5s 189ms/step - loss: 47.3334 - mean_squared_error: 47.3334 - mean_absolute_error: 3.3302 - root_mean_squared_error: 6.8799 - val_loss: 72.8533 - val_mean_squared_error: 72.8533 - val_mean_absolute_error: 3.9430 - val_root_mean_squared_error: 8.5354
# Epoch 17/100
# 28/28 [==============================] - 6s 216ms/step - loss: 59.4418 - mean_squared_error: 59.4419 - mean_absolute_error: 3.8631 - root_mean_squared_error: 7.7099 - val_loss: 73.9281 - val_mean_squared_error: 73.9281 - val_mean_absolute_error: 3.9122 - val_root_mean_squared_error: 8.5981
# Epoch 18/100
# 28/28 [==============================] - 5s 177ms/step - loss: 52.1888 - mean_squared_error: 52.1888 - mean_absolute_error: 3.5625 - root_mean_squared_error: 7.2242 - val_loss: 79.9153 - val_mean_squared_error: 79.9153 - val_mean_absolute_error: 4.1159 - val_root_mean_squared_error: 8.9395
# Epoch 19/100
# 28/28 [==============================] - 6s 214ms/step - loss: 47.7354 - mean_squared_error: 47.7354 - mean_absolute_error: 3.4001 - root_mean_squared_error: 6.9091 - val_loss: 67.5012 - val_mean_squared_error: 67.5012 - val_mean_absolute_error: 3.9099 - val_root_mean_squared_error: 8.2159
# Epoch 20/100
# 28/28 [==============================] - 6s 218ms/step - loss: 45.2258 - mean_squared_error: 45.2258 - mean_absolute_error: 3.2593 - root_mean_squared_error: 6.7250 - val_loss: 67.2931 - val_mean_squared_error: 67.2931 - val_mean_absolute_error: 3.9537 - val_root_mean_squared_error: 8.2032
# Epoch 21/100
# 28/28 [==============================] - 5s 184ms/step - loss: 46.5858 - mean_squared_error: 46.5858 - mean_absolute_error: 3.3509 - root_mean_squared_error: 6.8254 - val_loss: 81.2682 - val_mean_squared_error: 81.2682 - val_mean_absolute_error: 4.3910 - val_root_mean_squared_error: 9.0149
# Epoch 22/100
# 28/28 [==============================] - 6s 213ms/step - loss: 52.2979 - mean_squared_error: 52.2979 - mean_absolute_error: 3.5667 - root_mean_squared_error: 7.2317 - val_loss: 71.5570 - val_mean_squared_error: 71.5570 - val_mean_absolute_error: 3.9317 - val_root_mean_squared_error: 8.4591
# Epoch 23/100
# 28/28 [==============================] - 5s 189ms/step - loss: 46.2024 - mean_squared_error: 46.2024 - mean_absolute_error: 3.3019 - root_mean_squared_error: 6.7972 - val_loss: 68.4473 - val_mean_squared_error: 68.4473 - val_mean_absolute_error: 3.9699 - val_root_mean_squared_error: 8.2733
# Epoch 24/100
# 28/28 [==============================] - 6s 218ms/step - loss: 45.0552 - mean_squared_error: 45.0552 - mean_absolute_error: 3.2114 - root_mean_squared_error: 6.7123 - val_loss: 68.6508 - val_mean_squared_error: 68.6508 - val_mean_absolute_error: 4.0230 - val_root_mean_squared_error: 8.2856
# Epoch 25/100
# 28/28 [==============================] - 5s 173ms/step - loss: 46.1710 - mean_squared_error: 46.1710 - mean_absolute_error: 3.3309 - root_mean_squared_error: 6.7949 - val_loss: 67.6333 - val_mean_squared_error: 67.6333 - val_mean_absolute_error: 3.9690 - val_root_mean_squared_error: 8.2239
# Epoch 26/100
# 28/28 [==============================] - 6s 208ms/step - loss: 45.2880 - mean_squared_error: 45.2880 - mean_absolute_error: 3.3042 - root_mean_squared_error: 6.7296 - val_loss: 72.5748 - val_mean_squared_error: 72.5748 - val_mean_absolute_error: 4.2065 - val_root_mean_squared_error: 8.5191
# Epoch 27/100
# 28/28 [==============================] - 5s 188ms/step - loss: 43.3492 - mean_squared_error: 43.3492 - mean_absolute_error: 3.2410 - root_mean_squared_error: 6.5840 - val_loss: 69.8638 - val_mean_squared_error: 69.8638 - val_mean_absolute_error: 4.0398 - val_root_mean_squared_error: 8.3585
# Epoch 28/100
# 28/28 [==============================] - 5s 194ms/step - loss: 42.0525 - mean_squared_error: 42.0525 - mean_absolute_error: 3.1642 - root_mean_squared_error: 6.4848 - val_loss: 69.4096 - val_mean_squared_error: 69.4096 - val_mean_absolute_error: 3.9622 - val_root_mean_squared_error: 8.3312
# Epoch 29/100
# 28/28 [==============================] - 5s 191ms/step - loss: 43.2717 - mean_squared_error: 43.2717 - mean_absolute_error: 3.2117 - root_mean_squared_error: 6.5781 - val_loss: 64.1925 - val_mean_squared_error: 64.1925 - val_mean_absolute_error: 3.7811 - val_root_mean_squared_error: 8.0120
# Epoch 30/100
# 28/28 [==============================] - 5s 187ms/step - loss: 43.9690 - mean_squared_error: 43.9690 - mean_absolute_error: 3.2603 - root_mean_squared_error: 6.6309 - val_loss: 61.6740 - val_mean_squared_error: 61.6740 - val_mean_absolute_error: 3.7863 - val_root_mean_squared_error: 7.8533
# Epoch 31/100
# 28/28 [==============================] - 6s 210ms/step - loss: 41.9314 - mean_squared_error: 41.9314 - mean_absolute_error: 3.1335 - root_mean_squared_error: 6.4754 - val_loss: 68.2037 - val_mean_squared_error: 68.2037 - val_mean_absolute_error: 3.8793 - val_root_mean_squared_error: 8.2586
# Epoch 32/100
# 28/28 [==============================] - 5s 189ms/step - loss: 41.2023 - mean_squared_error: 41.2023 - mean_absolute_error: 3.1609 - root_mean_squared_error: 6.4189 - val_loss: 64.0452 - val_mean_squared_error: 64.0452 - val_mean_absolute_error: 3.8589 - val_root_mean_squared_error: 8.0028
# Epoch 33/100
# 28/28 [==============================] - 6s 214ms/step - loss: 40.3450 - mean_squared_error: 40.3450 - mean_absolute_error: 3.1005 - root_mean_squared_error: 6.3518 - val_loss: 68.3704 - val_mean_squared_error: 68.3704 - val_mean_absolute_error: 4.1624 - val_root_mean_squared_error: 8.2686
# Epoch 34/100
# 28/28 [==============================] - 5s 187ms/step - loss: 42.1456 - mean_squared_error: 42.1456 - mean_absolute_error: 3.1888 - root_mean_squared_error: 6.4920 - val_loss: 70.6643 - val_mean_squared_error: 70.6643 - val_mean_absolute_error: 4.1198 - val_root_mean_squared_error: 8.4062
# Epoch 35/100
# 28/28 [==============================] - 5s 180ms/step - loss: 40.5756 - mean_squared_error: 40.5756 - mean_absolute_error: 3.1273 - root_mean_squared_error: 6.3699 - val_loss: 62.8885 - val_mean_squared_error: 62.8885 - val_mean_absolute_error: 3.7648 - val_root_mean_squared_error: 7.9302
# Epoch 36/100
# 28/28 [==============================] - 6s 213ms/step - loss: 40.8589 - mean_squared_error: 40.8589 - mean_absolute_error: 3.1471 - root_mean_squared_error: 6.3921 - val_loss: 64.1749 - val_mean_squared_error: 64.1749 - val_mean_absolute_error: 3.8482 - val_root_mean_squared_error: 8.0109
# Epoch 37/100
# 28/28 [==============================] - 5s 188ms/step - loss: 40.5559 - mean_squared_error: 40.5559 - mean_absolute_error: 3.1289 - root_mean_squared_error: 6.3684 - val_loss: 75.9785 - val_mean_squared_error: 75.9785 - val_mean_absolute_error: 4.3186 - val_root_mean_squared_error: 8.7166
# Epoch 38/100
# 28/28 [==============================] - 6s 212ms/step - loss: 42.6222 - mean_squared_error: 42.6222 - mean_absolute_error: 3.2727 - root_mean_squared_error: 6.5286 - val_loss: 68.5822 - val_mean_squared_error: 68.5822 - val_mean_absolute_error: 4.0704 - val_root_mean_squared_error: 8.2814
# Epoch 39/100
# 28/28 [==============================] - 5s 185ms/step - loss: 39.8992 - mean_squared_error: 39.8992 - mean_absolute_error: 3.0742 - root_mean_squared_error: 6.3166 - val_loss: 68.1331 - val_mean_squared_error: 68.1331 - val_mean_absolute_error: 4.0545 - val_root_mean_squared_error: 8.2543
# Epoch 40/100
# 28/28 [==============================] - 6s 224ms/step - loss: 40.0845 - mean_squared_error: 40.0845 - mean_absolute_error: 3.1511 - root_mean_squared_error: 6.3312 - val_loss: 70.8926 - val_mean_squared_error: 70.8926 - val_mean_absolute_error: 4.1802 - val_root_mean_squared_error: 8.4198
# Epoch 41/100
# 28/28 [==============================] - 5s 175ms/step - loss: 40.4348 - mean_squared_error: 40.4348 - mean_absolute_error: 3.1479 - root_mean_squared_error: 6.3588 - val_loss: 69.7603 - val_mean_squared_error: 69.7603 - val_mean_absolute_error: 4.1548 - val_root_mean_squared_error: 8.3523
# Epoch 42/100
# 28/28 [==============================] - 5s 177ms/step - loss: 44.0098 - mean_squared_error: 44.0098 - mean_absolute_error: 3.2565 - root_mean_squared_error: 6.6340 - val_loss: 60.1860 - val_mean_squared_error: 60.1860 - val_mean_absolute_error: 3.8345 - val_root_mean_squared_error: 7.7580
# Epoch 43/100
# 28/28 [==============================] - 6s 209ms/step - loss: 41.5869 - mean_squared_error: 41.5869 - mean_absolute_error: 3.2146 - root_mean_squared_error: 6.4488 - val_loss: 63.5587 - val_mean_squared_error: 63.5587 - val_mean_absolute_error: 3.8319 - val_root_mean_squared_error: 7.9724
# Epoch 44/100
# 28/28 [==============================] - 5s 180ms/step - loss: 41.8142 - mean_squared_error: 41.8142 - mean_absolute_error: 3.1867 - root_mean_squared_error: 6.4664 - val_loss: 64.4704 - val_mean_squared_error: 64.4704 - val_mean_absolute_error: 3.9396 - val_root_mean_squared_error: 8.0293
# Epoch 45/100
# 28/28 [==============================] - 6s 212ms/step - loss: 41.1452 - mean_squared_error: 41.1452 - mean_absolute_error: 3.1479 - root_mean_squared_error: 6.4144 - val_loss: 64.8502 - val_mean_squared_error: 64.8502 - val_mean_absolute_error: 3.8685 - val_root_mean_squared_error: 8.0530
# Epoch 46/100
# 28/28 [==============================] - 5s 196ms/step - loss: 43.7643 - mean_squared_error: 43.7643 - mean_absolute_error: 3.2405 - root_mean_squared_error: 6.6155 - val_loss: 76.5275 - val_mean_squared_error: 76.5275 - val_mean_absolute_error: 4.3215 - val_root_mean_squared_error: 8.7480
# Epoch 47/100
# 28/28 [==============================] - 6s 211ms/step - loss: 41.0396 - mean_squared_error: 41.0396 - mean_absolute_error: 3.0947 - root_mean_squared_error: 6.4062 - val_loss: 67.9323 - val_mean_squared_error: 67.9323 - val_mean_absolute_error: 3.8679 - val_root_mean_squared_error: 8.2421
# Epoch 48/100
# 28/28 [==============================] - 5s 180ms/step - loss: 39.3703 - mean_squared_error: 39.3703 - mean_absolute_error: 3.0300 - root_mean_squared_error: 6.2746 - val_loss: 69.8459 - val_mean_squared_error: 69.8459 - val_mean_absolute_error: 4.0572 - val_root_mean_squared_error: 8.3574
# Epoch 49/100
# 28/28 [==============================] - 5s 191ms/step - loss: 39.3798 - mean_squared_error: 39.3798 - mean_absolute_error: 3.0564 - root_mean_squared_error: 6.2753 - val_loss: 66.3532 - val_mean_squared_error: 66.3531 - val_mean_absolute_error: 4.0972 - val_root_mean_squared_error: 8.1457
# Epoch 50/100
# 28/28 [==============================] - 6s 202ms/step - loss: 39.4213 - mean_squared_error: 39.4213 - mean_absolute_error: 3.0771 - root_mean_squared_error: 6.2786 - val_loss: 66.6756 - val_mean_squared_error: 66.6756 - val_mean_absolute_error: 3.8985 - val_root_mean_squared_error: 8.1655
# Epoch 51/100
# 28/28 [==============================] - 5s 181ms/step - loss: 40.0064 - mean_squared_error: 40.0064 - mean_absolute_error: 3.1170 - root_mean_squared_error: 6.3251 - val_loss: 65.1098 - val_mean_squared_error: 65.1098 - val_mean_absolute_error: 4.0155 - val_root_mean_squared_error: 8.0691
# Epoch 52/100
# 28/28 [==============================] - 6s 223ms/step - loss: 38.8793 - mean_squared_error: 38.8793 - mean_absolute_error: 3.0438 - root_mean_squared_error: 6.2353 - val_loss: 63.3935 - val_mean_squared_error: 63.3935 - val_mean_absolute_error: 3.7775 - val_root_mean_squared_error: 7.9620
# Epoch 53/100
# 28/28 [==============================] - 5s 195ms/step - loss: 37.8246 - mean_squared_error: 37.8246 - mean_absolute_error: 3.0034 - root_mean_squared_error: 6.1502 - val_loss: 63.2400 - val_mean_squared_error: 63.2400 - val_mean_absolute_error: 3.7465 - val_root_mean_squared_error: 7.9524
# Epoch 54/100
# 28/28 [==============================] - 6s 208ms/step - loss: 38.2603 - mean_squared_error: 38.2603 - mean_absolute_error: 3.0177 - root_mean_squared_error: 6.1855 - val_loss: 66.3258 - val_mean_squared_error: 66.3257 - val_mean_absolute_error: 3.8809 - val_root_mean_squared_error: 8.1441
# Epoch 55/100
# 28/28 [==============================] - 5s 193ms/step - loss: 38.0114 - mean_squared_error: 38.0114 - mean_absolute_error: 2.9904 - root_mean_squared_error: 6.1653 - val_loss: 71.4339 - val_mean_squared_error: 71.4339 - val_mean_absolute_error: 3.9798 - val_root_mean_squared_error: 8.4519
# Epoch 56/100
# 28/28 [==============================] - 5s 185ms/step - loss: 38.6485 - mean_squared_error: 38.6485 - mean_absolute_error: 3.0224 - root_mean_squared_error: 6.2168 - val_loss: 65.2029 - val_mean_squared_error: 65.2029 - val_mean_absolute_error: 3.9423 - val_root_mean_squared_error: 8.0748
# Epoch 57/100
# 28/28 [==============================] - 6s 212ms/step - loss: 37.4792 - mean_squared_error: 37.4792 - mean_absolute_error: 3.0138 - root_mean_squared_error: 6.1220 - val_loss: 63.7003 - val_mean_squared_error: 63.7003 - val_mean_absolute_error: 3.8679 - val_root_mean_squared_error: 7.9812
# Epoch 58/100
# 28/28 [==============================] - 5s 173ms/step - loss: 38.2971 - mean_squared_error: 38.2970 - mean_absolute_error: 3.0474 - root_mean_squared_error: 6.1885 - val_loss: 63.1388 - val_mean_squared_error: 63.1388 - val_mean_absolute_error: 3.8834 - val_root_mean_squared_error: 7.9460
# Epoch 59/100
# 28/28 [==============================] - 6s 213ms/step - loss: 36.4940 - mean_squared_error: 36.4940 - mean_absolute_error: 2.9925 - root_mean_squared_error: 6.0410 - val_loss: 64.8866 - val_mean_squared_error: 64.8866 - val_mean_absolute_error: 3.8400 - val_root_mean_squared_error: 8.0552
# Epoch 60/100
# 28/28 [==============================] - 5s 177ms/step - loss: 37.9009 - mean_squared_error: 37.9009 - mean_absolute_error: 3.0352 - root_mean_squared_error: 6.1564 - val_loss: 65.6138 - val_mean_squared_error: 65.6138 - val_mean_absolute_error: 3.8322 - val_root_mean_squared_error: 8.1002
# Epoch 61/100
# 28/28 [==============================] - 6s 210ms/step - loss: 37.5972 - mean_squared_error: 37.5972 - mean_absolute_error: 3.0462 - root_mean_squared_error: 6.1317 - val_loss: 75.7051 - val_mean_squared_error: 75.7051 - val_mean_absolute_error: 4.0570 - val_root_mean_squared_error: 8.7009
# Epoch 62/100
# 28/28 [==============================] - 5s 183ms/step - loss: 39.6484 - mean_squared_error: 39.6484 - mean_absolute_error: 3.0561 - root_mean_squared_error: 6.2967 - val_loss: 71.3956 - val_mean_squared_error: 71.3956 - val_mean_absolute_error: 4.2533 - val_root_mean_squared_error: 8.4496
# Epoch 63/100
# 28/28 [==============================] - 5s 195ms/step - loss: 38.6189 - mean_squared_error: 38.6189 - mean_absolute_error: 3.0479 - root_mean_squared_error: 6.2144 - val_loss: 64.6977 - val_mean_squared_error: 64.6977 - val_mean_absolute_error: 3.9181 - val_root_mean_squared_error: 8.0435
# Epoch 64/100
# 28/28 [==============================] - 7s 251ms/step - loss: 35.8473 - mean_squared_error: 35.8473 - mean_absolute_error: 2.9704 - root_mean_squared_error: 5.9873 - val_loss: 66.1125 - val_mean_squared_error: 66.1125 - val_mean_absolute_error: 4.0197 - val_root_mean_squared_error: 8.1310
# Epoch 65/100
# 28/28 [==============================] - 5s 177ms/step - loss: 35.5350 - mean_squared_error: 35.5350 - mean_absolute_error: 2.9036 - root_mean_squared_error: 5.9611 - val_loss: 62.4395 - val_mean_squared_error: 62.4395 - val_mean_absolute_error: 3.8948 - val_root_mean_squared_error: 7.9019
# Epoch 66/100
# 28/28 [==============================] - 6s 227ms/step - loss: 35.3130 - mean_squared_error: 35.3130 - mean_absolute_error: 2.9338 - root_mean_squared_error: 5.9425 - val_loss: 63.7207 - val_mean_squared_error: 63.7207 - val_mean_absolute_error: 3.8830 - val_root_mean_squared_error: 7.9825
# Epoch 67/100
# 28/28 [==============================] - 5s 193ms/step - loss: 37.5146 - mean_squared_error: 37.5146 - mean_absolute_error: 3.0241 - root_mean_squared_error: 6.1249 - val_loss: 65.0256 - val_mean_squared_error: 65.0256 - val_mean_absolute_error: 3.9184 - val_root_mean_squared_error: 8.0638
# Epoch 68/100
# 28/28 [==============================] - 6s 218ms/step - loss: 42.1080 - mean_squared_error: 42.1080 - mean_absolute_error: 3.2257 - root_mean_squared_error: 6.4891 - val_loss: 63.8933 - val_mean_squared_error: 63.8933 - val_mean_absolute_error: 3.7523 - val_root_mean_squared_error: 7.9933
# Epoch 69/100
# 28/28 [==============================] - 5s 181ms/step - loss: 37.5694 - mean_squared_error: 37.5694 - mean_absolute_error: 3.0013 - root_mean_squared_error: 6.1294 - val_loss: 72.5565 - val_mean_squared_error: 72.5565 - val_mean_absolute_error: 4.0219 - val_root_mean_squared_error: 8.5180
# Epoch 70/100
# 28/28 [==============================] - 5s 196ms/step - loss: 37.8767 - mean_squared_error: 37.8767 - mean_absolute_error: 3.0297 - root_mean_squared_error: 6.1544 - val_loss: 64.4995 - val_mean_squared_error: 64.4995 - val_mean_absolute_error: 3.8525 - val_root_mean_squared_error: 8.0312
# Epoch 71/100
# 28/28 [==============================] - 6s 212ms/step - loss: 35.7081 - mean_squared_error: 35.7081 - mean_absolute_error: 2.9287 - root_mean_squared_error: 5.9756 - val_loss: 72.9800 - val_mean_squared_error: 72.9800 - val_mean_absolute_error: 4.1026 - val_root_mean_squared_error: 8.5428
# Epoch 72/100
# 28/28 [==============================] - 5s 190ms/step - loss: 35.4331 - mean_squared_error: 35.4331 - mean_absolute_error: 2.9403 - root_mean_squared_error: 5.9526 - val_loss: 77.2715 - val_mean_squared_error: 77.2715 - val_mean_absolute_error: 4.2123 - val_root_mean_squared_error: 8.7904
# Epoch 73/100
# 28/28 [==============================] - 6s 212ms/step - loss: 34.1395 - mean_squared_error: 34.1395 - mean_absolute_error: 2.8663 - root_mean_squared_error: 5.8429 - val_loss: 69.3798 - val_mean_squared_error: 69.3799 - val_mean_absolute_error: 3.8394 - val_root_mean_squared_error: 8.3295
# Epoch 74/100
# 28/28 [==============================] - 5s 194ms/step - loss: 35.6581 - mean_squared_error: 35.6581 - mean_absolute_error: 2.9415 - root_mean_squared_error: 5.9714 - val_loss: 61.3985 - val_mean_squared_error: 61.3985 - val_mean_absolute_error: 3.7946 - val_root_mean_squared_error: 7.8357
# Epoch 75/100
# 28/28 [==============================] - 6s 229ms/step - loss: 33.4152 - mean_squared_error: 33.4152 - mean_absolute_error: 2.8666 - root_mean_squared_error: 5.7806 - val_loss: 64.2155 - val_mean_squared_error: 64.2155 - val_mean_absolute_error: 3.8697 - val_root_mean_squared_error: 8.0135
# Epoch 76/100
# 28/28 [==============================] - 5s 192ms/step - loss: 33.4825 - mean_squared_error: 33.4825 - mean_absolute_error: 2.8302 - root_mean_squared_error: 5.7864 - val_loss: 63.4651 - val_mean_squared_error: 63.4651 - val_mean_absolute_error: 3.8778 - val_root_mean_squared_error: 7.9665
# Epoch 77/100
# 28/28 [==============================] - 6s 211ms/step - loss: 34.2709 - mean_squared_error: 34.2709 - mean_absolute_error: 2.8676 - root_mean_squared_error: 5.8541 - val_loss: 62.6429 - val_mean_squared_error: 62.6429 - val_mean_absolute_error: 3.7606 - val_root_mean_squared_error: 7.9147
# Epoch 78/100
# 28/28 [==============================] - 5s 184ms/step - loss: 34.2379 - mean_squared_error: 34.2379 - mean_absolute_error: 2.8617 - root_mean_squared_error: 5.8513 - val_loss: 69.3995 - val_mean_squared_error: 69.3995 - val_mean_absolute_error: 4.0490 - val_root_mean_squared_error: 8.3306
# Epoch 79/100
# 28/28 [==============================] - 5s 186ms/step - loss: 33.2501 - mean_squared_error: 33.2501 - mean_absolute_error: 2.8227 - root_mean_squared_error: 5.7663 - val_loss: 64.0423 - val_mean_squared_error: 64.0423 - val_mean_absolute_error: 3.8733 - val_root_mean_squared_error: 8.0026
# Epoch 80/100
# 28/28 [==============================] - 6s 206ms/step - loss: 32.2975 - mean_squared_error: 32.2975 - mean_absolute_error: 2.7898 - root_mean_squared_error: 5.6831 - val_loss: 69.0823 - val_mean_squared_error: 69.0823 - val_mean_absolute_error: 4.0805 - val_root_mean_squared_error: 8.3116
# Epoch 81/100
# 28/28 [==============================] - 5s 182ms/step - loss: 33.0869 - mean_squared_error: 33.0869 - mean_absolute_error: 2.8048 - root_mean_squared_error: 5.7521 - val_loss: 70.0070 - val_mean_squared_error: 70.0070 - val_mean_absolute_error: 4.1166 - val_root_mean_squared_error: 8.3670
# Epoch 82/100
# 28/28 [==============================] - 6s 215ms/step - loss: 32.7127 - mean_squared_error: 32.7127 - mean_absolute_error: 2.7994 - root_mean_squared_error: 5.7195 - val_loss: 63.2182 - val_mean_squared_error: 63.2182 - val_mean_absolute_error: 3.9493 - val_root_mean_squared_error: 7.9510
# Epoch 83/100
# 28/28 [==============================] - 5s 191ms/step - loss: 32.1265 - mean_squared_error: 32.1265 - mean_absolute_error: 2.7576 - root_mean_squared_error: 5.6680 - val_loss: 61.0678 - val_mean_squared_error: 61.0678 - val_mean_absolute_error: 3.8285 - val_root_mean_squared_error: 7.8146
# Epoch 84/100
# 28/28 [==============================] - 6s 209ms/step - loss: 32.1970 - mean_squared_error: 32.1970 - mean_absolute_error: 2.7968 - root_mean_squared_error: 5.6742 - val_loss: 62.6635 - val_mean_squared_error: 62.6635 - val_mean_absolute_error: 3.7707 - val_root_mean_squared_error: 7.9160
# Epoch 85/100
# 28/28 [==============================] - 6s 200ms/step - loss: 31.4528 - mean_squared_error: 31.4528 - mean_absolute_error: 2.7443 - root_mean_squared_error: 5.6083 - val_loss: 68.1369 - val_mean_squared_error: 68.1369 - val_mean_absolute_error: 3.8810 - val_root_mean_squared_error: 8.2545
# Epoch 86/100
# 28/28 [==============================] - 5s 185ms/step - loss: 32.0150 - mean_squared_error: 32.0150 - mean_absolute_error: 2.7731 - root_mean_squared_error: 5.6582 - val_loss: 68.0790 - val_mean_squared_error: 68.0790 - val_mean_absolute_error: 4.1122 - val_root_mean_squared_error: 8.2510
# Epoch 87/100
# 28/28 [==============================] - 6s 214ms/step - loss: 30.9607 - mean_squared_error: 30.9607 - mean_absolute_error: 2.7075 - root_mean_squared_error: 5.5642 - val_loss: 62.6986 - val_mean_squared_error: 62.6986 - val_mean_absolute_error: 3.7694 - val_root_mean_squared_error: 7.9182
# Epoch 88/100
# 28/28 [==============================] - 5s 190ms/step - loss: 31.4928 - mean_squared_error: 31.4928 - mean_absolute_error: 2.7505 - root_mean_squared_error: 5.6118 - val_loss: 62.9147 - val_mean_squared_error: 62.9147 - val_mean_absolute_error: 3.8547 - val_root_mean_squared_error: 7.9319
# Epoch 89/100
# 28/28 [==============================] - 6s 225ms/step - loss: 31.1079 - mean_squared_error: 31.1079 - mean_absolute_error: 2.7229 - root_mean_squared_error: 5.5774 - val_loss: 68.9176 - val_mean_squared_error: 68.9176 - val_mean_absolute_error: 4.1007 - val_root_mean_squared_error: 8.3017
# Epoch 90/100
# 28/28 [==============================] - 5s 185ms/step - loss: 31.0114 - mean_squared_error: 31.0114 - mean_absolute_error: 2.7323 - root_mean_squared_error: 5.5688 - val_loss: 68.1973 - val_mean_squared_error: 68.1973 - val_mean_absolute_error: 3.8336 - val_root_mean_squared_error: 8.2582
# Epoch 91/100
# 28/28 [==============================] - 6s 223ms/step - loss: 30.6051 - mean_squared_error: 30.6051 - mean_absolute_error: 2.7030 - root_mean_squared_error: 5.5322 - val_loss: 67.0611 - val_mean_squared_error: 67.0611 - val_mean_absolute_error: 3.8765 - val_root_mean_squared_error: 8.1891
# Epoch 92/100
# 28/28 [==============================] - 5s 182ms/step - loss: 30.7233 - mean_squared_error: 30.7233 - mean_absolute_error: 2.6811 - root_mean_squared_error: 5.5429 - val_loss: 66.4109 - val_mean_squared_error: 66.4109 - val_mean_absolute_error: 3.9592 - val_root_mean_squared_error: 8.1493
# Epoch 93/100
# 28/28 [==============================] - 5s 195ms/step - loss: 30.9072 - mean_squared_error: 30.9072 - mean_absolute_error: 2.7267 - root_mean_squared_error: 5.5594 - val_loss: 66.9804 - val_mean_squared_error: 66.9804 - val_mean_absolute_error: 4.0402 - val_root_mean_squared_error: 8.1842
# Epoch 94/100
# 28/28 [==============================] - 6s 199ms/step - loss: 31.8423 - mean_squared_error: 31.8423 - mean_absolute_error: 2.8313 - root_mean_squared_error: 5.6429 - val_loss: 65.1142 - val_mean_squared_error: 65.1142 - val_mean_absolute_error: 3.9727 - val_root_mean_squared_error: 8.0693
# Epoch 95/100
# 28/28 [==============================] - 5s 192ms/step - loss: 31.6388 - mean_squared_error: 31.6388 - mean_absolute_error: 2.7562 - root_mean_squared_error: 5.6248 - val_loss: 64.6013 - val_mean_squared_error: 64.6013 - val_mean_absolute_error: 3.9565 - val_root_mean_squared_error: 8.0375
# Epoch 96/100
# 28/28 [==============================] - 6s 214ms/step - loss: 31.7472 - mean_squared_error: 31.7472 - mean_absolute_error: 2.7585 - root_mean_squared_error: 5.6345 - val_loss: 70.4577 - val_mean_squared_error: 70.4577 - val_mean_absolute_error: 4.1042 - val_root_mean_squared_error: 8.3939
# Epoch 97/100
# 28/28 [==============================] - 5s 186ms/step - loss: 31.4265 - mean_squared_error: 31.4265 - mean_absolute_error: 2.7603 - root_mean_squared_error: 5.6059 - val_loss: 67.3717 - val_mean_squared_error: 67.3717 - val_mean_absolute_error: 4.0660 - val_root_mean_squared_error: 8.2080
# Epoch 98/100
# 28/28 [==============================] - 6s 216ms/step - loss: 31.7524 - mean_squared_error: 31.7524 - mean_absolute_error: 2.7839 - root_mean_squared_error: 5.6349 - val_loss: 68.6826 - val_mean_squared_error: 68.6826 - val_mean_absolute_error: 4.1570 - val_root_mean_squared_error: 8.2875
# Epoch 99/100
# 28/28 [==============================] - 5s 191ms/step - loss: 31.6694 - mean_squared_error: 31.6694 - mean_absolute_error: 2.7558 - root_mean_squared_error: 5.6276 - val_loss: 71.1048 - val_mean_squared_error: 71.1048 - val_mean_absolute_error: 4.1448 - val_root_mean_squared_error: 8.4324
# Epoch 100/100
# 28/28 [==============================] - 5s 193ms/step - loss: 37.3427 - mean_squared_error: 37.3427 - mean_absolute_error: 2.9859 - root_mean_squared_error: 6.1109 - val_loss: 64.7322 - val_mean_squared_error: 64.7322 - val_mean_absolute_error: 3.8401 - val_root_mean_squared_error: 8.0456

# %% [markdown]
# # Training results

# %%
from utils.plotting import training_loss_plot

if not in_google_colab():
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

plot = training_loss_plot(train_score, filename='download/training_loss.pdf')
plot.show()

# %% [markdown]
# # Testing

# %%
### Predict on the test set
from utils.evaluation import phases_report, phases_report_std

print('Testmetriken:')

report = phases_report(y_pred, bis.test_dataset, propofolrate.test_dataset)
report
# Out:
# Testmetriken:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                 106.97       139.87           7.35         7.55
# Induction           286.04       637.60          12.50        18.34
# Maintenance          68.05        60.90           6.19         5.68
# Recovery            251.12       361.57          11.66        13.46
#
#             Prediction RMSE Baseline RMSE
# All                   10.34         11.83
# Induction             16.91         25.25
# Maintenance            8.25          7.80
# Recovery              15.85         19.02

# %%
phases_report_std(report, y_pred, bis.test_dataset, propofolrate.test_dataset)
# Out:
# All      	min: 	 15 	max: 	 6
# Induction 	min: 	 23 	max: 	 10
# Maintenance 	min: 	 13 	max: 	 6
# Recovery 	min: 	 19 	max: 	 22
#              Prediction MSE  Baseline MSE  Prediction MAE  Baseline MAE  \
# All                   70.71         82.42            2.54          2.54
# Induction            301.17        403.81            6.83          8.45
# Maintenance           48.54         43.11            2.37          2.15
# Recovery             139.03        185.95            5.07          6.28
#
#              Prediction RMSE  Baseline RMSE
# All                     3.21           3.31
# Induction               7.53           7.29
# Maintenance             2.65           2.51
# Recovery                5.78           6.47

# %%
from utils.plotting import full_histogramm_plot

plot = full_histogramm_plot(groundtruth = bis.test_dataset, prediction = y_pred, filename='download/histogramm.pdf')
plot.show()

# %%
from utils.plotting import single_prediction_plot

for case in test_index:
    single_prediction_plot(
        case = case,
        index = test_index,
        groundtruth = bis.test_dataset,
        prediction = y_pred,
        infusion = propofolrate.test_dataset,
        error = 'Prediction RMSE',
        filename = 'download/' + str(case) + '.pdf')

print('Finished')
# Out:
# /content/utils/plotting.py:79: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(12/2.54, 6/2.54))
# Finished

# %%
from utils.plotting import full_prediction_plot

full_prediction_plot(index = test_index, groundtruth = bis.test_dataset, prediction = y_pred, infusion = propofolrate.test_dataset)
