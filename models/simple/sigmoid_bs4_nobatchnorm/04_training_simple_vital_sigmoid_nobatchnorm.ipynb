# %% [markdown]
# # Initialization

# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset02/'
vitaldbpath = 'vitaldb_tiva/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt
import pickle

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 630, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 630 (delta 87), reused 169 (delta 87), pack-reused 461
# Receiving objects: 100% (630/630), 124.94 MiB | 13.30 MiB/s, done.
# Resolving deltas: 100% (291/291), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl.metadata (520 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.31.0)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.1 MB/s eta 0:00:00
# Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 14.6 MB/s eta 0:00:00
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %% [markdown]
# # Data loading

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolrate.name = 'Propofol Rate'
    propofolrate.tracks = ['Orchestra/PPF20_RATE']
    propofolrate.filterON = False
    propofolrate.generateDataset(normalization=md.NormNone)
    propofolrate.save('03_propofol_rate.npz')

    remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    remifentanilrate.name = 'Remifentanil Rate'
    remifentanilrate.tracks = ['Orchestra/RFTN20_RATE']
    remifentanilrate.filterON = False
    remifentanilrate.generateDataset(normalization=md.NormNone)
    remifentanilrate.save('03_remifentanil_rate.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolrate.load('03_propofol_rate.npz')

remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
remifentanilrate.load('03_remifentanil_rate.npz')

train_index, val_index, test_index = bis.split(np.array(bis.index))

# %% [markdown]
# # Model creation

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### LSTM layers for the blood pressure data

### Combine the vital data
vital_train = np.concatenate([bloodpressure.train_dataset, etCO2.train_dataset, spO2.train_dataset, hr.train_dataset], axis=2)
vital_validation = np.concatenate([bloodpressure.validation_dataset, etCO2.validation_dataset, spO2.validation_dataset, hr.validation_dataset], axis=2)
vital_test = np.concatenate([bloodpressure.test_dataset, etCO2.test_dataset, spO2.test_dataset, hr.test_dataset], axis=2)

### LSTM layers for the vital data
input_vital = Input(shape=(None, vital_train.shape[2]))
vital_layer = Masking(mask_value=0.0)(input_vital)

### INFO layers
input_info = Input(shape=(info.train_dataset.shape[1],))
info_layer = RepeatVector(vital_train.shape[1])(input_info)

## Concatenate the LSTM output with the info layer
comb_layer = Concatenate()([vital_layer, info_layer])
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=128, activation='relu')(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=32, activation='relu')(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)


output = Dense(units=1, activation='sigmoid')(comb_layer)
output = Lambda(lambda x: x * 100)(output)

# Define the model
model = Model(inputs=[input_vital, input_info], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 6)]            0         []
#
#  input_2 (InputLayer)        [(None, 5)]                  0         []
#
#  masking (Masking)           (None, None, 6)              0         ['input_1[0][0]']
#
#  repeat_vector (RepeatVecto  (None, 3680, 5)              0         ['input_2[0][0]']
#  r)
#
#  concatenate (Concatenate)   (None, 3680, 11)             0         ['masking[0][0]',
#                                                                      'repeat_vector[0][0]']
#
#  lstm (LSTM)                 (None, 3680, 32)             5632      ['concatenate[0][0]']
#
#  lstm_1 (LSTM)               (None, 3680, 32)             8320      ['lstm[0][0]']
#
#  lstm_2 (LSTM)               (None, 3680, 32)             8320      ['lstm_1[0][0]']
#
#  dense (Dense)               (None, 3680, 128)            4224      ['lstm_2[0][0]']
#
#  dense_1 (Dense)             (None, 3680, 32)             4128      ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 3680, 1)              33        ['dense_1[0][0]']
#
#  lambda (Lambda)             (None, 3680, 1)              0         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 30657 (119.75 KB)
# Trainable params: 30657 (119.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %%
# Rolling mean on BIS data
y = pd.DataFrame(bis.train_dataset[:,:,0].T).rolling(min_periods=1,window=20, center=True).mean().to_numpy().T[:,:,np.newaxis]

# Define training stop criteria
class StopTrainingCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(StopTrainingCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_loss') is not None:
            if logs.get('val_loss') < self.threshold:
                print(f"\nValidation loss is below {self.threshold}, stopping training.")
                self.model.stop_training = True

stop_training_callback = StopTrainingCallback(threshold = 35)


if in_google_colab():
    # Train the model
    history = model.fit([vital_train, info.train_dataset],
                        y,
                        validation_data=([vital_validation, info.validation_dataset], bis.validation_dataset),
                        epochs=100,
                        batch_size=4,
                        callbacks=[stop_training_callback]
                        )

    train_score = history.history

    # Save the model
    model.save('download/model.keras')

    # Save the training history
    with open('download/train_score.pkl', 'wb') as f:
        pickle.dump(train_score, f)

    # Save the prediction
    y_pred = model.predict([vital_test, info.test_dataset], verbose=0)
    with open('download/prediction.pkl', 'wb') as f:
        pickle.dump(y_pred, f)

else:
    # Load train score data
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

    # Load test prediction data
    with open('prediction.pkl', 'rb') as f:
        y_pred = pickle.load(f)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 28s 353ms/step - loss: 1337.9194 - mean_squared_error: 1337.9194 - mean_absolute_error: 30.6973 - root_mean_squared_error: 36.5776 - val_loss: 1164.7009 - val_mean_squared_error: 1164.7010 - val_mean_absolute_error: 29.1756 - val_root_mean_squared_error: 34.1277
# Epoch 2/100
# 28/28 [==============================] - 5s 193ms/step - loss: 803.1691 - mean_squared_error: 803.1691 - mean_absolute_error: 23.9818 - root_mean_squared_error: 28.3402 - val_loss: 489.7130 - val_mean_squared_error: 489.7129 - val_mean_absolute_error: 19.5331 - val_root_mean_squared_error: 22.1295
# Epoch 3/100
# 28/28 [==============================] - 5s 180ms/step - loss: 267.9814 - mean_squared_error: 267.9814 - mean_absolute_error: 14.0498 - root_mean_squared_error: 16.3701 - val_loss: 167.3029 - val_mean_squared_error: 167.3029 - val_mean_absolute_error: 11.3836 - val_root_mean_squared_error: 12.9346
# Epoch 4/100
# 28/28 [==============================] - 6s 212ms/step - loss: 109.9686 - mean_squared_error: 109.9686 - mean_absolute_error: 8.6143 - root_mean_squared_error: 10.4866 - val_loss: 106.0490 - val_mean_squared_error: 106.0490 - val_mean_absolute_error: 8.0558 - val_root_mean_squared_error: 10.2980
# Epoch 5/100
# 28/28 [==============================] - 5s 187ms/step - loss: 81.6672 - mean_squared_error: 81.6672 - mean_absolute_error: 6.8852 - root_mean_squared_error: 9.0370 - val_loss: 93.0837 - val_mean_squared_error: 93.0837 - val_mean_absolute_error: 6.8411 - val_root_mean_squared_error: 9.6480
# Epoch 6/100
# 28/28 [==============================] - 6s 214ms/step - loss: 71.9539 - mean_squared_error: 71.9539 - mean_absolute_error: 6.0188 - root_mean_squared_error: 8.4826 - val_loss: 97.7844 - val_mean_squared_error: 97.7844 - val_mean_absolute_error: 6.3344 - val_root_mean_squared_error: 9.8886
# Epoch 7/100
# 28/28 [==============================] - 5s 184ms/step - loss: 67.4460 - mean_squared_error: 67.4460 - mean_absolute_error: 5.5594 - root_mean_squared_error: 8.2126 - val_loss: 87.1954 - val_mean_squared_error: 87.1954 - val_mean_absolute_error: 6.1850 - val_root_mean_squared_error: 9.3378
# Epoch 8/100
# 28/28 [==============================] - 6s 207ms/step - loss: 63.7767 - mean_squared_error: 63.7767 - mean_absolute_error: 5.2962 - root_mean_squared_error: 7.9860 - val_loss: 95.4444 - val_mean_squared_error: 95.4444 - val_mean_absolute_error: 6.0449 - val_root_mean_squared_error: 9.7696
# Epoch 9/100
# 28/28 [==============================] - 5s 174ms/step - loss: 60.7116 - mean_squared_error: 60.7116 - mean_absolute_error: 5.0074 - root_mean_squared_error: 7.7918 - val_loss: 84.9485 - val_mean_squared_error: 84.9485 - val_mean_absolute_error: 5.4998 - val_root_mean_squared_error: 9.2168
# Epoch 10/100
# 28/28 [==============================] - 5s 187ms/step - loss: 57.4768 - mean_squared_error: 57.4768 - mean_absolute_error: 4.7871 - root_mean_squared_error: 7.5813 - val_loss: 83.6636 - val_mean_squared_error: 83.6636 - val_mean_absolute_error: 5.3338 - val_root_mean_squared_error: 9.1468
# Epoch 11/100
# 28/28 [==============================] - 6s 226ms/step - loss: 56.3652 - mean_squared_error: 56.3652 - mean_absolute_error: 4.7025 - root_mean_squared_error: 7.5077 - val_loss: 89.7761 - val_mean_squared_error: 89.7761 - val_mean_absolute_error: 5.5299 - val_root_mean_squared_error: 9.4750
# Epoch 12/100
# 28/28 [==============================] - 5s 183ms/step - loss: 53.7003 - mean_squared_error: 53.7003 - mean_absolute_error: 4.5395 - root_mean_squared_error: 7.3280 - val_loss: 87.1069 - val_mean_squared_error: 87.1069 - val_mean_absolute_error: 5.2641 - val_root_mean_squared_error: 9.3331
# Epoch 13/100
# 28/28 [==============================] - 6s 224ms/step - loss: 50.8834 - mean_squared_error: 50.8834 - mean_absolute_error: 4.3832 - root_mean_squared_error: 7.1333 - val_loss: 77.8475 - val_mean_squared_error: 77.8475 - val_mean_absolute_error: 5.0155 - val_root_mean_squared_error: 8.8231
# Epoch 14/100
# 28/28 [==============================] - 5s 170ms/step - loss: 52.2689 - mean_squared_error: 52.2689 - mean_absolute_error: 4.3577 - root_mean_squared_error: 7.2297 - val_loss: 87.9440 - val_mean_squared_error: 87.9440 - val_mean_absolute_error: 5.0554 - val_root_mean_squared_error: 9.3778
# Epoch 15/100
# 28/28 [==============================] - 6s 200ms/step - loss: 50.1469 - mean_squared_error: 50.1469 - mean_absolute_error: 4.2395 - root_mean_squared_error: 7.0814 - val_loss: 84.5750 - val_mean_squared_error: 84.5750 - val_mean_absolute_error: 5.0507 - val_root_mean_squared_error: 9.1965
# Epoch 16/100
# 28/28 [==============================] - 5s 190ms/step - loss: 50.6804 - mean_squared_error: 50.6804 - mean_absolute_error: 4.2131 - root_mean_squared_error: 7.1190 - val_loss: 72.1208 - val_mean_squared_error: 72.1208 - val_mean_absolute_error: 4.6677 - val_root_mean_squared_error: 8.4924
# Epoch 17/100
# 28/28 [==============================] - 5s 176ms/step - loss: 47.6664 - mean_squared_error: 47.6664 - mean_absolute_error: 4.0818 - root_mean_squared_error: 6.9041 - val_loss: 76.9097 - val_mean_squared_error: 76.9097 - val_mean_absolute_error: 4.7898 - val_root_mean_squared_error: 8.7698
# Epoch 18/100
# 28/28 [==============================] - 6s 217ms/step - loss: 47.7993 - mean_squared_error: 47.7993 - mean_absolute_error: 4.0287 - root_mean_squared_error: 6.9137 - val_loss: 76.5206 - val_mean_squared_error: 76.5207 - val_mean_absolute_error: 4.8288 - val_root_mean_squared_error: 8.7476
# Epoch 19/100
# 28/28 [==============================] - 5s 180ms/step - loss: 45.0945 - mean_squared_error: 45.0945 - mean_absolute_error: 3.9362 - root_mean_squared_error: 6.7152 - val_loss: 68.3198 - val_mean_squared_error: 68.3198 - val_mean_absolute_error: 4.6432 - val_root_mean_squared_error: 8.2656
# Epoch 20/100
# 28/28 [==============================] - 6s 218ms/step - loss: 43.7984 - mean_squared_error: 43.7984 - mean_absolute_error: 3.8656 - root_mean_squared_error: 6.6180 - val_loss: 67.4204 - val_mean_squared_error: 67.4204 - val_mean_absolute_error: 4.5641 - val_root_mean_squared_error: 8.2110
# Epoch 21/100
# 28/28 [==============================] - 5s 176ms/step - loss: 44.2594 - mean_squared_error: 44.2594 - mean_absolute_error: 3.8182 - root_mean_squared_error: 6.6528 - val_loss: 69.8569 - val_mean_squared_error: 69.8569 - val_mean_absolute_error: 4.6137 - val_root_mean_squared_error: 8.3580
# Epoch 22/100
# 28/28 [==============================] - 6s 199ms/step - loss: 43.8815 - mean_squared_error: 43.8815 - mean_absolute_error: 3.8214 - root_mean_squared_error: 6.6243 - val_loss: 65.6471 - val_mean_squared_error: 65.6471 - val_mean_absolute_error: 4.4741 - val_root_mean_squared_error: 8.1023
# Epoch 23/100
# 28/28 [==============================] - 5s 191ms/step - loss: 41.4309 - mean_squared_error: 41.4309 - mean_absolute_error: 3.6845 - root_mean_squared_error: 6.4367 - val_loss: 67.4282 - val_mean_squared_error: 67.4282 - val_mean_absolute_error: 4.4984 - val_root_mean_squared_error: 8.2115
# Epoch 24/100
# 28/28 [==============================] - 5s 180ms/step - loss: 41.0485 - mean_squared_error: 41.0485 - mean_absolute_error: 3.6652 - root_mean_squared_error: 6.4069 - val_loss: 75.0363 - val_mean_squared_error: 75.0363 - val_mean_absolute_error: 4.7470 - val_root_mean_squared_error: 8.6623
# Epoch 25/100
# 28/28 [==============================] - 7s 253ms/step - loss: 43.2374 - mean_squared_error: 43.2374 - mean_absolute_error: 3.7170 - root_mean_squared_error: 6.5755 - val_loss: 63.7998 - val_mean_squared_error: 63.7998 - val_mean_absolute_error: 4.3498 - val_root_mean_squared_error: 7.9875
# Epoch 26/100
# 28/28 [==============================] - 5s 179ms/step - loss: 42.8578 - mean_squared_error: 42.8578 - mean_absolute_error: 3.7371 - root_mean_squared_error: 6.5466 - val_loss: 74.5032 - val_mean_squared_error: 74.5032 - val_mean_absolute_error: 4.6379 - val_root_mean_squared_error: 8.6315
# Epoch 27/100
# 28/28 [==============================] - 6s 214ms/step - loss: 40.6247 - mean_squared_error: 40.6248 - mean_absolute_error: 3.5886 - root_mean_squared_error: 6.3738 - val_loss: 63.9302 - val_mean_squared_error: 63.9302 - val_mean_absolute_error: 4.3699 - val_root_mean_squared_error: 7.9956
# Epoch 28/100
# 28/28 [==============================] - 5s 188ms/step - loss: 41.0923 - mean_squared_error: 41.0923 - mean_absolute_error: 3.6147 - root_mean_squared_error: 6.4103 - val_loss: 64.7827 - val_mean_squared_error: 64.7827 - val_mean_absolute_error: 4.3203 - val_root_mean_squared_error: 8.0488
# Epoch 29/100
# 28/28 [==============================] - 5s 188ms/step - loss: 39.9364 - mean_squared_error: 39.9364 - mean_absolute_error: 3.5569 - root_mean_squared_error: 6.3195 - val_loss: 85.1709 - val_mean_squared_error: 85.1709 - val_mean_absolute_error: 4.8117 - val_root_mean_squared_error: 9.2288
# Epoch 30/100
# 28/28 [==============================] - 6s 199ms/step - loss: 39.7797 - mean_squared_error: 39.7797 - mean_absolute_error: 3.5028 - root_mean_squared_error: 6.3071 - val_loss: 75.2860 - val_mean_squared_error: 75.2860 - val_mean_absolute_error: 4.5638 - val_root_mean_squared_error: 8.6768
# Epoch 31/100
# 28/28 [==============================] - 5s 185ms/step - loss: 38.9636 - mean_squared_error: 38.9636 - mean_absolute_error: 3.4862 - root_mean_squared_error: 6.2421 - val_loss: 74.7497 - val_mean_squared_error: 74.7497 - val_mean_absolute_error: 4.4747 - val_root_mean_squared_error: 8.6458
# Epoch 32/100
# 28/28 [==============================] - 6s 225ms/step - loss: 39.8385 - mean_squared_error: 39.8385 - mean_absolute_error: 3.4942 - root_mean_squared_error: 6.3118 - val_loss: 74.2113 - val_mean_squared_error: 74.2113 - val_mean_absolute_error: 4.4696 - val_root_mean_squared_error: 8.6146
# Epoch 33/100
# 28/28 [==============================] - 5s 174ms/step - loss: 38.4214 - mean_squared_error: 38.4214 - mean_absolute_error: 3.4403 - root_mean_squared_error: 6.1985 - val_loss: 63.8294 - val_mean_squared_error: 63.8294 - val_mean_absolute_error: 4.3074 - val_root_mean_squared_error: 7.9893
# Epoch 34/100
# 28/28 [==============================] - 6s 206ms/step - loss: 37.4546 - mean_squared_error: 37.4546 - mean_absolute_error: 3.3956 - root_mean_squared_error: 6.1200 - val_loss: 64.9087 - val_mean_squared_error: 64.9087 - val_mean_absolute_error: 4.2570 - val_root_mean_squared_error: 8.0566
# Epoch 35/100
# 28/28 [==============================] - 5s 180ms/step - loss: 37.4412 - mean_squared_error: 37.4412 - mean_absolute_error: 3.3676 - root_mean_squared_error: 6.1189 - val_loss: 75.8968 - val_mean_squared_error: 75.8967 - val_mean_absolute_error: 4.4703 - val_root_mean_squared_error: 8.7119
# Epoch 36/100
# 28/28 [==============================] - 5s 191ms/step - loss: 36.5607 - mean_squared_error: 36.5607 - mean_absolute_error: 3.3368 - root_mean_squared_error: 6.0465 - val_loss: 63.2142 - val_mean_squared_error: 63.2142 - val_mean_absolute_error: 4.1189 - val_root_mean_squared_error: 7.9507
# Epoch 37/100
# 28/28 [==============================] - 6s 212ms/step - loss: 38.8905 - mean_squared_error: 38.8905 - mean_absolute_error: 3.4347 - root_mean_squared_error: 6.2362 - val_loss: 65.2552 - val_mean_squared_error: 65.2552 - val_mean_absolute_error: 4.2481 - val_root_mean_squared_error: 8.0781
# Epoch 38/100
# 28/28 [==============================] - 5s 189ms/step - loss: 37.4448 - mean_squared_error: 37.4448 - mean_absolute_error: 3.3446 - root_mean_squared_error: 6.1192 - val_loss: 67.3389 - val_mean_squared_error: 67.3389 - val_mean_absolute_error: 4.2796 - val_root_mean_squared_error: 8.2060
# Epoch 39/100
# 28/28 [==============================] - 6s 207ms/step - loss: 38.7683 - mean_squared_error: 38.7683 - mean_absolute_error: 3.3731 - root_mean_squared_error: 6.2264 - val_loss: 69.9219 - val_mean_squared_error: 69.9219 - val_mean_absolute_error: 4.5511 - val_root_mean_squared_error: 8.3619
# Epoch 40/100
# 28/28 [==============================] - 5s 189ms/step - loss: 43.0569 - mean_squared_error: 43.0569 - mean_absolute_error: 3.5668 - root_mean_squared_error: 6.5618 - val_loss: 61.8094 - val_mean_squared_error: 61.8094 - val_mean_absolute_error: 3.9461 - val_root_mean_squared_error: 7.8619
# Epoch 41/100
# 28/28 [==============================] - 6s 211ms/step - loss: 43.6238 - mean_squared_error: 43.6238 - mean_absolute_error: 3.4754 - root_mean_squared_error: 6.6048 - val_loss: 65.7810 - val_mean_squared_error: 65.7810 - val_mean_absolute_error: 4.3221 - val_root_mean_squared_error: 8.1105
# Epoch 42/100
# 28/28 [==============================] - 5s 177ms/step - loss: 38.9073 - mean_squared_error: 38.9073 - mean_absolute_error: 3.3568 - root_mean_squared_error: 6.2376 - val_loss: 64.7050 - val_mean_squared_error: 64.7050 - val_mean_absolute_error: 4.2251 - val_root_mean_squared_error: 8.0439
# Epoch 43/100
# 28/28 [==============================] - 5s 188ms/step - loss: 37.5990 - mean_squared_error: 37.5990 - mean_absolute_error: 3.2939 - root_mean_squared_error: 6.1318 - val_loss: 68.9739 - val_mean_squared_error: 68.9739 - val_mean_absolute_error: 4.2038 - val_root_mean_squared_error: 8.3051
# Epoch 44/100
# 28/28 [==============================] - 6s 206ms/step - loss: 36.4361 - mean_squared_error: 36.4361 - mean_absolute_error: 3.2313 - root_mean_squared_error: 6.0362 - val_loss: 69.8560 - val_mean_squared_error: 69.8560 - val_mean_absolute_error: 4.2600 - val_root_mean_squared_error: 8.3580
# Epoch 45/100
# 28/28 [==============================] - 5s 177ms/step - loss: 35.6658 - mean_squared_error: 35.6658 - mean_absolute_error: 3.1762 - root_mean_squared_error: 5.9721 - val_loss: 66.6405 - val_mean_squared_error: 66.6405 - val_mean_absolute_error: 4.2099 - val_root_mean_squared_error: 8.1634
# Epoch 46/100
# 28/28 [==============================] - 6s 214ms/step - loss: 35.0762 - mean_squared_error: 35.0762 - mean_absolute_error: 3.1628 - root_mean_squared_error: 5.9225 - val_loss: 64.4444 - val_mean_squared_error: 64.4444 - val_mean_absolute_error: 4.1179 - val_root_mean_squared_error: 8.0277
# Epoch 47/100
# 28/28 [==============================] - 5s 175ms/step - loss: 35.9546 - mean_squared_error: 35.9546 - mean_absolute_error: 3.1903 - root_mean_squared_error: 5.9962 - val_loss: 65.3454 - val_mean_squared_error: 65.3454 - val_mean_absolute_error: 4.2029 - val_root_mean_squared_error: 8.0836
# Epoch 48/100
# 28/28 [==============================] - 6s 202ms/step - loss: 34.4831 - mean_squared_error: 34.4831 - mean_absolute_error: 3.1231 - root_mean_squared_error: 5.8722 - val_loss: 69.6498 - val_mean_squared_error: 69.6498 - val_mean_absolute_error: 4.1861 - val_root_mean_squared_error: 8.3456
# Epoch 49/100
# 28/28 [==============================] - 5s 181ms/step - loss: 33.7929 - mean_squared_error: 33.7929 - mean_absolute_error: 3.0984 - root_mean_squared_error: 5.8132 - val_loss: 66.4345 - val_mean_squared_error: 66.4345 - val_mean_absolute_error: 4.1974 - val_root_mean_squared_error: 8.1507
# Epoch 50/100
# 28/28 [==============================] - 5s 179ms/step - loss: 33.5593 - mean_squared_error: 33.5593 - mean_absolute_error: 3.0694 - root_mean_squared_error: 5.7930 - val_loss: 68.1471 - val_mean_squared_error: 68.1471 - val_mean_absolute_error: 4.2085 - val_root_mean_squared_error: 8.2551
# Epoch 51/100
# 28/28 [==============================] - 6s 210ms/step - loss: 34.1506 - mean_squared_error: 34.1506 - mean_absolute_error: 3.0939 - root_mean_squared_error: 5.8438 - val_loss: 69.4369 - val_mean_squared_error: 69.4369 - val_mean_absolute_error: 4.1923 - val_root_mean_squared_error: 8.3329
# Epoch 52/100
# 28/28 [==============================] - 5s 171ms/step - loss: 34.2093 - mean_squared_error: 34.2093 - mean_absolute_error: 3.0838 - root_mean_squared_error: 5.8489 - val_loss: 69.5145 - val_mean_squared_error: 69.5145 - val_mean_absolute_error: 4.2082 - val_root_mean_squared_error: 8.3375
# Epoch 53/100
# 28/28 [==============================] - 6s 210ms/step - loss: 33.9544 - mean_squared_error: 33.9544 - mean_absolute_error: 3.0730 - root_mean_squared_error: 5.8270 - val_loss: 64.5615 - val_mean_squared_error: 64.5615 - val_mean_absolute_error: 4.0395 - val_root_mean_squared_error: 8.0350
# Epoch 54/100
# 28/28 [==============================] - 5s 177ms/step - loss: 33.0906 - mean_squared_error: 33.0906 - mean_absolute_error: 3.0281 - root_mean_squared_error: 5.7524 - val_loss: 70.0198 - val_mean_squared_error: 70.0198 - val_mean_absolute_error: 4.1682 - val_root_mean_squared_error: 8.3678
# Epoch 55/100
# 28/28 [==============================] - 5s 187ms/step - loss: 33.2374 - mean_squared_error: 33.2374 - mean_absolute_error: 3.0324 - root_mean_squared_error: 5.7652 - val_loss: 60.7267 - val_mean_squared_error: 60.7267 - val_mean_absolute_error: 4.0026 - val_root_mean_squared_error: 7.7927
# Epoch 56/100
# 28/28 [==============================] - 6s 208ms/step - loss: 33.4211 - mean_squared_error: 33.4211 - mean_absolute_error: 3.0260 - root_mean_squared_error: 5.7811 - val_loss: 66.1811 - val_mean_squared_error: 66.1811 - val_mean_absolute_error: 4.2296 - val_root_mean_squared_error: 8.1352
# Epoch 57/100
# 28/28 [==============================] - 5s 192ms/step - loss: 33.8310 - mean_squared_error: 33.8310 - mean_absolute_error: 3.0603 - root_mean_squared_error: 5.8164 - val_loss: 63.8733 - val_mean_squared_error: 63.8733 - val_mean_absolute_error: 4.0958 - val_root_mean_squared_error: 7.9921
# Epoch 58/100
# 28/28 [==============================] - 6s 205ms/step - loss: 33.6105 - mean_squared_error: 33.6105 - mean_absolute_error: 3.0385 - root_mean_squared_error: 5.7975 - val_loss: 60.1080 - val_mean_squared_error: 60.1080 - val_mean_absolute_error: 3.9450 - val_root_mean_squared_error: 7.7529
# Epoch 59/100
# 28/28 [==============================] - 5s 186ms/step - loss: 33.3884 - mean_squared_error: 33.3884 - mean_absolute_error: 3.0334 - root_mean_squared_error: 5.7783 - val_loss: 64.5440 - val_mean_squared_error: 64.5440 - val_mean_absolute_error: 4.1279 - val_root_mean_squared_error: 8.0339
# Epoch 60/100
# 28/28 [==============================] - 6s 214ms/step - loss: 31.6726 - mean_squared_error: 31.6726 - mean_absolute_error: 2.9340 - root_mean_squared_error: 5.6278 - val_loss: 68.7648 - val_mean_squared_error: 68.7648 - val_mean_absolute_error: 4.1646 - val_root_mean_squared_error: 8.2925
# Epoch 61/100
# 28/28 [==============================] - 5s 187ms/step - loss: 31.8420 - mean_squared_error: 31.8420 - mean_absolute_error: 2.9422 - root_mean_squared_error: 5.6429 - val_loss: 75.1219 - val_mean_squared_error: 75.1219 - val_mean_absolute_error: 4.3544 - val_root_mean_squared_error: 8.6673
# Epoch 62/100
# 28/28 [==============================] - 5s 183ms/step - loss: 31.7196 - mean_squared_error: 31.7196 - mean_absolute_error: 2.9300 - root_mean_squared_error: 5.6320 - val_loss: 68.2033 - val_mean_squared_error: 68.2033 - val_mean_absolute_error: 4.1616 - val_root_mean_squared_error: 8.2585
# Epoch 63/100
# 28/28 [==============================] - 6s 209ms/step - loss: 31.4116 - mean_squared_error: 31.4116 - mean_absolute_error: 2.9193 - root_mean_squared_error: 5.6046 - val_loss: 62.6383 - val_mean_squared_error: 62.6382 - val_mean_absolute_error: 3.9692 - val_root_mean_squared_error: 7.9144
# Epoch 64/100
# 28/28 [==============================] - 5s 175ms/step - loss: 34.3287 - mean_squared_error: 34.3287 - mean_absolute_error: 3.0289 - root_mean_squared_error: 5.8591 - val_loss: 61.7157 - val_mean_squared_error: 61.7157 - val_mean_absolute_error: 3.9322 - val_root_mean_squared_error: 7.8559
# Epoch 65/100
# 28/28 [==============================] - 6s 209ms/step - loss: 36.4555 - mean_squared_error: 36.4555 - mean_absolute_error: 3.1293 - root_mean_squared_error: 6.0378 - val_loss: 66.7982 - val_mean_squared_error: 66.7982 - val_mean_absolute_error: 4.0624 - val_root_mean_squared_error: 8.1730
# Epoch 66/100
# 28/28 [==============================] - 5s 185ms/step - loss: 34.1628 - mean_squared_error: 34.1628 - mean_absolute_error: 3.0033 - root_mean_squared_error: 5.8449 - val_loss: 60.9738 - val_mean_squared_error: 60.9738 - val_mean_absolute_error: 4.0279 - val_root_mean_squared_error: 7.8086
# Epoch 67/100
# 28/28 [==============================] - 6s 210ms/step - loss: 32.8642 - mean_squared_error: 32.8642 - mean_absolute_error: 2.9639 - root_mean_squared_error: 5.7327 - val_loss: 68.1439 - val_mean_squared_error: 68.1439 - val_mean_absolute_error: 4.1852 - val_root_mean_squared_error: 8.2549
# Epoch 68/100
# 28/28 [==============================] - 5s 180ms/step - loss: 31.4945 - mean_squared_error: 31.4945 - mean_absolute_error: 2.9048 - root_mean_squared_error: 5.6120 - val_loss: 60.0131 - val_mean_squared_error: 60.0131 - val_mean_absolute_error: 3.8629 - val_root_mean_squared_error: 7.7468
# Epoch 69/100
# 28/28 [==============================] - 6s 209ms/step - loss: 31.6830 - mean_squared_error: 31.6830 - mean_absolute_error: 2.8934 - root_mean_squared_error: 5.6288 - val_loss: 63.6780 - val_mean_squared_error: 63.6780 - val_mean_absolute_error: 4.0529 - val_root_mean_squared_error: 7.9799
# Epoch 70/100
# 28/28 [==============================] - 6s 211ms/step - loss: 30.0250 - mean_squared_error: 30.0250 - mean_absolute_error: 2.8249 - root_mean_squared_error: 5.4795 - val_loss: 66.5886 - val_mean_squared_error: 66.5886 - val_mean_absolute_error: 4.1034 - val_root_mean_squared_error: 8.1602
# Epoch 71/100
# 28/28 [==============================] - 5s 182ms/step - loss: 32.1454 - mean_squared_error: 32.1454 - mean_absolute_error: 2.9359 - root_mean_squared_error: 5.6697 - val_loss: 63.0338 - val_mean_squared_error: 63.0338 - val_mean_absolute_error: 3.9641 - val_root_mean_squared_error: 7.9394
# Epoch 72/100
# 28/28 [==============================] - 6s 225ms/step - loss: 31.2690 - mean_squared_error: 31.2690 - mean_absolute_error: 2.8760 - root_mean_squared_error: 5.5919 - val_loss: 73.4384 - val_mean_squared_error: 73.4384 - val_mean_absolute_error: 4.3288 - val_root_mean_squared_error: 8.5696
# Epoch 73/100
# 28/28 [==============================] - 5s 176ms/step - loss: 32.8535 - mean_squared_error: 32.8535 - mean_absolute_error: 2.9351 - root_mean_squared_error: 5.7318 - val_loss: 61.4903 - val_mean_squared_error: 61.4903 - val_mean_absolute_error: 3.8259 - val_root_mean_squared_error: 7.8416
# Epoch 74/100
# 28/28 [==============================] - 5s 196ms/step - loss: 32.0019 - mean_squared_error: 32.0019 - mean_absolute_error: 2.8780 - root_mean_squared_error: 5.6570 - val_loss: 68.6644 - val_mean_squared_error: 68.6644 - val_mean_absolute_error: 4.1269 - val_root_mean_squared_error: 8.2864
# Epoch 75/100
# 28/28 [==============================] - 5s 193ms/step - loss: 33.6217 - mean_squared_error: 33.6217 - mean_absolute_error: 2.9537 - root_mean_squared_error: 5.7984 - val_loss: 65.5477 - val_mean_squared_error: 65.5477 - val_mean_absolute_error: 4.0874 - val_root_mean_squared_error: 8.0962
# Epoch 76/100
# 28/28 [==============================] - 5s 190ms/step - loss: 32.4642 - mean_squared_error: 32.4642 - mean_absolute_error: 2.9135 - root_mean_squared_error: 5.6977 - val_loss: 77.5965 - val_mean_squared_error: 77.5965 - val_mean_absolute_error: 4.2725 - val_root_mean_squared_error: 8.8089
# Epoch 77/100
# 28/28 [==============================] - 6s 216ms/step - loss: 30.4314 - mean_squared_error: 30.4314 - mean_absolute_error: 2.8062 - root_mean_squared_error: 5.5165 - val_loss: 75.3839 - val_mean_squared_error: 75.3839 - val_mean_absolute_error: 4.2561 - val_root_mean_squared_error: 8.6824
# Epoch 78/100
# 28/28 [==============================] - 5s 174ms/step - loss: 29.4787 - mean_squared_error: 29.4787 - mean_absolute_error: 2.7941 - root_mean_squared_error: 5.4294 - val_loss: 69.8421 - val_mean_squared_error: 69.8421 - val_mean_absolute_error: 4.2219 - val_root_mean_squared_error: 8.3572
# Epoch 79/100
# 28/28 [==============================] - 6s 220ms/step - loss: 28.6694 - mean_squared_error: 28.6694 - mean_absolute_error: 2.7389 - root_mean_squared_error: 5.3544 - val_loss: 64.0836 - val_mean_squared_error: 64.0836 - val_mean_absolute_error: 4.0216 - val_root_mean_squared_error: 8.0052
# Epoch 80/100
# 28/28 [==============================] - 5s 180ms/step - loss: 28.6969 - mean_squared_error: 28.6969 - mean_absolute_error: 2.7238 - root_mean_squared_error: 5.3570 - val_loss: 64.2537 - val_mean_squared_error: 64.2537 - val_mean_absolute_error: 4.0703 - val_root_mean_squared_error: 8.0158
# Epoch 81/100
# 28/28 [==============================] - 6s 202ms/step - loss: 29.1074 - mean_squared_error: 29.1074 - mean_absolute_error: 2.7453 - root_mean_squared_error: 5.3951 - val_loss: 65.6312 - val_mean_squared_error: 65.6312 - val_mean_absolute_error: 4.0168 - val_root_mean_squared_error: 8.1013
# Epoch 82/100
# 28/28 [==============================] - 5s 178ms/step - loss: 29.7606 - mean_squared_error: 29.7606 - mean_absolute_error: 2.7753 - root_mean_squared_error: 5.4553 - val_loss: 63.7042 - val_mean_squared_error: 63.7042 - val_mean_absolute_error: 3.9817 - val_root_mean_squared_error: 7.9815
# Epoch 83/100
# 28/28 [==============================] - 5s 185ms/step - loss: 28.6723 - mean_squared_error: 28.6723 - mean_absolute_error: 2.7308 - root_mean_squared_error: 5.3546 - val_loss: 69.4371 - val_mean_squared_error: 69.4371 - val_mean_absolute_error: 4.1463 - val_root_mean_squared_error: 8.3329
# Epoch 84/100
# 28/28 [==============================] - 6s 219ms/step - loss: 28.2380 - mean_squared_error: 28.2380 - mean_absolute_error: 2.6921 - root_mean_squared_error: 5.3139 - val_loss: 65.2145 - val_mean_squared_error: 65.2145 - val_mean_absolute_error: 4.0399 - val_root_mean_squared_error: 8.0756
# Epoch 85/100
# 28/28 [==============================] - 5s 175ms/step - loss: 30.7523 - mean_squared_error: 30.7523 - mean_absolute_error: 2.8289 - root_mean_squared_error: 5.5455 - val_loss: 75.1574 - val_mean_squared_error: 75.1574 - val_mean_absolute_error: 4.3760 - val_root_mean_squared_error: 8.6693
# Epoch 86/100
# 28/28 [==============================] - 6s 221ms/step - loss: 29.6992 - mean_squared_error: 29.6992 - mean_absolute_error: 2.7505 - root_mean_squared_error: 5.4497 - val_loss: 65.4946 - val_mean_squared_error: 65.4946 - val_mean_absolute_error: 4.0549 - val_root_mean_squared_error: 8.0929
# Epoch 87/100
# 28/28 [==============================] - 5s 186ms/step - loss: 29.5964 - mean_squared_error: 29.5964 - mean_absolute_error: 2.7487 - root_mean_squared_error: 5.4403 - val_loss: 61.1160 - val_mean_squared_error: 61.1160 - val_mean_absolute_error: 3.8422 - val_root_mean_squared_error: 7.8177
# Epoch 88/100
# 28/28 [==============================] - 5s 194ms/step - loss: 29.4468 - mean_squared_error: 29.4468 - mean_absolute_error: 2.7795 - root_mean_squared_error: 5.4265 - val_loss: 67.4287 - val_mean_squared_error: 67.4287 - val_mean_absolute_error: 4.1055 - val_root_mean_squared_error: 8.2115
# Epoch 89/100
# 28/28 [==============================] - 6s 198ms/step - loss: 28.2682 - mean_squared_error: 28.2682 - mean_absolute_error: 2.6964 - root_mean_squared_error: 5.3168 - val_loss: 68.9409 - val_mean_squared_error: 68.9409 - val_mean_absolute_error: 4.1172 - val_root_mean_squared_error: 8.3031
# Epoch 90/100
# 28/28 [==============================] - 5s 188ms/step - loss: 27.1912 - mean_squared_error: 27.1912 - mean_absolute_error: 2.6373 - root_mean_squared_error: 5.2145 - val_loss: 63.5869 - val_mean_squared_error: 63.5869 - val_mean_absolute_error: 3.9569 - val_root_mean_squared_error: 7.9741
# Epoch 91/100
# 28/28 [==============================] - 6s 224ms/step - loss: 26.8558 - mean_squared_error: 26.8558 - mean_absolute_error: 2.6083 - root_mean_squared_error: 5.1823 - val_loss: 63.5095 - val_mean_squared_error: 63.5095 - val_mean_absolute_error: 3.9427 - val_root_mean_squared_error: 7.9693
# Epoch 92/100
# 28/28 [==============================] - 5s 178ms/step - loss: 26.9710 - mean_squared_error: 26.9710 - mean_absolute_error: 2.6053 - root_mean_squared_error: 5.1934 - val_loss: 66.0998 - val_mean_squared_error: 66.0998 - val_mean_absolute_error: 4.0235 - val_root_mean_squared_error: 8.1302
# Epoch 93/100
# 28/28 [==============================] - 6s 213ms/step - loss: 26.5688 - mean_squared_error: 26.5688 - mean_absolute_error: 2.6133 - root_mean_squared_error: 5.1545 - val_loss: 64.4589 - val_mean_squared_error: 64.4589 - val_mean_absolute_error: 3.9390 - val_root_mean_squared_error: 8.0286
# Epoch 94/100
# 28/28 [==============================] - 5s 185ms/step - loss: 29.9461 - mean_squared_error: 29.9461 - mean_absolute_error: 2.7959 - root_mean_squared_error: 5.4723 - val_loss: 61.2453 - val_mean_squared_error: 61.2453 - val_mean_absolute_error: 3.8376 - val_root_mean_squared_error: 7.8259
# Epoch 95/100
# 28/28 [==============================] - 6s 201ms/step - loss: 36.3904 - mean_squared_error: 36.3904 - mean_absolute_error: 3.0279 - root_mean_squared_error: 6.0324 - val_loss: 73.3259 - val_mean_squared_error: 73.3259 - val_mean_absolute_error: 4.2701 - val_root_mean_squared_error: 8.5631
# Epoch 96/100
# 28/28 [==============================] - 5s 182ms/step - loss: 33.5750 - mean_squared_error: 33.5750 - mean_absolute_error: 2.9049 - root_mean_squared_error: 5.7944 - val_loss: 63.6700 - val_mean_squared_error: 63.6700 - val_mean_absolute_error: 3.9336 - val_root_mean_squared_error: 7.9793
# Epoch 97/100
# 28/28 [==============================] - 5s 185ms/step - loss: 31.7116 - mean_squared_error: 31.7116 - mean_absolute_error: 2.8257 - root_mean_squared_error: 5.6313 - val_loss: 64.3604 - val_mean_squared_error: 64.3604 - val_mean_absolute_error: 3.9464 - val_root_mean_squared_error: 8.0225
# Epoch 98/100
# 28/28 [==============================] - 6s 219ms/step - loss: 30.5140 - mean_squared_error: 30.5140 - mean_absolute_error: 2.7723 - root_mean_squared_error: 5.5239 - val_loss: 63.2118 - val_mean_squared_error: 63.2118 - val_mean_absolute_error: 3.9116 - val_root_mean_squared_error: 7.9506
# Epoch 99/100
# 28/28 [==============================] - 5s 179ms/step - loss: 28.6964 - mean_squared_error: 28.6964 - mean_absolute_error: 2.6801 - root_mean_squared_error: 5.3569 - val_loss: 61.3488 - val_mean_squared_error: 61.3488 - val_mean_absolute_error: 3.8569 - val_root_mean_squared_error: 7.8325
# Epoch 100/100
# 28/28 [==============================] - 6s 204ms/step - loss: 28.3894 - mean_squared_error: 28.3894 - mean_absolute_error: 2.6570 - root_mean_squared_error: 5.3282 - val_loss: 65.5406 - val_mean_squared_error: 65.5406 - val_mean_absolute_error: 3.9772 - val_root_mean_squared_error: 8.0957

# %% [markdown]
# # Training results

# %%
from utils.plotting import training_loss_plot

if not in_google_colab():
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

plot = training_loss_plot(train_score, filename='download/training_loss.pdf')
plot.show()

# %% [markdown]
# # Testing

# %%
### Predict on the test set
from utils.evaluation import phases_report, phases_report_std

print('Testmetriken:')

report = phases_report(y_pred, bis.test_dataset, propofolrate.test_dataset)
report
# Out:
# Testmetriken:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                 114.84       139.87           7.85         7.55
# Induction           279.98       637.60          12.61        18.34
# Maintenance          80.80        60.90           6.80         5.68
# Recovery            234.18       361.57          11.66        13.46
#
#             Prediction RMSE Baseline RMSE
# All                   10.72         11.83
# Induction             16.73         25.25
# Maintenance            8.99          7.80
# Recovery              15.30         19.02

# %%
phases_report_std(report, y_pred, bis.test_dataset, propofolrate.test_dataset)
# Out:
# All      	min: 	 15 	max: 	 6
# Induction 	min: 	 23 	max: 	 10
# Maintenance 	min: 	 13 	max: 	 6
# Recovery 	min: 	 19 	max: 	 22
#              Prediction MSE  Baseline MSE  Prediction MAE  Baseline MAE  \
# All                   67.17         82.42            2.30          2.54
# Induction            236.60        403.81            5.74          8.45
# Maintenance           52.56         43.11            2.12          2.15
# Recovery             138.36        185.95            4.75          6.28
#
#              Prediction RMSE  Baseline RMSE
# All                     2.83           3.31
# Induction               6.53           7.29
# Maintenance             2.63           2.51
# Recovery                5.26           6.47

# %%
from utils.plotting import full_histogramm_plot

plot = full_histogramm_plot(groundtruth = bis.test_dataset, prediction = y_pred, filename='download/histogramm.pdf')
plot.show()

# %%
from utils.plotting import single_prediction_plot

for case in test_index:
    single_prediction_plot(
        case = case,
        index = test_index,
        groundtruth = bis.test_dataset,
        prediction = y_pred,
        infusion = propofolrate.test_dataset,
        error = 'Prediction RMSE',
        filename = 'download/' + str(case) + '.pdf')

print('Finished')
# Out:
# /content/utils/plotting.py:79: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(12/2.54, 6/2.54))
# Finished

# %%
from utils.plotting import full_prediction_plot

full_prediction_plot(index = test_index, groundtruth = bis.test_dataset, prediction = y_pred, infusion = propofolrate.test_dataset)
