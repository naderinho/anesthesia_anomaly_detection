# %% [markdown]
# # Initialization

# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset02/'
vitaldbpath = 'vitaldb_tiva/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt
import pickle

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 472, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 472 (delta 2), reused 5 (delta 1), pack-reused 461
# Receiving objects: 100% (472/472), 79.91 MiB | 20.25 MiB/s, done.
# Resolving deltas: 100% (206/206), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.31.0)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %% [markdown]
# # Data loading

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolrate.name = 'Propofol Rate'
    propofolrate.tracks = ['Orchestra/PPF20_RATE']
    propofolrate.filterON = False
    propofolrate.generateDataset(normalization=md.NormNone)
    propofolrate.save('03_propofol_rate.npz')

    remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    remifentanilrate.name = 'Remifentanil Rate'
    remifentanilrate.tracks = ['Orchestra/RFTN20_RATE']
    remifentanilrate.filterON = False
    remifentanilrate.generateDataset(normalization=md.NormNone)
    remifentanilrate.save('03_remifentanil_rate.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolrate.load('03_propofol_rate.npz')

remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
remifentanilrate.load('03_remifentanil_rate.npz')

train_index, val_index, test_index = bis.split(np.array(bis.index))

# %% [markdown]
# # Model creation

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### LSTM layers for the blood pressure data

### Combine the vital data
vital_train = np.concatenate([bloodpressure.train_dataset, etCO2.train_dataset, spO2.train_dataset, hr.train_dataset], axis=2)
vital_validation = np.concatenate([bloodpressure.validation_dataset, etCO2.validation_dataset, spO2.validation_dataset, hr.validation_dataset], axis=2)
vital_test = np.concatenate([bloodpressure.test_dataset, etCO2.test_dataset, spO2.test_dataset, hr.test_dataset], axis=2)

### LSTM layers for the vital data
input_vital = Input(shape=(None, vital_train.shape[2]))
vital_layer = Masking(mask_value=0.0)(input_vital)

### INFO layers
input_info = Input(shape=(info.train_dataset.shape[1],))
info_layer = RepeatVector(vital_train.shape[1])(input_info)

## Concatenate the LSTM output with the info layer
comb_layer = Concatenate()([vital_layer, info_layer])
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=128, activation='relu')(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=32, activation='relu')(comb_layer)
#comb_layer = BatchNormalization()(comb_layer)


output = Dense(units=1, activation='sigmoid')(comb_layer)
output = Lambda(lambda x: x * 100)(output)

# Define the model
model = Model(inputs=[input_vital, input_info], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 6)]            0         []
#
#  input_2 (InputLayer)        [(None, 5)]                  0         []
#
#  masking (Masking)           (None, None, 6)              0         ['input_1[0][0]']
#
#  repeat_vector (RepeatVecto  (None, 3680, 5)              0         ['input_2[0][0]']
#  r)
#
#  concatenate (Concatenate)   (None, 3680, 11)             0         ['masking[0][0]',
#                                                                      'repeat_vector[0][0]']
#
#  lstm (LSTM)                 (None, 3680, 32)             5632      ['concatenate[0][0]']
#
#  lstm_1 (LSTM)               (None, 3680, 32)             8320      ['lstm[0][0]']
#
#  lstm_2 (LSTM)               (None, 3680, 32)             8320      ['lstm_1[0][0]']
#
#  dense (Dense)               (None, 3680, 128)            4224      ['lstm_2[0][0]']
#
#  dense_1 (Dense)             (None, 3680, 32)             4128      ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 3680, 1)              33        ['dense_1[0][0]']
#
#  lambda (Lambda)             (None, 3680, 1)              0         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 30657 (119.75 KB)
# Trainable params: 30657 (119.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %%
# Rolling mean on BIS data
y = pd.DataFrame(bis.train_dataset[:,:,0].T).rolling(min_periods=1,window=20, center=True).mean().to_numpy().T[:,:,np.newaxis]

# Define training stop criteria
class StopTrainingCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(StopTrainingCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_loss') is not None:
            if logs.get('val_loss') < self.threshold:
                print(f"\nValidation loss is below {self.threshold}, stopping training.")
                self.model.stop_training = True

stop_training_callback = StopTrainingCallback(threshold = 35)



# Train the model
history = model.fit([vital_train, info.train_dataset],
                    y,
                    validation_data=([vital_validation, info.validation_dataset], bis.validation_dataset),
                    epochs=50,
                    batch_size=4,
                    callbacks=[stop_training_callback]
                    )

# Save the model
model.save('model.keras')

# Save the training history
train_score = history.history

with open('train_score.pkl', 'wb') as f:
    pickle.dump(train_score, f)
# Out:
# Epoch 1/50
# 28/28 [==============================] - 33s 265ms/step - loss: 1333.0168 - mean_squared_error: 1333.0164 - mean_absolute_error: 30.6282 - root_mean_squared_error: 36.5105 - val_loss: 1147.5569 - val_mean_squared_error: 1147.5568 - val_mean_absolute_error: 28.9482 - val_root_mean_squared_error: 33.8756
# Epoch 2/50
# 28/28 [==============================] - 6s 208ms/step - loss: 806.7257 - mean_squared_error: 806.7257 - mean_absolute_error: 24.0376 - root_mean_squared_error: 28.4029 - val_loss: 504.5510 - val_mean_squared_error: 504.5510 - val_mean_absolute_error: 19.8302 - val_root_mean_squared_error: 22.4622
# Epoch 3/50
# 28/28 [==============================] - 5s 184ms/step - loss: 291.9391 - mean_squared_error: 291.9391 - mean_absolute_error: 14.6787 - root_mean_squared_error: 17.0862 - val_loss: 176.0664 - val_mean_squared_error: 176.0664 - val_mean_absolute_error: 11.4254 - val_root_mean_squared_error: 13.2690
# Epoch 4/50
# 28/28 [==============================] - 6s 216ms/step - loss: 122.7102 - mean_squared_error: 122.7102 - mean_absolute_error: 9.2612 - root_mean_squared_error: 11.0775 - val_loss: 113.9277 - val_mean_squared_error: 113.9277 - val_mean_absolute_error: 8.5816 - val_root_mean_squared_error: 10.6737
# Epoch 5/50
# 28/28 [==============================] - 5s 192ms/step - loss: 93.9374 - mean_squared_error: 93.9374 - mean_absolute_error: 7.5280 - root_mean_squared_error: 9.6921 - val_loss: 98.3848 - val_mean_squared_error: 98.3848 - val_mean_absolute_error: 7.0594 - val_root_mean_squared_error: 9.9189
# Epoch 6/50
# 28/28 [==============================] - 5s 178ms/step - loss: 79.0585 - mean_squared_error: 79.0585 - mean_absolute_error: 6.4589 - root_mean_squared_error: 8.8915 - val_loss: 88.9660 - val_mean_squared_error: 88.9660 - val_mean_absolute_error: 6.5806 - val_root_mean_squared_error: 9.4322
# Epoch 7/50
# 28/28 [==============================] - 5s 192ms/step - loss: 71.2073 - mean_squared_error: 71.2073 - mean_absolute_error: 5.9259 - root_mean_squared_error: 8.4384 - val_loss: 91.7096 - val_mean_squared_error: 91.7096 - val_mean_absolute_error: 6.4440 - val_root_mean_squared_error: 9.5765
# Epoch 8/50
# 28/28 [==============================] - 5s 168ms/step - loss: 69.4788 - mean_squared_error: 69.4788 - mean_absolute_error: 5.6792 - root_mean_squared_error: 8.3354 - val_loss: 88.3220 - val_mean_squared_error: 88.3220 - val_mean_absolute_error: 5.9583 - val_root_mean_squared_error: 9.3980
# Epoch 9/50
# 28/28 [==============================] - 6s 202ms/step - loss: 62.1423 - mean_squared_error: 62.1423 - mean_absolute_error: 5.2421 - root_mean_squared_error: 7.8830 - val_loss: 90.6519 - val_mean_squared_error: 90.6519 - val_mean_absolute_error: 6.1385 - val_root_mean_squared_error: 9.5211
# Epoch 10/50
# 28/28 [==============================] - 5s 172ms/step - loss: 61.8065 - mean_squared_error: 61.8065 - mean_absolute_error: 5.1132 - root_mean_squared_error: 7.8617 - val_loss: 90.1104 - val_mean_squared_error: 90.1104 - val_mean_absolute_error: 5.9700 - val_root_mean_squared_error: 9.4926
# Epoch 11/50
# 28/28 [==============================] - 5s 172ms/step - loss: 60.1032 - mean_squared_error: 60.1032 - mean_absolute_error: 4.9887 - root_mean_squared_error: 7.7526 - val_loss: 81.9726 - val_mean_squared_error: 81.9726 - val_mean_absolute_error: 5.4825 - val_root_mean_squared_error: 9.0539
# Epoch 12/50
# 28/28 [==============================] - 6s 205ms/step - loss: 57.6653 - mean_squared_error: 57.6653 - mean_absolute_error: 4.7756 - root_mean_squared_error: 7.5938 - val_loss: 81.9168 - val_mean_squared_error: 81.9168 - val_mean_absolute_error: 5.5145 - val_root_mean_squared_error: 9.0508
# Epoch 13/50
# 28/28 [==============================] - 5s 177ms/step - loss: 54.3616 - mean_squared_error: 54.3616 - mean_absolute_error: 4.6016 - root_mean_squared_error: 7.3730 - val_loss: 88.8159 - val_mean_squared_error: 88.8159 - val_mean_absolute_error: 5.5083 - val_root_mean_squared_error: 9.4242
# Epoch 14/50
# 28/28 [==============================] - 6s 217ms/step - loss: 53.3787 - mean_squared_error: 53.3787 - mean_absolute_error: 4.4958 - root_mean_squared_error: 7.3061 - val_loss: 83.6026 - val_mean_squared_error: 83.6026 - val_mean_absolute_error: 5.2591 - val_root_mean_squared_error: 9.1434
# Epoch 15/50
# 28/28 [==============================] - 5s 172ms/step - loss: 53.0864 - mean_squared_error: 53.0864 - mean_absolute_error: 4.4384 - root_mean_squared_error: 7.2860 - val_loss: 73.9003 - val_mean_squared_error: 73.9004 - val_mean_absolute_error: 5.1513 - val_root_mean_squared_error: 8.5965
# Epoch 16/50
# 28/28 [==============================] - 6s 207ms/step - loss: 50.8504 - mean_squared_error: 50.8504 - mean_absolute_error: 4.3192 - root_mean_squared_error: 7.1309 - val_loss: 75.6911 - val_mean_squared_error: 75.6911 - val_mean_absolute_error: 5.0508 - val_root_mean_squared_error: 8.7001
# Epoch 17/50
# 28/28 [==============================] - 5s 185ms/step - loss: 48.8898 - mean_squared_error: 48.8898 - mean_absolute_error: 4.2120 - root_mean_squared_error: 6.9921 - val_loss: 71.6095 - val_mean_squared_error: 71.6095 - val_mean_absolute_error: 4.7991 - val_root_mean_squared_error: 8.4622
# Epoch 18/50
# 28/28 [==============================] - 5s 178ms/step - loss: 54.0042 - mean_squared_error: 54.0042 - mean_absolute_error: 4.4294 - root_mean_squared_error: 7.3488 - val_loss: 75.8182 - val_mean_squared_error: 75.8182 - val_mean_absolute_error: 5.0561 - val_root_mean_squared_error: 8.7074
# Epoch 19/50
# 28/28 [==============================] - 6s 205ms/step - loss: 48.4770 - mean_squared_error: 48.4770 - mean_absolute_error: 4.1121 - root_mean_squared_error: 6.9625 - val_loss: 87.4927 - val_mean_squared_error: 87.4927 - val_mean_absolute_error: 5.2740 - val_root_mean_squared_error: 9.3538
# Epoch 20/50
# 28/28 [==============================] - 5s 180ms/step - loss: 50.1387 - mean_squared_error: 50.1387 - mean_absolute_error: 4.2365 - root_mean_squared_error: 7.0809 - val_loss: 76.4144 - val_mean_squared_error: 76.4144 - val_mean_absolute_error: 4.8918 - val_root_mean_squared_error: 8.7415
# Epoch 21/50
# 28/28 [==============================] - 6s 217ms/step - loss: 45.9431 - mean_squared_error: 45.9431 - mean_absolute_error: 4.0435 - root_mean_squared_error: 6.7781 - val_loss: 68.1359 - val_mean_squared_error: 68.1359 - val_mean_absolute_error: 4.5799 - val_root_mean_squared_error: 8.2544
# Epoch 22/50
# 28/28 [==============================] - 5s 180ms/step - loss: 45.5596 - mean_squared_error: 45.5596 - mean_absolute_error: 3.9631 - root_mean_squared_error: 6.7498 - val_loss: 93.6123 - val_mean_squared_error: 93.6123 - val_mean_absolute_error: 5.2876 - val_root_mean_squared_error: 9.6753
# Epoch 23/50
# 28/28 [==============================] - 5s 180ms/step - loss: 44.4209 - mean_squared_error: 44.4209 - mean_absolute_error: 3.8814 - root_mean_squared_error: 6.6649 - val_loss: 87.3465 - val_mean_squared_error: 87.3465 - val_mean_absolute_error: 5.1707 - val_root_mean_squared_error: 9.3459
# Epoch 24/50
# 28/28 [==============================] - 6s 204ms/step - loss: 46.2352 - mean_squared_error: 46.2352 - mean_absolute_error: 3.8839 - root_mean_squared_error: 6.7996 - val_loss: 75.5407 - val_mean_squared_error: 75.5407 - val_mean_absolute_error: 4.9362 - val_root_mean_squared_error: 8.6914
# Epoch 25/50
# 28/28 [==============================] - 5s 176ms/step - loss: 48.1999 - mean_squared_error: 48.1999 - mean_absolute_error: 4.0090 - root_mean_squared_error: 6.9426 - val_loss: 81.9873 - val_mean_squared_error: 81.9873 - val_mean_absolute_error: 5.0489 - val_root_mean_squared_error: 9.0547
# Epoch 26/50
# 28/28 [==============================] - 6s 212ms/step - loss: 49.8893 - mean_squared_error: 49.8893 - mean_absolute_error: 3.9799 - root_mean_squared_error: 7.0632 - val_loss: 68.4566 - val_mean_squared_error: 68.4566 - val_mean_absolute_error: 4.7091 - val_root_mean_squared_error: 8.2739
# Epoch 27/50
# 28/28 [==============================] - 5s 174ms/step - loss: 57.1979 - mean_squared_error: 57.1979 - mean_absolute_error: 4.2346 - root_mean_squared_error: 7.5629 - val_loss: 69.2830 - val_mean_squared_error: 69.2830 - val_mean_absolute_error: 4.6162 - val_root_mean_squared_error: 8.3236
# Epoch 28/50
# 28/28 [==============================] - 5s 182ms/step - loss: 50.3654 - mean_squared_error: 50.3654 - mean_absolute_error: 4.0196 - root_mean_squared_error: 7.0969 - val_loss: 63.3201 - val_mean_squared_error: 63.3201 - val_mean_absolute_error: 4.3760 - val_root_mean_squared_error: 7.9574
# Epoch 29/50
# 28/28 [==============================] - 5s 191ms/step - loss: 47.8865 - mean_squared_error: 47.8865 - mean_absolute_error: 3.9844 - root_mean_squared_error: 6.9200 - val_loss: 64.5107 - val_mean_squared_error: 64.5107 - val_mean_absolute_error: 4.3908 - val_root_mean_squared_error: 8.0319
# Epoch 30/50
# 28/28 [==============================] - 5s 176ms/step - loss: 45.9313 - mean_squared_error: 45.9313 - mean_absolute_error: 3.8333 - root_mean_squared_error: 6.7773 - val_loss: 70.4061 - val_mean_squared_error: 70.4061 - val_mean_absolute_error: 4.3625 - val_root_mean_squared_error: 8.3908
# Epoch 31/50
# 28/28 [==============================] - 6s 207ms/step - loss: 44.6563 - mean_squared_error: 44.6563 - mean_absolute_error: 3.7846 - root_mean_squared_error: 6.6825 - val_loss: 86.1505 - val_mean_squared_error: 86.1505 - val_mean_absolute_error: 5.1144 - val_root_mean_squared_error: 9.2817
# Epoch 32/50
# 28/28 [==============================] - 5s 176ms/step - loss: 46.5310 - mean_squared_error: 46.5310 - mean_absolute_error: 3.8949 - root_mean_squared_error: 6.8214 - val_loss: 69.3306 - val_mean_squared_error: 69.3306 - val_mean_absolute_error: 4.3421 - val_root_mean_squared_error: 8.3265
# Epoch 33/50
# 28/28 [==============================] - 5s 194ms/step - loss: 43.9676 - mean_squared_error: 43.9676 - mean_absolute_error: 3.7609 - root_mean_squared_error: 6.6308 - val_loss: 70.3174 - val_mean_squared_error: 70.3174 - val_mean_absolute_error: 4.6668 - val_root_mean_squared_error: 8.3855
# Epoch 34/50
# 28/28 [==============================] - 5s 195ms/step - loss: 40.6648 - mean_squared_error: 40.6648 - mean_absolute_error: 3.6529 - root_mean_squared_error: 6.3769 - val_loss: 64.2854 - val_mean_squared_error: 64.2854 - val_mean_absolute_error: 4.2425 - val_root_mean_squared_error: 8.0178
# Epoch 35/50
# 28/28 [==============================] - 5s 176ms/step - loss: 41.7559 - mean_squared_error: 41.7559 - mean_absolute_error: 3.6703 - root_mean_squared_error: 6.4619 - val_loss: 68.1397 - val_mean_squared_error: 68.1397 - val_mean_absolute_error: 4.4031 - val_root_mean_squared_error: 8.2547
# Epoch 36/50
# 28/28 [==============================] - 6s 204ms/step - loss: 40.5119 - mean_squared_error: 40.5119 - mean_absolute_error: 3.6002 - root_mean_squared_error: 6.3649 - val_loss: 65.2686 - val_mean_squared_error: 65.2686 - val_mean_absolute_error: 4.5221 - val_root_mean_squared_error: 8.0789
# Epoch 37/50
# 28/28 [==============================] - 5s 180ms/step - loss: 40.2646 - mean_squared_error: 40.2646 - mean_absolute_error: 3.5899 - root_mean_squared_error: 6.3454 - val_loss: 60.6562 - val_mean_squared_error: 60.6562 - val_mean_absolute_error: 4.2234 - val_root_mean_squared_error: 7.7882
# Epoch 38/50
# 28/28 [==============================] - 5s 195ms/step - loss: 41.7860 - mean_squared_error: 41.7860 - mean_absolute_error: 3.6754 - root_mean_squared_error: 6.4642 - val_loss: 60.7436 - val_mean_squared_error: 60.7436 - val_mean_absolute_error: 4.2008 - val_root_mean_squared_error: 7.7938
# Epoch 39/50
# 28/28 [==============================] - 5s 180ms/step - loss: 40.2793 - mean_squared_error: 40.2793 - mean_absolute_error: 3.5508 - root_mean_squared_error: 6.3466 - val_loss: 69.6243 - val_mean_squared_error: 69.6243 - val_mean_absolute_error: 4.5295 - val_root_mean_squared_error: 8.3441
# Epoch 40/50
# 28/28 [==============================] - 5s 174ms/step - loss: 38.8750 - mean_squared_error: 38.8750 - mean_absolute_error: 3.4899 - root_mean_squared_error: 6.2350 - val_loss: 69.5836 - val_mean_squared_error: 69.5836 - val_mean_absolute_error: 4.4157 - val_root_mean_squared_error: 8.3417
# Epoch 41/50
# 28/28 [==============================] - 6s 203ms/step - loss: 38.3164 - mean_squared_error: 38.3164 - mean_absolute_error: 3.4759 - root_mean_squared_error: 6.1900 - val_loss: 66.8469 - val_mean_squared_error: 66.8469 - val_mean_absolute_error: 4.3267 - val_root_mean_squared_error: 8.1760
# Epoch 42/50
# 28/28 [==============================] - 5s 183ms/step - loss: 38.2181 - mean_squared_error: 38.2181 - mean_absolute_error: 3.4213 - root_mean_squared_error: 6.1821 - val_loss: 69.9119 - val_mean_squared_error: 69.9119 - val_mean_absolute_error: 4.5535 - val_root_mean_squared_error: 8.3613
# Epoch 43/50
# 28/28 [==============================] - 6s 212ms/step - loss: 40.0477 - mean_squared_error: 40.0477 - mean_absolute_error: 3.5135 - root_mean_squared_error: 6.3283 - val_loss: 58.7529 - val_mean_squared_error: 58.7529 - val_mean_absolute_error: 4.1167 - val_root_mean_squared_error: 7.6650
# Epoch 44/50
# 28/28 [==============================] - 5s 167ms/step - loss: 39.4472 - mean_squared_error: 39.4472 - mean_absolute_error: 3.4642 - root_mean_squared_error: 6.2807 - val_loss: 67.9899 - val_mean_squared_error: 67.9899 - val_mean_absolute_error: 4.5751 - val_root_mean_squared_error: 8.2456
# Epoch 45/50
# 28/28 [==============================] - 5s 177ms/step - loss: 38.5038 - mean_squared_error: 38.5038 - mean_absolute_error: 3.4565 - root_mean_squared_error: 6.2051 - val_loss: 65.6487 - val_mean_squared_error: 65.6487 - val_mean_absolute_error: 4.2773 - val_root_mean_squared_error: 8.1024
# Epoch 46/50
# 28/28 [==============================] - 6s 205ms/step - loss: 40.4379 - mean_squared_error: 40.4379 - mean_absolute_error: 3.5376 - root_mean_squared_error: 6.3591 - val_loss: 63.8675 - val_mean_squared_error: 63.8675 - val_mean_absolute_error: 4.2627 - val_root_mean_squared_error: 7.9917
# Epoch 47/50
# 28/28 [==============================] - 5s 172ms/step - loss: 37.8088 - mean_squared_error: 37.8088 - mean_absolute_error: 3.3870 - root_mean_squared_error: 6.1489 - val_loss: 68.1152 - val_mean_squared_error: 68.1152 - val_mean_absolute_error: 4.3074 - val_root_mean_squared_error: 8.2532
# Epoch 48/50
# 28/28 [==============================] - 6s 208ms/step - loss: 36.9582 - mean_squared_error: 36.9582 - mean_absolute_error: 3.3629 - root_mean_squared_error: 6.0793 - val_loss: 60.7554 - val_mean_squared_error: 60.7554 - val_mean_absolute_error: 4.1422 - val_root_mean_squared_error: 7.7946
# Epoch 49/50
# 28/28 [==============================] - 5s 173ms/step - loss: 36.8408 - mean_squared_error: 36.8408 - mean_absolute_error: 3.3272 - root_mean_squared_error: 6.0697 - val_loss: 61.1333 - val_mean_squared_error: 61.1333 - val_mean_absolute_error: 4.1600 - val_root_mean_squared_error: 7.8188
# Epoch 50/50
# 28/28 [==============================] - 5s 170ms/step - loss: 37.1878 - mean_squared_error: 37.1878 - mean_absolute_error: 3.3293 - root_mean_squared_error: 6.0982 - val_loss: 63.6995 - val_mean_squared_error: 63.6996 - val_mean_absolute_error: 4.2338 - val_root_mean_squared_error: 7.9812

# %% [markdown]
# # Training results

# %%
from utils.plotting import training_loss_plot

with open('train_score.pkl', 'rb') as f:
    train_score = pickle.load(f)

plot = training_loss_plot(train_score, 'training_loss.pdf')
plot.show()

# %% [markdown]
# # Testing

# %%
### Predict on the test set
from utils.evaluation import phases_report, phases_report_std

y_pred = model.predict([vital_test, info.test_dataset], verbose=0)




print('Testmetriken:')

report = phases_report(y_pred, bis.test_dataset, propofolrate.test_dataset)
report
# Out:
# Testmetriken:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                 107.06       139.87           7.94         7.55
# Induction           228.97       637.60          11.61        18.34
# Maintenance          77.21        60.90           7.07         5.68
# Recovery            228.72       361.57          11.39        13.46
#
#             Prediction RMSE Baseline RMSE
# All                   10.35         11.83
# Induction             15.13         25.25
# Maintenance            8.79          7.80
# Recovery              15.12         19.02

# %%
phases_report_std(report, y_pred, bis.test_dataset, propofolrate.test_dataset)
# Out:
# All      	min: 	 15 	max: 	 6
# Induction 	min: 	 23 	max: 	 10
# Maintenance 	min: 	 13 	max: 	 6
# Recovery 	min: 	 19 	max: 	 22
#              Prediction MSE  Baseline MSE  Prediction MAE  Baseline MAE  \
# All                   44.81         82.42            1.65          2.54
# Induction            225.30        403.81            5.29          8.45
# Maintenance           31.99         43.11            1.70          2.15
# Recovery             121.43        185.95            4.18          6.28
#
#              Prediction RMSE  Baseline RMSE
# All                     2.09           3.31
# Induction               5.76           7.29
# Maintenance             1.82           2.51
# Recovery                5.04           6.47

# %%
from utils.plotting import full_histogramm_plot

plot = full_histogramm_plot(groundtruth = bis.test_dataset, prediction = y_pred)
plot.show()

# %%
from utils.plotting import single_prediction_plot

plot = single_prediction_plot(
    case = 5680,
    index = test_index,
    groundtruth = bis.test_dataset,
    prediction = y_pred,
    infusion = propofolrate.test_dataset,
    error = 'Prediction RMSE',
    filename = None)

plot.show()

# %%
from utils.plotting import full_prediction_plot

full_prediction_plot(index = test_index, groundtruth = bis.test_dataset, prediction = y_pred, infusion = propofolrate.test_dataset)
