# %% [markdown]
# # Initialization

# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset02/'
vitaldbpath = 'vitaldb_tiva/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt
import pickle

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 630, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 630 (delta 87), reused 169 (delta 87), pack-reused 461
# Receiving objects: 100% (630/630), 124.94 MiB | 15.23 MiB/s, done.
# Resolving deltas: 100% (291/291), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl.metadata (520 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.31.0)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.7 MB/s eta 0:00:00
# Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 14.9 MB/s eta 0:00:00
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %% [markdown]
# # Data loading

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolrate.name = 'Propofol Rate'
    propofolrate.tracks = ['Orchestra/PPF20_RATE']
    propofolrate.filterON = False
    propofolrate.generateDataset(normalization=md.NormNone)
    propofolrate.save('03_propofol_rate.npz')

    remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    remifentanilrate.name = 'Remifentanil Rate'
    remifentanilrate.tracks = ['Orchestra/RFTN20_RATE']
    remifentanilrate.filterON = False
    remifentanilrate.generateDataset(normalization=md.NormNone)
    remifentanilrate.save('03_remifentanil_rate.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolrate.load('03_propofol_rate.npz')

remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
remifentanilrate.load('03_remifentanil_rate.npz')

train_index, val_index, test_index = bis.split(np.array(bis.index))

# %% [markdown]
# # Model creation

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### LSTM layers for the blood pressure data

### Combine the vital data
vital_train = np.concatenate([bloodpressure.train_dataset, etCO2.train_dataset, spO2.train_dataset, hr.train_dataset], axis=2)
vital_validation = np.concatenate([bloodpressure.validation_dataset, etCO2.validation_dataset, spO2.validation_dataset, hr.validation_dataset], axis=2)
vital_test = np.concatenate([bloodpressure.test_dataset, etCO2.test_dataset, spO2.test_dataset, hr.test_dataset], axis=2)

### LSTM layers for the vital data
input_vital = Input(shape=(None, vital_train.shape[2]))
vital_layer = Masking(mask_value=0.0)(input_vital)

### INFO layers
input_info = Input(shape=(info.train_dataset.shape[1],))
info_layer = RepeatVector(vital_train.shape[1])(input_info)

## Concatenate the LSTM output with the info layer
comb_layer = Concatenate()([vital_layer, info_layer])
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=128, activation='relu')(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=32, activation='relu')(comb_layer)
comb_layer = BatchNormalization()(comb_layer)


output = Dense(units=1, activation='sigmoid')(comb_layer)
output = Lambda(lambda x: x * 100)(output)

# Define the model
model = Model(inputs=[input_vital, input_info], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 6)]            0         []
#
#  input_2 (InputLayer)        [(None, 5)]                  0         []
#
#  masking (Masking)           (None, None, 6)              0         ['input_1[0][0]']
#
#  repeat_vector (RepeatVecto  (None, 3680, 5)              0         ['input_2[0][0]']
#  r)
#
#  concatenate (Concatenate)   (None, 3680, 11)             0         ['masking[0][0]',
#                                                                      'repeat_vector[0][0]']
#
#  lstm (LSTM)                 (None, 3680, 32)             5632      ['concatenate[0][0]']
#
#  batch_normalization (Batch  (None, 3680, 32)             128       ['lstm[0][0]']
#  Normalization)
#
#  lstm_1 (LSTM)               (None, 3680, 32)             8320      ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 3680, 32)             128       ['lstm_1[0][0]']
#  chNormalization)
#
#  lstm_2 (LSTM)               (None, 3680, 32)             8320      ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, 3680, 32)             128       ['lstm_2[0][0]']
#  chNormalization)
#
#  dense (Dense)               (None, 3680, 128)            4224      ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  batch_normalization_3 (Bat  (None, 3680, 128)            512       ['dense[0][0]']
#  chNormalization)
#
#  dense_1 (Dense)             (None, 3680, 32)             4128      ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  batch_normalization_4 (Bat  (None, 3680, 32)             128       ['dense_1[0][0]']
#  chNormalization)
#
#  dense_2 (Dense)             (None, 3680, 1)              33        ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  lambda (Lambda)             (None, 3680, 1)              0         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 31681 (123.75 KB)
# Trainable params: 31169 (121.75 KB)
# Non-trainable params: 512 (2.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %%
# Rolling mean on BIS data
y = pd.DataFrame(bis.train_dataset[:,:,0].T).rolling(min_periods=1,window=20, center=True).mean().to_numpy().T[:,:,np.newaxis]

# Define training stop criteria
class StopTrainingCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(StopTrainingCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_loss') is not None:
            if logs.get('val_loss') < self.threshold:
                print(f"\nValidation loss is below {self.threshold}, stopping training.")
                self.model.stop_training = True

stop_training_callback = StopTrainingCallback(threshold = 35)


if in_google_colab():
    # Train the model
    history = model.fit([vital_train, info.train_dataset],
                        y,
                        validation_data=([vital_validation, info.validation_dataset], bis.validation_dataset),
                        epochs=100,
                        batch_size=4,
                        callbacks=[stop_training_callback]
                        )

    train_score = history.history

    # Save the model
    model.save('download/model.keras')

    # Save the training history
    with open('download/train_score.pkl', 'wb') as f:
        pickle.dump(train_score, f)

    # Save the prediction
    y_pred = model.predict([vital_test, info.test_dataset], verbose=0)
    with open('download/prediction.pkl', 'wb') as f:
        pickle.dump(y_pred, f)

else:
    # Load train score data
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

    # Load test prediction data
    with open('prediction.pkl', 'rb') as f:
        y_pred = pickle.load(f)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 31s 289ms/step - loss: 240.5167 - mean_squared_error: 240.5167 - mean_absolute_error: 9.8599 - root_mean_squared_error: 15.5086 - val_loss: 781.9727 - val_mean_squared_error: 781.9727 - val_mean_absolute_error: 24.1187 - val_root_mean_squared_error: 27.9638
# Epoch 2/100
# 28/28 [==============================] - 6s 201ms/step - loss: 113.9448 - mean_squared_error: 113.9448 - mean_absolute_error: 6.4472 - root_mean_squared_error: 10.6745 - val_loss: 479.2171 - val_mean_squared_error: 479.2172 - val_mean_absolute_error: 19.5540 - val_root_mean_squared_error: 21.8910
# Epoch 3/100
# 28/28 [==============================] - 5s 187ms/step - loss: 92.7324 - mean_squared_error: 92.7324 - mean_absolute_error: 6.1202 - root_mean_squared_error: 9.6298 - val_loss: 344.9452 - val_mean_squared_error: 344.9452 - val_mean_absolute_error: 16.6559 - val_root_mean_squared_error: 18.5727
# Epoch 4/100
# 28/28 [==============================] - 6s 201ms/step - loss: 79.8031 - mean_squared_error: 79.8031 - mean_absolute_error: 5.4766 - root_mean_squared_error: 8.9333 - val_loss: 273.1362 - val_mean_squared_error: 273.1362 - val_mean_absolute_error: 14.3058 - val_root_mean_squared_error: 16.5268
# Epoch 5/100
# 28/28 [==============================] - 5s 184ms/step - loss: 77.2255 - mean_squared_error: 77.2254 - mean_absolute_error: 5.4169 - root_mean_squared_error: 8.7878 - val_loss: 226.3844 - val_mean_squared_error: 226.3844 - val_mean_absolute_error: 12.2017 - val_root_mean_squared_error: 15.0461
# Epoch 6/100
# 28/28 [==============================] - 5s 187ms/step - loss: 70.4782 - mean_squared_error: 70.4782 - mean_absolute_error: 5.1660 - root_mean_squared_error: 8.3951 - val_loss: 189.6482 - val_mean_squared_error: 189.6482 - val_mean_absolute_error: 10.5434 - val_root_mean_squared_error: 13.7713
# Epoch 7/100
# 28/28 [==============================] - 6s 209ms/step - loss: 65.8639 - mean_squared_error: 65.8639 - mean_absolute_error: 4.9882 - root_mean_squared_error: 8.1157 - val_loss: 160.6704 - val_mean_squared_error: 160.6704 - val_mean_absolute_error: 9.1334 - val_root_mean_squared_error: 12.6756
# Epoch 8/100
# 28/28 [==============================] - 5s 186ms/step - loss: 65.4559 - mean_squared_error: 65.4559 - mean_absolute_error: 4.9985 - root_mean_squared_error: 8.0905 - val_loss: 136.1910 - val_mean_squared_error: 136.1910 - val_mean_absolute_error: 7.9652 - val_root_mean_squared_error: 11.6701
# Epoch 9/100
# 28/28 [==============================] - 6s 214ms/step - loss: 62.1685 - mean_squared_error: 62.1685 - mean_absolute_error: 4.7918 - root_mean_squared_error: 7.8847 - val_loss: 112.7354 - val_mean_squared_error: 112.7354 - val_mean_absolute_error: 6.7770 - val_root_mean_squared_error: 10.6177
# Epoch 10/100
# 28/28 [==============================] - 5s 173ms/step - loss: 60.5572 - mean_squared_error: 60.5572 - mean_absolute_error: 4.7366 - root_mean_squared_error: 7.7819 - val_loss: 100.7562 - val_mean_squared_error: 100.7562 - val_mean_absolute_error: 6.0940 - val_root_mean_squared_error: 10.0377
# Epoch 11/100
# 28/28 [==============================] - 5s 188ms/step - loss: 58.1157 - mean_squared_error: 58.1157 - mean_absolute_error: 4.6188 - root_mean_squared_error: 7.6234 - val_loss: 89.5016 - val_mean_squared_error: 89.5016 - val_mean_absolute_error: 5.5449 - val_root_mean_squared_error: 9.4605
# Epoch 12/100
# 28/28 [==============================] - 6s 195ms/step - loss: 56.9555 - mean_squared_error: 56.9555 - mean_absolute_error: 4.5608 - root_mean_squared_error: 7.5469 - val_loss: 77.1154 - val_mean_squared_error: 77.1154 - val_mean_absolute_error: 5.0406 - val_root_mean_squared_error: 8.7815
# Epoch 13/100
# 28/28 [==============================] - 5s 185ms/step - loss: 54.5563 - mean_squared_error: 54.5563 - mean_absolute_error: 4.3235 - root_mean_squared_error: 7.3862 - val_loss: 80.9801 - val_mean_squared_error: 80.9801 - val_mean_absolute_error: 4.9114 - val_root_mean_squared_error: 8.9989
# Epoch 14/100
# 28/28 [==============================] - 7s 262ms/step - loss: 56.1200 - mean_squared_error: 56.1200 - mean_absolute_error: 4.4028 - root_mean_squared_error: 7.4913 - val_loss: 74.4262 - val_mean_squared_error: 74.4262 - val_mean_absolute_error: 4.8984 - val_root_mean_squared_error: 8.6271
# Epoch 15/100
# 28/28 [==============================] - 5s 170ms/step - loss: 54.2404 - mean_squared_error: 54.2404 - mean_absolute_error: 4.3562 - root_mean_squared_error: 7.3648 - val_loss: 73.6427 - val_mean_squared_error: 73.6427 - val_mean_absolute_error: 4.7438 - val_root_mean_squared_error: 8.5815
# Epoch 16/100
# 28/28 [==============================] - 6s 197ms/step - loss: 54.0081 - mean_squared_error: 54.0081 - mean_absolute_error: 4.3149 - root_mean_squared_error: 7.3490 - val_loss: 75.4593 - val_mean_squared_error: 75.4593 - val_mean_absolute_error: 4.7698 - val_root_mean_squared_error: 8.6867
# Epoch 17/100
# 28/28 [==============================] - 5s 190ms/step - loss: 51.9384 - mean_squared_error: 51.9384 - mean_absolute_error: 4.2852 - root_mean_squared_error: 7.2068 - val_loss: 72.1894 - val_mean_squared_error: 72.1894 - val_mean_absolute_error: 4.7268 - val_root_mean_squared_error: 8.4964
# Epoch 18/100
# 28/28 [==============================] - 5s 198ms/step - loss: 49.5473 - mean_squared_error: 49.5473 - mean_absolute_error: 4.1256 - root_mean_squared_error: 7.0390 - val_loss: 75.2209 - val_mean_squared_error: 75.2209 - val_mean_absolute_error: 4.8219 - val_root_mean_squared_error: 8.6730
# Epoch 19/100
# 28/28 [==============================] - 5s 192ms/step - loss: 50.3287 - mean_squared_error: 50.3287 - mean_absolute_error: 4.0992 - root_mean_squared_error: 7.0943 - val_loss: 71.7624 - val_mean_squared_error: 71.7624 - val_mean_absolute_error: 4.6690 - val_root_mean_squared_error: 8.4713
# Epoch 20/100
# 28/28 [==============================] - 5s 172ms/step - loss: 50.0177 - mean_squared_error: 50.0177 - mean_absolute_error: 4.0273 - root_mean_squared_error: 7.0723 - val_loss: 69.8486 - val_mean_squared_error: 69.8486 - val_mean_absolute_error: 4.5398 - val_root_mean_squared_error: 8.3575
# Epoch 21/100
# 28/28 [==============================] - 6s 220ms/step - loss: 48.4403 - mean_squared_error: 48.4403 - mean_absolute_error: 3.9923 - root_mean_squared_error: 6.9599 - val_loss: 73.7446 - val_mean_squared_error: 73.7446 - val_mean_absolute_error: 4.6412 - val_root_mean_squared_error: 8.5875
# Epoch 22/100
# 28/28 [==============================] - 5s 173ms/step - loss: 49.7263 - mean_squared_error: 49.7263 - mean_absolute_error: 4.0743 - root_mean_squared_error: 7.0517 - val_loss: 70.5813 - val_mean_squared_error: 70.5813 - val_mean_absolute_error: 4.5522 - val_root_mean_squared_error: 8.4013
# Epoch 23/100
# 28/28 [==============================] - 6s 217ms/step - loss: 47.0660 - mean_squared_error: 47.0660 - mean_absolute_error: 3.9903 - root_mean_squared_error: 6.8605 - val_loss: 72.0262 - val_mean_squared_error: 72.0262 - val_mean_absolute_error: 4.5146 - val_root_mean_squared_error: 8.4868
# Epoch 24/100
# 28/28 [==============================] - 5s 182ms/step - loss: 47.2282 - mean_squared_error: 47.2282 - mean_absolute_error: 3.9440 - root_mean_squared_error: 6.8723 - val_loss: 76.9434 - val_mean_squared_error: 76.9434 - val_mean_absolute_error: 4.8341 - val_root_mean_squared_error: 8.7717
# Epoch 25/100
# 28/28 [==============================] - 5s 175ms/step - loss: 49.5231 - mean_squared_error: 49.5230 - mean_absolute_error: 3.9865 - root_mean_squared_error: 7.0373 - val_loss: 73.2421 - val_mean_squared_error: 73.2421 - val_mean_absolute_error: 4.6704 - val_root_mean_squared_error: 8.5582
# Epoch 26/100
# 28/28 [==============================] - 6s 216ms/step - loss: 48.4698 - mean_squared_error: 48.4698 - mean_absolute_error: 3.9555 - root_mean_squared_error: 6.9620 - val_loss: 78.0261 - val_mean_squared_error: 78.0261 - val_mean_absolute_error: 4.7258 - val_root_mean_squared_error: 8.8332
# Epoch 27/100
# 28/28 [==============================] - 5s 187ms/step - loss: 46.1222 - mean_squared_error: 46.1222 - mean_absolute_error: 3.8793 - root_mean_squared_error: 6.7913 - val_loss: 76.1754 - val_mean_squared_error: 76.1753 - val_mean_absolute_error: 4.6979 - val_root_mean_squared_error: 8.7278
# Epoch 28/100
# 28/28 [==============================] - 6s 222ms/step - loss: 45.4068 - mean_squared_error: 45.4068 - mean_absolute_error: 3.8497 - root_mean_squared_error: 6.7385 - val_loss: 71.5995 - val_mean_squared_error: 71.5995 - val_mean_absolute_error: 4.4906 - val_root_mean_squared_error: 8.4616
# Epoch 29/100
# 28/28 [==============================] - 5s 172ms/step - loss: 46.5803 - mean_squared_error: 46.5803 - mean_absolute_error: 3.8696 - root_mean_squared_error: 6.8250 - val_loss: 74.4510 - val_mean_squared_error: 74.4510 - val_mean_absolute_error: 4.5066 - val_root_mean_squared_error: 8.6285
# Epoch 30/100
# 28/28 [==============================] - 6s 205ms/step - loss: 44.7865 - mean_squared_error: 44.7865 - mean_absolute_error: 3.7484 - root_mean_squared_error: 6.6923 - val_loss: 78.2998 - val_mean_squared_error: 78.2998 - val_mean_absolute_error: 4.7379 - val_root_mean_squared_error: 8.8487
# Epoch 31/100
# 28/28 [==============================] - 5s 171ms/step - loss: 44.8435 - mean_squared_error: 44.8435 - mean_absolute_error: 3.7662 - root_mean_squared_error: 6.6965 - val_loss: 77.5196 - val_mean_squared_error: 77.5196 - val_mean_absolute_error: 4.6287 - val_root_mean_squared_error: 8.8045
# Epoch 32/100
# 28/28 [==============================] - 5s 184ms/step - loss: 45.2487 - mean_squared_error: 45.2487 - mean_absolute_error: 3.8022 - root_mean_squared_error: 6.7267 - val_loss: 73.3854 - val_mean_squared_error: 73.3854 - val_mean_absolute_error: 4.5509 - val_root_mean_squared_error: 8.5665
# Epoch 33/100
# 28/28 [==============================] - 6s 224ms/step - loss: 43.8085 - mean_squared_error: 43.8085 - mean_absolute_error: 3.7160 - root_mean_squared_error: 6.6188 - val_loss: 70.9986 - val_mean_squared_error: 70.9986 - val_mean_absolute_error: 4.4029 - val_root_mean_squared_error: 8.4261
# Epoch 34/100
# 28/28 [==============================] - 5s 178ms/step - loss: 43.0846 - mean_squared_error: 43.0846 - mean_absolute_error: 3.6992 - root_mean_squared_error: 6.5639 - val_loss: 73.8725 - val_mean_squared_error: 73.8725 - val_mean_absolute_error: 4.3998 - val_root_mean_squared_error: 8.5949
# Epoch 35/100
# 28/28 [==============================] - 6s 219ms/step - loss: 43.3399 - mean_squared_error: 43.3399 - mean_absolute_error: 3.6700 - root_mean_squared_error: 6.5833 - val_loss: 70.6618 - val_mean_squared_error: 70.6618 - val_mean_absolute_error: 4.4582 - val_root_mean_squared_error: 8.4061
# Epoch 36/100
# 28/28 [==============================] - 5s 187ms/step - loss: 43.4103 - mean_squared_error: 43.4104 - mean_absolute_error: 3.7335 - root_mean_squared_error: 6.5887 - val_loss: 71.0754 - val_mean_squared_error: 71.0754 - val_mean_absolute_error: 4.4484 - val_root_mean_squared_error: 8.4306
# Epoch 37/100
# 28/28 [==============================] - 6s 202ms/step - loss: 43.6616 - mean_squared_error: 43.6616 - mean_absolute_error: 3.7287 - root_mean_squared_error: 6.6077 - val_loss: 71.8236 - val_mean_squared_error: 71.8236 - val_mean_absolute_error: 4.4098 - val_root_mean_squared_error: 8.4749
# Epoch 38/100
# 28/28 [==============================] - 5s 185ms/step - loss: 43.4573 - mean_squared_error: 43.4573 - mean_absolute_error: 3.6971 - root_mean_squared_error: 6.5922 - val_loss: 70.2247 - val_mean_squared_error: 70.2247 - val_mean_absolute_error: 4.3568 - val_root_mean_squared_error: 8.3800
# Epoch 39/100
# 28/28 [==============================] - 5s 177ms/step - loss: 44.0376 - mean_squared_error: 44.0376 - mean_absolute_error: 3.7371 - root_mean_squared_error: 6.6361 - val_loss: 69.9042 - val_mean_squared_error: 69.9042 - val_mean_absolute_error: 4.4356 - val_root_mean_squared_error: 8.3609
# Epoch 40/100
# 28/28 [==============================] - 6s 220ms/step - loss: 42.3985 - mean_squared_error: 42.3985 - mean_absolute_error: 3.6441 - root_mean_squared_error: 6.5114 - val_loss: 66.9328 - val_mean_squared_error: 66.9328 - val_mean_absolute_error: 4.2646 - val_root_mean_squared_error: 8.1812
# Epoch 41/100
# 28/28 [==============================] - 5s 173ms/step - loss: 41.9279 - mean_squared_error: 41.9279 - mean_absolute_error: 3.6027 - root_mean_squared_error: 6.4752 - val_loss: 70.4954 - val_mean_squared_error: 70.4954 - val_mean_absolute_error: 4.5363 - val_root_mean_squared_error: 8.3962
# Epoch 42/100
# 28/28 [==============================] - 6s 222ms/step - loss: 41.0508 - mean_squared_error: 41.0508 - mean_absolute_error: 3.5637 - root_mean_squared_error: 6.4071 - val_loss: 67.1325 - val_mean_squared_error: 67.1325 - val_mean_absolute_error: 4.3507 - val_root_mean_squared_error: 8.1934
# Epoch 43/100
# 28/28 [==============================] - 5s 171ms/step - loss: 43.1938 - mean_squared_error: 43.1938 - mean_absolute_error: 3.6974 - root_mean_squared_error: 6.5722 - val_loss: 64.6251 - val_mean_squared_error: 64.6251 - val_mean_absolute_error: 4.2670 - val_root_mean_squared_error: 8.0390
# Epoch 44/100
# 28/28 [==============================] - 5s 195ms/step - loss: 41.3282 - mean_squared_error: 41.3282 - mean_absolute_error: 3.5655 - root_mean_squared_error: 6.4287 - val_loss: 64.4254 - val_mean_squared_error: 64.4254 - val_mean_absolute_error: 4.2155 - val_root_mean_squared_error: 8.0265
# Epoch 45/100
# 28/28 [==============================] - 6s 202ms/step - loss: 41.1388 - mean_squared_error: 41.1388 - mean_absolute_error: 3.6308 - root_mean_squared_error: 6.4140 - val_loss: 67.9519 - val_mean_squared_error: 67.9519 - val_mean_absolute_error: 4.3176 - val_root_mean_squared_error: 8.2433
# Epoch 46/100
# 28/28 [==============================] - 5s 184ms/step - loss: 41.0469 - mean_squared_error: 41.0469 - mean_absolute_error: 3.5608 - root_mean_squared_error: 6.4068 - val_loss: 68.0618 - val_mean_squared_error: 68.0618 - val_mean_absolute_error: 4.2869 - val_root_mean_squared_error: 8.2500
# Epoch 47/100
# 28/28 [==============================] - 6s 209ms/step - loss: 42.1207 - mean_squared_error: 42.1207 - mean_absolute_error: 3.5670 - root_mean_squared_error: 6.4900 - val_loss: 64.5061 - val_mean_squared_error: 64.5061 - val_mean_absolute_error: 4.2626 - val_root_mean_squared_error: 8.0316
# Epoch 48/100
# 28/28 [==============================] - 5s 189ms/step - loss: 41.0102 - mean_squared_error: 41.0102 - mean_absolute_error: 3.5538 - root_mean_squared_error: 6.4039 - val_loss: 61.5805 - val_mean_squared_error: 61.5805 - val_mean_absolute_error: 4.1116 - val_root_mean_squared_error: 7.8473
# Epoch 49/100
# 28/28 [==============================] - 6s 213ms/step - loss: 39.9807 - mean_squared_error: 39.9807 - mean_absolute_error: 3.5019 - root_mean_squared_error: 6.3230 - val_loss: 63.7576 - val_mean_squared_error: 63.7576 - val_mean_absolute_error: 4.2420 - val_root_mean_squared_error: 7.9848
# Epoch 50/100
# 28/28 [==============================] - 5s 180ms/step - loss: 41.8858 - mean_squared_error: 41.8858 - mean_absolute_error: 3.5928 - root_mean_squared_error: 6.4719 - val_loss: 66.8553 - val_mean_squared_error: 66.8553 - val_mean_absolute_error: 4.3601 - val_root_mean_squared_error: 8.1765
# Epoch 51/100
# 28/28 [==============================] - 6s 202ms/step - loss: 41.2552 - mean_squared_error: 41.2552 - mean_absolute_error: 3.5220 - root_mean_squared_error: 6.4230 - val_loss: 67.8675 - val_mean_squared_error: 67.8675 - val_mean_absolute_error: 4.3137 - val_root_mean_squared_error: 8.2382
# Epoch 52/100
# 28/28 [==============================] - 6s 203ms/step - loss: 40.2251 - mean_squared_error: 40.2251 - mean_absolute_error: 3.5046 - root_mean_squared_error: 6.3423 - val_loss: 65.4254 - val_mean_squared_error: 65.4254 - val_mean_absolute_error: 4.3056 - val_root_mean_squared_error: 8.0886
# Epoch 53/100
# 28/28 [==============================] - 5s 190ms/step - loss: 40.2709 - mean_squared_error: 40.2709 - mean_absolute_error: 3.5095 - root_mean_squared_error: 6.3459 - val_loss: 63.6606 - val_mean_squared_error: 63.6606 - val_mean_absolute_error: 4.2195 - val_root_mean_squared_error: 7.9788
# Epoch 54/100
# 28/28 [==============================] - 6s 205ms/step - loss: 39.1607 - mean_squared_error: 39.1607 - mean_absolute_error: 3.4700 - root_mean_squared_error: 6.2578 - val_loss: 66.0499 - val_mean_squared_error: 66.0499 - val_mean_absolute_error: 4.3669 - val_root_mean_squared_error: 8.1271
# Epoch 55/100
# 28/28 [==============================] - 5s 175ms/step - loss: 39.0776 - mean_squared_error: 39.0776 - mean_absolute_error: 3.4311 - root_mean_squared_error: 6.2512 - val_loss: 62.7287 - val_mean_squared_error: 62.7287 - val_mean_absolute_error: 4.1961 - val_root_mean_squared_error: 7.9201
# Epoch 56/100
# 28/28 [==============================] - 6s 226ms/step - loss: 39.1443 - mean_squared_error: 39.1443 - mean_absolute_error: 3.4395 - root_mean_squared_error: 6.2565 - val_loss: 62.4100 - val_mean_squared_error: 62.4100 - val_mean_absolute_error: 4.1223 - val_root_mean_squared_error: 7.9000
# Epoch 57/100
# 28/28 [==============================] - 6s 202ms/step - loss: 40.2683 - mean_squared_error: 40.2683 - mean_absolute_error: 3.4753 - root_mean_squared_error: 6.3457 - val_loss: 62.7378 - val_mean_squared_error: 62.7378 - val_mean_absolute_error: 4.1229 - val_root_mean_squared_error: 7.9207
# Epoch 58/100
# 28/28 [==============================] - 6s 230ms/step - loss: 38.1093 - mean_squared_error: 38.1093 - mean_absolute_error: 3.3811 - root_mean_squared_error: 6.1733 - val_loss: 64.4221 - val_mean_squared_error: 64.4221 - val_mean_absolute_error: 4.1607 - val_root_mean_squared_error: 8.0263
# Epoch 59/100
# 28/28 [==============================] - 5s 176ms/step - loss: 37.7732 - mean_squared_error: 37.7732 - mean_absolute_error: 3.3303 - root_mean_squared_error: 6.1460 - val_loss: 66.0896 - val_mean_squared_error: 66.0896 - val_mean_absolute_error: 4.3320 - val_root_mean_squared_error: 8.1295
# Epoch 60/100
# 28/28 [==============================] - 5s 187ms/step - loss: 38.0478 - mean_squared_error: 38.0478 - mean_absolute_error: 3.3948 - root_mean_squared_error: 6.1683 - val_loss: 67.9304 - val_mean_squared_error: 67.9304 - val_mean_absolute_error: 4.2727 - val_root_mean_squared_error: 8.2420
# Epoch 61/100
# 28/28 [==============================] - 6s 200ms/step - loss: 38.6954 - mean_squared_error: 38.6954 - mean_absolute_error: 3.3556 - root_mean_squared_error: 6.2206 - val_loss: 63.2833 - val_mean_squared_error: 63.2833 - val_mean_absolute_error: 4.1653 - val_root_mean_squared_error: 7.9551
# Epoch 62/100
# 28/28 [==============================] - 5s 180ms/step - loss: 38.6939 - mean_squared_error: 38.6939 - mean_absolute_error: 3.4242 - root_mean_squared_error: 6.2204 - val_loss: 68.2755 - val_mean_squared_error: 68.2755 - val_mean_absolute_error: 4.3625 - val_root_mean_squared_error: 8.2629
# Epoch 63/100
# 28/28 [==============================] - 6s 222ms/step - loss: 40.0811 - mean_squared_error: 40.0811 - mean_absolute_error: 3.4707 - root_mean_squared_error: 6.3310 - val_loss: 60.6855 - val_mean_squared_error: 60.6855 - val_mean_absolute_error: 4.0953 - val_root_mean_squared_error: 7.7901
# Epoch 64/100
# 28/28 [==============================] - 5s 179ms/step - loss: 38.2236 - mean_squared_error: 38.2236 - mean_absolute_error: 3.4255 - root_mean_squared_error: 6.1825 - val_loss: 64.7388 - val_mean_squared_error: 64.7387 - val_mean_absolute_error: 4.2277 - val_root_mean_squared_error: 8.0460
# Epoch 65/100
# 28/28 [==============================] - 6s 207ms/step - loss: 40.2145 - mean_squared_error: 40.2145 - mean_absolute_error: 3.4355 - root_mean_squared_error: 6.3415 - val_loss: 57.9996 - val_mean_squared_error: 57.9996 - val_mean_absolute_error: 3.8982 - val_root_mean_squared_error: 7.6157
# Epoch 66/100
# 28/28 [==============================] - 6s 199ms/step - loss: 37.8297 - mean_squared_error: 37.8297 - mean_absolute_error: 3.3550 - root_mean_squared_error: 6.1506 - val_loss: 56.4538 - val_mean_squared_error: 56.4538 - val_mean_absolute_error: 3.8510 - val_root_mean_squared_error: 7.5136
# Epoch 67/100
# 28/28 [==============================] - 5s 188ms/step - loss: 38.2957 - mean_squared_error: 38.2957 - mean_absolute_error: 3.3895 - root_mean_squared_error: 6.1884 - val_loss: 64.0291 - val_mean_squared_error: 64.0291 - val_mean_absolute_error: 4.1546 - val_root_mean_squared_error: 8.0018
# Epoch 68/100
# 28/28 [==============================] - 6s 217ms/step - loss: 36.8035 - mean_squared_error: 36.8035 - mean_absolute_error: 3.2981 - root_mean_squared_error: 6.0666 - val_loss: 62.9230 - val_mean_squared_error: 62.9230 - val_mean_absolute_error: 4.0879 - val_root_mean_squared_error: 7.9324
# Epoch 69/100
# 28/28 [==============================] - 5s 187ms/step - loss: 37.1869 - mean_squared_error: 37.1869 - mean_absolute_error: 3.3023 - root_mean_squared_error: 6.0981 - val_loss: 69.9343 - val_mean_squared_error: 69.9343 - val_mean_absolute_error: 4.3291 - val_root_mean_squared_error: 8.3627
# Epoch 70/100
# 28/28 [==============================] - 6s 222ms/step - loss: 37.2296 - mean_squared_error: 37.2296 - mean_absolute_error: 3.3193 - root_mean_squared_error: 6.1016 - val_loss: 66.4269 - val_mean_squared_error: 66.4269 - val_mean_absolute_error: 4.1615 - val_root_mean_squared_error: 8.1503
# Epoch 71/100
# 28/28 [==============================] - 5s 179ms/step - loss: 37.8007 - mean_squared_error: 37.8007 - mean_absolute_error: 3.3455 - root_mean_squared_error: 6.1482 - val_loss: 69.5786 - val_mean_squared_error: 69.5786 - val_mean_absolute_error: 4.2582 - val_root_mean_squared_error: 8.3414
# Epoch 72/100
# 28/28 [==============================] - 6s 218ms/step - loss: 37.7420 - mean_squared_error: 37.7420 - mean_absolute_error: 3.3377 - root_mean_squared_error: 6.1434 - val_loss: 73.5608 - val_mean_squared_error: 73.5608 - val_mean_absolute_error: 4.3867 - val_root_mean_squared_error: 8.5768
# Epoch 73/100
# 28/28 [==============================] - 5s 186ms/step - loss: 35.7214 - mean_squared_error: 35.7214 - mean_absolute_error: 3.1767 - root_mean_squared_error: 5.9767 - val_loss: 76.1850 - val_mean_squared_error: 76.1850 - val_mean_absolute_error: 4.4272 - val_root_mean_squared_error: 8.7284
# Epoch 74/100
# 28/28 [==============================] - 5s 186ms/step - loss: 35.8992 - mean_squared_error: 35.8992 - mean_absolute_error: 3.2184 - root_mean_squared_error: 5.9916 - val_loss: 63.8920 - val_mean_squared_error: 63.8920 - val_mean_absolute_error: 4.1436 - val_root_mean_squared_error: 7.9932
# Epoch 75/100
# 28/28 [==============================] - 6s 217ms/step - loss: 36.6389 - mean_squared_error: 36.6389 - mean_absolute_error: 3.2791 - root_mean_squared_error: 6.0530 - val_loss: 72.4648 - val_mean_squared_error: 72.4648 - val_mean_absolute_error: 4.3412 - val_root_mean_squared_error: 8.5126
# Epoch 76/100
# 28/28 [==============================] - 5s 184ms/step - loss: 36.6833 - mean_squared_error: 36.6833 - mean_absolute_error: 3.2782 - root_mean_squared_error: 6.0567 - val_loss: 72.6084 - val_mean_squared_error: 72.6084 - val_mean_absolute_error: 4.3798 - val_root_mean_squared_error: 8.5211
# Epoch 77/100
# 28/28 [==============================] - 6s 217ms/step - loss: 35.2022 - mean_squared_error: 35.2022 - mean_absolute_error: 3.2209 - root_mean_squared_error: 5.9331 - val_loss: 65.6315 - val_mean_squared_error: 65.6315 - val_mean_absolute_error: 4.2815 - val_root_mean_squared_error: 8.1013
# Epoch 78/100
# 28/28 [==============================] - 5s 177ms/step - loss: 37.3672 - mean_squared_error: 37.3672 - mean_absolute_error: 3.3397 - root_mean_squared_error: 6.1129 - val_loss: 57.3274 - val_mean_squared_error: 57.3274 - val_mean_absolute_error: 3.9175 - val_root_mean_squared_error: 7.5715
# Epoch 79/100
# 28/28 [==============================] - 6s 212ms/step - loss: 35.9826 - mean_squared_error: 35.9826 - mean_absolute_error: 3.2245 - root_mean_squared_error: 5.9986 - val_loss: 60.7422 - val_mean_squared_error: 60.7422 - val_mean_absolute_error: 4.0251 - val_root_mean_squared_error: 7.7937
# Epoch 80/100
# 28/28 [==============================] - 5s 187ms/step - loss: 37.6831 - mean_squared_error: 37.6831 - mean_absolute_error: 3.3083 - root_mean_squared_error: 6.1387 - val_loss: 61.9170 - val_mean_squared_error: 61.9170 - val_mean_absolute_error: 4.1576 - val_root_mean_squared_error: 7.8687
# Epoch 81/100
# 28/28 [==============================] - 5s 175ms/step - loss: 36.5878 - mean_squared_error: 36.5878 - mean_absolute_error: 3.2940 - root_mean_squared_error: 6.0488 - val_loss: 66.8927 - val_mean_squared_error: 66.8928 - val_mean_absolute_error: 4.2765 - val_root_mean_squared_error: 8.1788
# Epoch 82/100
# 28/28 [==============================] - 6s 211ms/step - loss: 37.5478 - mean_squared_error: 37.5478 - mean_absolute_error: 3.3374 - root_mean_squared_error: 6.1276 - val_loss: 66.1355 - val_mean_squared_error: 66.1355 - val_mean_absolute_error: 4.2131 - val_root_mean_squared_error: 8.1324
# Epoch 83/100
# 28/28 [==============================] - 5s 179ms/step - loss: 35.8596 - mean_squared_error: 35.8596 - mean_absolute_error: 3.2561 - root_mean_squared_error: 5.9883 - val_loss: 64.7059 - val_mean_squared_error: 64.7059 - val_mean_absolute_error: 4.1863 - val_root_mean_squared_error: 8.0440
# Epoch 84/100
# 28/28 [==============================] - 6s 217ms/step - loss: 35.6647 - mean_squared_error: 35.6647 - mean_absolute_error: 3.2314 - root_mean_squared_error: 5.9720 - val_loss: 69.9319 - val_mean_squared_error: 69.9319 - val_mean_absolute_error: 4.4699 - val_root_mean_squared_error: 8.3625
# Epoch 85/100
# 28/28 [==============================] - 5s 184ms/step - loss: 35.8528 - mean_squared_error: 35.8528 - mean_absolute_error: 3.2630 - root_mean_squared_error: 5.9877 - val_loss: 65.9170 - val_mean_squared_error: 65.9170 - val_mean_absolute_error: 4.0602 - val_root_mean_squared_error: 8.1189
# Epoch 86/100
# 28/28 [==============================] - 6s 219ms/step - loss: 36.6514 - mean_squared_error: 36.6514 - mean_absolute_error: 3.1992 - root_mean_squared_error: 6.0540 - val_loss: 71.7717 - val_mean_squared_error: 71.7717 - val_mean_absolute_error: 4.4463 - val_root_mean_squared_error: 8.4718
# Epoch 87/100
# 28/28 [==============================] - 5s 177ms/step - loss: 34.6477 - mean_squared_error: 34.6477 - mean_absolute_error: 3.1705 - root_mean_squared_error: 5.8862 - val_loss: 65.2589 - val_mean_squared_error: 65.2589 - val_mean_absolute_error: 4.2544 - val_root_mean_squared_error: 8.0783
# Epoch 88/100
# 28/28 [==============================] - 5s 177ms/step - loss: 36.3723 - mean_squared_error: 36.3723 - mean_absolute_error: 3.3010 - root_mean_squared_error: 6.0309 - val_loss: 69.6562 - val_mean_squared_error: 69.6562 - val_mean_absolute_error: 4.2817 - val_root_mean_squared_error: 8.3460
# Epoch 89/100
# 28/28 [==============================] - 6s 216ms/step - loss: 36.1124 - mean_squared_error: 36.1124 - mean_absolute_error: 3.2496 - root_mean_squared_error: 6.0094 - val_loss: 67.0512 - val_mean_squared_error: 67.0512 - val_mean_absolute_error: 4.2309 - val_root_mean_squared_error: 8.1885
# Epoch 90/100
# 28/28 [==============================] - 5s 180ms/step - loss: 36.3347 - mean_squared_error: 36.3347 - mean_absolute_error: 3.2478 - root_mean_squared_error: 6.0278 - val_loss: 72.1483 - val_mean_squared_error: 72.1483 - val_mean_absolute_error: 4.5461 - val_root_mean_squared_error: 8.4940
# Epoch 91/100
# 28/28 [==============================] - 6s 204ms/step - loss: 34.9564 - mean_squared_error: 34.9564 - mean_absolute_error: 3.1781 - root_mean_squared_error: 5.9124 - val_loss: 65.7952 - val_mean_squared_error: 65.7952 - val_mean_absolute_error: 4.1653 - val_root_mean_squared_error: 8.1114
# Epoch 92/100
# 28/28 [==============================] - 5s 194ms/step - loss: 34.6826 - mean_squared_error: 34.6826 - mean_absolute_error: 3.1493 - root_mean_squared_error: 5.8892 - val_loss: 66.0111 - val_mean_squared_error: 66.0111 - val_mean_absolute_error: 4.2534 - val_root_mean_squared_error: 8.1247
# Epoch 93/100
# 28/28 [==============================] - 6s 207ms/step - loss: 35.4537 - mean_squared_error: 35.4537 - mean_absolute_error: 3.2110 - root_mean_squared_error: 5.9543 - val_loss: 72.4387 - val_mean_squared_error: 72.4387 - val_mean_absolute_error: 4.5146 - val_root_mean_squared_error: 8.5111
# Epoch 94/100
# 28/28 [==============================] - 5s 194ms/step - loss: 34.9328 - mean_squared_error: 34.9328 - mean_absolute_error: 3.1941 - root_mean_squared_error: 5.9104 - val_loss: 66.4765 - val_mean_squared_error: 66.4765 - val_mean_absolute_error: 4.1994 - val_root_mean_squared_error: 8.1533
# Epoch 95/100
# 28/28 [==============================] - 5s 178ms/step - loss: 34.8278 - mean_squared_error: 34.8278 - mean_absolute_error: 3.1433 - root_mean_squared_error: 5.9015 - val_loss: 62.3430 - val_mean_squared_error: 62.3430 - val_mean_absolute_error: 4.0105 - val_root_mean_squared_error: 7.8958
# Epoch 96/100
# 28/28 [==============================] - 6s 211ms/step - loss: 34.7497 - mean_squared_error: 34.7497 - mean_absolute_error: 3.1161 - root_mean_squared_error: 5.8949 - val_loss: 73.3209 - val_mean_squared_error: 73.3209 - val_mean_absolute_error: 4.4800 - val_root_mean_squared_error: 8.5628
# Epoch 97/100
# 28/28 [==============================] - 5s 186ms/step - loss: 34.8605 - mean_squared_error: 34.8605 - mean_absolute_error: 3.1863 - root_mean_squared_error: 5.9043 - val_loss: 61.9932 - val_mean_squared_error: 61.9932 - val_mean_absolute_error: 4.0226 - val_root_mean_squared_error: 7.8736
# Epoch 98/100
# 28/28 [==============================] - 6s 215ms/step - loss: 35.4156 - mean_squared_error: 35.4156 - mean_absolute_error: 3.2163 - root_mean_squared_error: 5.9511 - val_loss: 64.7410 - val_mean_squared_error: 64.7410 - val_mean_absolute_error: 4.0600 - val_root_mean_squared_error: 8.0462
# Epoch 99/100
# 28/28 [==============================] - 5s 187ms/step - loss: 34.0620 - mean_squared_error: 34.0620 - mean_absolute_error: 3.1070 - root_mean_squared_error: 5.8363 - val_loss: 67.6508 - val_mean_squared_error: 67.6508 - val_mean_absolute_error: 4.1675 - val_root_mean_squared_error: 8.2250
# Epoch 100/100
# 28/28 [==============================] - 6s 203ms/step - loss: 34.9093 - mean_squared_error: 34.9093 - mean_absolute_error: 3.1631 - root_mean_squared_error: 5.9084 - val_loss: 62.3211 - val_mean_squared_error: 62.3211 - val_mean_absolute_error: 4.0341 - val_root_mean_squared_error: 7.8944

# %% [markdown]
# # Training results

# %%
from utils.plotting import training_loss_plot

if not in_google_colab():
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

plot = training_loss_plot(train_score, filename='download/training_loss.pdf')
plot.show()

# %% [markdown]
# # Testing

# %%
### Predict on the test set
from utils.evaluation import phases_report, phases_report_std

print('Testmetriken:')

report = phases_report(y_pred, bis.test_dataset, propofolrate.test_dataset)
report
# Out:
# Testmetriken:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                 110.62       139.87           7.61         7.55
# Induction           247.64       637.60          12.00        18.34
# Maintenance          72.99        60.90           6.47         5.68
# Recovery            276.87       361.57          12.45        13.46
#
#             Prediction RMSE Baseline RMSE
# All                   10.52         11.83
# Induction             15.74         25.25
# Maintenance            8.54          7.80
# Recovery              16.64         19.02

# %%
phases_report_std(report, y_pred, bis.test_dataset, propofolrate.test_dataset)
# Out:
# All      	min: 	 15 	max: 	 6
# Induction 	min: 	 23 	max: 	 10
# Maintenance 	min: 	 13 	max: 	 6
# Recovery 	min: 	 19 	max: 	 22
#              Prediction MSE  Baseline MSE  Prediction MAE  Baseline MAE  \
# All                   60.23         82.42            1.95          2.54
# Induction            187.05        403.81            4.85          8.45
# Maintenance           45.15         43.11            1.84          2.15
# Recovery             229.03        185.95            6.51          6.28
#
#              Prediction RMSE  Baseline RMSE
# All                     2.49           3.31
# Induction               5.19           7.29
# Maintenance             2.27           2.51
# Recovery                6.75           6.47

# %%
from utils.plotting import full_histogramm_plot

plot = full_histogramm_plot(groundtruth = bis.test_dataset, prediction = y_pred, filename='download/histogramm.pdf')
plot.show()

# %%
from utils.plotting import single_prediction_plot

for case in test_index:
    single_prediction_plot(
        case = case,
        index = test_index,
        groundtruth = bis.test_dataset,
        prediction = y_pred,
        infusion = propofolrate.test_dataset,
        error = 'Prediction RMSE',
        filename = 'download/' + str(case) + '.pdf')

print('Finished')
# Out:
# /content/utils/plotting.py:79: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(12/2.54, 6/2.54))
# Finished

# %%
from utils.plotting import full_prediction_plot

full_prediction_plot(index = test_index, groundtruth = bis.test_dataset, prediction = y_pred, infusion = propofolrate.test_dataset)
