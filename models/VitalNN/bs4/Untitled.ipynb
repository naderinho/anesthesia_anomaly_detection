# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
physical_devices)
# Out:
# Num GPUs: 1

# %%
# !pip uninstall tensorflow keras tf-keras -y
# !pip install tensorflow==2.15.0
# !pip install tf-keras==2.15.1
# !pip install keras==2.15.0
# Out:
# Found existing installation: tensorflow 2.17.0
# Uninstalling tensorflow-2.17.0:
#   Successfully uninstalled tensorflow-2.17.0
# Found existing installation: keras 3.4.1
# Uninstalling keras-3.4.1:
#   Successfully uninstalled keras-3.4.1
# Found existing installation: tf_keras 2.17.0
# Uninstalling tf_keras-2.17.0:
#   Successfully uninstalled tf_keras-2.17.0
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.3.0 (from versions: 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.0.post1, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0)
# ERROR: No matching distribution found for tensorflow==2.3.0
# Collecting tf-keras==2.15.1
#   Downloading tf_keras-2.15.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow<2.16,>=2.15 (from tf-keras==2.15.1)
#   Downloading tensorflow-2.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (18.1.1)
# Collecting ml-dtypes~=0.3.1 (from tensorflow<2.16,>=2.15->tf-keras==2.15.1)
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow<2.16,>=2.15->tf-keras==2.15.1)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.64.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow<2.16,>=2.15->tf-keras==2.15.1)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow<2.16,>=2.15->tf-keras==2.15.1)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow<2.16,>=2.15->tf-keras==2.15.1)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.2.2)
# Downloading tf_keras-2.15.1-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 34.2 MB/s eta 0:00:00
# Downloading tensorflow-2.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 2.7 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 76.7 MB/s eta 0:00:00
# Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 87.4 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 111.0 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 32.4 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, tensorboard, tensorflow, tf-keras
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.0
#     Uninstalling ml-dtypes-0.4.0:
#       Successfully uninstalled ml-dtypes-0.4.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
# Successfully installed keras-2.15.0 ml-dtypes-0.3.2 tensorboard-2.15.2 tensorflow-2.15.1 tensorflow-estimator-2.15.0 tf-keras-2.15.1 wrapt-1.14.1
# Requirement already satisfied: keras==2.15.0 in /usr/local/lib/python3.10/dist-packages (2.15.0)

# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset02/'
vitaldbpath = 'vitaldb_tiva/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt
import pickle

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 1241, done.
# remote: Counting objects: 100% (278/278), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 1241 (delta 193), reused 257 (delta 178), pack-reused 963 (from 1)
# Receiving objects: 100% (1241/1241), 259.46 MiB | 31.04 MiB/s, done.
# Resolving deltas: 100% (724/724), done.
# Updating files: 100% (607/607), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl.metadata (520 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.32.3)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.9 MB/s eta 0:00:00
# Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolrate.name = 'Propofol Rate'
    propofolrate.tracks = ['Orchestra/PPF20_RATE']
    propofolrate.filterON = False
    propofolrate.generateDataset(normalization=md.NormNone)
    propofolrate.save('03_propofol_rate.npz')

    remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    remifentanilrate.name = 'Remifentanil Rate'
    remifentanilrate.tracks = ['Orchestra/RFTN20_RATE']
    remifentanilrate.filterON = False
    remifentanilrate.generateDataset(normalization=md.NormNone)
    remifentanilrate.save('03_remifentanil_rate.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolrate.load('03_propofol_rate.npz')

remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
remifentanilrate.load('03_remifentanil_rate.npz')

train_index, val_index, test_index = bis.split(np.array(bis.index))

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### LSTM layers for the blood pressure data

### Combine the vital data
vital_train = np.concatenate([bloodpressure.train_dataset, etCO2.train_dataset, spO2.train_dataset, hr.train_dataset], axis=2)
vital_validation = np.concatenate([bloodpressure.validation_dataset, etCO2.validation_dataset, spO2.validation_dataset, hr.validation_dataset], axis=2)
vital_test = np.concatenate([bloodpressure.test_dataset, etCO2.test_dataset, spO2.test_dataset, hr.test_dataset], axis=2)

### LSTM layers for the vital data
input_vital = Input(shape=(None, vital_train.shape[2]))
vital_layer = Masking(mask_value=0.0)(input_vital)

### INFO layers
input_info = Input(shape=(info.train_dataset.shape[1],))
info_layer = RepeatVector(vital_train.shape[1])(input_info)

## Concatenate the LSTM output with the info layer
comb_layer = Concatenate()([vital_layer, info_layer])
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=128, activation='relu')(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=32, activation='relu')(comb_layer)
comb_layer = BatchNormalization()(comb_layer)


output = Dense(units=1, activation=ReLU(max_value=1.0))(comb_layer)
output = Lambda(lambda x: x * 100)(output)

# Define the model
model = Model(inputs=[input_vital, input_info], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, None, 6)]            0         []
#
#  input_4 (InputLayer)        [(None, 5)]                  0         []
#
#  masking_1 (Masking)         (None, None, 6)              0         ['input_3[0][0]']
#
#  repeat_vector_1 (RepeatVec  (None, 3680, 5)              0         ['input_4[0][0]']
#  tor)
#
#  concatenate_1 (Concatenate  (None, 3680, 11)             0         ['masking_1[0][0]',
#  )                                                                   'repeat_vector_1[0][0]']
#
#  lstm_3 (LSTM)               (None, 3680, 32)             5632      ['concatenate_1[0][0]']
#
#  batch_normalization_5 (Bat  (None, 3680, 32)             128       ['lstm_3[0][0]']
#  chNormalization)
#
#  lstm_4 (LSTM)               (None, 3680, 32)             8320      ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  batch_normalization_6 (Bat  (None, 3680, 32)             128       ['lstm_4[0][0]']
#  chNormalization)
#
#  lstm_5 (LSTM)               (None, 3680, 32)             8320      ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  batch_normalization_7 (Bat  (None, 3680, 32)             128       ['lstm_5[0][0]']
#  chNormalization)
#
#  dense_3 (Dense)             (None, 3680, 128)            4224      ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  batch_normalization_8 (Bat  (None, 3680, 128)            512       ['dense_3[0][0]']
#  chNormalization)
#
#  dense_4 (Dense)             (None, 3680, 32)             4128      ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  batch_normalization_9 (Bat  (None, 3680, 32)             128       ['dense_4[0][0]']
#  chNormalization)
#
#  dense_5 (Dense)             (None, 3680, 1)              33        ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  lambda_1 (Lambda)           (None, 3680, 1)              0         ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 31681 (123.75 KB)
# Trainable params: 31169 (121.75 KB)
# Non-trainable params: 512 (2.00 KB)
# __________________________________________________________________________________________________

# %%
# Rolling mean on BIS data
y = pd.DataFrame(bis.train_dataset[:,:,0].T).rolling(min_periods=1,window=12, center=True).mean().to_numpy().T[:,:,np.newaxis]

# Define training stop criteria
class StopTrainingCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(StopTrainingCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_loss') is not None:
            if logs.get('val_loss') < self.threshold:
                print(f"\nValidation loss is below {self.threshold}, stopping training.")
                self.model.stop_training = True

stop_training_callback = StopTrainingCallback(threshold = 35)


if in_google_colab():
    # Train the model
    history = model.fit([vital_train, info.train_dataset],
                        y,
                        validation_data=([vital_validation, info.validation_dataset], bis.validation_dataset),
                        epochs=100,
                        batch_size=4,
                        callbacks=[stop_training_callback]
                        )

    train_score = history.history

    # Save the model
    model.save('download/model.keras')

    # Save the training history
    with open('download/train_score.pkl', 'wb') as f:
        pickle.dump(train_score, f)

    # Save the prediction
    y_pred = model.predict([vital_test, info.test_dataset], verbose=0)
    with open('download/prediction.pkl', 'wb') as f:
        pickle.dump(y_pred, f)

else:
    # Load train score data
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

    # Load test prediction data
    with open('prediction.pkl', 'rb') as f:
        y_pred = pickle.load(f)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 22s 285ms/step - loss: 781.0281 - mean_squared_error: 781.0281 - mean_absolute_error: 16.6880 - root_mean_squared_error: 27.9469 - val_loss: 749.0923 - val_mean_squared_error: 749.0923 - val_mean_absolute_error: 16.5991 - val_root_mean_squared_error: 27.3696
# Epoch 2/100
# 28/28 [==============================] - 6s 196ms/step - loss: 618.5273 - mean_squared_error: 618.5273 - mean_absolute_error: 14.5537 - root_mean_squared_error: 24.8702 - val_loss: 539.1023 - val_mean_squared_error: 539.1023 - val_mean_absolute_error: 13.5947 - val_root_mean_squared_error: 23.2186
# Epoch 3/100
# 28/28 [==============================] - 5s 179ms/step - loss: 472.0457 - mean_squared_error: 472.0456 - mean_absolute_error: 12.1731 - root_mean_squared_error: 21.7266 - val_loss: 345.1375 - val_mean_squared_error: 345.1375 - val_mean_absolute_error: 16.5166 - val_root_mean_squared_error: 18.5779
# Epoch 4/100
# 28/28 [==============================] - 6s 203ms/step - loss: 355.6519 - mean_squared_error: 355.6519 - mean_absolute_error: 10.1684 - root_mean_squared_error: 18.8587 - val_loss: 215.0996 - val_mean_squared_error: 215.0996 - val_mean_absolute_error: 7.2313 - val_root_mean_squared_error: 14.6663
# Epoch 5/100
# 28/28 [==============================] - 5s 169ms/step - loss: 229.2949 - mean_squared_error: 229.2949 - mean_absolute_error: 7.6285 - root_mean_squared_error: 15.1425 - val_loss: 126.1128 - val_mean_squared_error: 126.1128 - val_mean_absolute_error: 5.2390 - val_root_mean_squared_error: 11.2300
# Epoch 6/100
# 28/28 [==============================] - 5s 184ms/step - loss: 174.0877 - mean_squared_error: 174.0877 - mean_absolute_error: 6.6154 - root_mean_squared_error: 13.1942 - val_loss: 96.1715 - val_mean_squared_error: 96.1715 - val_mean_absolute_error: 4.5960 - val_root_mean_squared_error: 9.8067
# Epoch 7/100
# 28/28 [==============================] - 6s 200ms/step - loss: 122.8246 - mean_squared_error: 122.8246 - mean_absolute_error: 5.5908 - root_mean_squared_error: 11.0826 - val_loss: 102.6598 - val_mean_squared_error: 102.6598 - val_mean_absolute_error: 4.6995 - val_root_mean_squared_error: 10.1321
# Epoch 8/100
# 28/28 [==============================] - 5s 177ms/step - loss: 98.2888 - mean_squared_error: 98.2888 - mean_absolute_error: 4.9286 - root_mean_squared_error: 9.9141 - val_loss: 99.2083 - val_mean_squared_error: 99.2083 - val_mean_absolute_error: 4.8966 - val_root_mean_squared_error: 9.9603
# Epoch 9/100
# 28/28 [==============================] - 6s 205ms/step - loss: 85.7744 - mean_squared_error: 85.7744 - mean_absolute_error: 4.6147 - root_mean_squared_error: 9.2614 - val_loss: 77.4447 - val_mean_squared_error: 77.4447 - val_mean_absolute_error: 3.9949 - val_root_mean_squared_error: 8.8003
# Epoch 10/100
# 28/28 [==============================] - 5s 164ms/step - loss: 76.0981 - mean_squared_error: 76.0981 - mean_absolute_error: 4.3372 - root_mean_squared_error: 8.7234 - val_loss: 86.7764 - val_mean_squared_error: 86.7764 - val_mean_absolute_error: 4.1646 - val_root_mean_squared_error: 9.3154
# Epoch 11/100
# 28/28 [==============================] - 5s 196ms/step - loss: 74.8355 - mean_squared_error: 74.8355 - mean_absolute_error: 4.2928 - root_mean_squared_error: 8.6508 - val_loss: 77.7754 - val_mean_squared_error: 77.7754 - val_mean_absolute_error: 4.0768 - val_root_mean_squared_error: 8.8190
# Epoch 12/100
# 28/28 [==============================] - 5s 189ms/step - loss: 70.4027 - mean_squared_error: 70.4027 - mean_absolute_error: 4.1812 - root_mean_squared_error: 8.3906 - val_loss: 74.4285 - val_mean_squared_error: 74.4285 - val_mean_absolute_error: 3.9102 - val_root_mean_squared_error: 8.6272
# Epoch 13/100
# 28/28 [==============================] - 5s 171ms/step - loss: 69.2902 - mean_squared_error: 69.2902 - mean_absolute_error: 4.0510 - root_mean_squared_error: 8.3241 - val_loss: 79.5763 - val_mean_squared_error: 79.5763 - val_mean_absolute_error: 3.9970 - val_root_mean_squared_error: 8.9206
# Epoch 14/100
# 28/28 [==============================] - 6s 211ms/step - loss: 64.7517 - mean_squared_error: 64.7517 - mean_absolute_error: 3.9766 - root_mean_squared_error: 8.0468 - val_loss: 78.4145 - val_mean_squared_error: 78.4145 - val_mean_absolute_error: 4.0538 - val_root_mean_squared_error: 8.8552
# Epoch 15/100
# 28/28 [==============================] - 5s 167ms/step - loss: 64.4500 - mean_squared_error: 64.4500 - mean_absolute_error: 3.8860 - root_mean_squared_error: 8.0281 - val_loss: 71.0821 - val_mean_squared_error: 71.0821 - val_mean_absolute_error: 3.9380 - val_root_mean_squared_error: 8.4310
# Epoch 16/100
# 28/28 [==============================] - 5s 194ms/step - loss: 64.8418 - mean_squared_error: 64.8418 - mean_absolute_error: 3.9517 - root_mean_squared_error: 8.0524 - val_loss: 82.2824 - val_mean_squared_error: 82.2824 - val_mean_absolute_error: 4.2582 - val_root_mean_squared_error: 9.0710
# Epoch 17/100
# 28/28 [==============================] - 5s 174ms/step - loss: 62.7269 - mean_squared_error: 62.7270 - mean_absolute_error: 3.9448 - root_mean_squared_error: 7.9200 - val_loss: 73.9704 - val_mean_squared_error: 73.9704 - val_mean_absolute_error: 3.9589 - val_root_mean_squared_error: 8.6006
# Epoch 18/100
# 28/28 [==============================] - 5s 181ms/step - loss: 63.2389 - mean_squared_error: 63.2389 - mean_absolute_error: 3.8824 - root_mean_squared_error: 7.9523 - val_loss: 75.5409 - val_mean_squared_error: 75.5409 - val_mean_absolute_error: 3.9846 - val_root_mean_squared_error: 8.6914
# Epoch 19/100
# 28/28 [==============================] - 6s 229ms/step - loss: 59.0642 - mean_squared_error: 59.0642 - mean_absolute_error: 3.7678 - root_mean_squared_error: 7.6853 - val_loss: 72.3131 - val_mean_squared_error: 72.3131 - val_mean_absolute_error: 3.9348 - val_root_mean_squared_error: 8.5037
# Epoch 20/100
# 28/28 [==============================] - 5s 173ms/step - loss: 59.2353 - mean_squared_error: 59.2353 - mean_absolute_error: 3.7584 - root_mean_squared_error: 7.6964 - val_loss: 76.3489 - val_mean_squared_error: 76.3489 - val_mean_absolute_error: 4.0526 - val_root_mean_squared_error: 8.7378
# Epoch 21/100
# 28/28 [==============================] - 6s 226ms/step - loss: 57.4546 - mean_squared_error: 57.4546 - mean_absolute_error: 3.6526 - root_mean_squared_error: 7.5799 - val_loss: 73.4520 - val_mean_squared_error: 73.4520 - val_mean_absolute_error: 3.9669 - val_root_mean_squared_error: 8.5704
# Epoch 22/100
# 28/28 [==============================] - 5s 177ms/step - loss: 58.2331 - mean_squared_error: 58.2331 - mean_absolute_error: 3.7648 - root_mean_squared_error: 7.6311 - val_loss: 70.9033 - val_mean_squared_error: 70.9033 - val_mean_absolute_error: 3.9560 - val_root_mean_squared_error: 8.4204
# Epoch 23/100
# 28/28 [==============================] - 5s 182ms/step - loss: 57.9393 - mean_squared_error: 57.9394 - mean_absolute_error: 3.7494 - root_mean_squared_error: 7.6118 - val_loss: 71.1313 - val_mean_squared_error: 71.1313 - val_mean_absolute_error: 3.9154 - val_root_mean_squared_error: 8.4339
# Epoch 24/100
# 28/28 [==============================] - 6s 211ms/step - loss: 57.2912 - mean_squared_error: 57.2912 - mean_absolute_error: 3.6892 - root_mean_squared_error: 7.5691 - val_loss: 85.2745 - val_mean_squared_error: 85.2745 - val_mean_absolute_error: 4.3440 - val_root_mean_squared_error: 9.2344
# Epoch 25/100
# 28/28 [==============================] - 5s 184ms/step - loss: 65.3437 - mean_squared_error: 65.3437 - mean_absolute_error: 4.1715 - root_mean_squared_error: 8.0835 - val_loss: 87.6434 - val_mean_squared_error: 87.6434 - val_mean_absolute_error: 4.4075 - val_root_mean_squared_error: 9.3618
# Epoch 26/100
# 28/28 [==============================] - 6s 215ms/step - loss: 74.5030 - mean_squared_error: 74.5030 - mean_absolute_error: 4.1937 - root_mean_squared_error: 8.6315 - val_loss: 119.4846 - val_mean_squared_error: 119.4846 - val_mean_absolute_error: 5.9763 - val_root_mean_squared_error: 10.9309
# Epoch 27/100
# 28/28 [==============================] - 5s 177ms/step - loss: 63.9980 - mean_squared_error: 63.9980 - mean_absolute_error: 3.9440 - root_mean_squared_error: 7.9999 - val_loss: 84.0755 - val_mean_squared_error: 84.0755 - val_mean_absolute_error: 4.2254 - val_root_mean_squared_error: 9.1693
# Epoch 28/100
# 28/28 [==============================] - 5s 192ms/step - loss: 58.4618 - mean_squared_error: 58.4618 - mean_absolute_error: 3.7029 - root_mean_squared_error: 7.6460 - val_loss: 67.1935 - val_mean_squared_error: 67.1935 - val_mean_absolute_error: 3.8916 - val_root_mean_squared_error: 8.1972
# Epoch 29/100
# 28/28 [==============================] - 6s 200ms/step - loss: 57.5077 - mean_squared_error: 57.5077 - mean_absolute_error: 3.6726 - root_mean_squared_error: 7.5834 - val_loss: 76.9131 - val_mean_squared_error: 76.9131 - val_mean_absolute_error: 4.0661 - val_root_mean_squared_error: 8.7700
# Epoch 30/100
# 28/28 [==============================] - 5s 187ms/step - loss: 55.5583 - mean_squared_error: 55.5583 - mean_absolute_error: 3.6416 - root_mean_squared_error: 7.4537 - val_loss: 78.3208 - val_mean_squared_error: 78.3208 - val_mean_absolute_error: 4.1443 - val_root_mean_squared_error: 8.8499
# Epoch 31/100
# 28/28 [==============================] - 6s 216ms/step - loss: 55.7304 - mean_squared_error: 55.7304 - mean_absolute_error: 3.6366 - root_mean_squared_error: 7.4653 - val_loss: 71.4941 - val_mean_squared_error: 71.4941 - val_mean_absolute_error: 3.9909 - val_root_mean_squared_error: 8.4554
# Epoch 32/100
# 28/28 [==============================] - 5s 175ms/step - loss: 58.7041 - mean_squared_error: 58.7041 - mean_absolute_error: 3.8455 - root_mean_squared_error: 7.6619 - val_loss: 80.9875 - val_mean_squared_error: 80.9875 - val_mean_absolute_error: 4.2786 - val_root_mean_squared_error: 8.9993
# Epoch 33/100
# 28/28 [==============================] - 6s 208ms/step - loss: 53.6693 - mean_squared_error: 53.6693 - mean_absolute_error: 3.5726 - root_mean_squared_error: 7.3259 - val_loss: 80.4897 - val_mean_squared_error: 80.4897 - val_mean_absolute_error: 4.1980 - val_root_mean_squared_error: 8.9716
# Epoch 34/100
# 28/28 [==============================] - 5s 181ms/step - loss: 53.9144 - mean_squared_error: 53.9144 - mean_absolute_error: 3.5555 - root_mean_squared_error: 7.3426 - val_loss: 74.0384 - val_mean_squared_error: 74.0384 - val_mean_absolute_error: 4.0174 - val_root_mean_squared_error: 8.6046
# Epoch 35/100
# 28/28 [==============================] - 5s 183ms/step - loss: 56.4528 - mean_squared_error: 56.4527 - mean_absolute_error: 3.6525 - root_mean_squared_error: 7.5135 - val_loss: 71.6692 - val_mean_squared_error: 71.6692 - val_mean_absolute_error: 3.9378 - val_root_mean_squared_error: 8.4658
# Epoch 36/100
# 28/28 [==============================] - 6s 208ms/step - loss: 53.3949 - mean_squared_error: 53.3949 - mean_absolute_error: 3.5618 - root_mean_squared_error: 7.3072 - val_loss: 75.4105 - val_mean_squared_error: 75.4105 - val_mean_absolute_error: 4.1046 - val_root_mean_squared_error: 8.6839
# Epoch 37/100
# 28/28 [==============================] - 5s 182ms/step - loss: 53.6086 - mean_squared_error: 53.6086 - mean_absolute_error: 3.5302 - root_mean_squared_error: 7.3218 - val_loss: 73.2079 - val_mean_squared_error: 73.2079 - val_mean_absolute_error: 4.0570 - val_root_mean_squared_error: 8.5562
# Epoch 38/100
# 28/28 [==============================] - 6s 214ms/step - loss: 51.8684 - mean_squared_error: 51.8684 - mean_absolute_error: 3.4886 - root_mean_squared_error: 7.2020 - val_loss: 72.8014 - val_mean_squared_error: 72.8014 - val_mean_absolute_error: 3.9679 - val_root_mean_squared_error: 8.5324
# Epoch 39/100
# 28/28 [==============================] - 5s 185ms/step - loss: 53.0702 - mean_squared_error: 53.0702 - mean_absolute_error: 3.5405 - root_mean_squared_error: 7.2849 - val_loss: 74.5918 - val_mean_squared_error: 74.5918 - val_mean_absolute_error: 4.1520 - val_root_mean_squared_error: 8.6367
# Epoch 40/100
# 28/28 [==============================] - 5s 193ms/step - loss: 52.6061 - mean_squared_error: 52.6061 - mean_absolute_error: 3.5152 - root_mean_squared_error: 7.2530 - val_loss: 77.6372 - val_mean_squared_error: 77.6372 - val_mean_absolute_error: 4.0875 - val_root_mean_squared_error: 8.8112
# Epoch 41/100
# 28/28 [==============================] - 6s 202ms/step - loss: 51.9952 - mean_squared_error: 51.9952 - mean_absolute_error: 3.4935 - root_mean_squared_error: 7.2108 - val_loss: 71.5051 - val_mean_squared_error: 71.5051 - val_mean_absolute_error: 3.8768 - val_root_mean_squared_error: 8.4561
# Epoch 42/100
# 28/28 [==============================] - 5s 170ms/step - loss: 50.7557 - mean_squared_error: 50.7557 - mean_absolute_error: 3.4766 - root_mean_squared_error: 7.1243 - val_loss: 79.1660 - val_mean_squared_error: 79.1660 - val_mean_absolute_error: 4.0712 - val_root_mean_squared_error: 8.8975
# Epoch 43/100
# 28/28 [==============================] - 6s 209ms/step - loss: 51.4214 - mean_squared_error: 51.4215 - mean_absolute_error: 3.5053 - root_mean_squared_error: 7.1709 - val_loss: 72.3963 - val_mean_squared_error: 72.3963 - val_mean_absolute_error: 4.0227 - val_root_mean_squared_error: 8.5086
# Epoch 44/100
# 28/28 [==============================] - 5s 178ms/step - loss: 49.8113 - mean_squared_error: 49.8113 - mean_absolute_error: 3.4236 - root_mean_squared_error: 7.0577 - val_loss: 71.8607 - val_mean_squared_error: 71.8607 - val_mean_absolute_error: 4.0029 - val_root_mean_squared_error: 8.4771
# Epoch 45/100
# 28/28 [==============================] - 6s 198ms/step - loss: 50.0547 - mean_squared_error: 50.0547 - mean_absolute_error: 3.4299 - root_mean_squared_error: 7.0749 - val_loss: 65.8288 - val_mean_squared_error: 65.8288 - val_mean_absolute_error: 3.8431 - val_root_mean_squared_error: 8.1135
# Epoch 46/100
# 28/28 [==============================] - 5s 178ms/step - loss: 50.5235 - mean_squared_error: 50.5235 - mean_absolute_error: 3.4668 - root_mean_squared_error: 7.1080 - val_loss: 75.0195 - val_mean_squared_error: 75.0195 - val_mean_absolute_error: 4.0080 - val_root_mean_squared_error: 8.6614
# Epoch 47/100
# 28/28 [==============================] - 5s 179ms/step - loss: 50.9261 - mean_squared_error: 50.9261 - mean_absolute_error: 3.4949 - root_mean_squared_error: 7.1362 - val_loss: 70.5268 - val_mean_squared_error: 70.5268 - val_mean_absolute_error: 3.9744 - val_root_mean_squared_error: 8.3980
# Epoch 48/100
# 28/28 [==============================] - 6s 200ms/step - loss: 50.6480 - mean_squared_error: 50.6480 - mean_absolute_error: 3.4704 - root_mean_squared_error: 7.1167 - val_loss: 65.6615 - val_mean_squared_error: 65.6615 - val_mean_absolute_error: 3.8617 - val_root_mean_squared_error: 8.1032
# Epoch 49/100
# 28/28 [==============================] - 5s 170ms/step - loss: 48.7628 - mean_squared_error: 48.7628 - mean_absolute_error: 3.4176 - root_mean_squared_error: 6.9830 - val_loss: 81.8711 - val_mean_squared_error: 81.8711 - val_mean_absolute_error: 4.0794 - val_root_mean_squared_error: 9.0483
# Epoch 50/100
# 28/28 [==============================] - 6s 205ms/step - loss: 50.5055 - mean_squared_error: 50.5056 - mean_absolute_error: 3.4433 - root_mean_squared_error: 7.1067 - val_loss: 73.7917 - val_mean_squared_error: 73.7917 - val_mean_absolute_error: 4.0904 - val_root_mean_squared_error: 8.5902
# Epoch 51/100
# 28/28 [==============================] - 5s 170ms/step - loss: 48.8535 - mean_squared_error: 48.8535 - mean_absolute_error: 3.4239 - root_mean_squared_error: 6.9895 - val_loss: 69.3861 - val_mean_squared_error: 69.3861 - val_mean_absolute_error: 3.8669 - val_root_mean_squared_error: 8.3298
# Epoch 52/100
# 28/28 [==============================] - 5s 182ms/step - loss: 47.6258 - mean_squared_error: 47.6258 - mean_absolute_error: 3.3524 - root_mean_squared_error: 6.9011 - val_loss: 70.1012 - val_mean_squared_error: 70.1012 - val_mean_absolute_error: 3.9907 - val_root_mean_squared_error: 8.3726
# Epoch 53/100
# 28/28 [==============================] - 6s 203ms/step - loss: 48.7788 - mean_squared_error: 48.7788 - mean_absolute_error: 3.4143 - root_mean_squared_error: 6.9842 - val_loss: 69.5484 - val_mean_squared_error: 69.5484 - val_mean_absolute_error: 3.8777 - val_root_mean_squared_error: 8.3396
# Epoch 54/100
# 28/28 [==============================] - 5s 180ms/step - loss: 49.3636 - mean_squared_error: 49.3636 - mean_absolute_error: 3.4318 - root_mean_squared_error: 7.0259 - val_loss: 83.9357 - val_mean_squared_error: 83.9357 - val_mean_absolute_error: 4.1141 - val_root_mean_squared_error: 9.1616
# Epoch 55/100
# 28/28 [==============================] - 6s 201ms/step - loss: 48.7890 - mean_squared_error: 48.7890 - mean_absolute_error: 3.3936 - root_mean_squared_error: 6.9849 - val_loss: 68.0298 - val_mean_squared_error: 68.0298 - val_mean_absolute_error: 3.9236 - val_root_mean_squared_error: 8.2480
# Epoch 56/100
# 28/28 [==============================] - 5s 179ms/step - loss: 48.6588 - mean_squared_error: 48.6588 - mean_absolute_error: 3.4225 - root_mean_squared_error: 6.9756 - val_loss: 64.5880 - val_mean_squared_error: 64.5880 - val_mean_absolute_error: 3.7855 - val_root_mean_squared_error: 8.0367
# Epoch 57/100
# 28/28 [==============================] - 5s 173ms/step - loss: 46.6796 - mean_squared_error: 46.6796 - mean_absolute_error: 3.2836 - root_mean_squared_error: 6.8322 - val_loss: 67.0601 - val_mean_squared_error: 67.0601 - val_mean_absolute_error: 3.9183 - val_root_mean_squared_error: 8.1890
# Epoch 58/100
# 28/28 [==============================] - 6s 212ms/step - loss: 48.1737 - mean_squared_error: 48.1737 - mean_absolute_error: 3.4365 - root_mean_squared_error: 6.9407 - val_loss: 68.6817 - val_mean_squared_error: 68.6817 - val_mean_absolute_error: 3.8498 - val_root_mean_squared_error: 8.2874
# Epoch 59/100
# 28/28 [==============================] - 5s 180ms/step - loss: 47.6360 - mean_squared_error: 47.6360 - mean_absolute_error: 3.3465 - root_mean_squared_error: 6.9019 - val_loss: 74.7126 - val_mean_squared_error: 74.7126 - val_mean_absolute_error: 4.0891 - val_root_mean_squared_error: 8.6436
# Epoch 60/100
# 28/28 [==============================] - 6s 200ms/step - loss: 48.6607 - mean_squared_error: 48.6607 - mean_absolute_error: 3.4077 - root_mean_squared_error: 6.9757 - val_loss: 62.6107 - val_mean_squared_error: 62.6107 - val_mean_absolute_error: 3.7508 - val_root_mean_squared_error: 7.9127
# Epoch 61/100
# 28/28 [==============================] - 5s 169ms/step - loss: 47.7367 - mean_squared_error: 47.7367 - mean_absolute_error: 3.3910 - root_mean_squared_error: 6.9092 - val_loss: 69.1448 - val_mean_squared_error: 69.1448 - val_mean_absolute_error: 3.9931 - val_root_mean_squared_error: 8.3153
# Epoch 62/100
# 28/28 [==============================] - 5s 184ms/step - loss: 47.5754 - mean_squared_error: 47.5754 - mean_absolute_error: 3.3863 - root_mean_squared_error: 6.8975 - val_loss: 82.8844 - val_mean_squared_error: 82.8844 - val_mean_absolute_error: 4.2333 - val_root_mean_squared_error: 9.1041
# Epoch 63/100
# 28/28 [==============================] - 5s 197ms/step - loss: 46.8926 - mean_squared_error: 46.8926 - mean_absolute_error: 3.3294 - root_mean_squared_error: 6.8478 - val_loss: 68.2958 - val_mean_squared_error: 68.2958 - val_mean_absolute_error: 3.8724 - val_root_mean_squared_error: 8.2641
# Epoch 64/100
# 28/28 [==============================] - 5s 172ms/step - loss: 46.4771 - mean_squared_error: 46.4771 - mean_absolute_error: 3.3660 - root_mean_squared_error: 6.8174 - val_loss: 62.7557 - val_mean_squared_error: 62.7557 - val_mean_absolute_error: 3.8116 - val_root_mean_squared_error: 7.9219
# Epoch 65/100
# 28/28 [==============================] - 6s 224ms/step - loss: 46.5751 - mean_squared_error: 46.5751 - mean_absolute_error: 3.3366 - root_mean_squared_error: 6.8246 - val_loss: 72.0173 - val_mean_squared_error: 72.0173 - val_mean_absolute_error: 3.9758 - val_root_mean_squared_error: 8.4863
# Epoch 66/100
# 28/28 [==============================] - 5s 169ms/step - loss: 47.7608 - mean_squared_error: 47.7608 - mean_absolute_error: 3.3628 - root_mean_squared_error: 6.9109 - val_loss: 83.0366 - val_mean_squared_error: 83.0366 - val_mean_absolute_error: 4.1093 - val_root_mean_squared_error: 9.1124
# Epoch 67/100
# 28/28 [==============================] - 5s 182ms/step - loss: 46.0685 - mean_squared_error: 46.0685 - mean_absolute_error: 3.3262 - root_mean_squared_error: 6.7874 - val_loss: 66.3104 - val_mean_squared_error: 66.3104 - val_mean_absolute_error: 3.9238 - val_root_mean_squared_error: 8.1431
# Epoch 68/100
# 28/28 [==============================] - 6s 200ms/step - loss: 46.1929 - mean_squared_error: 46.1929 - mean_absolute_error: 3.3571 - root_mean_squared_error: 6.7965 - val_loss: 91.2239 - val_mean_squared_error: 91.2239 - val_mean_absolute_error: 4.5383 - val_root_mean_squared_error: 9.5511
# Epoch 69/100
# 28/28 [==============================] - 5s 178ms/step - loss: 49.1110 - mean_squared_error: 49.1110 - mean_absolute_error: 3.4333 - root_mean_squared_error: 7.0079 - val_loss: 68.4472 - val_mean_squared_error: 68.4472 - val_mean_absolute_error: 4.0118 - val_root_mean_squared_error: 8.2733
# Epoch 70/100
# 28/28 [==============================] - 6s 208ms/step - loss: 45.2603 - mean_squared_error: 45.2603 - mean_absolute_error: 3.2892 - root_mean_squared_error: 6.7276 - val_loss: 65.5717 - val_mean_squared_error: 65.5717 - val_mean_absolute_error: 3.7793 - val_root_mean_squared_error: 8.0976
# Epoch 71/100
# 28/28 [==============================] - 5s 172ms/step - loss: 46.4604 - mean_squared_error: 46.4604 - mean_absolute_error: 3.3113 - root_mean_squared_error: 6.8162 - val_loss: 68.3904 - val_mean_squared_error: 68.3904 - val_mean_absolute_error: 4.0423 - val_root_mean_squared_error: 8.2698
# Epoch 72/100
# 28/28 [==============================] - 5s 198ms/step - loss: 45.6554 - mean_squared_error: 45.6554 - mean_absolute_error: 3.3497 - root_mean_squared_error: 6.7569 - val_loss: 78.8826 - val_mean_squared_error: 78.8826 - val_mean_absolute_error: 4.0896 - val_root_mean_squared_error: 8.8816
# Epoch 73/100
# 28/28 [==============================] - 5s 186ms/step - loss: 45.8656 - mean_squared_error: 45.8656 - mean_absolute_error: 3.2960 - root_mean_squared_error: 6.7724 - val_loss: 75.9141 - val_mean_squared_error: 75.9141 - val_mean_absolute_error: 4.2288 - val_root_mean_squared_error: 8.7129
# Epoch 74/100
# 28/28 [==============================] - 5s 177ms/step - loss: 45.8795 - mean_squared_error: 45.8795 - mean_absolute_error: 3.3973 - root_mean_squared_error: 6.7734 - val_loss: 65.5783 - val_mean_squared_error: 65.5783 - val_mean_absolute_error: 3.8302 - val_root_mean_squared_error: 8.0980
# Epoch 75/100
# 28/28 [==============================] - 6s 213ms/step - loss: 46.1264 - mean_squared_error: 46.1264 - mean_absolute_error: 3.3353 - root_mean_squared_error: 6.7916 - val_loss: 70.4467 - val_mean_squared_error: 70.4467 - val_mean_absolute_error: 3.9422 - val_root_mean_squared_error: 8.3933
# Epoch 76/100
# 28/28 [==============================] - 5s 189ms/step - loss: 45.4562 - mean_squared_error: 45.4562 - mean_absolute_error: 3.3323 - root_mean_squared_error: 6.7421 - val_loss: 59.6265 - val_mean_squared_error: 59.6265 - val_mean_absolute_error: 3.7027 - val_root_mean_squared_error: 7.7218
# Epoch 77/100
# 28/28 [==============================] - 6s 213ms/step - loss: 45.5197 - mean_squared_error: 45.5197 - mean_absolute_error: 3.3250 - root_mean_squared_error: 6.7468 - val_loss: 69.4442 - val_mean_squared_error: 69.4442 - val_mean_absolute_error: 4.1107 - val_root_mean_squared_error: 8.3333
# Epoch 78/100
# 28/28 [==============================] - 5s 185ms/step - loss: 44.6067 - mean_squared_error: 44.6067 - mean_absolute_error: 3.2446 - root_mean_squared_error: 6.6788 - val_loss: 58.6678 - val_mean_squared_error: 58.6678 - val_mean_absolute_error: 3.6920 - val_root_mean_squared_error: 7.6595
# Epoch 79/100
# 28/28 [==============================] - 5s 190ms/step - loss: 44.7657 - mean_squared_error: 44.7657 - mean_absolute_error: 3.2960 - root_mean_squared_error: 6.6907 - val_loss: 62.3717 - val_mean_squared_error: 62.3717 - val_mean_absolute_error: 3.8238 - val_root_mean_squared_error: 7.8976
# Epoch 80/100
# 28/28 [==============================] - 6s 199ms/step - loss: 44.7003 - mean_squared_error: 44.7003 - mean_absolute_error: 3.2689 - root_mean_squared_error: 6.6858 - val_loss: 59.4276 - val_mean_squared_error: 59.4276 - val_mean_absolute_error: 3.7590 - val_root_mean_squared_error: 7.7089
# Epoch 81/100
# 28/28 [==============================] - 5s 175ms/step - loss: 42.5101 - mean_squared_error: 42.5101 - mean_absolute_error: 3.2020 - root_mean_squared_error: 6.5200 - val_loss: 62.8103 - val_mean_squared_error: 62.8103 - val_mean_absolute_error: 3.8262 - val_root_mean_squared_error: 7.9253
# Epoch 82/100
# 28/28 [==============================] - 6s 211ms/step - loss: 46.1447 - mean_squared_error: 46.1447 - mean_absolute_error: 3.3098 - root_mean_squared_error: 6.7930 - val_loss: 69.0260 - val_mean_squared_error: 69.0260 - val_mean_absolute_error: 4.1290 - val_root_mean_squared_error: 8.3082
# Epoch 83/100
# 28/28 [==============================] - 5s 176ms/step - loss: 43.4853 - mean_squared_error: 43.4853 - mean_absolute_error: 3.2271 - root_mean_squared_error: 6.5943 - val_loss: 56.8504 - val_mean_squared_error: 56.8504 - val_mean_absolute_error: 3.5923 - val_root_mean_squared_error: 7.5399
# Epoch 84/100
# 28/28 [==============================] - 5s 184ms/step - loss: 43.8525 - mean_squared_error: 43.8526 - mean_absolute_error: 3.2082 - root_mean_squared_error: 6.6221 - val_loss: 68.4429 - val_mean_squared_error: 68.4429 - val_mean_absolute_error: 4.0696 - val_root_mean_squared_error: 8.2730
# Epoch 85/100
# 28/28 [==============================] - 6s 209ms/step - loss: 44.7955 - mean_squared_error: 44.7955 - mean_absolute_error: 3.2810 - root_mean_squared_error: 6.6929 - val_loss: 73.2986 - val_mean_squared_error: 73.2986 - val_mean_absolute_error: 4.1481 - val_root_mean_squared_error: 8.5615
# Epoch 86/100
# 28/28 [==============================] - 5s 170ms/step - loss: 45.2190 - mean_squared_error: 45.2190 - mean_absolute_error: 3.3163 - root_mean_squared_error: 6.7245 - val_loss: 68.8407 - val_mean_squared_error: 68.8407 - val_mean_absolute_error: 4.1646 - val_root_mean_squared_error: 8.2970
# Epoch 87/100
# 28/28 [==============================] - 6s 213ms/step - loss: 45.8257 - mean_squared_error: 45.8257 - mean_absolute_error: 3.3608 - root_mean_squared_error: 6.7695 - val_loss: 67.4440 - val_mean_squared_error: 67.4440 - val_mean_absolute_error: 3.9177 - val_root_mean_squared_error: 8.2124
# Epoch 88/100
# 28/28 [==============================] - 5s 192ms/step - loss: 44.5457 - mean_squared_error: 44.5457 - mean_absolute_error: 3.2701 - root_mean_squared_error: 6.6743 - val_loss: 60.4897 - val_mean_squared_error: 60.4897 - val_mean_absolute_error: 3.8401 - val_root_mean_squared_error: 7.7775
# Epoch 89/100
# 28/28 [==============================] - 6s 203ms/step - loss: 42.9381 - mean_squared_error: 42.9381 - mean_absolute_error: 3.1834 - root_mean_squared_error: 6.5527 - val_loss: 61.4643 - val_mean_squared_error: 61.4643 - val_mean_absolute_error: 3.8046 - val_root_mean_squared_error: 7.8399
# Epoch 90/100
# 28/28 [==============================] - 5s 177ms/step - loss: 42.8638 - mean_squared_error: 42.8638 - mean_absolute_error: 3.2404 - root_mean_squared_error: 6.5470 - val_loss: 58.0499 - val_mean_squared_error: 58.0499 - val_mean_absolute_error: 3.6263 - val_root_mean_squared_error: 7.6191
# Epoch 91/100
# 28/28 [==============================] - 5s 182ms/step - loss: 42.9330 - mean_squared_error: 42.9330 - mean_absolute_error: 3.1980 - root_mean_squared_error: 6.5523 - val_loss: 56.3780 - val_mean_squared_error: 56.3780 - val_mean_absolute_error: 3.6469 - val_root_mean_squared_error: 7.5085
# Epoch 92/100
# 28/28 [==============================] - 6s 204ms/step - loss: 42.8265 - mean_squared_error: 42.8265 - mean_absolute_error: 3.2300 - root_mean_squared_error: 6.5442 - val_loss: 68.2910 - val_mean_squared_error: 68.2910 - val_mean_absolute_error: 4.1017 - val_root_mean_squared_error: 8.2638
# Epoch 93/100
# 28/28 [==============================] - 5s 184ms/step - loss: 42.7972 - mean_squared_error: 42.7972 - mean_absolute_error: 3.1996 - root_mean_squared_error: 6.5420 - val_loss: 60.5416 - val_mean_squared_error: 60.5416 - val_mean_absolute_error: 3.7821 - val_root_mean_squared_error: 7.7808
# Epoch 94/100
# 28/28 [==============================] - 6s 222ms/step - loss: 42.5611 - mean_squared_error: 42.5611 - mean_absolute_error: 3.2842 - root_mean_squared_error: 6.5239 - val_loss: 67.2045 - val_mean_squared_error: 67.2045 - val_mean_absolute_error: 3.9597 - val_root_mean_squared_error: 8.1978
# Epoch 95/100
# 28/28 [==============================] - 5s 181ms/step - loss: 42.4982 - mean_squared_error: 42.4982 - mean_absolute_error: 3.1736 - root_mean_squared_error: 6.5191 - val_loss: 61.5489 - val_mean_squared_error: 61.5489 - val_mean_absolute_error: 3.8553 - val_root_mean_squared_error: 7.8453
# Epoch 96/100
# 28/28 [==============================] - 6s 200ms/step - loss: 42.4844 - mean_squared_error: 42.4844 - mean_absolute_error: 3.2256 - root_mean_squared_error: 6.5180 - val_loss: 64.1186 - val_mean_squared_error: 64.1186 - val_mean_absolute_error: 3.9727 - val_root_mean_squared_error: 8.0074
# Epoch 97/100
# 28/28 [==============================] - 5s 192ms/step - loss: 41.8492 - mean_squared_error: 41.8492 - mean_absolute_error: 3.2218 - root_mean_squared_error: 6.4691 - val_loss: 66.9062 - val_mean_squared_error: 66.9062 - val_mean_absolute_error: 3.9396 - val_root_mean_squared_error: 8.1796
# Epoch 98/100
# 28/28 [==============================] - 5s 192ms/step - loss: 44.5472 - mean_squared_error: 44.5472 - mean_absolute_error: 3.2731 - root_mean_squared_error: 6.6744 - val_loss: 61.8691 - val_mean_squared_error: 61.8691 - val_mean_absolute_error: 3.8812 - val_root_mean_squared_error: 7.8657
# Epoch 99/100
# 28/28 [==============================] - 6s 210ms/step - loss: 41.4154 - mean_squared_error: 41.4154 - mean_absolute_error: 3.1606 - root_mean_squared_error: 6.4355 - val_loss: 62.3580 - val_mean_squared_error: 62.3580 - val_mean_absolute_error: 3.8581 - val_root_mean_squared_error: 7.8967
# Epoch 100/100
# 28/28 [==============================] - 5s 184ms/step - loss: 42.3828 - mean_squared_error: 42.3828 - mean_absolute_error: 3.2098 - root_mean_squared_error: 6.5102 - val_loss: 58.8648 - val_mean_squared_error: 58.8648 - val_mean_absolute_error: 3.7152 - val_root_mean_squared_error: 7.6723

# %%
from utils.plotting import training_loss_plot

if not in_google_colab():
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

plot = training_loss_plot(train_score, filename='download/training_loss.pdf')
plot.show()

# %%
### Predict on the test set
from utils.evaluation import phases_report, phases_report_std

print('Testmetriken:')

report = phases_report(y_pred, bis.test_dataset, propofolrate.test_dataset)
report
# Out:
# Testmetriken:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                 109.89       139.87           7.74         7.55
# Induction           259.81       637.60          12.58        18.34
# Maintenance          75.13        60.90           6.64         5.68
# Recovery            245.89       361.57          11.91        13.46
#
#             Prediction RMSE Baseline RMSE
# All                   10.48         11.83
# Induction             16.12         25.25
# Maintenance            8.67          7.80
# Recovery              15.68         19.02

# %%
phases_report_std(report, y_pred, bis.test_dataset, propofolrate.test_dataset)
# Out:
# All      	min: 	 15 	max: 	 6
# Induction 	min: 	 23 	max: 	 10
# Maintenance 	min: 	 13 	max: 	 6
# Recovery 	min: 	 19 	max: 	 22
#              Prediction MSE  Baseline MSE  Prediction MAE  Baseline MAE  \
# All                   56.67         82.42            2.11          2.54
# Induction            255.35        403.81            5.86          8.45
# Maintenance           39.63         43.11            1.80          2.15
# Recovery             145.74        185.95            5.00          6.28
#
#              Prediction RMSE  Baseline RMSE
# All                     2.61           3.31
# Induction               6.17           7.29
# Maintenance             2.12           2.51
# Recovery                5.68           6.47

# %%
from utils.plotting import full_histogramm_plot

plot = full_histogramm_plot(groundtruth = bis.test_dataset, prediction = y_pred, filename='download/histogramm.pdf')
plot.show()

# %%
from utils.plotting import single_prediction_plot

for case in test_index:
    single_prediction_plot(
        case = case,
        index = test_index,
        groundtruth = bis.test_dataset,
        prediction = y_pred,
        infusion = propofolrate.test_dataset,
        error = 'Prediction RMSE',
        filename = 'download/' + str(case) + '.pdf')

print('Finished')
# Out:
# /content/utils/plotting.py:79: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(12/2.54, 6/2.54))
# Finished

# %%
from utils.plotting import full_prediction_plot

full_prediction_plot(index = test_index, groundtruth = bis.test_dataset, prediction = y_pred, infusion = propofolrate.test_dataset)
