# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset02/'
vitaldbpath = 'vitaldb_tiva/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 332, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 332 (delta 23), reused 56 (delta 13), pack-reused 264
# Receiving objects: 100% (332/332), 46.50 MiB | 19.22 MiB/s, done.
# Resolving deltas: 100% (123/123), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.31.0)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolrate.name = 'Propofol Rate'
    propofolrate.tracks = ['Orchestra/PPF20_RATE']
    propofolrate.filterON = False
    propofolrate.generateDataset(normalization=md.NormNone)
    propofolrate.save('03_propofol_rate.npz')

    propofolvol = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolvol.name = 'Propofol Volume'
    propofolvol.tracks = ['Orchestra/PPF20_VOL']
    propofolvol.filterON = False
    propofolvol.filter = [2, 0, 500]
    propofolvol.generateDataset(normalization=md.NormNone)
    propofolvol.save('03_propofol_vol.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolrate.load('03_propofol_rate.npz')

propofolvol = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolvol.load('03_propofol_vol.npz')

train_index, val_index, test_index = bis.split(np.array(bis.index))

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### LSTM layers for the blood pressure data

### Blood Pressure layers
input_vital = Input(shape=(None, bloodpressure.train_dataset.shape[2]))
vital_layer = Masking(mask_value=0.0)(input_vital)

vital_layer = LSTM(units=32, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = LSTM(units=32, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = LSTM(units=32, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = LSTM(units=8, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = LSTM(units=4, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = Dense(units=4, activation='sigmoid')(vital_layer)

input_propofol = Input(shape=(None, propofolrate.train_dataset.shape[2]))
propofol_layer = BatchNormalization()(input_propofol)
propofol_layer = LSTM(units=32, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=32, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=32, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=8, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=4, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = Dense(units=4, activation='sigmoid')(propofol_layer)

### INFO layers
input_info = Input(shape=(info.train_dataset.shape[1],))
info_layer = RepeatVector(bloodpressure.train_dataset.shape[1])(input_info)
info_layer = Dense(units=16, activation='sigmoid')(info_layer)
info_layer = Dense(units=16, activation='sigmoid')(info_layer)


## Concatenate the Propofol output with the info layer
comb_layer = Concatenate()([vital_layer, propofol_layer, info_layer])
comb_layer = Dense(units=1, activation='sigmoid')(comb_layer)
output = Lambda(lambda x: x * 100)(comb_layer)

# Define the model
model = Model(inputs=[input_vital, input_propofol, input_info], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.005)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

model.summary()
#y = pd.DataFrame(bis.train_dataset[:,:,0].T).rolling(min_periods=1,window=20, center=True).mean().to_numpy().T[:,:,np.newaxis]

# Train the model
history = model.fit([bloodpressure.train_dataset, propofolrate.train_dataset, info.train_dataset],
                    bis.train_dataset,
                    validation_data=([bloodpressure.validation_dataset, propofolrate.validation_dataset , info.validation_dataset], bis.validation_dataset),
                    epochs=30,
                    batch_size=4
                    )

train_score = history.history
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 3)]            0         []
#
#  input_2 (InputLayer)        [(None, None, 1)]            0         []
#
#  masking (Masking)           (None, None, 3)              0         ['input_1[0][0]']
#
#  batch_normalization_5 (Bat  (None, None, 1)              4         ['input_2[0][0]']
#  chNormalization)
#
#  lstm (LSTM)                 (None, None, 32)             4608      ['masking[0][0]']
#
#  lstm_5 (LSTM)               (None, None, 32)             4352      ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  batch_normalization (Batch  (None, None, 32)             128       ['lstm[0][0]']
#  Normalization)
#
#  batch_normalization_6 (Bat  (None, None, 32)             128       ['lstm_5[0][0]']
#  chNormalization)
#
#  lstm_1 (LSTM)               (None, None, 32)             8320      ['batch_normalization[0][0]']
#
#  lstm_6 (LSTM)               (None, None, 32)             8320      ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  batch_normalization_1 (Bat  (None, None, 32)             128       ['lstm_1[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, None, 32)             128       ['lstm_6[0][0]']
#  chNormalization)
#
#  lstm_2 (LSTM)               (None, None, 32)             8320      ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  lstm_7 (LSTM)               (None, None, 32)             8320      ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, None, 32)             128       ['lstm_2[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, None, 32)             128       ['lstm_7[0][0]']
#  chNormalization)
#
#  lstm_3 (LSTM)               (None, None, 8)              1312      ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  lstm_8 (LSTM)               (None, None, 8)              1312      ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  batch_normalization_3 (Bat  (None, None, 8)              32        ['lstm_3[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, None, 8)              32        ['lstm_8[0][0]']
#  chNormalization)
#
#  input_3 (InputLayer)        [(None, 5)]                  0         []
#
#  lstm_4 (LSTM)               (None, None, 4)              208       ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  lstm_9 (LSTM)               (None, None, 4)              208       ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  repeat_vector (RepeatVecto  (None, 3680, 5)              0         ['input_3[0][0]']
#  r)
#
#  batch_normalization_4 (Bat  (None, None, 4)              16        ['lstm_4[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, None, 4)              16        ['lstm_9[0][0]']
#  tchNormalization)
#
#  dense_2 (Dense)             (None, 3680, 16)             96        ['repeat_vector[0][0]']
#
#  dense (Dense)               (None, None, 4)              20        ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  dense_1 (Dense)             (None, None, 4)              20        ['batch_normalization_10[0][0]
#                                                                     ']
#
#  dense_3 (Dense)             (None, 3680, 16)             272       ['dense_2[0][0]']
#
#  concatenate (Concatenate)   (None, 3680, 24)             0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 3680, 1)              25        ['concatenate[0][0]']
#
#  lambda (Lambda)             (None, 3680, 1)              0         ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 46581 (181.96 KB)
# Trainable params: 46147 (180.26 KB)
# Non-trainable params: 434 (1.70 KB)
# __________________________________________________________________________________________________
# Epoch 1/30
# 28/28 [==============================] - 67s 982ms/step - loss: 463.5908 - mean_squared_error: 463.5909 - mean_absolute_error: 17.3911 - root_mean_squared_error: 21.5312 - val_loss: 382.1591 - val_mean_squared_error: 382.1591 - val_mean_absolute_error: 17.1666 - val_root_mean_squared_error: 19.5489
# Epoch 2/30
# 28/28 [==============================] - 21s 752ms/step - loss: 151.9019 - mean_squared_error: 151.9019 - mean_absolute_error: 10.0030 - root_mean_squared_error: 12.3249 - val_loss: 217.0455 - val_mean_squared_error: 217.0455 - val_mean_absolute_error: 12.2084 - val_root_mean_squared_error: 14.7325
# Epoch 3/30
# 28/28 [==============================] - 21s 745ms/step - loss: 98.6948 - mean_squared_error: 98.6948 - mean_absolute_error: 7.4640 - root_mean_squared_error: 9.9345 - val_loss: 689.7478 - val_mean_squared_error: 689.7478 - val_mean_absolute_error: 22.8803 - val_root_mean_squared_error: 26.2631
# Epoch 4/30
# 28/28 [==============================] - 22s 780ms/step - loss: 84.4372 - mean_squared_error: 84.4372 - mean_absolute_error: 6.5062 - root_mean_squared_error: 9.1890 - val_loss: 673.2954 - val_mean_squared_error: 673.2954 - val_mean_absolute_error: 23.0059 - val_root_mean_squared_error: 25.9479
# Epoch 5/30
# 28/28 [==============================] - 20s 710ms/step - loss: 78.6824 - mean_squared_error: 78.6824 - mean_absolute_error: 6.0160 - root_mean_squared_error: 8.8703 - val_loss: 538.5729 - val_mean_squared_error: 538.5728 - val_mean_absolute_error: 20.7334 - val_root_mean_squared_error: 23.2072
# Epoch 6/30
# 28/28 [==============================] - 22s 780ms/step - loss: 95.3788 - mean_squared_error: 95.3788 - mean_absolute_error: 6.3990 - root_mean_squared_error: 9.7662 - val_loss: 548.8890 - val_mean_squared_error: 548.8890 - val_mean_absolute_error: 21.1778 - val_root_mean_squared_error: 23.4284
# Epoch 7/30
# 28/28 [==============================] - 21s 760ms/step - loss: 80.2273 - mean_squared_error: 80.2273 - mean_absolute_error: 5.7493 - root_mean_squared_error: 8.9570 - val_loss: 117.5794 - val_mean_squared_error: 117.5794 - val_mean_absolute_error: 8.1505 - val_root_mean_squared_error: 10.8434
# Epoch 8/30
# 28/28 [==============================] - 20s 703ms/step - loss: 77.7314 - mean_squared_error: 77.7314 - mean_absolute_error: 5.6917 - root_mean_squared_error: 8.8165 - val_loss: 120.1560 - val_mean_squared_error: 120.1560 - val_mean_absolute_error: 7.3376 - val_root_mean_squared_error: 10.9616
# Epoch 9/30
# 28/28 [==============================] - 22s 783ms/step - loss: 82.5285 - mean_squared_error: 82.5285 - mean_absolute_error: 5.6379 - root_mean_squared_error: 9.0845 - val_loss: 259.4532 - val_mean_squared_error: 259.4532 - val_mean_absolute_error: 14.1746 - val_root_mean_squared_error: 16.1076
# Epoch 10/30
# 28/28 [==============================] - 21s 747ms/step - loss: 70.4531 - mean_squared_error: 70.4531 - mean_absolute_error: 5.1074 - root_mean_squared_error: 8.3936 - val_loss: 227.9467 - val_mean_squared_error: 227.9467 - val_mean_absolute_error: 13.6710 - val_root_mean_squared_error: 15.0979
# Epoch 11/30
# 28/28 [==============================] - 22s 776ms/step - loss: 66.3507 - mean_squared_error: 66.3507 - mean_absolute_error: 5.0796 - root_mean_squared_error: 8.1456 - val_loss: 79.8628 - val_mean_squared_error: 79.8628 - val_mean_absolute_error: 5.8622 - val_root_mean_squared_error: 8.9366
# Epoch 12/30
# 28/28 [==============================] - 22s 788ms/step - loss: 63.9411 - mean_squared_error: 63.9411 - mean_absolute_error: 4.8674 - root_mean_squared_error: 7.9963 - val_loss: 70.1462 - val_mean_squared_error: 70.1462 - val_mean_absolute_error: 5.7111 - val_root_mean_squared_error: 8.3753
# Epoch 13/30
# 28/28 [==============================] - 21s 744ms/step - loss: 62.3063 - mean_squared_error: 62.3063 - mean_absolute_error: 4.8705 - root_mean_squared_error: 7.8934 - val_loss: 133.2398 - val_mean_squared_error: 133.2398 - val_mean_absolute_error: 10.1509 - val_root_mean_squared_error: 11.5430
# Epoch 14/30
# 28/28 [==============================] - 21s 735ms/step - loss: 62.8922 - mean_squared_error: 62.8922 - mean_absolute_error: 4.8863 - root_mean_squared_error: 7.9305 - val_loss: 139.6936 - val_mean_squared_error: 139.6935 - val_mean_absolute_error: 10.3867 - val_root_mean_squared_error: 11.8192
# Epoch 15/30
# 28/28 [==============================] - 21s 760ms/step - loss: 69.6736 - mean_squared_error: 69.6736 - mean_absolute_error: 5.2702 - root_mean_squared_error: 8.3471 - val_loss: 61.4825 - val_mean_squared_error: 61.4825 - val_mean_absolute_error: 4.7301 - val_root_mean_squared_error: 7.8411
# Epoch 16/30
# 28/28 [==============================] - 21s 753ms/step - loss: 61.4068 - mean_squared_error: 61.4068 - mean_absolute_error: 4.7840 - root_mean_squared_error: 7.8362 - val_loss: 81.3460 - val_mean_squared_error: 81.3460 - val_mean_absolute_error: 4.9108 - val_root_mean_squared_error: 9.0192
# Epoch 17/30
# 28/28 [==============================] - 22s 793ms/step - loss: 52.8167 - mean_squared_error: 52.8167 - mean_absolute_error: 4.4943 - root_mean_squared_error: 7.2675 - val_loss: 71.1592 - val_mean_squared_error: 71.1592 - val_mean_absolute_error: 4.9650 - val_root_mean_squared_error: 8.4356
# Epoch 18/30
# 28/28 [==============================] - 21s 759ms/step - loss: 48.0009 - mean_squared_error: 48.0009 - mean_absolute_error: 4.2641 - root_mean_squared_error: 6.9283 - val_loss: 70.2633 - val_mean_squared_error: 70.2633 - val_mean_absolute_error: 4.9861 - val_root_mean_squared_error: 8.3823
# Epoch 19/30
# 28/28 [==============================] - 20s 708ms/step - loss: 50.9695 - mean_squared_error: 50.9695 - mean_absolute_error: 4.3688 - root_mean_squared_error: 7.1393 - val_loss: 62.0576 - val_mean_squared_error: 62.0576 - val_mean_absolute_error: 4.7300 - val_root_mean_squared_error: 7.8777
# Epoch 20/30
# 28/28 [==============================] - 21s 767ms/step - loss: 45.9112 - mean_squared_error: 45.9112 - mean_absolute_error: 4.1426 - root_mean_squared_error: 6.7758 - val_loss: 56.5048 - val_mean_squared_error: 56.5048 - val_mean_absolute_error: 4.5114 - val_root_mean_squared_error: 7.5170
# Epoch 21/30
# 28/28 [==============================] - 21s 753ms/step - loss: 48.3575 - mean_squared_error: 48.3575 - mean_absolute_error: 4.2420 - root_mean_squared_error: 6.9540 - val_loss: 53.4618 - val_mean_squared_error: 53.4618 - val_mean_absolute_error: 4.2296 - val_root_mean_squared_error: 7.3118
# Epoch 22/30
# 28/28 [==============================] - 21s 753ms/step - loss: 48.5019 - mean_squared_error: 48.5019 - mean_absolute_error: 4.2306 - root_mean_squared_error: 6.9643 - val_loss: 78.3520 - val_mean_squared_error: 78.3520 - val_mean_absolute_error: 6.2200 - val_root_mean_squared_error: 8.8517
# Epoch 23/30
# 28/28 [==============================] - 20s 729ms/step - loss: 45.8286 - mean_squared_error: 45.8286 - mean_absolute_error: 4.0586 - root_mean_squared_error: 6.7697 - val_loss: 45.7230 - val_mean_squared_error: 45.7230 - val_mean_absolute_error: 4.0362 - val_root_mean_squared_error: 6.7619
# Epoch 24/30
# 28/28 [==============================] - 20s 719ms/step - loss: 43.0160 - mean_squared_error: 43.0160 - mean_absolute_error: 3.9287 - root_mean_squared_error: 6.5587 - val_loss: 47.1771 - val_mean_squared_error: 47.1771 - val_mean_absolute_error: 4.0496 - val_root_mean_squared_error: 6.8686
# Epoch 25/30
# 28/28 [==============================] - 22s 792ms/step - loss: 44.6270 - mean_squared_error: 44.6270 - mean_absolute_error: 3.9869 - root_mean_squared_error: 6.6803 - val_loss: 67.4484 - val_mean_squared_error: 67.4484 - val_mean_absolute_error: 5.0399 - val_root_mean_squared_error: 8.2127
# Epoch 26/30
# 28/28 [==============================] - 20s 708ms/step - loss: 45.7421 - mean_squared_error: 45.7421 - mean_absolute_error: 3.9725 - root_mean_squared_error: 6.7633 - val_loss: 50.5145 - val_mean_squared_error: 50.5145 - val_mean_absolute_error: 4.1072 - val_root_mean_squared_error: 7.1074
# Epoch 27/30
# 28/28 [==============================] - 22s 794ms/step - loss: 46.4396 - mean_squared_error: 46.4396 - mean_absolute_error: 4.0207 - root_mean_squared_error: 6.8147 - val_loss: 77.9624 - val_mean_squared_error: 77.9624 - val_mean_absolute_error: 5.2520 - val_root_mean_squared_error: 8.8296
# Epoch 28/30
# 28/28 [==============================] - 21s 749ms/step - loss: 42.7435 - mean_squared_error: 42.7435 - mean_absolute_error: 3.8587 - root_mean_squared_error: 6.5378 - val_loss: 62.8201 - val_mean_squared_error: 62.8201 - val_mean_absolute_error: 4.6313 - val_root_mean_squared_error: 7.9259
# Epoch 29/30
# 28/28 [==============================] - 20s 707ms/step - loss: 46.2945 - mean_squared_error: 46.2945 - mean_absolute_error: 4.0465 - root_mean_squared_error: 6.8040 - val_loss: 55.5019 - val_mean_squared_error: 55.5019 - val_mean_absolute_error: 4.1581 - val_root_mean_squared_error: 7.4500
# Epoch 30/30
# 28/28 [==============================] - 21s 752ms/step - loss: 45.3405 - mean_squared_error: 45.3405 - mean_absolute_error: 3.9412 - root_mean_squared_error: 6.7335 - val_loss: 44.9019 - val_mean_squared_error: 44.9019 - val_mean_absolute_error: 3.6630 - val_root_mean_squared_error: 6.7009

# %%
model.save('model_bis_propofol_info.keras')

# %% [markdown]
# # Training results

# %%
from utils.plotting import training_loss_plot

### Training Summary
plot = training_loss_plot(train_score)
plot.show()

# %% [markdown]
# # Testing

# %%
### Predict on the test set
from utils.evaluation import phases_report

y_pred =  model.predict([bloodpressure.test_dataset, propofolrate.test_dataset, info.test_dataset], verbose=0)

phases_report(y_pred, bis.test_dataset, propofolrate.test_dataset)
# Out:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                  86.31       139.87           6.80         7.55
# Induction           173.17       637.60          10.46        18.34
# Maintenance          63.92        60.90           5.97         5.68
# Recovery            180.94       361.57           9.93        13.46
#
#             Prediction RMSE Baseline RMSE
# All                    9.29         11.83
# Induction             13.16         25.25
# Maintenance            7.99          7.80
# Recovery              13.45         19.02

# %%
from utils.plotting import single_prediction_plot

plot = single_prediction_plot(5, test_index, bis.test_dataset, y_pred)
plot.show()

# %%
from utils.plotting import full_prediction_plot

full_prediction_plot(test_index, bis.test_dataset, y_pred)
