# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset02/'
vitaldbpath = 'vitaldb_tiva/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 332, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 332 (delta 23), reused 56 (delta 13), pack-reused 264
# Receiving objects: 100% (332/332), 46.50 MiB | 24.08 MiB/s, done.
# Resolving deltas: 100% (123/123), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.31.0)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolrate.name = 'Propofol Rate'
    propofolrate.tracks = ['Orchestra/PPF20_RATE']
    propofolrate.filterON = False
    propofolrate.generateDataset(normalization=md.NormNone)
    propofolrate.save('03_propofol_rate.npz')

    propofolvol = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolvol.name = 'Propofol Volume'
    propofolvol.tracks = ['Orchestra/PPF20_VOL']
    propofolvol.filterON = False
    propofolvol.filter = [2, 0, 500]
    propofolvol.generateDataset(normalization=md.NormNone)
    propofolvol.save('03_propofol_vol.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolrate.load('03_propofol_rate.npz')

propofolvol = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolvol.load('03_propofol_vol.npz')

train_index, val_index, test_index = bis.split(np.array(bis.index))

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### LSTM layers for the blood pressure data

### Blood Pressure layers
input_vital = Input(shape=(None, bloodpressure.train_dataset.shape[2]))
vital_layer = Masking(mask_value=0.0)(input_vital)

vital_layer = LSTM(units=32, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = LSTM(units=32, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = LSTM(units=32, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = LSTM(units=8, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = LSTM(units=4, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = Dense(units=4, activation='sigmoid')(vital_layer)

input_propofol = Input(shape=(None, propofolrate.train_dataset.shape[2]))
propofol_layer = BatchNormalization()(input_propofol)
propofol_layer = LSTM(units=32, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=32, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=32, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=8, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=4, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = Dense(units=4, activation='sigmoid')(propofol_layer)

### INFO layers
input_info = Input(shape=(info.train_dataset.shape[1],))
info_layer = RepeatVector(bloodpressure.train_dataset.shape[1])(input_info)
info_layer = Dense(units=16, activation='sigmoid')(info_layer)
info_layer = Dense(units=16, activation='sigmoid')(info_layer)


## Concatenate the Propofol output with the info layer
comb_layer = Concatenate()([vital_layer, propofol_layer, info_layer])
comb_layer = Dense(units=1, activation='sigmoid')(comb_layer)
output = Lambda(lambda x: x * 100)(comb_layer)

# Define the model
model = Model(inputs=[input_vital, input_propofol, input_info], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.005)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

#model.summary()
#y = pd.DataFrame(bis.train_dataset[:,:,0].T).rolling(min_periods=1,window=20, center=True).mean().to_numpy().T[:,:,np.newaxis]

class StopTrainingCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(StopTrainingCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_loss') is not None:
            if logs.get('val_loss') < self.threshold:
                print(f"\nValidation loss is below {self.threshold}, stopping training.")
                self.model.stop_training = True

stop_training_callback = StopTrainingCallback(threshold = 60)

# Train the model
history = model.fit([bloodpressure.train_dataset, propofolrate.train_dataset, info.train_dataset],
                    bis.train_dataset,
                    validation_data=([bloodpressure.validation_dataset, propofolrate.validation_dataset , info.validation_dataset], bis.validation_dataset),
                    epochs=50,
                    callbacks=[stop_training_callback],
                    batch_size=4
                    )

train_score = history.history
# Out:
# Epoch 1/50
# 28/28 [==============================] - 79s 1s/step - loss: 1141.0254 - mean_squared_error: 1141.0253 - mean_absolute_error: 28.0915 - root_mean_squared_error: 33.7791 - val_loss: 496.1611 - val_mean_squared_error: 496.1611 - val_mean_absolute_error: 20.4736 - val_root_mean_squared_error: 22.2747
# Epoch 2/50
# 28/28 [==============================] - 22s 806ms/step - loss: 372.3755 - mean_squared_error: 372.3754 - mean_absolute_error: 16.9849 - root_mean_squared_error: 19.2970 - val_loss: 441.6741 - val_mean_squared_error: 441.6741 - val_mean_absolute_error: 19.0716 - val_root_mean_squared_error: 21.0160
# Epoch 3/50
# 28/28 [==============================] - 23s 833ms/step - loss: 257.0675 - mean_squared_error: 257.0675 - mean_absolute_error: 13.9537 - root_mean_squared_error: 16.0333 - val_loss: 545.3329 - val_mean_squared_error: 545.3329 - val_mean_absolute_error: 20.7463 - val_root_mean_squared_error: 23.3524
# Epoch 4/50
# 28/28 [==============================] - 23s 821ms/step - loss: 184.3481 - mean_squared_error: 184.3481 - mean_absolute_error: 11.5426 - root_mean_squared_error: 13.5775 - val_loss: 670.4523 - val_mean_squared_error: 670.4523 - val_mean_absolute_error: 22.6229 - val_root_mean_squared_error: 25.8931
# Epoch 5/50
# 28/28 [==============================] - 23s 808ms/step - loss: 141.2423 - mean_squared_error: 141.2423 - mean_absolute_error: 9.8336 - root_mean_squared_error: 11.8845 - val_loss: 686.9830 - val_mean_squared_error: 686.9830 - val_mean_absolute_error: 22.7213 - val_root_mean_squared_error: 26.2104
# Epoch 6/50
# 28/28 [==============================] - 22s 774ms/step - loss: 116.2652 - mean_squared_error: 116.2652 - mean_absolute_error: 8.7048 - root_mean_squared_error: 10.7826 - val_loss: 725.2123 - val_mean_squared_error: 725.2123 - val_mean_absolute_error: 23.2476 - val_root_mean_squared_error: 26.9298
# Epoch 7/50
# 28/28 [==============================] - 24s 859ms/step - loss: 102.8080 - mean_squared_error: 102.8080 - mean_absolute_error: 7.8814 - root_mean_squared_error: 10.1394 - val_loss: 690.2265 - val_mean_squared_error: 690.2265 - val_mean_absolute_error: 22.8333 - val_root_mean_squared_error: 26.2722
# Epoch 8/50
# 28/28 [==============================] - 23s 816ms/step - loss: 91.9213 - mean_squared_error: 91.9213 - mean_absolute_error: 7.4220 - root_mean_squared_error: 9.5876 - val_loss: 617.5573 - val_mean_squared_error: 617.5573 - val_mean_absolute_error: 21.7156 - val_root_mean_squared_error: 24.8507
# Epoch 9/50
# 28/28 [==============================] - 22s 797ms/step - loss: 88.3756 - mean_squared_error: 88.3756 - mean_absolute_error: 7.0208 - root_mean_squared_error: 9.4008 - val_loss: 130.1464 - val_mean_squared_error: 130.1464 - val_mean_absolute_error: 8.7252 - val_root_mean_squared_error: 11.4082
# Epoch 10/50
# 28/28 [==============================] - 23s 844ms/step - loss: 85.2615 - mean_squared_error: 85.2615 - mean_absolute_error: 6.7737 - root_mean_squared_error: 9.2337 - val_loss: 460.5121 - val_mean_squared_error: 460.5121 - val_mean_absolute_error: 18.9145 - val_root_mean_squared_error: 21.4595
# Epoch 11/50
# 28/28 [==============================] - 23s 844ms/step - loss: 77.8240 - mean_squared_error: 77.8240 - mean_absolute_error: 6.3635 - root_mean_squared_error: 8.8218 - val_loss: 424.8791 - val_mean_squared_error: 424.8790 - val_mean_absolute_error: 18.2564 - val_root_mean_squared_error: 20.6126
# Epoch 12/50
# 28/28 [==============================] - 23s 817ms/step - loss: 75.7297 - mean_squared_error: 75.7297 - mean_absolute_error: 6.2256 - root_mean_squared_error: 8.7023 - val_loss: 357.3387 - val_mean_squared_error: 357.3387 - val_mean_absolute_error: 16.7170 - val_root_mean_squared_error: 18.9034
# Epoch 13/50
# 28/28 [==============================] - 24s 838ms/step - loss: 72.2585 - mean_squared_error: 72.2585 - mean_absolute_error: 5.9137 - root_mean_squared_error: 8.5005 - val_loss: 318.7988 - val_mean_squared_error: 318.7988 - val_mean_absolute_error: 15.8632 - val_root_mean_squared_error: 17.8549
# Epoch 14/50
# 28/28 [==============================] - 24s 857ms/step - loss: 69.6489 - mean_squared_error: 69.6489 - mean_absolute_error: 5.8236 - root_mean_squared_error: 8.3456 - val_loss: 89.7588 - val_mean_squared_error: 89.7588 - val_mean_absolute_error: 7.1490 - val_root_mean_squared_error: 9.4741
# Epoch 15/50
# 28/28 [==============================] - 23s 816ms/step - loss: 69.0652 - mean_squared_error: 69.0652 - mean_absolute_error: 5.6736 - root_mean_squared_error: 8.3105 - val_loss: 258.6564 - val_mean_squared_error: 258.6564 - val_mean_absolute_error: 14.2929 - val_root_mean_squared_error: 16.0828
# Epoch 16/50
# 28/28 [==============================] - 23s 809ms/step - loss: 66.5083 - mean_squared_error: 66.5083 - mean_absolute_error: 5.5780 - root_mean_squared_error: 8.1553 - val_loss: 236.9801 - val_mean_squared_error: 236.9801 - val_mean_absolute_error: 13.7968 - val_root_mean_squared_error: 15.3942
# Epoch 17/50
# 28/28 [==============================] - 24s 864ms/step - loss: 64.6580 - mean_squared_error: 64.6580 - mean_absolute_error: 5.4251 - root_mean_squared_error: 8.0410 - val_loss: 216.0630 - val_mean_squared_error: 216.0630 - val_mean_absolute_error: 13.3716 - val_root_mean_squared_error: 14.6991
# Epoch 18/50
# 28/28 [==============================] - 24s 856ms/step - loss: 64.9521 - mean_squared_error: 64.9521 - mean_absolute_error: 5.4084 - root_mean_squared_error: 8.0593 - val_loss: 232.1402 - val_mean_squared_error: 232.1402 - val_mean_absolute_error: 13.6038 - val_root_mean_squared_error: 15.2361
# Epoch 19/50
# 28/28 [==============================] - 22s 788ms/step - loss: 62.9328 - mean_squared_error: 62.9328 - mean_absolute_error: 5.3097 - root_mean_squared_error: 7.9330 - val_loss: 220.1705 - val_mean_squared_error: 220.1705 - val_mean_absolute_error: 13.3916 - val_root_mean_squared_error: 14.8381
# Epoch 20/50
# 28/28 [==============================] - 23s 821ms/step - loss: 60.8779 - mean_squared_error: 60.8779 - mean_absolute_error: 5.1727 - root_mean_squared_error: 7.8024 - val_loss: 77.9932 - val_mean_squared_error: 77.9932 - val_mean_absolute_error: 6.8301 - val_root_mean_squared_error: 8.8314
# Epoch 21/50
# 28/28 [==============================] - 24s 858ms/step - loss: 60.4731 - mean_squared_error: 60.4731 - mean_absolute_error: 5.1388 - root_mean_squared_error: 7.7764 - val_loss: 85.2512 - val_mean_squared_error: 85.2512 - val_mean_absolute_error: 5.4223 - val_root_mean_squared_error: 9.2332
# Epoch 22/50
# 28/28 [==============================] - 23s 825ms/step - loss: 60.8598 - mean_squared_error: 60.8598 - mean_absolute_error: 5.0956 - root_mean_squared_error: 7.8013 - val_loss: 193.4719 - val_mean_squared_error: 193.4719 - val_mean_absolute_error: 12.7192 - val_root_mean_squared_error: 13.9094
# Epoch 23/50
# 28/28 [==============================] - 22s 774ms/step - loss: 58.7617 - mean_squared_error: 58.7617 - mean_absolute_error: 5.0890 - root_mean_squared_error: 7.6656 - val_loss: 168.8144 - val_mean_squared_error: 168.8144 - val_mean_absolute_error: 11.7936 - val_root_mean_squared_error: 12.9929
# Epoch 24/50
# 28/28 [==============================] - 24s 861ms/step - loss: 59.2577 - mean_squared_error: 59.2577 - mean_absolute_error: 5.0122 - root_mean_squared_error: 7.6979 - val_loss: 152.7864 - val_mean_squared_error: 152.7864 - val_mean_absolute_error: 11.2308 - val_root_mean_squared_error: 12.3607
# Epoch 25/50
# 28/28 [==============================] - 23s 823ms/step - loss: 57.0616 - mean_squared_error: 57.0616 - mean_absolute_error: 4.8491 - root_mean_squared_error: 7.5539 - val_loss: 159.6387 - val_mean_squared_error: 159.6387 - val_mean_absolute_error: 11.4859 - val_root_mean_squared_error: 12.6348
# Epoch 26/50
# 28/28 [==============================] - 23s 828ms/step - loss: 55.6536 - mean_squared_error: 55.6536 - mean_absolute_error: 4.8187 - root_mean_squared_error: 7.4601 - val_loss: 141.7948 - val_mean_squared_error: 141.7948 - val_mean_absolute_error: 10.6909 - val_root_mean_squared_error: 11.9078
# Epoch 27/50
# 28/28 [==============================] - 23s 829ms/step - loss: 55.4761 - mean_squared_error: 55.4761 - mean_absolute_error: 4.8858 - root_mean_squared_error: 7.4482 - val_loss: 120.0224 - val_mean_squared_error: 120.0224 - val_mean_absolute_error: 6.7059 - val_root_mean_squared_error: 10.9555
# Epoch 28/50
# 28/28 [==============================] - 23s 837ms/step - loss: 53.1967 - mean_squared_error: 53.1967 - mean_absolute_error: 4.7354 - root_mean_squared_error: 7.2936 - val_loss: 171.2942 - val_mean_squared_error: 171.2942 - val_mean_absolute_error: 12.0898 - val_root_mean_squared_error: 13.0879
# Epoch 29/50
# 28/28 [==============================] - 23s 825ms/step - loss: 53.1313 - mean_squared_error: 53.1313 - mean_absolute_error: 4.7834 - root_mean_squared_error: 7.2891 - val_loss: 180.3631 - val_mean_squared_error: 180.3631 - val_mean_absolute_error: 12.4330 - val_root_mean_squared_error: 13.4299
# Epoch 30/50
# 28/28 [==============================] - 22s 807ms/step - loss: 50.0481 - mean_squared_error: 50.0481 - mean_absolute_error: 4.6469 - root_mean_squared_error: 7.0745 - val_loss: 187.0683 - val_mean_squared_error: 187.0683 - val_mean_absolute_error: 12.7414 - val_root_mean_squared_error: 13.6773
# Epoch 31/50
# 28/28 [==============================] - 23s 837ms/step - loss: 52.0443 - mean_squared_error: 52.0443 - mean_absolute_error: 4.7404 - root_mean_squared_error: 7.2142 - val_loss: 159.4716 - val_mean_squared_error: 159.4716 - val_mean_absolute_error: 11.6767 - val_root_mean_squared_error: 12.6282
# Epoch 32/50
# 28/28 [==============================] - 24s 846ms/step - loss: 51.3902 - mean_squared_error: 51.3902 - mean_absolute_error: 4.6987 - root_mean_squared_error: 7.1687 - val_loss: 111.7025 - val_mean_squared_error: 111.7025 - val_mean_absolute_error: 6.8989 - val_root_mean_squared_error: 10.5689
# Epoch 33/50
# 28/28 [==============================] - 23s 820ms/step - loss: 50.3527 - mean_squared_error: 50.3527 - mean_absolute_error: 4.6850 - root_mean_squared_error: 7.0960 - val_loss: 71.0983 - val_mean_squared_error: 71.0983 - val_mean_absolute_error: 5.4513 - val_root_mean_squared_error: 8.4320
# Epoch 34/50
# 28/28 [==============================] - 24s 833ms/step - loss: 54.4334 - mean_squared_error: 54.4334 - mean_absolute_error: 4.7663 - root_mean_squared_error: 7.3779 - val_loss: 94.5765 - val_mean_squared_error: 94.5765 - val_mean_absolute_error: 6.2594 - val_root_mean_squared_error: 9.7250
# Epoch 35/50
# 28/28 [==============================] - 24s 857ms/step - loss: 58.4834 - mean_squared_error: 58.4834 - mean_absolute_error: 5.0044 - root_mean_squared_error: 7.6474 - val_loss: 98.8779 - val_mean_squared_error: 98.8779 - val_mean_absolute_error: 8.0150 - val_root_mean_squared_error: 9.9437
# Epoch 36/50
# 28/28 [==============================] - 23s 839ms/step - loss: 52.7630 - mean_squared_error: 52.7630 - mean_absolute_error: 4.8656 - root_mean_squared_error: 7.2638 - val_loss: 121.4676 - val_mean_squared_error: 121.4676 - val_mean_absolute_error: 7.1529 - val_root_mean_squared_error: 11.0212
# Epoch 37/50
# 28/28 [==============================] - 22s 800ms/step - loss: 51.5648 - mean_squared_error: 51.5648 - mean_absolute_error: 4.8124 - root_mean_squared_error: 7.1809 - val_loss: 92.4882 - val_mean_squared_error: 92.4882 - val_mean_absolute_error: 8.0087 - val_root_mean_squared_error: 9.6171
# Epoch 38/50
# 28/28 [==============================] - 24s 866ms/step - loss: 46.5226 - mean_squared_error: 46.5226 - mean_absolute_error: 4.5578 - root_mean_squared_error: 6.8207 - val_loss: 73.7189 - val_mean_squared_error: 73.7189 - val_mean_absolute_error: 5.4233 - val_root_mean_squared_error: 8.5860
# Epoch 39/50
# 28/28 [==============================] - 24s 868ms/step - loss: 47.8524 - mean_squared_error: 47.8524 - mean_absolute_error: 4.5590 - root_mean_squared_error: 6.9175 - val_loss: 71.4473 - val_mean_squared_error: 71.4473 - val_mean_absolute_error: 5.4626 - val_root_mean_squared_error: 8.4526
# Epoch 40/50
# 28/28 [==============================] - 23s 831ms/step - loss: 46.2046 - mean_squared_error: 46.2046 - mean_absolute_error: 4.4631 - root_mean_squared_error: 6.7974 - val_loss: 65.1958 - val_mean_squared_error: 65.1957 - val_mean_absolute_error: 6.4139 - val_root_mean_squared_error: 8.0744
# Epoch 41/50
# 28/28 [==============================] - 22s 788ms/step - loss: 47.1663 - mean_squared_error: 47.1663 - mean_absolute_error: 4.4671 - root_mean_squared_error: 6.8678 - val_loss: 68.9107 - val_mean_squared_error: 68.9107 - val_mean_absolute_error: 6.9487 - val_root_mean_squared_error: 8.3012
# Epoch 42/50
# 28/28 [==============================] - 24s 870ms/step - loss: 46.1297 - mean_squared_error: 46.1297 - mean_absolute_error: 4.4365 - root_mean_squared_error: 6.7919 - val_loss: 84.1456 - val_mean_squared_error: 84.1456 - val_mean_absolute_error: 8.1306 - val_root_mean_squared_error: 9.1731
# Epoch 43/50
# 28/28 [==============================] - 24s 858ms/step - loss: 44.5127 - mean_squared_error: 44.5127 - mean_absolute_error: 4.3403 - root_mean_squared_error: 6.6718 - val_loss: 78.6745 - val_mean_squared_error: 78.6745 - val_mean_absolute_error: 7.5580 - val_root_mean_squared_error: 8.8699
# Epoch 44/50
# 28/28 [==============================] - ETA: 0s - loss: 43.1740 - mean_squared_error: 43.1740 - mean_absolute_error: 4.2638 - root_mean_squared_error: 6.5707
# Validation loss is below 60, stopping training.
# 28/28 [==============================] - 23s 840ms/step - loss: 43.1740 - mean_squared_error: 43.1740 - mean_absolute_error: 4.2638 - root_mean_squared_error: 6.5707 - val_loss: 50.7796 - val_mean_squared_error: 50.7796 - val_mean_absolute_error: 5.0525 - val_root_mean_squared_error: 7.1260

# %%
model.save('model_bis_propofol_info.keras')

# %% [markdown]
# # Training results

# %%
from utils.plotting import training_loss_plot

### Training Summary
plot = training_loss_plot(train_score)
plot.show()

# %% [markdown]
# # Testing

# %%
### Predict on the test set
from utils.evaluation import phases_report

y_pred =  model.predict([bloodpressure.test_dataset, propofolrate.test_dataset, info.test_dataset], verbose=0)

phases_report(y_pred, bis.test_dataset, propofolrate.test_dataset)
# Out:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                  79.08       139.87           6.95         7.55
# Induction           162.72       637.60          10.48        18.34
# Maintenance          64.41        60.90           6.35         5.68
# Recovery            120.75       361.57           8.59        13.46
#
#             Prediction RMSE Baseline RMSE
# All                    8.89         11.83
# Induction             12.76         25.25
# Maintenance            8.03          7.80
# Recovery              10.99         19.02

# %%
from utils.plotting import single_prediction_plot

plot = single_prediction_plot(5, test_index, bis.test_dataset, y_pred)
plot.show()

# %%
from utils.plotting import full_prediction_plot

full_prediction_plot(test_index, bis.test_dataset, y_pred)
