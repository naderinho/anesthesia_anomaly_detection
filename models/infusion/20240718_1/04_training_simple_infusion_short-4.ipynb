# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset02/'
vitaldbpath = 'vitaldb_tiva/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 332, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 332 (delta 23), reused 56 (delta 13), pack-reused 264
# Receiving objects: 100% (332/332), 46.50 MiB | 20.06 MiB/s, done.
# Resolving deltas: 100% (123/123), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.31.0)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolrate.name = 'Propofol Rate'
    propofolrate.tracks = ['Orchestra/PPF20_RATE']
    propofolrate.filterON = False
    propofolrate.generateDataset(normalization=md.NormNone)
    propofolrate.save('03_propofol_rate.npz')

    propofolvol = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolvol.name = 'Propofol Volume'
    propofolvol.tracks = ['Orchestra/PPF20_VOL']
    propofolvol.filterON = False
    propofolvol.filter = [2, 0, 500]
    propofolvol.generateDataset(normalization=md.NormNone)
    propofolvol.save('03_propofol_vol.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolrate.load('03_propofol_rate.npz')

propofolvol = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolvol.load('03_propofol_vol.npz')

train_index, val_index, test_index = bis.split(np.array(bis.index))

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### LSTM layers for the blood pressure data

### Blood Pressure layers
input_vital = Input(shape=(None, bloodpressure.train_dataset.shape[2]))
vital_layer = Masking(mask_value=0.0)(input_vital)

vital_layer = LSTM(units=64, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = LSTM(units=64, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = LSTM(units=64, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = LSTM(units=16, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = LSTM(units=4, return_sequences=True)(vital_layer)
vital_layer = BatchNormalization()(vital_layer)
vital_layer = Dense(units=4, activation='linear')(vital_layer)

input_propofol = Input(shape=(None, propofolrate.train_dataset.shape[2]))
propofol_layer = BatchNormalization()(input_propofol)
propofol_layer = LSTM(units=32, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=32, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=32, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=8, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=4, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = Dense(units=4, activation='linear')(propofol_layer)

### INFO layers
input_info = Input(shape=(info.train_dataset.shape[1],))
info_layer = RepeatVector(bloodpressure.train_dataset.shape[1])(input_info)
info_layer = Dense(units=16, activation='linear')(info_layer)
info_layer = Dense(units=16, activation='sigmoid')(info_layer)


## Concatenate the Propofol output with the info layer
comb_layer = Concatenate()([vital_layer, propofol_layer, info_layer])
comb_layer = Dense(units=1, activation='relu')(comb_layer)
output = Lambda(lambda x: x * 100)(comb_layer)

# Define the model
model = Model(inputs=[input_vital, input_propofol, input_info], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

#model.summary()
y = pd.DataFrame(bis.train_dataset[:,:,0].T).rolling(min_periods=1,window=3, center=True).mean().to_numpy().T[:,:,np.newaxis]

class StopTrainingCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(StopTrainingCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_loss') is not None:
            if logs.get('val_loss') < self.threshold:
                print(f"\nValidation loss is below {self.threshold}, stopping training.")
                self.model.stop_training = True

stop_training_callback = StopTrainingCallback(threshold = 40)

# Train the model
history = model.fit([bloodpressure.train_dataset, propofolrate.train_dataset, info.train_dataset],
                    y,
                    validation_data=([bloodpressure.validation_dataset, propofolrate.validation_dataset , info.validation_dataset], bis.validation_dataset),
                    epochs=150,
                    callbacks=[stop_training_callback],
                    batch_size=4
                    )

train_score = history.history
# Out:
# Epoch 1/150
# 28/28 [==============================] - 69s 970ms/step - loss: 356.5187 - mean_squared_error: 356.5187 - mean_absolute_error: 10.2515 - root_mean_squared_error: 18.8817 - val_loss: 707.3433 - val_mean_squared_error: 707.3433 - val_mean_absolute_error: 24.3725 - val_root_mean_squared_error: 26.5959
# Epoch 2/150
# 28/28 [==============================] - 21s 754ms/step - loss: 96.9358 - mean_squared_error: 96.9358 - mean_absolute_error: 4.7445 - root_mean_squared_error: 9.8456 - val_loss: 692.9117 - val_mean_squared_error: 692.9116 - val_mean_absolute_error: 23.1559 - val_root_mean_squared_error: 26.3232
# Epoch 3/150
# 28/28 [==============================] - 22s 778ms/step - loss: 68.9266 - mean_squared_error: 68.9266 - mean_absolute_error: 4.0923 - root_mean_squared_error: 8.3022 - val_loss: 687.2413 - val_mean_squared_error: 687.2413 - val_mean_absolute_error: 22.8638 - val_root_mean_squared_error: 26.2153
# Epoch 4/150
# 28/28 [==============================] - 20s 735ms/step - loss: 59.3615 - mean_squared_error: 59.3615 - mean_absolute_error: 3.8583 - root_mean_squared_error: 7.7046 - val_loss: 468.2218 - val_mean_squared_error: 468.2217 - val_mean_absolute_error: 19.2326 - val_root_mean_squared_error: 21.6384
# Epoch 5/150
# 28/28 [==============================] - 19s 690ms/step - loss: 56.5846 - mean_squared_error: 56.5846 - mean_absolute_error: 3.8011 - root_mean_squared_error: 7.5223 - val_loss: 434.3003 - val_mean_squared_error: 434.3003 - val_mean_absolute_error: 18.4185 - val_root_mean_squared_error: 20.8399
# Epoch 6/150
# 28/28 [==============================] - 22s 777ms/step - loss: 50.8276 - mean_squared_error: 50.8276 - mean_absolute_error: 3.5934 - root_mean_squared_error: 7.1293 - val_loss: 336.7447 - val_mean_squared_error: 336.7447 - val_mean_absolute_error: 16.2513 - val_root_mean_squared_error: 18.3506
# Epoch 7/150
# 28/28 [==============================] - 20s 734ms/step - loss: 47.8101 - mean_squared_error: 47.8101 - mean_absolute_error: 3.4706 - root_mean_squared_error: 6.9145 - val_loss: 289.7069 - val_mean_squared_error: 289.7069 - val_mean_absolute_error: 15.2156 - val_root_mean_squared_error: 17.0208
# Epoch 8/150
# 28/28 [==============================] - 22s 797ms/step - loss: 48.5762 - mean_squared_error: 48.5762 - mean_absolute_error: 3.5019 - root_mean_squared_error: 6.9697 - val_loss: 202.5491 - val_mean_squared_error: 202.5491 - val_mean_absolute_error: 12.5484 - val_root_mean_squared_error: 14.2320
# Epoch 9/150
# 28/28 [==============================] - 21s 739ms/step - loss: 46.1058 - mean_squared_error: 46.1058 - mean_absolute_error: 3.5138 - root_mean_squared_error: 6.7901 - val_loss: 124.9648 - val_mean_squared_error: 124.9648 - val_mean_absolute_error: 9.3067 - val_root_mean_squared_error: 11.1788
# Epoch 10/150
# 28/28 [==============================] - 21s 765ms/step - loss: 45.7032 - mean_squared_error: 45.7032 - mean_absolute_error: 3.4697 - root_mean_squared_error: 6.7604 - val_loss: 100.1998 - val_mean_squared_error: 100.1998 - val_mean_absolute_error: 7.7932 - val_root_mean_squared_error: 10.0100
# Epoch 11/150
# 28/28 [==============================] - 21s 766ms/step - loss: 43.2948 - mean_squared_error: 43.2948 - mean_absolute_error: 3.4087 - root_mean_squared_error: 6.5799 - val_loss: 78.7382 - val_mean_squared_error: 78.7383 - val_mean_absolute_error: 5.7118 - val_root_mean_squared_error: 8.8735
# Epoch 12/150
# 28/28 [==============================] - 20s 725ms/step - loss: 44.2866 - mean_squared_error: 44.2866 - mean_absolute_error: 3.4350 - root_mean_squared_error: 6.6548 - val_loss: 84.0527 - val_mean_squared_error: 84.0527 - val_mean_absolute_error: 6.7443 - val_root_mean_squared_error: 9.1680
# Epoch 13/150
# 28/28 [==============================] - 21s 745ms/step - loss: 42.5827 - mean_squared_error: 42.5827 - mean_absolute_error: 3.3515 - root_mean_squared_error: 6.5255 - val_loss: 68.6152 - val_mean_squared_error: 68.6152 - val_mean_absolute_error: 5.1050 - val_root_mean_squared_error: 8.2834
# Epoch 14/150
# 28/28 [==============================] - 21s 769ms/step - loss: 40.4452 - mean_squared_error: 40.4452 - mean_absolute_error: 3.2491 - root_mean_squared_error: 6.3597 - val_loss: 65.9352 - val_mean_squared_error: 65.9352 - val_mean_absolute_error: 4.2001 - val_root_mean_squared_error: 8.1201
# Epoch 15/150
# 28/28 [==============================] - 20s 731ms/step - loss: 41.9933 - mean_squared_error: 41.9933 - mean_absolute_error: 3.3617 - root_mean_squared_error: 6.4802 - val_loss: 61.9159 - val_mean_squared_error: 61.9159 - val_mean_absolute_error: 3.7385 - val_root_mean_squared_error: 7.8687
# Epoch 16/150
# 28/28 [==============================] - 21s 767ms/step - loss: 38.3695 - mean_squared_error: 38.3695 - mean_absolute_error: 3.1835 - root_mean_squared_error: 6.1943 - val_loss: 62.4342 - val_mean_squared_error: 62.4342 - val_mean_absolute_error: 3.9500 - val_root_mean_squared_error: 7.9015
# Epoch 17/150
# 28/28 [==============================] - 19s 692ms/step - loss: 39.0536 - mean_squared_error: 39.0536 - mean_absolute_error: 3.2235 - root_mean_squared_error: 6.2493 - val_loss: 59.4145 - val_mean_squared_error: 59.4145 - val_mean_absolute_error: 3.7402 - val_root_mean_squared_error: 7.7081
# Epoch 18/150
# 28/28 [==============================] - 21s 774ms/step - loss: 44.5776 - mean_squared_error: 44.5776 - mean_absolute_error: 3.3635 - root_mean_squared_error: 6.6766 - val_loss: 62.7077 - val_mean_squared_error: 62.7077 - val_mean_absolute_error: 3.7764 - val_root_mean_squared_error: 7.9188
# Epoch 19/150
# 28/28 [==============================] - 22s 797ms/step - loss: 42.7299 - mean_squared_error: 42.7299 - mean_absolute_error: 3.3364 - root_mean_squared_error: 6.5368 - val_loss: 64.0210 - val_mean_squared_error: 64.0210 - val_mean_absolute_error: 4.0031 - val_root_mean_squared_error: 8.0013
# Epoch 20/150
# 28/28 [==============================] - 20s 732ms/step - loss: 41.2521 - mean_squared_error: 41.2521 - mean_absolute_error: 3.3252 - root_mean_squared_error: 6.4228 - val_loss: 54.8821 - val_mean_squared_error: 54.8821 - val_mean_absolute_error: 3.6437 - val_root_mean_squared_error: 7.4082
# Epoch 21/150
# 28/28 [==============================] - 23s 811ms/step - loss: 38.8139 - mean_squared_error: 38.8139 - mean_absolute_error: 3.1772 - root_mean_squared_error: 6.2301 - val_loss: 53.4166 - val_mean_squared_error: 53.4166 - val_mean_absolute_error: 3.7119 - val_root_mean_squared_error: 7.3087
# Epoch 22/150
# 28/28 [==============================] - 20s 729ms/step - loss: 37.2198 - mean_squared_error: 37.2198 - mean_absolute_error: 3.1263 - root_mean_squared_error: 6.1008 - val_loss: 46.3576 - val_mean_squared_error: 46.3576 - val_mean_absolute_error: 3.4516 - val_root_mean_squared_error: 6.8086
# Epoch 23/150
# 28/28 [==============================] - 19s 689ms/step - loss: 37.7499 - mean_squared_error: 37.7499 - mean_absolute_error: 3.1282 - root_mean_squared_error: 6.1441 - val_loss: 51.3479 - val_mean_squared_error: 51.3479 - val_mean_absolute_error: 3.6819 - val_root_mean_squared_error: 7.1657
# Epoch 24/150
# 28/28 [==============================] - 21s 742ms/step - loss: 39.1509 - mean_squared_error: 39.1509 - mean_absolute_error: 3.2281 - root_mean_squared_error: 6.2571 - val_loss: 46.8716 - val_mean_squared_error: 46.8716 - val_mean_absolute_error: 3.4168 - val_root_mean_squared_error: 6.8463
# Epoch 25/150
# 28/28 [==============================] - 20s 719ms/step - loss: 37.8286 - mean_squared_error: 37.8286 - mean_absolute_error: 3.1226 - root_mean_squared_error: 6.1505 - val_loss: 44.3767 - val_mean_squared_error: 44.3767 - val_mean_absolute_error: 3.3228 - val_root_mean_squared_error: 6.6616
# Epoch 26/150
# 28/28 [==============================] - 22s 781ms/step - loss: 41.3846 - mean_squared_error: 41.3846 - mean_absolute_error: 3.3151 - root_mean_squared_error: 6.4331 - val_loss: 48.3774 - val_mean_squared_error: 48.3774 - val_mean_absolute_error: 3.5407 - val_root_mean_squared_error: 6.9554
# Epoch 27/150
# 28/28 [==============================] - 20s 732ms/step - loss: 37.3625 - mean_squared_error: 37.3625 - mean_absolute_error: 3.1013 - root_mean_squared_error: 6.1125 - val_loss: 45.7464 - val_mean_squared_error: 45.7464 - val_mean_absolute_error: 3.8242 - val_root_mean_squared_error: 6.7636
# Epoch 28/150
# 28/28 [==============================] - 22s 776ms/step - loss: 36.4172 - mean_squared_error: 36.4172 - mean_absolute_error: 3.0945 - root_mean_squared_error: 6.0347 - val_loss: 619.3924 - val_mean_squared_error: 619.3924 - val_mean_absolute_error: 21.6995 - val_root_mean_squared_error: 24.8876
# Epoch 29/150
# 28/28 [==============================] - 20s 735ms/step - loss: 38.5616 - mean_squared_error: 38.5616 - mean_absolute_error: 3.1678 - root_mean_squared_error: 6.2098 - val_loss: 46.8534 - val_mean_squared_error: 46.8534 - val_mean_absolute_error: 3.4125 - val_root_mean_squared_error: 6.8450
# Epoch 30/150
# 28/28 [==============================] - 21s 742ms/step - loss: 39.5596 - mean_squared_error: 39.5596 - mean_absolute_error: 3.2052 - root_mean_squared_error: 6.2896 - val_loss: 43.4597 - val_mean_squared_error: 43.4597 - val_mean_absolute_error: 3.2091 - val_root_mean_squared_error: 6.5924
# Epoch 31/150
# 28/28 [==============================] - 20s 724ms/step - loss: 36.9433 - mean_squared_error: 36.9433 - mean_absolute_error: 3.1429 - root_mean_squared_error: 6.0781 - val_loss: 46.3802 - val_mean_squared_error: 46.3802 - val_mean_absolute_error: 4.9287 - val_root_mean_squared_error: 6.8103
# Epoch 32/150
# 28/28 [==============================] - 20s 728ms/step - loss: 35.5757 - mean_squared_error: 35.5757 - mean_absolute_error: 3.0405 - root_mean_squared_error: 5.9645 - val_loss: 51.0572 - val_mean_squared_error: 51.0572 - val_mean_absolute_error: 3.5458 - val_root_mean_squared_error: 7.1454
# Epoch 33/150
# 28/28 [==============================] - 20s 723ms/step - loss: 35.4959 - mean_squared_error: 35.4959 - mean_absolute_error: 3.0300 - root_mean_squared_error: 5.9578 - val_loss: 42.3230 - val_mean_squared_error: 42.3230 - val_mean_absolute_error: 3.2263 - val_root_mean_squared_error: 6.5056
# Epoch 34/150
# 28/28 [==============================] - 20s 718ms/step - loss: 36.3570 - mean_squared_error: 36.3569 - mean_absolute_error: 3.0844 - root_mean_squared_error: 6.0297 - val_loss: 47.1420 - val_mean_squared_error: 47.1420 - val_mean_absolute_error: 3.4110 - val_root_mean_squared_error: 6.8660
# Epoch 35/150
# 28/28 [==============================] - 20s 723ms/step - loss: 34.7515 - mean_squared_error: 34.7515 - mean_absolute_error: 3.0399 - root_mean_squared_error: 5.8950 - val_loss: 46.9819 - val_mean_squared_error: 46.9819 - val_mean_absolute_error: 3.3411 - val_root_mean_squared_error: 6.8543
# Epoch 36/150
# 28/28 [==============================] - 20s 734ms/step - loss: 36.3780 - mean_squared_error: 36.3780 - mean_absolute_error: 3.0616 - root_mean_squared_error: 6.0314 - val_loss: 46.2277 - val_mean_squared_error: 46.2277 - val_mean_absolute_error: 3.4392 - val_root_mean_squared_error: 6.7991
# Epoch 37/150
# 28/28 [==============================] - 21s 761ms/step - loss: 36.8371 - mean_squared_error: 36.8371 - mean_absolute_error: 3.1023 - root_mean_squared_error: 6.0694 - val_loss: 45.5211 - val_mean_squared_error: 45.5211 - val_mean_absolute_error: 3.3746 - val_root_mean_squared_error: 6.7469
# Epoch 38/150
# 28/28 [==============================] - 21s 761ms/step - loss: 34.2488 - mean_squared_error: 34.2488 - mean_absolute_error: 2.9850 - root_mean_squared_error: 5.8522 - val_loss: 42.1571 - val_mean_squared_error: 42.1571 - val_mean_absolute_error: 3.2457 - val_root_mean_squared_error: 6.4929
# Epoch 39/150
# 28/28 [==============================] - 20s 728ms/step - loss: 36.0015 - mean_squared_error: 36.0015 - mean_absolute_error: 3.0537 - root_mean_squared_error: 6.0001 - val_loss: 49.1536 - val_mean_squared_error: 49.1536 - val_mean_absolute_error: 4.7261 - val_root_mean_squared_error: 7.0110
# Epoch 40/150
# 28/28 [==============================] - 21s 764ms/step - loss: 34.9937 - mean_squared_error: 34.9937 - mean_absolute_error: 3.0393 - root_mean_squared_error: 5.9155 - val_loss: 43.4254 - val_mean_squared_error: 43.4254 - val_mean_absolute_error: 3.2643 - val_root_mean_squared_error: 6.5898
# Epoch 41/150
# 28/28 [==============================] - 20s 734ms/step - loss: 35.5292 - mean_squared_error: 35.5292 - mean_absolute_error: 3.0318 - root_mean_squared_error: 5.9606 - val_loss: 49.2204 - val_mean_squared_error: 49.2204 - val_mean_absolute_error: 3.4731 - val_root_mean_squared_error: 7.0157
# Epoch 42/150
# 28/28 [==============================] - 21s 739ms/step - loss: 37.2744 - mean_squared_error: 37.2744 - mean_absolute_error: 3.1053 - root_mean_squared_error: 6.1053 - val_loss: 50.2657 - val_mean_squared_error: 50.2657 - val_mean_absolute_error: 4.1695 - val_root_mean_squared_error: 7.0898
# Epoch 43/150
# 28/28 [==============================] - 20s 733ms/step - loss: 36.8250 - mean_squared_error: 36.8250 - mean_absolute_error: 3.0976 - root_mean_squared_error: 6.0684 - val_loss: 54.7201 - val_mean_squared_error: 54.7201 - val_mean_absolute_error: 3.6080 - val_root_mean_squared_error: 7.3973
# Epoch 44/150
# 28/28 [==============================] - 22s 782ms/step - loss: 36.0115 - mean_squared_error: 36.0115 - mean_absolute_error: 3.0704 - root_mean_squared_error: 6.0010 - val_loss: 57.0373 - val_mean_squared_error: 57.0373 - val_mean_absolute_error: 3.8173 - val_root_mean_squared_error: 7.5523
# Epoch 45/150
# 28/28 [==============================] - 22s 776ms/step - loss: 35.0264 - mean_squared_error: 35.0264 - mean_absolute_error: 3.0338 - root_mean_squared_error: 5.9183 - val_loss: 74.8446 - val_mean_squared_error: 74.8446 - val_mean_absolute_error: 4.4202 - val_root_mean_squared_error: 8.6513
# Epoch 46/150
# 28/28 [==============================] - 20s 734ms/step - loss: 37.4488 - mean_squared_error: 37.4488 - mean_absolute_error: 3.1142 - root_mean_squared_error: 6.1195 - val_loss: 46.8955 - val_mean_squared_error: 46.8955 - val_mean_absolute_error: 3.3487 - val_root_mean_squared_error: 6.8480
# Epoch 47/150
# 28/28 [==============================] - 21s 746ms/step - loss: 36.1092 - mean_squared_error: 36.1092 - mean_absolute_error: 3.0853 - root_mean_squared_error: 6.0091 - val_loss: 68.1898 - val_mean_squared_error: 68.1898 - val_mean_absolute_error: 6.5408 - val_root_mean_squared_error: 8.2577
# Epoch 48/150
# 28/28 [==============================] - 21s 765ms/step - loss: 35.3337 - mean_squared_error: 35.3337 - mean_absolute_error: 3.0352 - root_mean_squared_error: 5.9442 - val_loss: 59.5259 - val_mean_squared_error: 59.5259 - val_mean_absolute_error: 3.9659 - val_root_mean_squared_error: 7.7153
# Epoch 49/150
# 28/28 [==============================] - 20s 733ms/step - loss: 35.4257 - mean_squared_error: 35.4257 - mean_absolute_error: 3.0424 - root_mean_squared_error: 5.9520 - val_loss: 47.3657 - val_mean_squared_error: 47.3657 - val_mean_absolute_error: 3.4396 - val_root_mean_squared_error: 6.8823
# Epoch 50/150
# 28/28 [==============================] - 22s 777ms/step - loss: 34.6257 - mean_squared_error: 34.6257 - mean_absolute_error: 3.0175 - root_mean_squared_error: 5.8844 - val_loss: 51.7987 - val_mean_squared_error: 51.7987 - val_mean_absolute_error: 3.5005 - val_root_mean_squared_error: 7.1971
# Epoch 51/150
# 28/28 [==============================] - 21s 742ms/step - loss: 34.9334 - mean_squared_error: 34.9334 - mean_absolute_error: 2.9912 - root_mean_squared_error: 5.9105 - val_loss: 42.9768 - val_mean_squared_error: 42.9768 - val_mean_absolute_error: 3.1972 - val_root_mean_squared_error: 6.5557
# Epoch 52/150
# 28/28 [==============================] - ETA: 0s - loss: 36.5969 - mean_squared_error: 36.5969 - mean_absolute_error: 3.0865 - root_mean_squared_error: 6.0495
# Validation loss is below 40, stopping training.
# 28/28 [==============================] - 21s 758ms/step - loss: 36.5969 - mean_squared_error: 36.5969 - mean_absolute_error: 3.0865 - root_mean_squared_error: 6.0495 - val_loss: 39.9958 - val_mean_squared_error: 39.9958 - val_mean_absolute_error: 3.1134 - val_root_mean_squared_error: 6.3242

# %%
model.save('model_bis_propofol_info.keras')

# %% [markdown]
# # Training results

# %%
from utils.plotting import training_loss_plot

### Training Summary
plot = training_loss_plot(train_score)
plot.show()

# %% [markdown]
# # Testing

# %%
### Predict on the test set
from utils.evaluation import phases_report

y_pred =  model.predict([bloodpressure.test_dataset, propofolrate.test_dataset, info.test_dataset], verbose=0)

phases_report(y_pred, bis.test_dataset, propofolrate.test_dataset)
# Out:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                  86.67       139.87           7.09         7.55
# Induction           130.31       637.60           9.03        18.34
# Maintenance          73.35        60.90           6.54         5.68
# Recovery            148.36       361.57           9.48        13.46
#
#             Prediction RMSE Baseline RMSE
# All                    9.31         11.83
# Induction             11.42         25.25
# Maintenance            8.56          7.80
# Recovery              12.18         19.02

# %%
from utils.plotting import single_prediction_plot

plot = single_prediction_plot(5, test_index, bis.test_dataset, y_pred)
plot.show()

# %%
from utils.plotting import full_prediction_plot

full_prediction_plot(test_index, bis.test_dataset, y_pred)
