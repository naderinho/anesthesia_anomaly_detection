# %% [markdown]
# # Initialization

# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset02/'
vitaldbpath = 'vitaldb_tiva/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt
import pickle

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 963, done.
# remote: Total 963 (delta 0), reused 0 (delta 0), pack-reused 963
# Receiving objects: 100% (963/963), 197.20 MiB | 15.11 MiB/s, done.
# Resolving deltas: 100% (531/531), done.
# Updating files: 100% (369/369), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl.metadata (520 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.31.0)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.9 MB/s eta 0:00:00
# Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 12.6 MB/s eta 0:00:00
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %% [markdown]
# # Data loading

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    info_non_norm = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info_non_norm.generateDataset(normalization=md.NormNone)
    info_non_norm.save('01_info_norm_none.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolrate.name = 'Propofol Rate'
    propofolrate.tracks = ['Orchestra/PPF20_RATE']
    propofolrate.filterON = False
    propofolrate.generateDataset(normalization=md.NormNone)
    propofolrate.save('03_propofol_rate.npz')

    remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    remifentanilrate.name = 'Remifentanil Rate'
    remifentanilrate.tracks = ['Orchestra/RFTN20_RATE']
    remifentanilrate.filterON = False
    remifentanilrate.generateDataset(normalization=md.NormNone)
    remifentanilrate.save('03_remifentanil_rate.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

info_non_norm = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info_non_norm.load('01_info_norm_none.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolrate.load('03_propofol_rate.npz')

remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
remifentanilrate.load('03_remifentanil_rate.npz')

train_index, val_index, test_index = bis.split(np.array(bis.index))

# %% [markdown]
# # Seperate the Data in + 60 years and older patients

# %%
young_index_train = np.where(info_non_norm.train_dataset[:,1] <  60)
old_index_train   = np.where(info_non_norm.train_dataset[:,1] >= 60)

print(young_index_train[0].shape, old_index_train[0].shape)

young_index_val = np.where(info_non_norm.validation_dataset[:,1] <  60)
old_index_val   = np.where(info_non_norm.validation_dataset[:,1] >= 60)

print(young_index_val[0].shape, old_index_val[0].shape)

young_index_test = np.where(info_non_norm.test_dataset[:,1] <  60)
old_index_test   = np.where(info_non_norm.test_dataset[:,1] >= 60)

print(young_index_test[0].shape, old_index_test[0].shape)
# Out:
# (47,) (64,)
# (10,) (10,)
# (9,) (15,)

# %% [markdown]
# # Model creation

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### Blood Pressure Input
input_bp = Input(shape=(None, bloodpressure.train_dataset.shape[2]))
bp_layer = Masking(mask_value=0.0)(input_bp)

bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=128, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=16, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=16, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = Dense(units=16, activation='linear')(bp_layer)

### etCO2 Input
input_co2 = Input(shape=(None, etCO2.train_dataset.shape[2]))

co2_layer = LSTM(units=64, return_sequences=True)(input_co2)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=64, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=64, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=16, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=8, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = Dense(units=8, activation='linear')(co2_layer)

### spo2 Input
input_spo2 = Input(shape=(None, spO2.train_dataset.shape[2]))

spo2_layer = LSTM(units=64, return_sequences=True)(input_spo2)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=64, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=64, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=16, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=8, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = Dense(units=8, activation='linear')(spo2_layer)

# Prpofol layers
input_propofol = Input(shape=(None, propofolrate.train_dataset.shape[2]))
propofol_layer = BatchNormalization()(input_propofol)
propofol_layer = LSTM(units=64, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=64, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=64, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=64, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=128, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=64, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=16, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = LSTM(units=16, return_sequences=True)(propofol_layer)
propofol_layer = BatchNormalization()(propofol_layer)
propofol_layer = Dense(units=16, activation='linear')(propofol_layer)

### INFO layers
input_info = Input(shape=(info.train_dataset.shape[1],))
info_layer = RepeatVector(bloodpressure.train_dataset.shape[1])(input_info)
info_layer = Dense(units=16, activation='linear')(info_layer)
info_layer = Dense(units=16, activation='sigmoid')(info_layer)


## Concatenate the Propofol output with the info layer
comb_layer = Concatenate()([bp_layer, co2_layer, spo2_layer, propofol_layer, info_layer])
comb_layer = Dense(units=64, activation='linear')(comb_layer)
comb_layer = Dense(units=64, activation='relu')(comb_layer)
comb_layer = Dense(units=64, activation='relu')(comb_layer)
comb_layer = Dense(units=32, activation='relu')(comb_layer)
comb_layer = Dense(units=16, activation='relu')(comb_layer)
comb_layer = Dense(units=1, activation='relu')(comb_layer)
output = Lambda(lambda x: x * 100)(comb_layer)

# Define the model
model = Model(inputs=[input_bp, input_co2, input_spo2, input_propofol, input_info], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.0005)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 3)]            0         []
#
#  input_4 (InputLayer)        [(None, None, 1)]            0         []
#
#  masking (Masking)           (None, None, 3)              0         ['input_1[0][0]']
#
#  batch_normalization_18 (Ba  (None, None, 1)              4         ['input_4[0][0]']
#  tchNormalization)
#
#  lstm (LSTM)                 (None, None, 64)             17408     ['masking[0][0]']
#
#  lstm_18 (LSTM)              (None, None, 64)             16896     ['batch_normalization_18[0][0]
#                                                                     ']
#
#  batch_normalization (Batch  (None, None, 64)             256       ['lstm[0][0]']
#  Normalization)
#
#  batch_normalization_19 (Ba  (None, None, 64)             256       ['lstm_18[0][0]']
#  tchNormalization)
#
#  lstm_1 (LSTM)               (None, None, 64)             33024     ['batch_normalization[0][0]']
#
#  lstm_19 (LSTM)              (None, None, 64)             33024     ['batch_normalization_19[0][0]
#                                                                     ']
#
#  batch_normalization_1 (Bat  (None, None, 64)             256       ['lstm_1[0][0]']
#  chNormalization)
#
#  batch_normalization_20 (Ba  (None, None, 64)             256       ['lstm_19[0][0]']
#  tchNormalization)
#
#  lstm_2 (LSTM)               (None, None, 64)             33024     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  lstm_20 (LSTM)              (None, None, 64)             33024     ['batch_normalization_20[0][0]
#                                                                     ']
#
#  batch_normalization_2 (Bat  (None, None, 64)             256       ['lstm_2[0][0]']
#  chNormalization)
#
#  input_2 (InputLayer)        [(None, None, 1)]            0         []
#
#  input_3 (InputLayer)        [(None, None, 1)]            0         []
#
#  batch_normalization_21 (Ba  (None, None, 64)             256       ['lstm_20[0][0]']
#  tchNormalization)
#
#  lstm_3 (LSTM)               (None, None, 64)             33024     ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  lstm_8 (LSTM)               (None, None, 64)             16896     ['input_2[0][0]']
#
#  lstm_13 (LSTM)              (None, None, 64)             16896     ['input_3[0][0]']
#
#  lstm_21 (LSTM)              (None, None, 64)             33024     ['batch_normalization_21[0][0]
#                                                                     ']
#
#  batch_normalization_3 (Bat  (None, None, 64)             256       ['lstm_3[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, None, 64)             256       ['lstm_8[0][0]']
#  chNormalization)
#
#  batch_normalization_13 (Ba  (None, None, 64)             256       ['lstm_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, None, 64)             256       ['lstm_21[0][0]']
#  tchNormalization)
#
#  lstm_4 (LSTM)               (None, None, 128)            98816     ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  lstm_9 (LSTM)               (None, None, 64)             33024     ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  lstm_14 (LSTM)              (None, None, 64)             33024     ['batch_normalization_13[0][0]
#                                                                     ']
#
#  lstm_22 (LSTM)              (None, None, 128)            98816     ['batch_normalization_22[0][0]
#                                                                     ']
#
#  batch_normalization_4 (Bat  (None, None, 128)            512       ['lstm_4[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, None, 64)             256       ['lstm_9[0][0]']
#  chNormalization)
#
#  batch_normalization_14 (Ba  (None, None, 64)             256       ['lstm_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, None, 128)            512       ['lstm_22[0][0]']
#  tchNormalization)
#
#  lstm_5 (LSTM)               (None, None, 64)             49408     ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  lstm_10 (LSTM)              (None, None, 64)             33024     ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  lstm_15 (LSTM)              (None, None, 64)             33024     ['batch_normalization_14[0][0]
#                                                                     ']
#
#  lstm_23 (LSTM)              (None, None, 64)             49408     ['batch_normalization_23[0][0]
#                                                                     ']
#
#  batch_normalization_5 (Bat  (None, None, 64)             256       ['lstm_5[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, None, 64)             256       ['lstm_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, None, 64)             256       ['lstm_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, None, 64)             256       ['lstm_23[0][0]']
#  tchNormalization)
#
#  lstm_6 (LSTM)               (None, None, 16)             5184      ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  lstm_11 (LSTM)              (None, None, 16)             5184      ['batch_normalization_10[0][0]
#                                                                     ']
#
#  lstm_16 (LSTM)              (None, None, 16)             5184      ['batch_normalization_15[0][0]
#                                                                     ']
#
#  lstm_24 (LSTM)              (None, None, 16)             5184      ['batch_normalization_24[0][0]
#                                                                     ']
#
#  batch_normalization_6 (Bat  (None, None, 16)             64        ['lstm_6[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, None, 16)             64        ['lstm_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, None, 16)             64        ['lstm_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, None, 16)             64        ['lstm_24[0][0]']
#  tchNormalization)
#
#  input_5 (InputLayer)        [(None, 5)]                  0         []
#
#  lstm_7 (LSTM)               (None, None, 16)             2112      ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  lstm_12 (LSTM)              (None, None, 8)              800       ['batch_normalization_11[0][0]
#                                                                     ']
#
#  lstm_17 (LSTM)              (None, None, 8)              800       ['batch_normalization_16[0][0]
#                                                                     ']
#
#  lstm_25 (LSTM)              (None, None, 16)             2112      ['batch_normalization_25[0][0]
#                                                                     ']
#
#  repeat_vector (RepeatVecto  (None, 3680, 5)              0         ['input_5[0][0]']
#  r)
#
#  batch_normalization_7 (Bat  (None, None, 16)             64        ['lstm_7[0][0]']
#  chNormalization)
#
#  batch_normalization_12 (Ba  (None, None, 8)              32        ['lstm_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, None, 8)              32        ['lstm_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, None, 16)             64        ['lstm_25[0][0]']
#  tchNormalization)
#
#  dense_4 (Dense)             (None, 3680, 16)             96        ['repeat_vector[0][0]']
#
#  dense (Dense)               (None, None, 16)             272       ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dense_1 (Dense)             (None, None, 8)              72        ['batch_normalization_12[0][0]
#                                                                     ']
#
#  dense_2 (Dense)             (None, None, 8)              72        ['batch_normalization_17[0][0]
#                                                                     ']
#
#  dense_3 (Dense)             (None, None, 16)             272       ['batch_normalization_26[0][0]
#                                                                     ']
#
#  dense_5 (Dense)             (None, 3680, 16)             272       ['dense_4[0][0]']
#
#  concatenate (Concatenate)   (None, 3680, 64)             0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 3680, 64)             4160      ['concatenate[0][0]']
#
#  dense_7 (Dense)             (None, 3680, 64)             4160      ['dense_6[0][0]']
#
#  dense_8 (Dense)             (None, 3680, 64)             4160      ['dense_7[0][0]']
#
#  dense_9 (Dense)             (None, 3680, 32)             2080      ['dense_8[0][0]']
#
#  dense_10 (Dense)            (None, 3680, 16)             528       ['dense_9[0][0]']
#
#  dense_11 (Dense)            (None, 3680, 1)              17        ['dense_10[0][0]']
#
#  lambda (Lambda)             (None, 3680, 1)              0         ['dense_11[0][0]']
#
# ==================================================================================================
# Total params: 743077 (2.83 MB)
# Trainable params: 740291 (2.82 MB)
# Non-trainable params: 2786 (10.88 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training on older patients

# %%
# Define training stop criteria
class StopTrainingCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(StopTrainingCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_loss') is not None:
            if logs.get('val_loss') < self.threshold:
                print(f"\nValidation loss is below {self.threshold}, stopping training.")
                self.model.stop_training = True

stop_training_callback = StopTrainingCallback(threshold = 35)


if in_google_colab():
    # Train the model
    history = model.fit([bloodpressure.train_dataset[old_index_train], etCO2.train_dataset[old_index_train], spO2.train_dataset[old_index_train], propofolrate.train_dataset[old_index_train], info.train_dataset[old_index_train]],
                        bis.train_dataset[old_index_train],
                        validation_data=([bloodpressure.validation_dataset[old_index_val], etCO2.validation_dataset[old_index_val], spO2.validation_dataset[old_index_val], propofolrate.validation_dataset[old_index_val], info.validation_dataset[old_index_val]], bis.validation_dataset[old_index_val]),
                        epochs=150,
                        callbacks=[stop_training_callback],
                        batch_size=4
                        )

    train_score = history.history

    # Save the model
    model.save('download/model.keras')

    # Save the training history
    with open('download/train_score.pkl', 'wb') as f:
        pickle.dump(train_score, f)

    # Save the prediction
    y_pred_young = model.predict([bloodpressure.test_dataset[young_index_test], etCO2.test_dataset[young_index_test], spO2.test_dataset[young_index_test], propofolrate.test_dataset[young_index_test], info.test_dataset[young_index_test]], verbose=0)
    with open('download/prediction_young.pkl', 'wb') as f:
        pickle.dump(y_pred_young, f)

    y_pred_old = model.predict([bloodpressure.test_dataset[old_index_test], etCO2.test_dataset[old_index_test], spO2.test_dataset[old_index_test], propofolrate.test_dataset[old_index_test], info.test_dataset[old_index_test]], verbose=0)
    with open('download/prediction_old.pkl', 'wb') as f:
        pickle.dump(y_pred_old, f)

else:
    # Load train score data
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

    # Load test prediction data
    with open('prediction_young.pkl', 'rb') as f:
        y_pred_young = pickle.load(f)

    with open('prediction_old.pkl', 'rb') as f:
        y_pred_old = pickle.load(f)
# Out:
# Epoch 1/150
# 16/16 [==============================] - 119s 3s/step - loss: 396.4668 - mean_squared_error: 396.4667 - mean_absolute_error: 12.6496 - root_mean_squared_error: 19.9115 - val_loss: 584.1820 - val_mean_squared_error: 584.1820 - val_mean_absolute_error: 20.0294 - val_root_mean_squared_error: 24.1699
# Epoch 2/150
# 16/16 [==============================] - 33s 2s/step - loss: 116.3082 - mean_squared_error: 116.3082 - mean_absolute_error: 5.4881 - root_mean_squared_error: 10.7846 - val_loss: 569.2679 - val_mean_squared_error: 569.2679 - val_mean_absolute_error: 19.7492 - val_root_mean_squared_error: 23.8593
# Epoch 3/150
# 16/16 [==============================] - 35s 2s/step - loss: 88.8037 - mean_squared_error: 88.8037 - mean_absolute_error: 4.7843 - root_mean_squared_error: 9.4236 - val_loss: 551.4535 - val_mean_squared_error: 551.4536 - val_mean_absolute_error: 19.7165 - val_root_mean_squared_error: 23.4830
# Epoch 4/150
# 16/16 [==============================] - 32s 2s/step - loss: 70.4301 - mean_squared_error: 70.4301 - mean_absolute_error: 4.1652 - root_mean_squared_error: 8.3923 - val_loss: 497.1608 - val_mean_squared_error: 497.1609 - val_mean_absolute_error: 19.5221 - val_root_mean_squared_error: 22.2971
# Epoch 5/150
# 16/16 [==============================] - 33s 2s/step - loss: 66.8085 - mean_squared_error: 66.8085 - mean_absolute_error: 4.0370 - root_mean_squared_error: 8.1736 - val_loss: 479.3339 - val_mean_squared_error: 479.3339 - val_mean_absolute_error: 19.4239 - val_root_mean_squared_error: 21.8937
# Epoch 6/150
# 16/16 [==============================] - 32s 2s/step - loss: 60.0225 - mean_squared_error: 60.0225 - mean_absolute_error: 3.8630 - root_mean_squared_error: 7.7474 - val_loss: 468.5226 - val_mean_squared_error: 468.5226 - val_mean_absolute_error: 19.5126 - val_root_mean_squared_error: 21.6454
# Epoch 7/150
# 16/16 [==============================] - 33s 2s/step - loss: 58.0587 - mean_squared_error: 58.0587 - mean_absolute_error: 3.7904 - root_mean_squared_error: 7.6196 - val_loss: 465.7883 - val_mean_squared_error: 465.7883 - val_mean_absolute_error: 19.6730 - val_root_mean_squared_error: 21.5821
# Epoch 8/150
# 16/16 [==============================] - 32s 2s/step - loss: 54.7951 - mean_squared_error: 54.7951 - mean_absolute_error: 3.6398 - root_mean_squared_error: 7.4024 - val_loss: 487.4522 - val_mean_squared_error: 487.4522 - val_mean_absolute_error: 20.3527 - val_root_mean_squared_error: 22.0783
# Epoch 9/150
# 16/16 [==============================] - 33s 2s/step - loss: 51.8559 - mean_squared_error: 51.8559 - mean_absolute_error: 3.6131 - root_mean_squared_error: 7.2011 - val_loss: 495.9033 - val_mean_squared_error: 495.9033 - val_mean_absolute_error: 20.5159 - val_root_mean_squared_error: 22.2689
# Epoch 10/150
# 16/16 [==============================] - 32s 2s/step - loss: 48.0890 - mean_squared_error: 48.0890 - mean_absolute_error: 3.4250 - root_mean_squared_error: 6.9346 - val_loss: 497.1893 - val_mean_squared_error: 497.1893 - val_mean_absolute_error: 20.4231 - val_root_mean_squared_error: 22.2977
# Epoch 11/150
# 16/16 [==============================] - 33s 2s/step - loss: 50.2769 - mean_squared_error: 50.2769 - mean_absolute_error: 3.4908 - root_mean_squared_error: 7.0906 - val_loss: 429.2480 - val_mean_squared_error: 429.2479 - val_mean_absolute_error: 18.4941 - val_root_mean_squared_error: 20.7183
# Epoch 12/150
# 16/16 [==============================] - 32s 2s/step - loss: 45.2397 - mean_squared_error: 45.2397 - mean_absolute_error: 3.3722 - root_mean_squared_error: 6.7260 - val_loss: 402.8657 - val_mean_squared_error: 402.8657 - val_mean_absolute_error: 18.0317 - val_root_mean_squared_error: 20.0715
# Epoch 13/150
# 16/16 [==============================] - 33s 2s/step - loss: 47.5118 - mean_squared_error: 47.5118 - mean_absolute_error: 3.4384 - root_mean_squared_error: 6.8929 - val_loss: 418.1310 - val_mean_squared_error: 418.1310 - val_mean_absolute_error: 18.5142 - val_root_mean_squared_error: 20.4483
# Epoch 14/150
# 16/16 [==============================] - 32s 2s/step - loss: 46.7479 - mean_squared_error: 46.7479 - mean_absolute_error: 3.4172 - root_mean_squared_error: 6.8372 - val_loss: 404.1589 - val_mean_squared_error: 404.1588 - val_mean_absolute_error: 17.9066 - val_root_mean_squared_error: 20.1037
# Epoch 15/150
# 16/16 [==============================] - 33s 2s/step - loss: 43.2422 - mean_squared_error: 43.2422 - mean_absolute_error: 3.2690 - root_mean_squared_error: 6.5759 - val_loss: 390.4978 - val_mean_squared_error: 390.4978 - val_mean_absolute_error: 17.5362 - val_root_mean_squared_error: 19.7610
# Epoch 16/150
# 16/16 [==============================] - 32s 2s/step - loss: 42.6831 - mean_squared_error: 42.6831 - mean_absolute_error: 3.2557 - root_mean_squared_error: 6.5332 - val_loss: 415.7910 - val_mean_squared_error: 415.7910 - val_mean_absolute_error: 18.1628 - val_root_mean_squared_error: 20.3910
# Epoch 17/150
# 16/16 [==============================] - 33s 2s/step - loss: 40.8188 - mean_squared_error: 40.8188 - mean_absolute_error: 3.2173 - root_mean_squared_error: 6.3890 - val_loss: 429.8619 - val_mean_squared_error: 429.8618 - val_mean_absolute_error: 18.3750 - val_root_mean_squared_error: 20.7331
# Epoch 18/150
# 16/16 [==============================] - 32s 2s/step - loss: 42.5780 - mean_squared_error: 42.5780 - mean_absolute_error: 3.2518 - root_mean_squared_error: 6.5252 - val_loss: 482.0487 - val_mean_squared_error: 482.0487 - val_mean_absolute_error: 19.1288 - val_root_mean_squared_error: 21.9556
# Epoch 19/150
# 16/16 [==============================] - 33s 2s/step - loss: 41.5153 - mean_squared_error: 41.5153 - mean_absolute_error: 3.2242 - root_mean_squared_error: 6.4432 - val_loss: 431.8346 - val_mean_squared_error: 431.8346 - val_mean_absolute_error: 18.1596 - val_root_mean_squared_error: 20.7806
# Epoch 20/150
# 16/16 [==============================] - 35s 2s/step - loss: 40.7766 - mean_squared_error: 40.7766 - mean_absolute_error: 3.2031 - root_mean_squared_error: 6.3857 - val_loss: 336.5166 - val_mean_squared_error: 336.5166 - val_mean_absolute_error: 16.1253 - val_root_mean_squared_error: 18.3444
# Epoch 21/150
# 16/16 [==============================] - 32s 2s/step - loss: 38.9663 - mean_squared_error: 38.9664 - mean_absolute_error: 3.1200 - root_mean_squared_error: 6.2423 - val_loss: 322.7858 - val_mean_squared_error: 322.7858 - val_mean_absolute_error: 15.9265 - val_root_mean_squared_error: 17.9662
# Epoch 22/150
# 16/16 [==============================] - 33s 2s/step - loss: 41.0643 - mean_squared_error: 41.0643 - mean_absolute_error: 3.2473 - root_mean_squared_error: 6.4081 - val_loss: 280.9614 - val_mean_squared_error: 280.9614 - val_mean_absolute_error: 14.8266 - val_root_mean_squared_error: 16.7619
# Epoch 23/150
# 16/16 [==============================] - 32s 2s/step - loss: 39.1127 - mean_squared_error: 39.1126 - mean_absolute_error: 3.1120 - root_mean_squared_error: 6.2540 - val_loss: 242.5325 - val_mean_squared_error: 242.5325 - val_mean_absolute_error: 13.7045 - val_root_mean_squared_error: 15.5735
# Epoch 24/150
# 16/16 [==============================] - 33s 2s/step - loss: 39.1825 - mean_squared_error: 39.1825 - mean_absolute_error: 3.1426 - root_mean_squared_error: 6.2596 - val_loss: 212.5753 - val_mean_squared_error: 212.5753 - val_mean_absolute_error: 12.7989 - val_root_mean_squared_error: 14.5800
# Epoch 25/150
# 16/16 [==============================] - 32s 2s/step - loss: 38.7807 - mean_squared_error: 38.7807 - mean_absolute_error: 3.1415 - root_mean_squared_error: 6.2274 - val_loss: 250.6408 - val_mean_squared_error: 250.6408 - val_mean_absolute_error: 13.8974 - val_root_mean_squared_error: 15.8316
# Epoch 26/150
# 16/16 [==============================] - 33s 2s/step - loss: 39.7844 - mean_squared_error: 39.7844 - mean_absolute_error: 3.1508 - root_mean_squared_error: 6.3075 - val_loss: 245.2908 - val_mean_squared_error: 245.2908 - val_mean_absolute_error: 13.7124 - val_root_mean_squared_error: 15.6618
# Epoch 27/150
# 16/16 [==============================] - 32s 2s/step - loss: 41.8497 - mean_squared_error: 41.8497 - mean_absolute_error: 3.2585 - root_mean_squared_error: 6.4691 - val_loss: 138.0546 - val_mean_squared_error: 138.0546 - val_mean_absolute_error: 9.8813 - val_root_mean_squared_error: 11.7497
# Epoch 28/150
# 16/16 [==============================] - 33s 2s/step - loss: 39.5910 - mean_squared_error: 39.5910 - mean_absolute_error: 3.1581 - root_mean_squared_error: 6.2921 - val_loss: 92.0773 - val_mean_squared_error: 92.0773 - val_mean_absolute_error: 8.0928 - val_root_mean_squared_error: 9.5957
# Epoch 29/150
# 16/16 [==============================] - 33s 2s/step - loss: 35.4379 - mean_squared_error: 35.4379 - mean_absolute_error: 2.9433 - root_mean_squared_error: 5.9530 - val_loss: 156.0409 - val_mean_squared_error: 156.0409 - val_mean_absolute_error: 11.0428 - val_root_mean_squared_error: 12.4916
# Epoch 30/150
# 16/16 [==============================] - 33s 2s/step - loss: 37.3872 - mean_squared_error: 37.3872 - mean_absolute_error: 3.0842 - root_mean_squared_error: 6.1145 - val_loss: 68.7311 - val_mean_squared_error: 68.7311 - val_mean_absolute_error: 5.7027 - val_root_mean_squared_error: 8.2904
# Epoch 31/150
# 16/16 [==============================] - 32s 2s/step - loss: 35.1314 - mean_squared_error: 35.1314 - mean_absolute_error: 2.9593 - root_mean_squared_error: 5.9272 - val_loss: 64.4472 - val_mean_squared_error: 64.4472 - val_mean_absolute_error: 5.2916 - val_root_mean_squared_error: 8.0279
# Epoch 32/150
# 16/16 [==============================] - 33s 2s/step - loss: 34.3363 - mean_squared_error: 34.3363 - mean_absolute_error: 2.9297 - root_mean_squared_error: 5.8597 - val_loss: 61.2173 - val_mean_squared_error: 61.2173 - val_mean_absolute_error: 5.0690 - val_root_mean_squared_error: 7.8242
# Epoch 33/150
# 16/16 [==============================] - 33s 2s/step - loss: 33.9724 - mean_squared_error: 33.9724 - mean_absolute_error: 2.9008 - root_mean_squared_error: 5.8286 - val_loss: 63.0449 - val_mean_squared_error: 63.0449 - val_mean_absolute_error: 5.0337 - val_root_mean_squared_error: 7.9401
# Epoch 34/150
# 16/16 [==============================] - 34s 2s/step - loss: 35.7480 - mean_squared_error: 35.7480 - mean_absolute_error: 3.0429 - root_mean_squared_error: 5.9790 - val_loss: 81.8243 - val_mean_squared_error: 81.8243 - val_mean_absolute_error: 6.8763 - val_root_mean_squared_error: 9.0457
# Epoch 35/150
# 16/16 [==============================] - 32s 2s/step - loss: 36.8871 - mean_squared_error: 36.8871 - mean_absolute_error: 3.0976 - root_mean_squared_error: 6.0735 - val_loss: 97.3928 - val_mean_squared_error: 97.3928 - val_mean_absolute_error: 8.0658 - val_root_mean_squared_error: 9.8688
# Epoch 36/150
# 16/16 [==============================] - 33s 2s/step - loss: 35.6741 - mean_squared_error: 35.6741 - mean_absolute_error: 3.0091 - root_mean_squared_error: 5.9728 - val_loss: 145.0724 - val_mean_squared_error: 145.0724 - val_mean_absolute_error: 10.6127 - val_root_mean_squared_error: 12.0446
# Epoch 37/150
# 16/16 [==============================] - 32s 2s/step - loss: 33.1693 - mean_squared_error: 33.1693 - mean_absolute_error: 2.9163 - root_mean_squared_error: 5.7593 - val_loss: 73.0426 - val_mean_squared_error: 73.0426 - val_mean_absolute_error: 6.6243 - val_root_mean_squared_error: 8.5465
# Epoch 38/150
# 16/16 [==============================] - 33s 2s/step - loss: 33.0948 - mean_squared_error: 33.0948 - mean_absolute_error: 2.8811 - root_mean_squared_error: 5.7528 - val_loss: 90.8349 - val_mean_squared_error: 90.8349 - val_mean_absolute_error: 8.0127 - val_root_mean_squared_error: 9.5307
# Epoch 39/150
# 16/16 [==============================] - 32s 2s/step - loss: 33.1779 - mean_squared_error: 33.1779 - mean_absolute_error: 2.8785 - root_mean_squared_error: 5.7600 - val_loss: 177.3343 - val_mean_squared_error: 177.3343 - val_mean_absolute_error: 11.9190 - val_root_mean_squared_error: 13.3167
# Epoch 40/150
# 16/16 [==============================] - 32s 2s/step - loss: 34.1447 - mean_squared_error: 34.1447 - mean_absolute_error: 2.9097 - root_mean_squared_error: 5.8433 - val_loss: 152.3284 - val_mean_squared_error: 152.3284 - val_mean_absolute_error: 10.9455 - val_root_mean_squared_error: 12.3421
# Epoch 41/150
# 16/16 [==============================] - 32s 2s/step - loss: 33.0152 - mean_squared_error: 33.0152 - mean_absolute_error: 2.8908 - root_mean_squared_error: 5.7459 - val_loss: 183.8722 - val_mean_squared_error: 183.8722 - val_mean_absolute_error: 12.0340 - val_root_mean_squared_error: 13.5599
# Epoch 42/150
# 16/16 [==============================] - 33s 2s/step - loss: 35.3193 - mean_squared_error: 35.3193 - mean_absolute_error: 2.9678 - root_mean_squared_error: 5.9430 - val_loss: 53.0121 - val_mean_squared_error: 53.0121 - val_mean_absolute_error: 4.2078 - val_root_mean_squared_error: 7.2809
# Epoch 43/150
# 16/16 [==============================] - 35s 2s/step - loss: 32.7668 - mean_squared_error: 32.7668 - mean_absolute_error: 2.8514 - root_mean_squared_error: 5.7242 - val_loss: 112.4095 - val_mean_squared_error: 112.4095 - val_mean_absolute_error: 9.2268 - val_root_mean_squared_error: 10.6023
# Epoch 44/150
# 16/16 [==============================] - 32s 2s/step - loss: 33.2215 - mean_squared_error: 33.2215 - mean_absolute_error: 2.9043 - root_mean_squared_error: 5.7638 - val_loss: 74.2627 - val_mean_squared_error: 74.2627 - val_mean_absolute_error: 6.9197 - val_root_mean_squared_error: 8.6176
# Epoch 45/150
# 16/16 [==============================] - 34s 2s/step - loss: 32.7873 - mean_squared_error: 32.7873 - mean_absolute_error: 2.8577 - root_mean_squared_error: 5.7260 - val_loss: 72.2379 - val_mean_squared_error: 72.2379 - val_mean_absolute_error: 6.8554 - val_root_mean_squared_error: 8.4993
# Epoch 46/150
# 16/16 [==============================] - 33s 2s/step - loss: 31.8843 - mean_squared_error: 31.8843 - mean_absolute_error: 2.8144 - root_mean_squared_error: 5.6466 - val_loss: 93.0336 - val_mean_squared_error: 93.0336 - val_mean_absolute_error: 8.1602 - val_root_mean_squared_error: 9.6454
# Epoch 47/150
# 16/16 [==============================] - 33s 2s/step - loss: 32.8166 - mean_squared_error: 32.8166 - mean_absolute_error: 2.8714 - root_mean_squared_error: 5.7286 - val_loss: 267.7123 - val_mean_squared_error: 267.7123 - val_mean_absolute_error: 14.5300 - val_root_mean_squared_error: 16.3619
# Epoch 48/150
# 16/16 [==============================] - 35s 2s/step - loss: 31.9715 - mean_squared_error: 31.9715 - mean_absolute_error: 2.8104 - root_mean_squared_error: 5.6543 - val_loss: 208.0201 - val_mean_squared_error: 208.0201 - val_mean_absolute_error: 12.8351 - val_root_mean_squared_error: 14.4229
# Epoch 49/150
# 16/16 [==============================] - 32s 2s/step - loss: 32.5546 - mean_squared_error: 32.5546 - mean_absolute_error: 2.8530 - root_mean_squared_error: 5.7057 - val_loss: 198.9539 - val_mean_squared_error: 198.9539 - val_mean_absolute_error: 12.6250 - val_root_mean_squared_error: 14.1051
# Epoch 50/150
# 16/16 [==============================] - 37s 2s/step - loss: 31.1954 - mean_squared_error: 31.1954 - mean_absolute_error: 2.7900 - root_mean_squared_error: 5.5853 - val_loss: 60.4864 - val_mean_squared_error: 60.4863 - val_mean_absolute_error: 5.0110 - val_root_mean_squared_error: 7.7773
# Epoch 51/150
# 16/16 [==============================] - 33s 2s/step - loss: 31.8802 - mean_squared_error: 31.8802 - mean_absolute_error: 2.8280 - root_mean_squared_error: 5.6463 - val_loss: 61.1165 - val_mean_squared_error: 61.1165 - val_mean_absolute_error: 5.5633 - val_root_mean_squared_error: 7.8177
# Epoch 52/150
# 16/16 [==============================] - 32s 2s/step - loss: 31.7334 - mean_squared_error: 31.7334 - mean_absolute_error: 2.8115 - root_mean_squared_error: 5.6332 - val_loss: 46.6943 - val_mean_squared_error: 46.6943 - val_mean_absolute_error: 3.4045 - val_root_mean_squared_error: 6.8333
# Epoch 53/150
# 16/16 [==============================] - 36s 2s/step - loss: 31.9963 - mean_squared_error: 31.9963 - mean_absolute_error: 2.8350 - root_mean_squared_error: 5.6565 - val_loss: 51.8313 - val_mean_squared_error: 51.8313 - val_mean_absolute_error: 3.4827 - val_root_mean_squared_error: 7.1994
# Epoch 54/150
# 16/16 [==============================] - 33s 2s/step - loss: 32.5692 - mean_squared_error: 32.5692 - mean_absolute_error: 2.8345 - root_mean_squared_error: 5.7069 - val_loss: 95.1833 - val_mean_squared_error: 95.1833 - val_mean_absolute_error: 8.2279 - val_root_mean_squared_error: 9.7562
# Epoch 55/150
# 16/16 [==============================] - 33s 2s/step - loss: 33.5153 - mean_squared_error: 33.5153 - mean_absolute_error: 2.9128 - root_mean_squared_error: 5.7892 - val_loss: 205.4859 - val_mean_squared_error: 205.4859 - val_mean_absolute_error: 12.8414 - val_root_mean_squared_error: 14.3348
# Epoch 56/150
# 16/16 [==============================] - 33s 2s/step - loss: 31.6205 - mean_squared_error: 31.6205 - mean_absolute_error: 2.8270 - root_mean_squared_error: 5.6232 - val_loss: 150.9285 - val_mean_squared_error: 150.9285 - val_mean_absolute_error: 10.9606 - val_root_mean_squared_error: 12.2853
# Epoch 57/150
# 16/16 [==============================] - 33s 2s/step - loss: 31.8399 - mean_squared_error: 31.8399 - mean_absolute_error: 2.8193 - root_mean_squared_error: 5.6427 - val_loss: 99.5642 - val_mean_squared_error: 99.5642 - val_mean_absolute_error: 8.6494 - val_root_mean_squared_error: 9.9782
# Epoch 58/150
# 16/16 [==============================] - 36s 2s/step - loss: 30.5717 - mean_squared_error: 30.5716 - mean_absolute_error: 2.7778 - root_mean_squared_error: 5.5292 - val_loss: 61.5719 - val_mean_squared_error: 61.5719 - val_mean_absolute_error: 3.9060 - val_root_mean_squared_error: 7.8468
# Epoch 59/150
# 16/16 [==============================] - 33s 2s/step - loss: 32.2293 - mean_squared_error: 32.2293 - mean_absolute_error: 2.8389 - root_mean_squared_error: 5.6771 - val_loss: 42.9009 - val_mean_squared_error: 42.9009 - val_mean_absolute_error: 3.2505 - val_root_mean_squared_error: 6.5499
# Epoch 60/150
# 16/16 [==============================] - 33s 2s/step - loss: 31.5212 - mean_squared_error: 31.5212 - mean_absolute_error: 2.7921 - root_mean_squared_error: 5.6144 - val_loss: 46.3413 - val_mean_squared_error: 46.3413 - val_mean_absolute_error: 3.5071 - val_root_mean_squared_error: 6.8074
# Epoch 61/150
# 16/16 [==============================] - 33s 2s/step - loss: 34.1901 - mean_squared_error: 34.1901 - mean_absolute_error: 2.9429 - root_mean_squared_error: 5.8472 - val_loss: 46.8779 - val_mean_squared_error: 46.8779 - val_mean_absolute_error: 3.3521 - val_root_mean_squared_error: 6.8467
# Epoch 62/150
# 16/16 [==============================] - 33s 2s/step - loss: 31.7917 - mean_squared_error: 31.7917 - mean_absolute_error: 2.8283 - root_mean_squared_error: 5.6384 - val_loss: 287.2621 - val_mean_squared_error: 287.2621 - val_mean_absolute_error: 15.0426 - val_root_mean_squared_error: 16.9488
# Epoch 63/150
# 16/16 [==============================] - 35s 2s/step - loss: 30.3143 - mean_squared_error: 30.3143 - mean_absolute_error: 2.7549 - root_mean_squared_error: 5.5058 - val_loss: 535.4566 - val_mean_squared_error: 535.4566 - val_mean_absolute_error: 20.0478 - val_root_mean_squared_error: 23.1399
# Epoch 64/150
# 16/16 [==============================] - 33s 2s/step - loss: 31.1116 - mean_squared_error: 31.1116 - mean_absolute_error: 2.7879 - root_mean_squared_error: 5.5778 - val_loss: 291.9254 - val_mean_squared_error: 291.9253 - val_mean_absolute_error: 15.2366 - val_root_mean_squared_error: 17.0858
# Epoch 65/150
# 16/16 [==============================] - 33s 2s/step - loss: 39.0767 - mean_squared_error: 39.0767 - mean_absolute_error: 3.2414 - root_mean_squared_error: 6.2511 - val_loss: 47.1501 - val_mean_squared_error: 47.1501 - val_mean_absolute_error: 3.4726 - val_root_mean_squared_error: 6.8666
# Epoch 66/150
# 16/16 [==============================] - 33s 2s/step - loss: 35.0146 - mean_squared_error: 35.0146 - mean_absolute_error: 2.9680 - root_mean_squared_error: 5.9173 - val_loss: 46.7938 - val_mean_squared_error: 46.7938 - val_mean_absolute_error: 3.3327 - val_root_mean_squared_error: 6.8406
# Epoch 67/150
# 16/16 [==============================] - 34s 2s/step - loss: 35.3703 - mean_squared_error: 35.3703 - mean_absolute_error: 3.0171 - root_mean_squared_error: 5.9473 - val_loss: 45.4450 - val_mean_squared_error: 45.4450 - val_mean_absolute_error: 3.2741 - val_root_mean_squared_error: 6.7413
# Epoch 68/150
# 16/16 [==============================] - 35s 2s/step - loss: 32.6835 - mean_squared_error: 32.6835 - mean_absolute_error: 2.8526 - root_mean_squared_error: 5.7169 - val_loss: 47.2195 - val_mean_squared_error: 47.2195 - val_mean_absolute_error: 3.3384 - val_root_mean_squared_error: 6.8716
# Epoch 69/150
# 16/16 [==============================] - 33s 2s/step - loss: 32.2203 - mean_squared_error: 32.2203 - mean_absolute_error: 2.8493 - root_mean_squared_error: 5.6763 - val_loss: 216.3036 - val_mean_squared_error: 216.3036 - val_mean_absolute_error: 13.0868 - val_root_mean_squared_error: 14.7073
# Epoch 70/150
# 16/16 [==============================] - 34s 2s/step - loss: 32.2660 - mean_squared_error: 32.2660 - mean_absolute_error: 2.8466 - root_mean_squared_error: 5.6803 - val_loss: 48.6221 - val_mean_squared_error: 48.6221 - val_mean_absolute_error: 3.5072 - val_root_mean_squared_error: 6.9730
# Epoch 71/150
# 16/16 [==============================] - 33s 2s/step - loss: 32.7471 - mean_squared_error: 32.7471 - mean_absolute_error: 2.8491 - root_mean_squared_error: 5.7225 - val_loss: 46.0682 - val_mean_squared_error: 46.0682 - val_mean_absolute_error: 3.3954 - val_root_mean_squared_error: 6.7874
# Epoch 72/150
# 16/16 [==============================] - 33s 2s/step - loss: 32.4654 - mean_squared_error: 32.4653 - mean_absolute_error: 2.8627 - root_mean_squared_error: 5.6978 - val_loss: 416.1527 - val_mean_squared_error: 416.1528 - val_mean_absolute_error: 17.8960 - val_root_mean_squared_error: 20.3998
# Epoch 73/150
# 16/16 [==============================] - 33s 2s/step - loss: 31.9966 - mean_squared_error: 31.9966 - mean_absolute_error: 2.8494 - root_mean_squared_error: 5.6566 - val_loss: 314.8452 - val_mean_squared_error: 314.8453 - val_mean_absolute_error: 15.7707 - val_root_mean_squared_error: 17.7439
# Epoch 74/150
# 16/16 [==============================] - 33s 2s/step - loss: 32.5374 - mean_squared_error: 32.5374 - mean_absolute_error: 2.8618 - root_mean_squared_error: 5.7042 - val_loss: 366.9651 - val_mean_squared_error: 366.9650 - val_mean_absolute_error: 16.9228 - val_root_mean_squared_error: 19.1563
# Epoch 75/150
# 16/16 [==============================] - 33s 2s/step - loss: 30.2525 - mean_squared_error: 30.2525 - mean_absolute_error: 2.7817 - root_mean_squared_error: 5.5002 - val_loss: 48.0198 - val_mean_squared_error: 48.0198 - val_mean_absolute_error: 3.4284 - val_root_mean_squared_error: 6.9296
# Epoch 76/150
# 16/16 [==============================] - 33s 2s/step - loss: 30.3052 - mean_squared_error: 30.3052 - mean_absolute_error: 2.7607 - root_mean_squared_error: 5.5050 - val_loss: 50.4309 - val_mean_squared_error: 50.4309 - val_mean_absolute_error: 3.5927 - val_root_mean_squared_error: 7.1015
# Epoch 77/150
# 16/16 [==============================] - 35s 2s/step - loss: 33.1999 - mean_squared_error: 33.1999 - mean_absolute_error: 2.9095 - root_mean_squared_error: 5.7619 - val_loss: 50.0785 - val_mean_squared_error: 50.0785 - val_mean_absolute_error: 3.5257 - val_root_mean_squared_error: 7.0766
# Epoch 78/150
# 16/16 [==============================] - 33s 2s/step - loss: 32.5592 - mean_squared_error: 32.5592 - mean_absolute_error: 2.8734 - root_mean_squared_error: 5.7061 - val_loss: 106.7346 - val_mean_squared_error: 106.7346 - val_mean_absolute_error: 8.8184 - val_root_mean_squared_error: 10.3312
# Epoch 79/150
# 16/16 [==============================] - 33s 2s/step - loss: 33.8102 - mean_squared_error: 33.8102 - mean_absolute_error: 2.9232 - root_mean_squared_error: 5.8147 - val_loss: 47.8852 - val_mean_squared_error: 47.8852 - val_mean_absolute_error: 3.4290 - val_root_mean_squared_error: 6.9199
# Epoch 80/150
# 16/16 [==============================] - 35s 2s/step - loss: 30.7179 - mean_squared_error: 30.7179 - mean_absolute_error: 2.7544 - root_mean_squared_error: 5.5424 - val_loss: 67.4774 - val_mean_squared_error: 67.4774 - val_mean_absolute_error: 6.0495 - val_root_mean_squared_error: 8.2145
# Epoch 81/150
# 16/16 [==============================] - 33s 2s/step - loss: 30.2289 - mean_squared_error: 30.2289 - mean_absolute_error: 2.7682 - root_mean_squared_error: 5.4981 - val_loss: 45.0514 - val_mean_squared_error: 45.0514 - val_mean_absolute_error: 3.3636 - val_root_mean_squared_error: 6.7120
# Epoch 82/150
# 16/16 [==============================] - 34s 2s/step - loss: 29.2064 - mean_squared_error: 29.2064 - mean_absolute_error: 2.7065 - root_mean_squared_error: 5.4043 - val_loss: 43.7900 - val_mean_squared_error: 43.7900 - val_mean_absolute_error: 3.2999 - val_root_mean_squared_error: 6.6174
# Epoch 83/150
# 16/16 [==============================] - 32s 2s/step - loss: 29.2007 - mean_squared_error: 29.2007 - mean_absolute_error: 2.7135 - root_mean_squared_error: 5.4038 - val_loss: 44.7798 - val_mean_squared_error: 44.7798 - val_mean_absolute_error: 3.3471 - val_root_mean_squared_error: 6.6918
# Epoch 84/150
# 16/16 [==============================] - 34s 2s/step - loss: 28.1681 - mean_squared_error: 28.1681 - mean_absolute_error: 2.6405 - root_mean_squared_error: 5.3074 - val_loss: 47.7354 - val_mean_squared_error: 47.7354 - val_mean_absolute_error: 3.5207 - val_root_mean_squared_error: 6.9091
# Epoch 85/150
# 16/16 [==============================] - 33s 2s/step - loss: 32.6052 - mean_squared_error: 32.6052 - mean_absolute_error: 2.8876 - root_mean_squared_error: 5.7101 - val_loss: 41.7858 - val_mean_squared_error: 41.7858 - val_mean_absolute_error: 3.1791 - val_root_mean_squared_error: 6.4642
# Epoch 86/150
# 16/16 [==============================] - 33s 2s/step - loss: 30.0557 - mean_squared_error: 30.0557 - mean_absolute_error: 2.7598 - root_mean_squared_error: 5.4823 - val_loss: 44.8865 - val_mean_squared_error: 44.8865 - val_mean_absolute_error: 3.3189 - val_root_mean_squared_error: 6.6997
# Epoch 87/150
# 16/16 [==============================] - 35s 2s/step - loss: 29.1193 - mean_squared_error: 29.1193 - mean_absolute_error: 2.7114 - root_mean_squared_error: 5.3962 - val_loss: 46.3637 - val_mean_squared_error: 46.3637 - val_mean_absolute_error: 3.3794 - val_root_mean_squared_error: 6.8091
# Epoch 88/150
# 16/16 [==============================] - 33s 2s/step - loss: 28.8277 - mean_squared_error: 28.8277 - mean_absolute_error: 2.6938 - root_mean_squared_error: 5.3691 - val_loss: 42.9775 - val_mean_squared_error: 42.9775 - val_mean_absolute_error: 3.3019 - val_root_mean_squared_error: 6.5557
# Epoch 89/150
# 16/16 [==============================] - 34s 2s/step - loss: 28.3158 - mean_squared_error: 28.3158 - mean_absolute_error: 2.6815 - root_mean_squared_error: 5.3213 - val_loss: 49.4021 - val_mean_squared_error: 49.4021 - val_mean_absolute_error: 3.5102 - val_root_mean_squared_error: 7.0287
# Epoch 90/150
# 16/16 [==============================] - 33s 2s/step - loss: 28.3231 - mean_squared_error: 28.3231 - mean_absolute_error: 2.6749 - root_mean_squared_error: 5.3219 - val_loss: 43.6376 - val_mean_squared_error: 43.6376 - val_mean_absolute_error: 3.2542 - val_root_mean_squared_error: 6.6059
# Epoch 91/150
# 16/16 [==============================] - 34s 2s/step - loss: 28.6218 - mean_squared_error: 28.6218 - mean_absolute_error: 2.6988 - root_mean_squared_error: 5.3499 - val_loss: 45.2495 - val_mean_squared_error: 45.2495 - val_mean_absolute_error: 3.2988 - val_root_mean_squared_error: 6.7268
# Epoch 92/150
# 16/16 [==============================] - 35s 2s/step - loss: 28.6988 - mean_squared_error: 28.6988 - mean_absolute_error: 2.7018 - root_mean_squared_error: 5.3571 - val_loss: 42.9424 - val_mean_squared_error: 42.9424 - val_mean_absolute_error: 3.3028 - val_root_mean_squared_error: 6.5530
# Epoch 93/150
# 16/16 [==============================] - 33s 2s/step - loss: 30.4942 - mean_squared_error: 30.4942 - mean_absolute_error: 2.7866 - root_mean_squared_error: 5.5222 - val_loss: 156.4945 - val_mean_squared_error: 156.4945 - val_mean_absolute_error: 11.3134 - val_root_mean_squared_error: 12.5098
# Epoch 94/150
# 16/16 [==============================] - 34s 2s/step - loss: 28.7176 - mean_squared_error: 28.7176 - mean_absolute_error: 2.6767 - root_mean_squared_error: 5.3589 - val_loss: 46.1203 - val_mean_squared_error: 46.1203 - val_mean_absolute_error: 3.4000 - val_root_mean_squared_error: 6.7912
# Epoch 95/150
# 16/16 [==============================] - 33s 2s/step - loss: 27.7904 - mean_squared_error: 27.7904 - mean_absolute_error: 2.6364 - root_mean_squared_error: 5.2717 - val_loss: 51.1477 - val_mean_squared_error: 51.1477 - val_mean_absolute_error: 3.5592 - val_root_mean_squared_error: 7.1518
# Epoch 96/150
# 16/16 [==============================] - 34s 2s/step - loss: 27.0684 - mean_squared_error: 27.0684 - mean_absolute_error: 2.5927 - root_mean_squared_error: 5.2027 - val_loss: 44.4945 - val_mean_squared_error: 44.4945 - val_mean_absolute_error: 3.3305 - val_root_mean_squared_error: 6.6704
# Epoch 97/150
# 16/16 [==============================] - 34s 2s/step - loss: 29.1025 - mean_squared_error: 29.1025 - mean_absolute_error: 2.7136 - root_mean_squared_error: 5.3947 - val_loss: 140.0542 - val_mean_squared_error: 140.0543 - val_mean_absolute_error: 10.4228 - val_root_mean_squared_error: 11.8345
# Epoch 98/150
# 16/16 [==============================] - 33s 2s/step - loss: 28.1129 - mean_squared_error: 28.1129 - mean_absolute_error: 2.6919 - root_mean_squared_error: 5.3022 - val_loss: 44.5487 - val_mean_squared_error: 44.5487 - val_mean_absolute_error: 3.3317 - val_root_mean_squared_error: 6.6745
# Epoch 99/150
# 16/16 [==============================] - 36s 2s/step - loss: 28.1793 - mean_squared_error: 28.1793 - mean_absolute_error: 2.6846 - root_mean_squared_error: 5.3084 - val_loss: 44.6525 - val_mean_squared_error: 44.6525 - val_mean_absolute_error: 3.3064 - val_root_mean_squared_error: 6.6823
# Epoch 100/150
# 16/16 [==============================] - 33s 2s/step - loss: 30.1960 - mean_squared_error: 30.1960 - mean_absolute_error: 2.7684 - root_mean_squared_error: 5.4951 - val_loss: 82.3871 - val_mean_squared_error: 82.3871 - val_mean_absolute_error: 7.6235 - val_root_mean_squared_error: 9.0767
# Epoch 101/150
# 16/16 [==============================] - 34s 2s/step - loss: 27.4856 - mean_squared_error: 27.4856 - mean_absolute_error: 2.6425 - root_mean_squared_error: 5.2427 - val_loss: 167.4236 - val_mean_squared_error: 167.4236 - val_mean_absolute_error: 11.5837 - val_root_mean_squared_error: 12.9392
# Epoch 102/150
# 16/16 [==============================] - 33s 2s/step - loss: 27.5356 - mean_squared_error: 27.5356 - mean_absolute_error: 2.6336 - root_mean_squared_error: 5.2474 - val_loss: 48.0178 - val_mean_squared_error: 48.0178 - val_mean_absolute_error: 3.4031 - val_root_mean_squared_error: 6.9295
# Epoch 103/150
# 16/16 [==============================] - 33s 2s/step - loss: 27.5530 - mean_squared_error: 27.5530 - mean_absolute_error: 2.6419 - root_mean_squared_error: 5.2491 - val_loss: 47.5826 - val_mean_squared_error: 47.5826 - val_mean_absolute_error: 3.4380 - val_root_mean_squared_error: 6.8980
# Epoch 104/150
# 16/16 [==============================] - 33s 2s/step - loss: 28.9880 - mean_squared_error: 28.9880 - mean_absolute_error: 2.6891 - root_mean_squared_error: 5.3841 - val_loss: 48.7633 - val_mean_squared_error: 48.7633 - val_mean_absolute_error: 3.5337 - val_root_mean_squared_error: 6.9831
# Epoch 105/150
# 16/16 [==============================] - 33s 2s/step - loss: 30.0706 - mean_squared_error: 30.0706 - mean_absolute_error: 2.7472 - root_mean_squared_error: 5.4837 - val_loss: 49.6623 - val_mean_squared_error: 49.6623 - val_mean_absolute_error: 3.4495 - val_root_mean_squared_error: 7.0471
# Epoch 106/150
# 16/16 [==============================] - 36s 2s/step - loss: 29.1668 - mean_squared_error: 29.1668 - mean_absolute_error: 2.7045 - root_mean_squared_error: 5.4006 - val_loss: 297.1219 - val_mean_squared_error: 297.1219 - val_mean_absolute_error: 15.3591 - val_root_mean_squared_error: 17.2372
# Epoch 107/150
# 16/16 [==============================] - 33s 2s/step - loss: 28.4902 - mean_squared_error: 28.4902 - mean_absolute_error: 2.6879 - root_mean_squared_error: 5.3376 - val_loss: 61.1300 - val_mean_squared_error: 61.1300 - val_mean_absolute_error: 3.8355 - val_root_mean_squared_error: 7.8186
# Epoch 108/150
# 16/16 [==============================] - 34s 2s/step - loss: 27.5367 - mean_squared_error: 27.5367 - mean_absolute_error: 2.6488 - root_mean_squared_error: 5.2475 - val_loss: 45.0512 - val_mean_squared_error: 45.0512 - val_mean_absolute_error: 3.3412 - val_root_mean_squared_error: 6.7120
# Epoch 109/150
# 16/16 [==============================] - 37s 2s/step - loss: 27.4809 - mean_squared_error: 27.4809 - mean_absolute_error: 2.6397 - root_mean_squared_error: 5.2422 - val_loss: 51.9636 - val_mean_squared_error: 51.9636 - val_mean_absolute_error: 3.6552 - val_root_mean_squared_error: 7.2086
# Epoch 110/150
# 16/16 [==============================] - 33s 2s/step - loss: 27.9462 - mean_squared_error: 27.9462 - mean_absolute_error: 2.6494 - root_mean_squared_error: 5.2864 - val_loss: 109.9819 - val_mean_squared_error: 109.9819 - val_mean_absolute_error: 9.1828 - val_root_mean_squared_error: 10.4872
# Epoch 111/150
# 16/16 [==============================] - 34s 2s/step - loss: 26.6636 - mean_squared_error: 26.6636 - mean_absolute_error: 2.6021 - root_mean_squared_error: 5.1637 - val_loss: 47.4160 - val_mean_squared_error: 47.4160 - val_mean_absolute_error: 3.4470 - val_root_mean_squared_error: 6.8859
# Epoch 112/150
# 16/16 [==============================] - 36s 2s/step - loss: 26.7486 - mean_squared_error: 26.7486 - mean_absolute_error: 2.6196 - root_mean_squared_error: 5.1719 - val_loss: 51.5523 - val_mean_squared_error: 51.5523 - val_mean_absolute_error: 3.5974 - val_root_mean_squared_error: 7.1800
# Epoch 113/150
# 16/16 [==============================] - 34s 2s/step - loss: 28.8065 - mean_squared_error: 28.8065 - mean_absolute_error: 2.6914 - root_mean_squared_error: 5.3672 - val_loss: 42.8527 - val_mean_squared_error: 42.8527 - val_mean_absolute_error: 3.2483 - val_root_mean_squared_error: 6.5462
# Epoch 114/150
# 16/16 [==============================] - 35s 2s/step - loss: 28.0553 - mean_squared_error: 28.0554 - mean_absolute_error: 2.6599 - root_mean_squared_error: 5.2967 - val_loss: 40.9097 - val_mean_squared_error: 40.9097 - val_mean_absolute_error: 3.1622 - val_root_mean_squared_error: 6.3961
# Epoch 115/150
# 16/16 [==============================] - 36s 2s/step - loss: 27.0409 - mean_squared_error: 27.0409 - mean_absolute_error: 2.5968 - root_mean_squared_error: 5.2001 - val_loss: 41.2694 - val_mean_squared_error: 41.2694 - val_mean_absolute_error: 3.1952 - val_root_mean_squared_error: 6.4241
# Epoch 116/150
# 16/16 [==============================] - 34s 2s/step - loss: 26.9788 - mean_squared_error: 26.9788 - mean_absolute_error: 2.6160 - root_mean_squared_error: 5.1941 - val_loss: 44.6722 - val_mean_squared_error: 44.6722 - val_mean_absolute_error: 3.3429 - val_root_mean_squared_error: 6.6837
# Epoch 117/150
# 16/16 [==============================] - 34s 2s/step - loss: 25.7083 - mean_squared_error: 25.7083 - mean_absolute_error: 2.5369 - root_mean_squared_error: 5.0703 - val_loss: 43.0767 - val_mean_squared_error: 43.0767 - val_mean_absolute_error: 3.2672 - val_root_mean_squared_error: 6.5633
# Epoch 118/150
# 16/16 [==============================] - 36s 2s/step - loss: 25.5319 - mean_squared_error: 25.5319 - mean_absolute_error: 2.5560 - root_mean_squared_error: 5.0529 - val_loss: 51.8635 - val_mean_squared_error: 51.8635 - val_mean_absolute_error: 3.4938 - val_root_mean_squared_error: 7.2016
# Epoch 119/150
# 16/16 [==============================] - 33s 2s/step - loss: 25.6593 - mean_squared_error: 25.6593 - mean_absolute_error: 2.5429 - root_mean_squared_error: 5.0655 - val_loss: 47.4177 - val_mean_squared_error: 47.4177 - val_mean_absolute_error: 3.3732 - val_root_mean_squared_error: 6.8860
# Epoch 120/150
# 16/16 [==============================] - 35s 2s/step - loss: 26.2627 - mean_squared_error: 26.2627 - mean_absolute_error: 2.5716 - root_mean_squared_error: 5.1247 - val_loss: 43.0937 - val_mean_squared_error: 43.0937 - val_mean_absolute_error: 3.2725 - val_root_mean_squared_error: 6.5646
# Epoch 121/150
# 16/16 [==============================] - 36s 2s/step - loss: 27.2090 - mean_squared_error: 27.2090 - mean_absolute_error: 2.6286 - root_mean_squared_error: 5.2162 - val_loss: 44.1917 - val_mean_squared_error: 44.1917 - val_mean_absolute_error: 3.3094 - val_root_mean_squared_error: 6.6477
# Epoch 122/150
# 16/16 [==============================] - 34s 2s/step - loss: 26.7289 - mean_squared_error: 26.7289 - mean_absolute_error: 2.5875 - root_mean_squared_error: 5.1700 - val_loss: 44.1302 - val_mean_squared_error: 44.1302 - val_mean_absolute_error: 3.3068 - val_root_mean_squared_error: 6.6431
# Epoch 123/150
# 16/16 [==============================] - 34s 2s/step - loss: 25.1349 - mean_squared_error: 25.1349 - mean_absolute_error: 2.4975 - root_mean_squared_error: 5.0135 - val_loss: 44.5649 - val_mean_squared_error: 44.5649 - val_mean_absolute_error: 3.3618 - val_root_mean_squared_error: 6.6757
# Epoch 124/150
# 16/16 [==============================] - 36s 2s/step - loss: 26.1971 - mean_squared_error: 26.1971 - mean_absolute_error: 2.5654 - root_mean_squared_error: 5.1183 - val_loss: 43.4024 - val_mean_squared_error: 43.4024 - val_mean_absolute_error: 3.3500 - val_root_mean_squared_error: 6.5881
# Epoch 125/150
# 16/16 [==============================] - 34s 2s/step - loss: 25.4962 - mean_squared_error: 25.4962 - mean_absolute_error: 2.5171 - root_mean_squared_error: 5.0494 - val_loss: 60.5592 - val_mean_squared_error: 60.5592 - val_mean_absolute_error: 5.8983 - val_root_mean_squared_error: 7.7820
# Epoch 126/150
# 16/16 [==============================] - 35s 2s/step - loss: 25.8588 - mean_squared_error: 25.8588 - mean_absolute_error: 2.5589 - root_mean_squared_error: 5.0852 - val_loss: 52.6969 - val_mean_squared_error: 52.6969 - val_mean_absolute_error: 3.6041 - val_root_mean_squared_error: 7.2593
# Epoch 127/150
# 16/16 [==============================] - 34s 2s/step - loss: 28.7619 - mean_squared_error: 28.7619 - mean_absolute_error: 2.6868 - root_mean_squared_error: 5.3630 - val_loss: 47.7131 - val_mean_squared_error: 47.7131 - val_mean_absolute_error: 3.4577 - val_root_mean_squared_error: 6.9075
# Epoch 128/150
# 16/16 [==============================] - 35s 2s/step - loss: 26.3485 - mean_squared_error: 26.3485 - mean_absolute_error: 2.5784 - root_mean_squared_error: 5.1331 - val_loss: 49.3057 - val_mean_squared_error: 49.3057 - val_mean_absolute_error: 3.4562 - val_root_mean_squared_error: 7.0218
# Epoch 129/150
# 16/16 [==============================] - 34s 2s/step - loss: 28.4479 - mean_squared_error: 28.4479 - mean_absolute_error: 2.6727 - root_mean_squared_error: 5.3337 - val_loss: 44.6642 - val_mean_squared_error: 44.6642 - val_mean_absolute_error: 3.2744 - val_root_mean_squared_error: 6.6831
# Epoch 130/150
# 16/16 [==============================] - 33s 2s/step - loss: 25.8556 - mean_squared_error: 25.8556 - mean_absolute_error: 2.5458 - root_mean_squared_error: 5.0848 - val_loss: 46.3454 - val_mean_squared_error: 46.3454 - val_mean_absolute_error: 3.3908 - val_root_mean_squared_error: 6.8077
# Epoch 131/150
# 16/16 [==============================] - 35s 2s/step - loss: 26.8449 - mean_squared_error: 26.8449 - mean_absolute_error: 2.5938 - root_mean_squared_error: 5.1812 - val_loss: 53.5140 - val_mean_squared_error: 53.5140 - val_mean_absolute_error: 3.5622 - val_root_mean_squared_error: 7.3153
# Epoch 132/150
# 16/16 [==============================] - 33s 2s/step - loss: 29.2963 - mean_squared_error: 29.2963 - mean_absolute_error: 2.7252 - root_mean_squared_error: 5.4126 - val_loss: 42.7342 - val_mean_squared_error: 42.7342 - val_mean_absolute_error: 3.2210 - val_root_mean_squared_error: 6.5371
# Epoch 133/150
# 16/16 [==============================] - 34s 2s/step - loss: 27.3875 - mean_squared_error: 27.3875 - mean_absolute_error: 2.6275 - root_mean_squared_error: 5.2333 - val_loss: 43.2097 - val_mean_squared_error: 43.2097 - val_mean_absolute_error: 3.2565 - val_root_mean_squared_error: 6.5734
# Epoch 134/150
# 16/16 [==============================] - 36s 2s/step - loss: 25.8905 - mean_squared_error: 25.8905 - mean_absolute_error: 2.5463 - root_mean_squared_error: 5.0883 - val_loss: 54.8097 - val_mean_squared_error: 54.8097 - val_mean_absolute_error: 4.7241 - val_root_mean_squared_error: 7.4034
# Epoch 135/150
# 16/16 [==============================] - 33s 2s/step - loss: 26.7924 - mean_squared_error: 26.7924 - mean_absolute_error: 2.5993 - root_mean_squared_error: 5.1761 - val_loss: 78.6851 - val_mean_squared_error: 78.6851 - val_mean_absolute_error: 6.9865 - val_root_mean_squared_error: 8.8705
# Epoch 136/150
# 16/16 [==============================] - 34s 2s/step - loss: 27.7293 - mean_squared_error: 27.7293 - mean_absolute_error: 2.6586 - root_mean_squared_error: 5.2659 - val_loss: 46.8093 - val_mean_squared_error: 46.8093 - val_mean_absolute_error: 3.4208 - val_root_mean_squared_error: 6.8417
# Epoch 137/150
# 16/16 [==============================] - 36s 2s/step - loss: 26.7479 - mean_squared_error: 26.7479 - mean_absolute_error: 2.5949 - root_mean_squared_error: 5.1718 - val_loss: 41.7243 - val_mean_squared_error: 41.7243 - val_mean_absolute_error: 3.1736 - val_root_mean_squared_error: 6.4594
# Epoch 138/150
# 16/16 [==============================] - 33s 2s/step - loss: 26.2785 - mean_squared_error: 26.2785 - mean_absolute_error: 2.5762 - root_mean_squared_error: 5.1263 - val_loss: 40.0502 - val_mean_squared_error: 40.0502 - val_mean_absolute_error: 3.1058 - val_root_mean_squared_error: 6.3285
# Epoch 139/150
# 16/16 [==============================] - 34s 2s/step - loss: 25.7795 - mean_squared_error: 25.7795 - mean_absolute_error: 2.5540 - root_mean_squared_error: 5.0774 - val_loss: 40.0002 - val_mean_squared_error: 40.0002 - val_mean_absolute_error: 3.1132 - val_root_mean_squared_error: 6.3246
# Epoch 140/150
# 16/16 [==============================] - 36s 2s/step - loss: 25.5936 - mean_squared_error: 25.5936 - mean_absolute_error: 2.5494 - root_mean_squared_error: 5.0590 - val_loss: 41.7880 - val_mean_squared_error: 41.7880 - val_mean_absolute_error: 3.2401 - val_root_mean_squared_error: 6.4644
# Epoch 141/150
# 16/16 [==============================] - 33s 2s/step - loss: 25.8891 - mean_squared_error: 25.8891 - mean_absolute_error: 2.5524 - root_mean_squared_error: 5.0881 - val_loss: 40.8196 - val_mean_squared_error: 40.8196 - val_mean_absolute_error: 3.2211 - val_root_mean_squared_error: 6.3890
# Epoch 142/150
# 16/16 [==============================] - 34s 2s/step - loss: 24.0413 - mean_squared_error: 24.0413 - mean_absolute_error: 2.4725 - root_mean_squared_error: 4.9032 - val_loss: 42.4149 - val_mean_squared_error: 42.4149 - val_mean_absolute_error: 3.2734 - val_root_mean_squared_error: 6.5127
# Epoch 143/150
# 16/16 [==============================] - 34s 2s/step - loss: 23.7924 - mean_squared_error: 23.7924 - mean_absolute_error: 2.4419 - root_mean_squared_error: 4.8777 - val_loss: 43.3843 - val_mean_squared_error: 43.3843 - val_mean_absolute_error: 3.3346 - val_root_mean_squared_error: 6.5867
# Epoch 144/150
# 16/16 [==============================] - 34s 2s/step - loss: 23.6869 - mean_squared_error: 23.6869 - mean_absolute_error: 2.4507 - root_mean_squared_error: 4.8669 - val_loss: 40.4779 - val_mean_squared_error: 40.4779 - val_mean_absolute_error: 3.1985 - val_root_mean_squared_error: 6.3622
# Epoch 145/150
# 16/16 [==============================] - 36s 2s/step - loss: 24.7007 - mean_squared_error: 24.7007 - mean_absolute_error: 2.4821 - root_mean_squared_error: 4.9700 - val_loss: 42.7243 - val_mean_squared_error: 42.7243 - val_mean_absolute_error: 3.2999 - val_root_mean_squared_error: 6.5364
# Epoch 146/150
# 16/16 [==============================] - 33s 2s/step - loss: 25.6974 - mean_squared_error: 25.6974 - mean_absolute_error: 2.5480 - root_mean_squared_error: 5.0693 - val_loss: 46.3285 - val_mean_squared_error: 46.3285 - val_mean_absolute_error: 3.4876 - val_root_mean_squared_error: 6.8065
# Epoch 147/150
# 16/16 [==============================] - 34s 2s/step - loss: 24.7950 - mean_squared_error: 24.7950 - mean_absolute_error: 2.5041 - root_mean_squared_error: 4.9795 - val_loss: 43.0474 - val_mean_squared_error: 43.0474 - val_mean_absolute_error: 3.2056 - val_root_mean_squared_error: 6.5610
# Epoch 148/150
# 16/16 [==============================] - 33s 2s/step - loss: 25.1017 - mean_squared_error: 25.1017 - mean_absolute_error: 2.5104 - root_mean_squared_error: 5.0102 - val_loss: 43.9138 - val_mean_squared_error: 43.9138 - val_mean_absolute_error: 3.2882 - val_root_mean_squared_error: 6.6268
# Epoch 149/150
# 16/16 [==============================] - 34s 2s/step - loss: 24.4481 - mean_squared_error: 24.4481 - mean_absolute_error: 2.4768 - root_mean_squared_error: 4.9445 - val_loss: 43.4320 - val_mean_squared_error: 43.4320 - val_mean_absolute_error: 3.3031 - val_root_mean_squared_error: 6.5903
# Epoch 150/150
# 16/16 [==============================] - 36s 2s/step - loss: 23.8064 - mean_squared_error: 23.8064 - mean_absolute_error: 2.4355 - root_mean_squared_error: 4.8792 - val_loss: 46.7694 - val_mean_squared_error: 46.7694 - val_mean_absolute_error: 3.4512 - val_root_mean_squared_error: 6.8388

# %% [markdown]
# # Training results

# %%
from utils.plotting import training_loss_plot

plot = training_loss_plot(train_score, filename='download/training_loss_old.pdf')
plot.show()

# %% [markdown]
# # Testing old

# %%
### Predict on the test set
from utils.evaluation import phases_report, phases_report_std

print('Testmetriken:')

report = phases_report(y_pred_old, bis.test_dataset[old_index_test], propofolrate.test_dataset[old_index_test])
report
# Out:
# Testmetriken:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                  69.96       138.97           6.28         7.10
# Induction           122.90       624.85           8.60        17.37
# Maintenance          54.03        47.75           5.64         4.92
# Recovery            127.54       374.76           8.41        13.62
#
#             Prediction RMSE Baseline RMSE
# All                    8.36         11.79
# Induction             11.09         25.00
# Maintenance            7.35          6.91
# Recovery              11.29         19.36

# %%
phases_report_std(report, y_pred_old, bis.test_dataset[old_index_test], propofolrate.test_dataset[old_index_test])
# Out:
# All      	min: 	 9 	max: 	 0
# Induction 	min: 	 14 	max: 	 5
# Maintenance 	min: 	 7 	max: 	 5
# Recovery 	min: 	 2 	max: 	 13
#              Prediction MSE  Baseline MSE  Prediction MAE  Baseline MAE  \
# All                   42.49         74.81            1.71          1.73
# Induction             95.72        423.91            3.10          8.80
# Maintenance           32.50         31.03            1.70          1.28
# Recovery              96.44        148.20            3.58          4.92
#
#              Prediction RMSE  Baseline RMSE
# All                     2.26           3.07
# Induction               3.58           7.75
# Maintenance             2.14           2.00
# Recovery                4.09           4.70

# %%
from utils.plotting import full_histogramm_plot

plot = full_histogramm_plot(groundtruth = bis.test_dataset[old_index_test], prediction = y_pred_old, filename='download/histogramm_old.pdf')
plot.show()

# %%
from utils.plotting import single_prediction_plot

for case in test_index[old_index_test]:
    single_prediction_plot(
        case = case,
        index = test_index[old_index_test],
        groundtruth = bis.test_dataset[old_index_test],
        prediction = y_pred_old,
        infusion = propofolrate.test_dataset[old_index_test],
        error = 'Prediction RMSE',
        filename = 'download/' + str(case) + '_male.pdf')

print('Finished')
# Out:
# Finished

# %% [markdown]
# # Testing young

# %%
### Predict on the test set
from utils.evaluation import phases_report, phases_report_std

print('Testmetriken:')

report = phases_report(y_pred_young, bis.test_dataset[young_index_test], propofolrate.test_dataset[young_index_test])
report
# Out:
# Testmetriken:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                  76.47       141.25           6.81         8.23
# Induction           119.66       660.01           8.64        20.05
# Maintenance          66.77        79.34           6.44         6.76
# Recovery            134.52       329.30           8.75        13.06
#
#             Prediction RMSE Baseline RMSE
# All                    8.74         11.88
# Induction             10.94         25.69
# Maintenance            8.17          8.91
# Recovery              11.60         18.15

# %%
phases_report_std(report, y_pred_young, bis.test_dataset[young_index_test], propofolrate.test_dataset[young_index_test])
# Out:
# All      	min: 	 7 	max: 	 3
# Induction 	min: 	 7 	max: 	 2
# Maintenance 	min: 	 8 	max: 	 3
# Recovery 	min: 	 7 	max: 	 2
#              Prediction MSE  Baseline MSE  Prediction MAE  Baseline MAE  \
# All                   21.76         93.53            1.23          3.38
# Induction             67.62        367.78            2.70          7.62
# Maintenance           23.26         49.31            1.40          2.53
# Recovery              99.63        227.58            4.34          7.95
#
#              Prediction RMSE  Baseline RMSE
# All                     1.26           3.65
# Induction               3.00           6.43
# Maintenance             1.57           2.63
# Recovery                4.88           8.15

# %%
from utils.plotting import full_histogramm_plot

plot = full_histogramm_plot(groundtruth = bis.test_dataset[young_index_test], prediction = y_pred_young, filename='download/histogramm_young.pdf')
plot.show()

# %%
from utils.plotting import single_prediction_plot

for case in test_index[young_index_test]:
    single_prediction_plot(
        case = case,
        index = test_index[young_index_test],
        groundtruth = bis.test_dataset[young_index_test],
        prediction = y_pred_young,
        infusion = propofolrate.test_dataset[young_index_test],
        error = 'Prediction RMSE',
        filename = 'download/' + str(case) + '_young.pdf')

print('Finished')
# Out:
# Finished
