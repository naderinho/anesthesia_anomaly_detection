# %% [markdown]
# # Initialization

# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset02/'
vitaldbpath = 'vitaldb_tiva/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt
import pickle

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 630, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 630 (delta 87), reused 169 (delta 87), pack-reused 461
# Receiving objects: 100% (630/630), 124.94 MiB | 14.38 MiB/s, done.
# Resolving deltas: 100% (291/291), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl.metadata (520 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.31.0)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.4 MB/s eta 0:00:00
# Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 8.2 MB/s eta 0:00:00
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %% [markdown]
# # Data loading

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    propofolrate.name = 'Propofol Rate'
    propofolrate.tracks = ['Orchestra/PPF20_RATE']
    propofolrate.filterON = False
    propofolrate.generateDataset(normalization=md.NormNone)
    propofolrate.save('03_propofol_rate.npz')

    remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    remifentanilrate.name = 'Remifentanil Rate'
    remifentanilrate.tracks = ['Orchestra/RFTN20_RATE']
    remifentanilrate.filterON = False
    remifentanilrate.generateDataset(normalization=md.NormNone)
    remifentanilrate.save('03_remifentanil_rate.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

propofolrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
propofolrate.load('03_propofol_rate.npz')

remifentanilrate = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
remifentanilrate.load('03_remifentanil_rate.npz')

train_index, val_index, test_index = bis.split(np.array(bis.index))

# %% [markdown]
# # Model creation

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### LSTM layers for the blood pressure data

### Combine the vital data
vital_train = np.concatenate([bloodpressure.train_dataset, etCO2.train_dataset, spO2.train_dataset, hr.train_dataset], axis=2)
vital_validation = np.concatenate([bloodpressure.validation_dataset, etCO2.validation_dataset, spO2.validation_dataset, hr.validation_dataset], axis=2)
vital_test = np.concatenate([bloodpressure.test_dataset, etCO2.test_dataset, spO2.test_dataset, hr.test_dataset], axis=2)

### LSTM layers for the vital data
input_vital = Input(shape=(None, vital_train.shape[2]))
vital_layer = Masking(mask_value=0.0)(input_vital)

comb_layer = LSTM(units=32, return_sequences=True)(vital_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = LSTM(units=32, return_sequences=True)(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=128, activation='relu')(comb_layer)
comb_layer = BatchNormalization()(comb_layer)
comb_layer = Dense(units=32, activation='relu')(comb_layer)
comb_layer = BatchNormalization()(comb_layer)


output = Dense(units=1, activation=ReLU(max_value=1.0))(comb_layer)
output = Lambda(lambda x: x * 100)(output)

# Define the model
model = Model(inputs=[input_vital], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.001)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, 6)]         0
#
#  masking (Masking)           (None, None, 6)           0
#
#  lstm (LSTM)                 (None, None, 32)          4992
#
#  batch_normalization (Batch  (None, None, 32)          128
#  Normalization)
#
#  lstm_1 (LSTM)               (None, None, 32)          8320
#
#  batch_normalization_1 (Bat  (None, None, 32)          128
#  chNormalization)
#
#  lstm_2 (LSTM)               (None, None, 32)          8320
#
#  batch_normalization_2 (Bat  (None, None, 32)          128
#  chNormalization)
#
#  dense (Dense)               (None, None, 128)         4224
#
#  batch_normalization_3 (Bat  (None, None, 128)         512
#  chNormalization)
#
#  dense_1 (Dense)             (None, None, 32)          4128
#
#  batch_normalization_4 (Bat  (None, None, 32)          128
#  chNormalization)
#
#  dense_2 (Dense)             (None, None, 1)           33
#
#  lambda (Lambda)             (None, None, 1)           0
#
# =================================================================
# Total params: 31041 (121.25 KB)
# Trainable params: 30529 (119.25 KB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %%
# Rolling mean on BIS data
y = pd.DataFrame(bis.train_dataset[:,:,0].T).rolling(min_periods=1,window=20, center=True).mean().to_numpy().T[:,:,np.newaxis]

# Define training stop criteria
class StopTrainingCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(StopTrainingCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_loss') is not None:
            if logs.get('val_loss') < self.threshold:
                print(f"\nValidation loss is below {self.threshold}, stopping training.")
                self.model.stop_training = True

stop_training_callback = StopTrainingCallback(threshold = 35)


if in_google_colab():
    # Train the model
    history = model.fit([vital_train],
                        y,
                        validation_data=([vital_validation], bis.validation_dataset),
                        epochs=100,
                        batch_size=4,
                        callbacks=[stop_training_callback]
                        )

    train_score = history.history

    # Save the model
    model.save('download/model.keras')

    # Save the training history
    with open('download/train_score.pkl', 'wb') as f:
        pickle.dump(train_score, f)

    # Save the prediction
    y_pred = model.predict([vital_test], verbose=0)
    with open('download/prediction.pkl', 'wb') as f:
        pickle.dump(y_pred, f)

else:
    # Load train score data
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

    # Load test prediction data
    with open('prediction.pkl', 'rb') as f:
        y_pred = pickle.load(f)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 28s 310ms/step - loss: 780.1470 - mean_squared_error: 780.1470 - mean_absolute_error: 16.8396 - root_mean_squared_error: 27.9311 - val_loss: 832.6685 - val_mean_squared_error: 832.6685 - val_mean_absolute_error: 17.6154 - val_root_mean_squared_error: 28.8560
# Epoch 2/100
# 28/28 [==============================] - 6s 200ms/step - loss: 638.2238 - mean_squared_error: 638.2238 - mean_absolute_error: 14.8295 - root_mean_squared_error: 25.2631 - val_loss: 745.2488 - val_mean_squared_error: 745.2488 - val_mean_absolute_error: 16.5397 - val_root_mean_squared_error: 27.2992
# Epoch 3/100
# 28/28 [==============================] - 5s 178ms/step - loss: 525.7219 - mean_squared_error: 525.7220 - mean_absolute_error: 13.2066 - root_mean_squared_error: 22.9286 - val_loss: 685.0767 - val_mean_squared_error: 685.0767 - val_mean_absolute_error: 15.7357 - val_root_mean_squared_error: 26.1740
# Epoch 4/100
# 28/28 [==============================] - 6s 224ms/step - loss: 373.3922 - mean_squared_error: 373.3922 - mean_absolute_error: 10.2848 - root_mean_squared_error: 19.3234 - val_loss: 322.0016 - val_mean_squared_error: 322.0016 - val_mean_absolute_error: 9.4557 - val_root_mean_squared_error: 17.9444
# Epoch 5/100
# 28/28 [==============================] - 5s 178ms/step - loss: 257.1356 - mean_squared_error: 257.1356 - mean_absolute_error: 8.1778 - root_mean_squared_error: 16.0354 - val_loss: 198.1076 - val_mean_squared_error: 198.1076 - val_mean_absolute_error: 10.2104 - val_root_mean_squared_error: 14.0751
# Epoch 6/100
# 28/28 [==============================] - 6s 212ms/step - loss: 192.6849 - mean_squared_error: 192.6849 - mean_absolute_error: 6.9008 - root_mean_squared_error: 13.8811 - val_loss: 133.4866 - val_mean_squared_error: 133.4866 - val_mean_absolute_error: 7.3022 - val_root_mean_squared_error: 11.5536
# Epoch 7/100
# 28/28 [==============================] - 5s 195ms/step - loss: 161.3154 - mean_squared_error: 161.3154 - mean_absolute_error: 6.3002 - root_mean_squared_error: 12.7010 - val_loss: 111.1355 - val_mean_squared_error: 111.1355 - val_mean_absolute_error: 4.7456 - val_root_mean_squared_error: 10.5421
# Epoch 8/100
# 28/28 [==============================] - 6s 206ms/step - loss: 113.1258 - mean_squared_error: 113.1258 - mean_absolute_error: 5.2609 - root_mean_squared_error: 10.6361 - val_loss: 86.4245 - val_mean_squared_error: 86.4245 - val_mean_absolute_error: 4.0157 - val_root_mean_squared_error: 9.2965
# Epoch 9/100
# 28/28 [==============================] - 5s 189ms/step - loss: 107.2560 - mean_squared_error: 107.2560 - mean_absolute_error: 5.1377 - root_mean_squared_error: 10.3564 - val_loss: 108.2018 - val_mean_squared_error: 108.2017 - val_mean_absolute_error: 4.8134 - val_root_mean_squared_error: 10.4020
# Epoch 10/100
# 28/28 [==============================] - 5s 176ms/step - loss: 91.5050 - mean_squared_error: 91.5050 - mean_absolute_error: 4.6638 - root_mean_squared_error: 9.5658 - val_loss: 96.2472 - val_mean_squared_error: 96.2472 - val_mean_absolute_error: 4.3315 - val_root_mean_squared_error: 9.8106
# Epoch 11/100
# 28/28 [==============================] - 6s 222ms/step - loss: 84.2044 - mean_squared_error: 84.2044 - mean_absolute_error: 4.5988 - root_mean_squared_error: 9.1763 - val_loss: 88.5428 - val_mean_squared_error: 88.5428 - val_mean_absolute_error: 4.2688 - val_root_mean_squared_error: 9.4097
# Epoch 12/100
# 28/28 [==============================] - 5s 177ms/step - loss: 84.4761 - mean_squared_error: 84.4761 - mean_absolute_error: 4.5790 - root_mean_squared_error: 9.1911 - val_loss: 94.8100 - val_mean_squared_error: 94.8100 - val_mean_absolute_error: 4.5476 - val_root_mean_squared_error: 9.7370
# Epoch 13/100
# 28/28 [==============================] - 6s 230ms/step - loss: 86.6426 - mean_squared_error: 86.6426 - mean_absolute_error: 4.5985 - root_mean_squared_error: 9.3082 - val_loss: 91.4015 - val_mean_squared_error: 91.4015 - val_mean_absolute_error: 4.6011 - val_root_mean_squared_error: 9.5604
# Epoch 14/100
# 28/28 [==============================] - 5s 189ms/step - loss: 69.1255 - mean_squared_error: 69.1255 - mean_absolute_error: 4.1852 - root_mean_squared_error: 8.3142 - val_loss: 87.1344 - val_mean_squared_error: 87.1344 - val_mean_absolute_error: 4.4807 - val_root_mean_squared_error: 9.3346
# Epoch 15/100
# 28/28 [==============================] - 6s 208ms/step - loss: 67.0703 - mean_squared_error: 67.0703 - mean_absolute_error: 3.9739 - root_mean_squared_error: 8.1896 - val_loss: 75.9512 - val_mean_squared_error: 75.9513 - val_mean_absolute_error: 4.1118 - val_root_mean_squared_error: 8.7150
# Epoch 16/100
# 28/28 [==============================] - 5s 185ms/step - loss: 66.7005 - mean_squared_error: 66.7005 - mean_absolute_error: 4.1111 - root_mean_squared_error: 8.1670 - val_loss: 86.9266 - val_mean_squared_error: 86.9266 - val_mean_absolute_error: 4.3998 - val_root_mean_squared_error: 9.3234
# Epoch 17/100
# 28/28 [==============================] - 5s 180ms/step - loss: 68.3764 - mean_squared_error: 68.3764 - mean_absolute_error: 4.0576 - root_mean_squared_error: 8.2690 - val_loss: 81.4731 - val_mean_squared_error: 81.4731 - val_mean_absolute_error: 4.3745 - val_root_mean_squared_error: 9.0262
# Epoch 18/100
# 28/28 [==============================] - 6s 223ms/step - loss: 64.2724 - mean_squared_error: 64.2724 - mean_absolute_error: 3.8897 - root_mean_squared_error: 8.0170 - val_loss: 76.1121 - val_mean_squared_error: 76.1121 - val_mean_absolute_error: 4.1788 - val_root_mean_squared_error: 8.7242
# Epoch 19/100
# 28/28 [==============================] - 5s 178ms/step - loss: 60.8668 - mean_squared_error: 60.8668 - mean_absolute_error: 3.7856 - root_mean_squared_error: 7.8017 - val_loss: 76.0191 - val_mean_squared_error: 76.0191 - val_mean_absolute_error: 4.1394 - val_root_mean_squared_error: 8.7189
# Epoch 20/100
# 28/28 [==============================] - 6s 203ms/step - loss: 61.1770 - mean_squared_error: 61.1770 - mean_absolute_error: 3.8299 - root_mean_squared_error: 7.8216 - val_loss: 78.4310 - val_mean_squared_error: 78.4310 - val_mean_absolute_error: 4.2449 - val_root_mean_squared_error: 8.8561
# Epoch 21/100
# 28/28 [==============================] - 5s 178ms/step - loss: 61.1753 - mean_squared_error: 61.1753 - mean_absolute_error: 3.7895 - root_mean_squared_error: 7.8215 - val_loss: 75.6857 - val_mean_squared_error: 75.6857 - val_mean_absolute_error: 4.1466 - val_root_mean_squared_error: 8.6998
# Epoch 22/100
# 28/28 [==============================] - 6s 201ms/step - loss: 73.2962 - mean_squared_error: 73.2962 - mean_absolute_error: 4.3833 - root_mean_squared_error: 8.5613 - val_loss: 104.3814 - val_mean_squared_error: 104.3814 - val_mean_absolute_error: 4.8231 - val_root_mean_squared_error: 10.2167
# Epoch 23/100
# 28/28 [==============================] - 6s 204ms/step - loss: 68.1059 - mean_squared_error: 68.1059 - mean_absolute_error: 4.0323 - root_mean_squared_error: 8.2526 - val_loss: 93.8063 - val_mean_squared_error: 93.8063 - val_mean_absolute_error: 4.5586 - val_root_mean_squared_error: 9.6854
# Epoch 24/100
# 28/28 [==============================] - 5s 190ms/step - loss: 67.1453 - mean_squared_error: 67.1453 - mean_absolute_error: 4.0489 - root_mean_squared_error: 8.1942 - val_loss: 91.7803 - val_mean_squared_error: 91.7803 - val_mean_absolute_error: 4.5476 - val_root_mean_squared_error: 9.5802
# Epoch 25/100
# 28/28 [==============================] - 6s 207ms/step - loss: 60.5592 - mean_squared_error: 60.5592 - mean_absolute_error: 3.7965 - root_mean_squared_error: 7.7820 - val_loss: 96.1810 - val_mean_squared_error: 96.1810 - val_mean_absolute_error: 4.6629 - val_root_mean_squared_error: 9.8072
# Epoch 26/100
# 28/28 [==============================] - 5s 185ms/step - loss: 57.1657 - mean_squared_error: 57.1657 - mean_absolute_error: 3.6755 - root_mean_squared_error: 7.5608 - val_loss: 76.7642 - val_mean_squared_error: 76.7642 - val_mean_absolute_error: 4.0392 - val_root_mean_squared_error: 8.7615
# Epoch 27/100
# 28/28 [==============================] - 6s 224ms/step - loss: 58.8169 - mean_squared_error: 58.8169 - mean_absolute_error: 3.7790 - root_mean_squared_error: 7.6692 - val_loss: 78.0292 - val_mean_squared_error: 78.0292 - val_mean_absolute_error: 4.2437 - val_root_mean_squared_error: 8.8334
# Epoch 28/100
# 28/28 [==============================] - 5s 179ms/step - loss: 60.1906 - mean_squared_error: 60.1906 - mean_absolute_error: 3.8393 - root_mean_squared_error: 7.7583 - val_loss: 70.9077 - val_mean_squared_error: 70.9077 - val_mean_absolute_error: 4.0141 - val_root_mean_squared_error: 8.4207
# Epoch 29/100
# 28/28 [==============================] - 6s 205ms/step - loss: 57.3216 - mean_squared_error: 57.3216 - mean_absolute_error: 3.7144 - root_mean_squared_error: 7.5711 - val_loss: 73.0750 - val_mean_squared_error: 73.0750 - val_mean_absolute_error: 3.9665 - val_root_mean_squared_error: 8.5484
# Epoch 30/100
# 28/28 [==============================] - 5s 190ms/step - loss: 56.0078 - mean_squared_error: 56.0078 - mean_absolute_error: 3.6702 - root_mean_squared_error: 7.4838 - val_loss: 78.2319 - val_mean_squared_error: 78.2319 - val_mean_absolute_error: 4.1264 - val_root_mean_squared_error: 8.8449
# Epoch 31/100
# 28/28 [==============================] - 5s 187ms/step - loss: 54.6562 - mean_squared_error: 54.6562 - mean_absolute_error: 3.6535 - root_mean_squared_error: 7.3930 - val_loss: 72.6554 - val_mean_squared_error: 72.6554 - val_mean_absolute_error: 4.0140 - val_root_mean_squared_error: 8.5238
# Epoch 32/100
# 28/28 [==============================] - 6s 205ms/step - loss: 53.3159 - mean_squared_error: 53.3159 - mean_absolute_error: 3.5962 - root_mean_squared_error: 7.3018 - val_loss: 74.1612 - val_mean_squared_error: 74.1612 - val_mean_absolute_error: 4.0436 - val_root_mean_squared_error: 8.6117
# Epoch 33/100
# 28/28 [==============================] - 5s 186ms/step - loss: 55.8845 - mean_squared_error: 55.8845 - mean_absolute_error: 3.6748 - root_mean_squared_error: 7.4756 - val_loss: 79.8460 - val_mean_squared_error: 79.8460 - val_mean_absolute_error: 4.1743 - val_root_mean_squared_error: 8.9357
# Epoch 34/100
# 28/28 [==============================] - 6s 227ms/step - loss: 55.3125 - mean_squared_error: 55.3125 - mean_absolute_error: 3.6873 - root_mean_squared_error: 7.4372 - val_loss: 76.5590 - val_mean_squared_error: 76.5590 - val_mean_absolute_error: 4.1461 - val_root_mean_squared_error: 8.7498
# Epoch 35/100
# 28/28 [==============================] - 6s 213ms/step - loss: 51.6162 - mean_squared_error: 51.6162 - mean_absolute_error: 3.5456 - root_mean_squared_error: 7.1844 - val_loss: 71.5802 - val_mean_squared_error: 71.5802 - val_mean_absolute_error: 3.9165 - val_root_mean_squared_error: 8.4605
# Epoch 36/100
# 28/28 [==============================] - 7s 243ms/step - loss: 51.9581 - mean_squared_error: 51.9581 - mean_absolute_error: 3.4997 - root_mean_squared_error: 7.2082 - val_loss: 68.8077 - val_mean_squared_error: 68.8077 - val_mean_absolute_error: 3.9543 - val_root_mean_squared_error: 8.2950
# Epoch 37/100
# 28/28 [==============================] - 5s 194ms/step - loss: 52.9867 - mean_squared_error: 52.9867 - mean_absolute_error: 3.5892 - root_mean_squared_error: 7.2792 - val_loss: 67.4735 - val_mean_squared_error: 67.4735 - val_mean_absolute_error: 3.9468 - val_root_mean_squared_error: 8.2142
# Epoch 38/100
# 28/28 [==============================] - 6s 214ms/step - loss: 51.1402 - mean_squared_error: 51.1402 - mean_absolute_error: 3.5364 - root_mean_squared_error: 7.1512 - val_loss: 68.2388 - val_mean_squared_error: 68.2388 - val_mean_absolute_error: 3.9058 - val_root_mean_squared_error: 8.2607
# Epoch 39/100
# 28/28 [==============================] - 5s 182ms/step - loss: 51.2615 - mean_squared_error: 51.2615 - mean_absolute_error: 3.5270 - root_mean_squared_error: 7.1597 - val_loss: 68.3078 - val_mean_squared_error: 68.3078 - val_mean_absolute_error: 3.8382 - val_root_mean_squared_error: 8.2649
# Epoch 40/100
# 28/28 [==============================] - 5s 192ms/step - loss: 52.6464 - mean_squared_error: 52.6464 - mean_absolute_error: 3.5643 - root_mean_squared_error: 7.2558 - val_loss: 70.6256 - val_mean_squared_error: 70.6256 - val_mean_absolute_error: 3.8879 - val_root_mean_squared_error: 8.4039
# Epoch 41/100
# 28/28 [==============================] - 6s 200ms/step - loss: 52.0739 - mean_squared_error: 52.0739 - mean_absolute_error: 3.6008 - root_mean_squared_error: 7.2162 - val_loss: 81.8286 - val_mean_squared_error: 81.8286 - val_mean_absolute_error: 4.5568 - val_root_mean_squared_error: 9.0459
# Epoch 42/100
# 28/28 [==============================] - 5s 191ms/step - loss: 49.5203 - mean_squared_error: 49.5203 - mean_absolute_error: 3.4608 - root_mean_squared_error: 7.0371 - val_loss: 80.7095 - val_mean_squared_error: 80.7095 - val_mean_absolute_error: 4.5385 - val_root_mean_squared_error: 8.9838
# Epoch 43/100
# 28/28 [==============================] - 6s 219ms/step - loss: 52.6067 - mean_squared_error: 52.6067 - mean_absolute_error: 3.5392 - root_mean_squared_error: 7.2530 - val_loss: 79.4404 - val_mean_squared_error: 79.4404 - val_mean_absolute_error: 4.5301 - val_root_mean_squared_error: 8.9129
# Epoch 44/100
# 28/28 [==============================] - 5s 187ms/step - loss: 50.9940 - mean_squared_error: 50.9940 - mean_absolute_error: 3.5368 - root_mean_squared_error: 7.1410 - val_loss: 66.3596 - val_mean_squared_error: 66.3597 - val_mean_absolute_error: 3.9082 - val_root_mean_squared_error: 8.1461
# Epoch 45/100
# 28/28 [==============================] - 6s 218ms/step - loss: 50.9785 - mean_squared_error: 50.9785 - mean_absolute_error: 3.5102 - root_mean_squared_error: 7.1399 - val_loss: 67.9324 - val_mean_squared_error: 67.9324 - val_mean_absolute_error: 3.9222 - val_root_mean_squared_error: 8.2421
# Epoch 46/100
# 28/28 [==============================] - 5s 184ms/step - loss: 49.1360 - mean_squared_error: 49.1360 - mean_absolute_error: 3.4860 - root_mean_squared_error: 7.0097 - val_loss: 70.9405 - val_mean_squared_error: 70.9405 - val_mean_absolute_error: 4.1053 - val_root_mean_squared_error: 8.4226
# Epoch 47/100
# 28/28 [==============================] - 6s 210ms/step - loss: 47.4789 - mean_squared_error: 47.4789 - mean_absolute_error: 3.3776 - root_mean_squared_error: 6.8905 - val_loss: 69.1097 - val_mean_squared_error: 69.1097 - val_mean_absolute_error: 3.8885 - val_root_mean_squared_error: 8.3132
# Epoch 48/100
# 28/28 [==============================] - 6s 199ms/step - loss: 48.1430 - mean_squared_error: 48.1430 - mean_absolute_error: 3.4035 - root_mean_squared_error: 6.9385 - val_loss: 66.3974 - val_mean_squared_error: 66.3974 - val_mean_absolute_error: 3.8881 - val_root_mean_squared_error: 8.1485
# Epoch 49/100
# 28/28 [==============================] - 5s 181ms/step - loss: 49.4152 - mean_squared_error: 49.4152 - mean_absolute_error: 3.4522 - root_mean_squared_error: 7.0296 - val_loss: 67.1629 - val_mean_squared_error: 67.1629 - val_mean_absolute_error: 3.7994 - val_root_mean_squared_error: 8.1953
# Epoch 50/100
# 28/28 [==============================] - 6s 215ms/step - loss: 48.5108 - mean_squared_error: 48.5108 - mean_absolute_error: 3.4950 - root_mean_squared_error: 6.9650 - val_loss: 66.5231 - val_mean_squared_error: 66.5231 - val_mean_absolute_error: 3.7651 - val_root_mean_squared_error: 8.1562
# Epoch 51/100
# 28/28 [==============================] - 5s 187ms/step - loss: 51.0695 - mean_squared_error: 51.0695 - mean_absolute_error: 3.5208 - root_mean_squared_error: 7.1463 - val_loss: 66.4848 - val_mean_squared_error: 66.4848 - val_mean_absolute_error: 3.8748 - val_root_mean_squared_error: 8.1538
# Epoch 52/100
# 28/28 [==============================] - 6s 224ms/step - loss: 50.4041 - mean_squared_error: 50.4041 - mean_absolute_error: 3.5253 - root_mean_squared_error: 7.0996 - val_loss: 64.9267 - val_mean_squared_error: 64.9267 - val_mean_absolute_error: 3.8637 - val_root_mean_squared_error: 8.0577
# Epoch 53/100
# 28/28 [==============================] - 5s 184ms/step - loss: 51.6318 - mean_squared_error: 51.6318 - mean_absolute_error: 3.5836 - root_mean_squared_error: 7.1855 - val_loss: 71.1082 - val_mean_squared_error: 71.1082 - val_mean_absolute_error: 4.1168 - val_root_mean_squared_error: 8.4326
# Epoch 54/100
# 28/28 [==============================] - 6s 212ms/step - loss: 52.7363 - mean_squared_error: 52.7363 - mean_absolute_error: 3.5787 - root_mean_squared_error: 7.2620 - val_loss: 81.8215 - val_mean_squared_error: 81.8215 - val_mean_absolute_error: 4.5128 - val_root_mean_squared_error: 9.0455
# Epoch 55/100
# 28/28 [==============================] - 5s 195ms/step - loss: 52.6819 - mean_squared_error: 52.6819 - mean_absolute_error: 3.5885 - root_mean_squared_error: 7.2582 - val_loss: 70.1436 - val_mean_squared_error: 70.1436 - val_mean_absolute_error: 4.0974 - val_root_mean_squared_error: 8.3752
# Epoch 56/100
# 28/28 [==============================] - 5s 190ms/step - loss: 50.4144 - mean_squared_error: 50.4144 - mean_absolute_error: 3.4863 - root_mean_squared_error: 7.1003 - val_loss: 67.9540 - val_mean_squared_error: 67.9540 - val_mean_absolute_error: 3.8428 - val_root_mean_squared_error: 8.2434
# Epoch 57/100
# 28/28 [==============================] - 6s 202ms/step - loss: 49.6525 - mean_squared_error: 49.6525 - mean_absolute_error: 3.4658 - root_mean_squared_error: 7.0465 - val_loss: 63.5295 - val_mean_squared_error: 63.5295 - val_mean_absolute_error: 3.8523 - val_root_mean_squared_error: 7.9705
# Epoch 58/100
# 28/28 [==============================] - 5s 191ms/step - loss: 50.3026 - mean_squared_error: 50.3026 - mean_absolute_error: 3.4957 - root_mean_squared_error: 7.0924 - val_loss: 66.4386 - val_mean_squared_error: 66.4387 - val_mean_absolute_error: 3.9107 - val_root_mean_squared_error: 8.1510
# Epoch 59/100
# 28/28 [==============================] - 6s 221ms/step - loss: 47.7462 - mean_squared_error: 47.7462 - mean_absolute_error: 3.3600 - root_mean_squared_error: 6.9099 - val_loss: 77.4493 - val_mean_squared_error: 77.4493 - val_mean_absolute_error: 4.4249 - val_root_mean_squared_error: 8.8005
# Epoch 60/100
# 28/28 [==============================] - 5s 189ms/step - loss: 51.5311 - mean_squared_error: 51.5311 - mean_absolute_error: 3.5594 - root_mean_squared_error: 7.1785 - val_loss: 62.9730 - val_mean_squared_error: 62.9730 - val_mean_absolute_error: 3.7607 - val_root_mean_squared_error: 7.9356
# Epoch 61/100
# 28/28 [==============================] - 6s 225ms/step - loss: 48.0432 - mean_squared_error: 48.0432 - mean_absolute_error: 3.4273 - root_mean_squared_error: 6.9313 - val_loss: 63.5840 - val_mean_squared_error: 63.5840 - val_mean_absolute_error: 3.7081 - val_root_mean_squared_error: 7.9740
# Epoch 62/100
# 28/28 [==============================] - 5s 187ms/step - loss: 45.7849 - mean_squared_error: 45.7849 - mean_absolute_error: 3.3004 - root_mean_squared_error: 6.7665 - val_loss: 65.7526 - val_mean_squared_error: 65.7526 - val_mean_absolute_error: 3.7828 - val_root_mean_squared_error: 8.1088
# Epoch 63/100
# 28/28 [==============================] - 6s 215ms/step - loss: 45.8426 - mean_squared_error: 45.8426 - mean_absolute_error: 3.3430 - root_mean_squared_error: 6.7707 - val_loss: 69.0752 - val_mean_squared_error: 69.0752 - val_mean_absolute_error: 3.9767 - val_root_mean_squared_error: 8.3112
# Epoch 64/100
# 28/28 [==============================] - 5s 187ms/step - loss: 46.0499 - mean_squared_error: 46.0499 - mean_absolute_error: 3.3338 - root_mean_squared_error: 6.7860 - val_loss: 67.4711 - val_mean_squared_error: 67.4711 - val_mean_absolute_error: 3.8659 - val_root_mean_squared_error: 8.2141
# Epoch 65/100
# 28/28 [==============================] - 5s 198ms/step - loss: 45.8316 - mean_squared_error: 45.8316 - mean_absolute_error: 3.3191 - root_mean_squared_error: 6.7699 - val_loss: 69.3034 - val_mean_squared_error: 69.3034 - val_mean_absolute_error: 3.9058 - val_root_mean_squared_error: 8.3249
# Epoch 66/100
# 28/28 [==============================] - 6s 209ms/step - loss: 46.2234 - mean_squared_error: 46.2234 - mean_absolute_error: 3.3255 - root_mean_squared_error: 6.7988 - val_loss: 68.9514 - val_mean_squared_error: 68.9514 - val_mean_absolute_error: 4.0410 - val_root_mean_squared_error: 8.3037
# Epoch 67/100
# 28/28 [==============================] - 5s 193ms/step - loss: 46.8340 - mean_squared_error: 46.8340 - mean_absolute_error: 3.3377 - root_mean_squared_error: 6.8435 - val_loss: 64.2650 - val_mean_squared_error: 64.2650 - val_mean_absolute_error: 3.7887 - val_root_mean_squared_error: 8.0165
# Epoch 68/100
# 28/28 [==============================] - 6s 214ms/step - loss: 46.3887 - mean_squared_error: 46.3887 - mean_absolute_error: 3.3489 - root_mean_squared_error: 6.8109 - val_loss: 69.9599 - val_mean_squared_error: 69.9599 - val_mean_absolute_error: 3.9723 - val_root_mean_squared_error: 8.3642
# Epoch 69/100
# 28/28 [==============================] - 5s 195ms/step - loss: 44.7928 - mean_squared_error: 44.7928 - mean_absolute_error: 3.2676 - root_mean_squared_error: 6.6927 - val_loss: 64.0886 - val_mean_squared_error: 64.0886 - val_mean_absolute_error: 3.7911 - val_root_mean_squared_error: 8.0055
# Epoch 70/100
# 28/28 [==============================] - 6s 218ms/step - loss: 44.2616 - mean_squared_error: 44.2616 - mean_absolute_error: 3.2689 - root_mean_squared_error: 6.6529 - val_loss: 63.1467 - val_mean_squared_error: 63.1467 - val_mean_absolute_error: 3.7535 - val_root_mean_squared_error: 7.9465
# Epoch 71/100
# 28/28 [==============================] - 5s 196ms/step - loss: 46.0877 - mean_squared_error: 46.0877 - mean_absolute_error: 3.3607 - root_mean_squared_error: 6.7888 - val_loss: 63.8494 - val_mean_squared_error: 63.8493 - val_mean_absolute_error: 3.9108 - val_root_mean_squared_error: 7.9906
# Epoch 72/100
# 28/28 [==============================] - 5s 194ms/step - loss: 46.2180 - mean_squared_error: 46.2180 - mean_absolute_error: 3.3738 - root_mean_squared_error: 6.7984 - val_loss: 67.4470 - val_mean_squared_error: 67.4471 - val_mean_absolute_error: 3.9321 - val_root_mean_squared_error: 8.2126
# Epoch 73/100
# 28/28 [==============================] - 6s 196ms/step - loss: 43.8401 - mean_squared_error: 43.8401 - mean_absolute_error: 3.2775 - root_mean_squared_error: 6.6212 - val_loss: 67.4898 - val_mean_squared_error: 67.4898 - val_mean_absolute_error: 3.8400 - val_root_mean_squared_error: 8.2152
# Epoch 74/100
# 28/28 [==============================] - 5s 183ms/step - loss: 46.8143 - mean_squared_error: 46.8143 - mean_absolute_error: 3.3871 - root_mean_squared_error: 6.8421 - val_loss: 65.7374 - val_mean_squared_error: 65.7374 - val_mean_absolute_error: 3.8499 - val_root_mean_squared_error: 8.1079
# Epoch 75/100
# 28/28 [==============================] - 6s 221ms/step - loss: 43.7032 - mean_squared_error: 43.7032 - mean_absolute_error: 3.2527 - root_mean_squared_error: 6.6108 - val_loss: 61.4716 - val_mean_squared_error: 61.4716 - val_mean_absolute_error: 3.7338 - val_root_mean_squared_error: 7.8404
# Epoch 76/100
# 28/28 [==============================] - 6s 199ms/step - loss: 44.6404 - mean_squared_error: 44.6404 - mean_absolute_error: 3.3229 - root_mean_squared_error: 6.6814 - val_loss: 66.0204 - val_mean_squared_error: 66.0204 - val_mean_absolute_error: 3.8661 - val_root_mean_squared_error: 8.1253
# Epoch 77/100
# 28/28 [==============================] - 6s 218ms/step - loss: 44.6115 - mean_squared_error: 44.6115 - mean_absolute_error: 3.2717 - root_mean_squared_error: 6.6792 - val_loss: 62.1263 - val_mean_squared_error: 62.1263 - val_mean_absolute_error: 3.8216 - val_root_mean_squared_error: 7.8820
# Epoch 78/100
# 28/28 [==============================] - 5s 186ms/step - loss: 45.9072 - mean_squared_error: 45.9072 - mean_absolute_error: 3.3772 - root_mean_squared_error: 6.7755 - val_loss: 63.8774 - val_mean_squared_error: 63.8774 - val_mean_absolute_error: 3.8671 - val_root_mean_squared_error: 7.9923
# Epoch 79/100
# 28/28 [==============================] - 6s 222ms/step - loss: 47.0849 - mean_squared_error: 47.0849 - mean_absolute_error: 3.4406 - root_mean_squared_error: 6.8618 - val_loss: 66.1982 - val_mean_squared_error: 66.1982 - val_mean_absolute_error: 3.9174 - val_root_mean_squared_error: 8.1362
# Epoch 80/100
# 28/28 [==============================] - 5s 183ms/step - loss: 45.4570 - mean_squared_error: 45.4570 - mean_absolute_error: 3.2969 - root_mean_squared_error: 6.7422 - val_loss: 68.3900 - val_mean_squared_error: 68.3900 - val_mean_absolute_error: 3.9626 - val_root_mean_squared_error: 8.2698
# Epoch 81/100
# 28/28 [==============================] - 6s 206ms/step - loss: 46.8195 - mean_squared_error: 46.8195 - mean_absolute_error: 3.3778 - root_mean_squared_error: 6.8425 - val_loss: 66.7115 - val_mean_squared_error: 66.7115 - val_mean_absolute_error: 3.8407 - val_root_mean_squared_error: 8.1677
# Epoch 82/100
# 28/28 [==============================] - 6s 199ms/step - loss: 44.3960 - mean_squared_error: 44.3960 - mean_absolute_error: 3.3242 - root_mean_squared_error: 6.6630 - val_loss: 66.7228 - val_mean_squared_error: 66.7228 - val_mean_absolute_error: 3.8451 - val_root_mean_squared_error: 8.1684
# Epoch 83/100
# 28/28 [==============================] - 6s 199ms/step - loss: 45.4912 - mean_squared_error: 45.4912 - mean_absolute_error: 3.3121 - root_mean_squared_error: 6.7447 - val_loss: 64.1097 - val_mean_squared_error: 64.1097 - val_mean_absolute_error: 3.8581 - val_root_mean_squared_error: 8.0069
# Epoch 84/100
# 28/28 [==============================] - 6s 228ms/step - loss: 44.9455 - mean_squared_error: 44.9455 - mean_absolute_error: 3.3342 - root_mean_squared_error: 6.7041 - val_loss: 74.8899 - val_mean_squared_error: 74.8899 - val_mean_absolute_error: 4.3766 - val_root_mean_squared_error: 8.6539
# Epoch 85/100
# 28/28 [==============================] - 6s 203ms/step - loss: 44.9001 - mean_squared_error: 44.9001 - mean_absolute_error: 3.3476 - root_mean_squared_error: 6.7008 - val_loss: 66.1207 - val_mean_squared_error: 66.1207 - val_mean_absolute_error: 3.9805 - val_root_mean_squared_error: 8.1315
# Epoch 86/100
# 28/28 [==============================] - 6s 223ms/step - loss: 46.2588 - mean_squared_error: 46.2588 - mean_absolute_error: 3.3498 - root_mean_squared_error: 6.8014 - val_loss: 84.4047 - val_mean_squared_error: 84.4047 - val_mean_absolute_error: 4.7052 - val_root_mean_squared_error: 9.1872
# Epoch 87/100
# 28/28 [==============================] - 6s 200ms/step - loss: 46.7938 - mean_squared_error: 46.7938 - mean_absolute_error: 3.4114 - root_mean_squared_error: 6.8406 - val_loss: 76.7403 - val_mean_squared_error: 76.7403 - val_mean_absolute_error: 4.2016 - val_root_mean_squared_error: 8.7602
# Epoch 88/100
# 28/28 [==============================] - 6s 230ms/step - loss: 45.8711 - mean_squared_error: 45.8711 - mean_absolute_error: 3.3164 - root_mean_squared_error: 6.7728 - val_loss: 75.3781 - val_mean_squared_error: 75.3781 - val_mean_absolute_error: 4.3314 - val_root_mean_squared_error: 8.6821
# Epoch 89/100
# 28/28 [==============================] - 5s 195ms/step - loss: 44.7922 - mean_squared_error: 44.7922 - mean_absolute_error: 3.2935 - root_mean_squared_error: 6.6927 - val_loss: 64.6793 - val_mean_squared_error: 64.6793 - val_mean_absolute_error: 3.8670 - val_root_mean_squared_error: 8.0423
# Epoch 90/100
# 28/28 [==============================] - 6s 227ms/step - loss: 44.5959 - mean_squared_error: 44.5959 - mean_absolute_error: 3.3033 - root_mean_squared_error: 6.6780 - val_loss: 64.5412 - val_mean_squared_error: 64.5412 - val_mean_absolute_error: 3.8591 - val_root_mean_squared_error: 8.0338
# Epoch 91/100
# 28/28 [==============================] - 5s 190ms/step - loss: 43.4816 - mean_squared_error: 43.4815 - mean_absolute_error: 3.2485 - root_mean_squared_error: 6.5941 - val_loss: 63.8293 - val_mean_squared_error: 63.8293 - val_mean_absolute_error: 3.8301 - val_root_mean_squared_error: 7.9893
# Epoch 92/100
# 28/28 [==============================] - 6s 203ms/step - loss: 44.7911 - mean_squared_error: 44.7911 - mean_absolute_error: 3.3014 - root_mean_squared_error: 6.6926 - val_loss: 68.0082 - val_mean_squared_error: 68.0082 - val_mean_absolute_error: 3.8834 - val_root_mean_squared_error: 8.2467
# Epoch 93/100
# 28/28 [==============================] - 6s 206ms/step - loss: 43.6029 - mean_squared_error: 43.6029 - mean_absolute_error: 3.3184 - root_mean_squared_error: 6.6032 - val_loss: 71.7063 - val_mean_squared_error: 71.7063 - val_mean_absolute_error: 3.9696 - val_root_mean_squared_error: 8.4680
# Epoch 94/100
# 28/28 [==============================] - 5s 189ms/step - loss: 44.3926 - mean_squared_error: 44.3926 - mean_absolute_error: 3.2974 - root_mean_squared_error: 6.6628 - val_loss: 72.8381 - val_mean_squared_error: 72.8381 - val_mean_absolute_error: 3.9438 - val_root_mean_squared_error: 8.5345
# Epoch 95/100
# 28/28 [==============================] - 6s 218ms/step - loss: 44.0621 - mean_squared_error: 44.0621 - mean_absolute_error: 3.2596 - root_mean_squared_error: 6.6379 - val_loss: 64.2374 - val_mean_squared_error: 64.2374 - val_mean_absolute_error: 3.9195 - val_root_mean_squared_error: 8.0148
# Epoch 96/100
# 28/28 [==============================] - 6s 198ms/step - loss: 43.6544 - mean_squared_error: 43.6544 - mean_absolute_error: 3.2997 - root_mean_squared_error: 6.6071 - val_loss: 68.6749 - val_mean_squared_error: 68.6749 - val_mean_absolute_error: 4.0291 - val_root_mean_squared_error: 8.2870
# Epoch 97/100
# 28/28 [==============================] - 6s 224ms/step - loss: 51.5006 - mean_squared_error: 51.5006 - mean_absolute_error: 3.7081 - root_mean_squared_error: 7.1764 - val_loss: 92.3233 - val_mean_squared_error: 92.3233 - val_mean_absolute_error: 4.6981 - val_root_mean_squared_error: 9.6085
# Epoch 98/100
# 28/28 [==============================] - 6s 201ms/step - loss: 58.7817 - mean_squared_error: 58.7817 - mean_absolute_error: 3.8043 - root_mean_squared_error: 7.6669 - val_loss: 76.3651 - val_mean_squared_error: 76.3651 - val_mean_absolute_error: 4.4861 - val_root_mean_squared_error: 8.7387
# Epoch 99/100
# 28/28 [==============================] - 6s 227ms/step - loss: 48.2173 - mean_squared_error: 48.2173 - mean_absolute_error: 3.4634 - root_mean_squared_error: 6.9439 - val_loss: 75.4752 - val_mean_squared_error: 75.4752 - val_mean_absolute_error: 4.3042 - val_root_mean_squared_error: 8.6876
# Epoch 100/100
# 28/28 [==============================] - 6s 200ms/step - loss: 46.0863 - mean_squared_error: 46.0863 - mean_absolute_error: 3.3600 - root_mean_squared_error: 6.7887 - val_loss: 69.0179 - val_mean_squared_error: 69.0179 - val_mean_absolute_error: 4.0679 - val_root_mean_squared_error: 8.3077

# %% [markdown]
# # Training results

# %%
from utils.plotting import training_loss_plot

if not in_google_colab():
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

plot = training_loss_plot(train_score, filename='download/training_loss.pdf')
plot.show()

# %% [markdown]
# # Testing

# %%
### Predict on the test set
from utils.evaluation import phases_report, phases_report_std

print('Testmetriken:')

report = phases_report(y_pred, bis.test_dataset, propofolrate.test_dataset)
report
# Out:
# Testmetriken:
#             Prediction MSE Baseline MSE Prediction MAE Baseline MAE  \
# All                 123.26       139.87           8.74         7.55
# Induction           284.44       637.60          12.64        18.34
# Maintenance          93.29        60.90           7.96         5.68
# Recovery            216.11       361.57          11.24        13.46
#
#             Prediction RMSE Baseline RMSE
# All                   11.10         11.83
# Induction             16.87         25.25
# Maintenance            9.66          7.80
# Recovery              14.70         19.02

# %%
phases_report_std(report, y_pred, bis.test_dataset, propofolrate.test_dataset)
# Out:
# All      	min: 	 15 	max: 	 6
# Induction 	min: 	 23 	max: 	 10
# Maintenance 	min: 	 13 	max: 	 6
# Recovery 	min: 	 19 	max: 	 22
#              Prediction MSE  Baseline MSE  Prediction MAE  Baseline MAE  \
# All                   48.62         82.42            1.64          2.54
# Induction            269.57        403.81            5.94          8.45
# Maintenance           37.18         43.11            1.81          2.15
# Recovery             121.64        185.95            3.74          6.28
#
#              Prediction RMSE  Baseline RMSE
# All                     2.08           3.31
# Induction               6.37           7.29
# Maintenance             1.97           2.51
# Recovery                4.84           6.47

# %%
from utils.plotting import full_histogramm_plot

plot = full_histogramm_plot(groundtruth = bis.test_dataset, prediction = y_pred, filename='download/histogramm.pdf')
plot.show()

# %%
from utils.plotting import single_prediction_plot

for case in test_index:
    single_prediction_plot(
        case = case,
        index = test_index,
        groundtruth = bis.test_dataset,
        prediction = y_pred,
        infusion = propofolrate.test_dataset,
        error = 'Prediction RMSE',
        filename = 'download/' + str(case) + '.pdf')

print('Finished')
# Out:
# /content/utils/plotting.py:79: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(12/2.54, 6/2.54))
# Finished

# %%
from utils.plotting import full_prediction_plot

full_prediction_plot(index = test_index, groundtruth = bis.test_dataset, prediction = y_pred, infusion = propofolrate.test_dataset)
