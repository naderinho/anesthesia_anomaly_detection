# %% [markdown]
# # Initialization

# %%
# !pip uninstall tensorflow keras tf-keras -y
# !pip install tensorflow==2.15.0
# !pip install tf-keras==2.15.1
# !pip install keras==2.15.0
# Out:
# Found existing installation: tensorflow 2.17.0
# Uninstalling tensorflow-2.17.0:
#   Successfully uninstalled tensorflow-2.17.0
# Found existing installation: keras 3.4.1
# Uninstalling keras-3.4.1:
#   Successfully uninstalled keras-3.4.1
# Found existing installation: tf_keras 2.17.0
# Uninstalling tf_keras-2.17.0:
#   Successfully uninstalled tf_keras-2.17.0
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15.0)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.64.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)
# Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.4 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 47.5 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 36.6 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 45.5 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 21.6 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.0
#     Uninstalling ml-dtypes-0.4.0:
#       Successfully uninstalled ml-dtypes-0.4.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.64 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.2.0 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 wrapt-1.14.1
# Collecting tf-keras==2.15.1
#   Downloading tf_keras-2.15.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tensorflow<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tf-keras==2.15.1) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras==2.15.1) (3.2.2)
# Downloading tf_keras-2.15.1-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 63.5 MB/s eta 0:00:00
# Installing collected packages: tf-keras
# Successfully installed tf-keras-2.15.1
# Requirement already satisfied: keras==2.15.0 in /usr/local/lib/python3.10/dist-packages (2.15.0)

# %%
import tensorflow as tf

### Configuration
create_dataset = False

def in_google_colab():
    """Checks if the code is running in Google Colab

    Returns:
        bool: _description_
    """
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_google_colab():
    print("Running in Google Colab")
    # Install necessary packages in Google Colab
    # !rm -r sample_data/
    # !git clone https://github.com/naderinho/anesthesia_anomaly_detection
    # !cp -r anesthesia_anomaly_detection/* .
    # !rm -r anesthesia_anomaly_detection/
    # !pip install vitaldb
    create_dataset = False
else:
    print("Running locally")

### Datasetpath
directory = 'data/'
datasetpath = 'dataset03/'
vitaldbpath = 'vitaldb_sevofl/'

### Import the necessary libraries
import numpy as np
import pandas as pd
import vitaldb as vf
import matplotlib.pyplot as plt
import pickle

### Custom functions
import modules as md
# Out:
# Running in Google Colab
# Cloning into 'anesthesia_anomaly_detection'...
# remote: Enumerating objects: 1241, done.
# remote: Counting objects: 100% (278/278), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 1241 (delta 193), reused 257 (delta 178), pack-reused 963 (from 1)
# Receiving objects: 100% (1241/1241), 259.46 MiB | 16.13 MiB/s, done.
# Resolving deltas: 100% (724/724), done.
# Updating files: 100% (607/607), done.
# Collecting vitaldb
#   Downloading vitaldb-1.4.9-py3-none-any.whl.metadata (520 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vitaldb) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vitaldb) (2.32.3)
# Collecting wfdb (from vitaldb)
#   Downloading wfdb-4.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vitaldb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vitaldb) (2024.7.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (3.7.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb->vitaldb) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb->vitaldb) (3.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vitaldb) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb->vitaldb) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb->vitaldb) (2.22)
# Downloading vitaldb-1.4.9-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.6 MB/s eta 0:00:00
# Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 13.4 MB/s eta 0:00:00
# Installing collected packages: wfdb, vitaldb
# Successfully installed vitaldb-1.4.9 wfdb-4.1.2

# %% [markdown]
# # Data loading

# %%
###### Create Dataset
if create_dataset:
    bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bis.name = 'Bispektralindex'
    bis.tracks = ['BIS/BIS']
    bis.filter = [20, 10, 100]
    bis.generateDataset(normalization=md.NormNone)
    bis.save('00_bis.npz')

    info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    info.generateDataset(normalization=md.NormStandard)
    info.save('01_info.npz')

    bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    bloodpressure.name = 'bloodpressure'
    bloodpressure.tracks = ['Solar8000/ART_DBP', 'Solar8000/ART_MBP', 'Solar8000/ART_SBP']
    bloodpressure.filter = [20, 20, 250]
    bloodpressure.generateDataset(normalization=md.NormStandard)
    bloodpressure.save('02_bloodpressure.npz')

    etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    etCO2.name = 'End Tidal CO2'
    etCO2.tracks = ['Primus/ETCO2']
    etCO2.filter = [5, 15, 50]
    etCO2.generateDataset(normalization=md.NormStandard)
    etCO2.save('02_etCO2.npz')

    spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    spO2.name = 'SpO2'
    spO2.tracks = ['Solar8000/PLETH_SPO2']
    spO2.filter = [3, 80, 100]
    spO2.generateDataset(normalization=md.NormStandard)
    spO2.save('02_spO2.npz')

    hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    hr.name = 'Heart Rate'
    hr.tracks = ['Solar8000/HR']
    hr.filter = [20, 40, 180]
    hr.generateDataset(normalization=md.NormStandard)
    hr.save('02_hr.npz')

    mac = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
    mac.name = 'MAC'
    mac.tracks = ['Primus/MAC']
    mac.filterON = False
    mac.generateDataset(normalization=md.NormNone)
    mac.save('03_mac.npz')

### Load the datasets
bis = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bis.load('00_bis.npz')

info = md.infoImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
info.load('01_info.npz')

bloodpressure = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
bloodpressure.load('02_bloodpressure.npz')

etCO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
etCO2.load('02_etCO2.npz')

spO2 = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
spO2.load('02_spO2.npz')

hr = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
hr.load('02_hr.npz')

mac = md.VitalImport(directory= directory, dataset=datasetpath, vitalpath=vitaldbpath)
mac.load('03_mac.npz')


train_index, val_index, test_index = bis.split(np.array(bis.index))

# %% [markdown]
# # Model creation

# %%
########################################## COMBINED MODEL ##########################################
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, ReLU, Dropout, Concatenate, Masking, Conv1D, MaxPooling1D, BatchNormalization, RepeatVector, Lambda
from tensorflow.keras.metrics import RootMeanSquaredError, MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError

### Blood Pressure Input
input_bp = Input(shape=(None, bloodpressure.train_dataset.shape[2]))
bp_layer = Masking(mask_value=0.0)(input_bp)

bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=128, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=64, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=16, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = LSTM(units=16, return_sequences=True)(bp_layer)
bp_layer = BatchNormalization()(bp_layer)
bp_layer = Dense(units=16, activation='linear')(bp_layer)

### etCO2 Input
input_co2 = Input(shape=(None, etCO2.train_dataset.shape[2]))

co2_layer = LSTM(units=64, return_sequences=True)(input_co2)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=64, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=64, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=16, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = LSTM(units=8, return_sequences=True)(co2_layer)
co2_layer = BatchNormalization()(co2_layer)
co2_layer = Dense(units=8, activation='linear')(co2_layer)

### spo2 Input
input_spo2 = Input(shape=(None, spO2.train_dataset.shape[2]))

spo2_layer = LSTM(units=64, return_sequences=True)(input_spo2)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=64, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=64, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=16, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = LSTM(units=8, return_sequences=True)(spo2_layer)
spo2_layer = BatchNormalization()(spo2_layer)
spo2_layer = Dense(units=8, activation='linear')(spo2_layer)

### INFO layers
input_info = Input(shape=(info.train_dataset.shape[1],))
info_layer = RepeatVector(bloodpressure.train_dataset.shape[1])(input_info)
info_layer = Dense(units=16, activation='linear')(info_layer)
info_layer = Dense(units=16, activation='sigmoid')(info_layer)


## Concatenate the Sevoflurane output with the info layer
comb_layer = Concatenate()([bp_layer, co2_layer, spo2_layer, info_layer])
comb_layer = Dense(units=64, activation='linear')(comb_layer)
comb_layer = Dense(units=64, activation='relu')(comb_layer)
comb_layer = Dense(units=64, activation='relu')(comb_layer)
comb_layer = Dense(units=32, activation='relu')(comb_layer)
comb_layer = Dense(units=16, activation='relu')(comb_layer)
comb_layer = Dense(units=1, activation=ReLU(max_value=1.0))(comb_layer)
output = Lambda(lambda x: x * 100)(comb_layer)

# Define the model
model = Model(inputs=[input_bp, input_co2, input_spo2, input_info], outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.0005)

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['MeanSquaredError','MeanAbsoluteError','RootMeanSquaredError']
              )

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 3)]            0         []
#
#  masking (Masking)           (None, None, 3)              0         ['input_1[0][0]']
#
#  lstm (LSTM)                 (None, None, 64)             17408     ['masking[0][0]']
#
#  batch_normalization (Batch  (None, None, 64)             256       ['lstm[0][0]']
#  Normalization)
#
#  lstm_1 (LSTM)               (None, None, 64)             33024     ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, None, 64)             256       ['lstm_1[0][0]']
#  chNormalization)
#
#  lstm_2 (LSTM)               (None, None, 64)             33024     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, None, 64)             256       ['lstm_2[0][0]']
#  chNormalization)
#
#  input_2 (InputLayer)        [(None, None, 1)]            0         []
#
#  input_3 (InputLayer)        [(None, None, 1)]            0         []
#
#  lstm_3 (LSTM)               (None, None, 64)             33024     ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  lstm_8 (LSTM)               (None, None, 64)             16896     ['input_2[0][0]']
#
#  lstm_13 (LSTM)              (None, None, 64)             16896     ['input_3[0][0]']
#
#  batch_normalization_3 (Bat  (None, None, 64)             256       ['lstm_3[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, None, 64)             256       ['lstm_8[0][0]']
#  chNormalization)
#
#  batch_normalization_13 (Ba  (None, None, 64)             256       ['lstm_13[0][0]']
#  tchNormalization)
#
#  lstm_4 (LSTM)               (None, None, 128)            98816     ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  lstm_9 (LSTM)               (None, None, 64)             33024     ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  lstm_14 (LSTM)              (None, None, 64)             33024     ['batch_normalization_13[0][0]
#                                                                     ']
#
#  batch_normalization_4 (Bat  (None, None, 128)            512       ['lstm_4[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, None, 64)             256       ['lstm_9[0][0]']
#  chNormalization)
#
#  batch_normalization_14 (Ba  (None, None, 64)             256       ['lstm_14[0][0]']
#  tchNormalization)
#
#  lstm_5 (LSTM)               (None, None, 64)             49408     ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  lstm_10 (LSTM)              (None, None, 64)             33024     ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  lstm_15 (LSTM)              (None, None, 64)             33024     ['batch_normalization_14[0][0]
#                                                                     ']
#
#  batch_normalization_5 (Bat  (None, None, 64)             256       ['lstm_5[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, None, 64)             256       ['lstm_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, None, 64)             256       ['lstm_15[0][0]']
#  tchNormalization)
#
#  lstm_6 (LSTM)               (None, None, 16)             5184      ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  lstm_11 (LSTM)              (None, None, 16)             5184      ['batch_normalization_10[0][0]
#                                                                     ']
#
#  lstm_16 (LSTM)              (None, None, 16)             5184      ['batch_normalization_15[0][0]
#                                                                     ']
#
#  batch_normalization_6 (Bat  (None, None, 16)             64        ['lstm_6[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, None, 16)             64        ['lstm_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, None, 16)             64        ['lstm_16[0][0]']
#  tchNormalization)
#
#  input_4 (InputLayer)        [(None, 5)]                  0         []
#
#  lstm_7 (LSTM)               (None, None, 16)             2112      ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  lstm_12 (LSTM)              (None, None, 8)              800       ['batch_normalization_11[0][0]
#                                                                     ']
#
#  lstm_17 (LSTM)              (None, None, 8)              800       ['batch_normalization_16[0][0]
#                                                                     ']
#
#  repeat_vector (RepeatVecto  (None, 3744, 5)              0         ['input_4[0][0]']
#  r)
#
#  batch_normalization_7 (Bat  (None, None, 16)             64        ['lstm_7[0][0]']
#  chNormalization)
#
#  batch_normalization_12 (Ba  (None, None, 8)              32        ['lstm_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, None, 8)              32        ['lstm_17[0][0]']
#  tchNormalization)
#
#  dense_3 (Dense)             (None, 3744, 16)             96        ['repeat_vector[0][0]']
#
#  dense (Dense)               (None, None, 16)             272       ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dense_1 (Dense)             (None, None, 8)              72        ['batch_normalization_12[0][0]
#                                                                     ']
#
#  dense_2 (Dense)             (None, None, 8)              72        ['batch_normalization_17[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 3744, 16)             272       ['dense_3[0][0]']
#
#  concatenate (Concatenate)   (None, 3744, 48)             0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 3744, 64)             3136      ['concatenate[0][0]']
#
#  dense_6 (Dense)             (None, 3744, 64)             4160      ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 3744, 64)             4160      ['dense_6[0][0]']
#
#  dense_8 (Dense)             (None, 3744, 32)             2080      ['dense_7[0][0]']
#
#  dense_9 (Dense)             (None, 3744, 16)             528       ['dense_8[0][0]']
#
#  dense_10 (Dense)            (None, 3744, 1)              17        ['dense_9[0][0]']
#
#  lambda (Lambda)             (None, 3744, 1)              0         ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 468369 (1.79 MB)
# Trainable params: 466545 (1.78 MB)
# Non-trainable params: 1824 (7.12 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %%
y_pred = model.predict([bloodpressure.test_dataset, etCO2.test_dataset, spO2.test_dataset, info.test_dataset], verbose=0)
with open('download/prediction.pkl', 'wb') as f:
    pickle.dump(y_pred, f)

# %%
# Rolling mean on BIS data
y = pd.DataFrame(bis.train_dataset[:,:,0].T).rolling(min_periods=1,window=3, center=True).mean().to_numpy().T[:,:,np.newaxis]

class SaveModelHistoryCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_interval, model_path, history_path):
        super(SaveModelHistoryCallback, self).__init__()
        self.save_interval = save_interval
        self.model_path = model_path
        self.history_path = history_path
        self.history = []

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.save_interval == 0:
            # Save model
            self.model.save(self.model_path.format(epoch=epoch+1))
            # Save history
            self.history.append(logs)
            with open(self.history_path.format(epoch=epoch+1), 'wb') as f:
                pickle.dump(self.history, f)

save_interval = 20
model_path = 'model_epoch_{epoch}.h5'
history_path = 'history_epoch_{epoch}.pkl'
save_model_history_callback = SaveModelHistoryCallback(save_interval, model_path, history_path)



if in_google_colab():
    # Train the model
    history = model.fit([bloodpressure.train_dataset, etCO2.train_dataset, spO2.train_dataset, info.train_dataset],
                        y,
                        validation_data=([bloodpressure.validation_dataset, etCO2.validation_dataset, spO2.validation_dataset, info.validation_dataset], bis.validation_dataset),
                        epochs=150,
                        callbacks=[save_model_history_callback],
                        batch_size=4
                        )

    train_score = history.history

    # Save the model
    model.save('download/model.keras')

    # Save the training history
    with open('download/train_score.pkl', 'wb') as f:
        pickle.dump(train_score, f)

    # Save the prediction
    y_pred = model.predict([bloodpressure.test_dataset, etCO2.test_dataset, spO2.test_dataset, info.test_dataset], verbose=0)
    with open('download/prediction.pkl', 'wb') as f:
        pickle.dump(y_pred, f)

else:
    # Load train score data
    with open('train_score.pkl', 'rb') as f:
        train_score = pickle.load(f)

    # Load test prediction data
    with open('prediction.pkl', 'rb') as f:
        y_pred = pickle.load(f)
# Out:
# Epoch 1/150
# 47/47 [==============================] - 131s 2s/step - loss: 219.8211 - mean_squared_error: 219.8210 - mean_absolute_error: 8.0321 - root_mean_squared_error: 14.8264 - val_loss: 507.2354 - val_mean_squared_error: 507.2354 - val_mean_absolute_error: 18.9608 - val_root_mean_squared_error: 22.5219
# Epoch 2/150
# 47/47 [==============================] - 60s 1s/step - loss: 86.6844 - mean_squared_error: 86.6845 - mean_absolute_error: 4.5979 - root_mean_squared_error: 9.3104 - val_loss: 414.2052 - val_mean_squared_error: 414.2052 - val_mean_absolute_error: 17.2283 - val_root_mean_squared_error: 20.3520
# Epoch 3/150
# 47/47 [==============================] - 58s 1s/step - loss: 73.1829 - mean_squared_error: 73.1829 - mean_absolute_error: 4.0891 - root_mean_squared_error: 8.5547 - val_loss: 265.0177 - val_mean_squared_error: 265.0177 - val_mean_absolute_error: 12.7083 - val_root_mean_squared_error: 16.2794
# Epoch 4/150
# 47/47 [==============================] - 65s 1s/step - loss: 61.0858 - mean_squared_error: 61.0858 - mean_absolute_error: 3.7493 - root_mean_squared_error: 7.8157 - val_loss: 138.5985 - val_mean_squared_error: 138.5985 - val_mean_absolute_error: 6.1237 - val_root_mean_squared_error: 11.7728
# Epoch 5/150
# 47/47 [==============================] - 64s 1s/step - loss: 58.6759 - mean_squared_error: 58.6759 - mean_absolute_error: 3.6636 - root_mean_squared_error: 7.6600 - val_loss: 123.8450 - val_mean_squared_error: 123.8450 - val_mean_absolute_error: 5.2916 - val_root_mean_squared_error: 11.1286
# Epoch 6/150
# 47/47 [==============================] - 64s 1s/step - loss: 55.6698 - mean_squared_error: 55.6698 - mean_absolute_error: 3.5328 - root_mean_squared_error: 7.4612 - val_loss: 96.4310 - val_mean_squared_error: 96.4310 - val_mean_absolute_error: 4.4872 - val_root_mean_squared_error: 9.8199
# Epoch 7/150
# 47/47 [==============================] - 59s 1s/step - loss: 53.5655 - mean_squared_error: 53.5655 - mean_absolute_error: 3.5110 - root_mean_squared_error: 7.3188 - val_loss: 77.7538 - val_mean_squared_error: 77.7538 - val_mean_absolute_error: 3.7950 - val_root_mean_squared_error: 8.8178
# Epoch 8/150
# 47/47 [==============================] - 59s 1s/step - loss: 53.3806 - mean_squared_error: 53.3806 - mean_absolute_error: 3.4987 - root_mean_squared_error: 7.3062 - val_loss: 64.4656 - val_mean_squared_error: 64.4656 - val_mean_absolute_error: 3.4844 - val_root_mean_squared_error: 8.0290
# Epoch 9/150
# 47/47 [==============================] - 59s 1s/step - loss: 51.7385 - mean_squared_error: 51.7385 - mean_absolute_error: 3.4283 - root_mean_squared_error: 7.1929 - val_loss: 60.7125 - val_mean_squared_error: 60.7125 - val_mean_absolute_error: 3.3347 - val_root_mean_squared_error: 7.7918
# Epoch 10/150
# 47/47 [==============================] - 59s 1s/step - loss: 50.1990 - mean_squared_error: 50.1990 - mean_absolute_error: 3.3769 - root_mean_squared_error: 7.0851 - val_loss: 71.9530 - val_mean_squared_error: 71.9530 - val_mean_absolute_error: 3.7436 - val_root_mean_squared_error: 8.4825
# Epoch 11/150
# 47/47 [==============================] - 65s 1s/step - loss: 48.4609 - mean_squared_error: 48.4609 - mean_absolute_error: 3.3257 - root_mean_squared_error: 6.9614 - val_loss: 55.9605 - val_mean_squared_error: 55.9605 - val_mean_absolute_error: 3.1930 - val_root_mean_squared_error: 7.4807
# Epoch 12/150
# 47/47 [==============================] - 64s 1s/step - loss: 47.6146 - mean_squared_error: 47.6146 - mean_absolute_error: 3.2659 - root_mean_squared_error: 6.9003 - val_loss: 49.0424 - val_mean_squared_error: 49.0424 - val_mean_absolute_error: 3.0724 - val_root_mean_squared_error: 7.0030
# Epoch 13/150
# 47/47 [==============================] - 64s 1s/step - loss: 51.1103 - mean_squared_error: 51.1103 - mean_absolute_error: 3.4411 - root_mean_squared_error: 7.1491 - val_loss: 50.5839 - val_mean_squared_error: 50.5839 - val_mean_absolute_error: 3.0950 - val_root_mean_squared_error: 7.1122
# Epoch 14/150
# 47/47 [==============================] - 65s 1s/step - loss: 48.6970 - mean_squared_error: 48.6970 - mean_absolute_error: 3.3406 - root_mean_squared_error: 6.9783 - val_loss: 48.3092 - val_mean_squared_error: 48.3092 - val_mean_absolute_error: 3.0912 - val_root_mean_squared_error: 6.9505
# Epoch 15/150
# 47/47 [==============================] - 66s 1s/step - loss: 47.1524 - mean_squared_error: 47.1524 - mean_absolute_error: 3.2375 - root_mean_squared_error: 6.8668 - val_loss: 46.6422 - val_mean_squared_error: 46.6422 - val_mean_absolute_error: 3.1215 - val_root_mean_squared_error: 6.8295
# Epoch 16/150
# 47/47 [==============================] - 60s 1s/step - loss: 45.8888 - mean_squared_error: 45.8888 - mean_absolute_error: 3.2236 - root_mean_squared_error: 6.7741 - val_loss: 51.2640 - val_mean_squared_error: 51.2640 - val_mean_absolute_error: 3.3168 - val_root_mean_squared_error: 7.1599
# Epoch 17/150
# 47/47 [==============================] - 59s 1s/step - loss: 45.9101 - mean_squared_error: 45.9101 - mean_absolute_error: 3.2169 - root_mean_squared_error: 6.7757 - val_loss: 50.9041 - val_mean_squared_error: 50.9041 - val_mean_absolute_error: 3.0980 - val_root_mean_squared_error: 7.1347
# Epoch 18/150
# 47/47 [==============================] - 60s 1s/step - loss: 45.5796 - mean_squared_error: 45.5796 - mean_absolute_error: 3.1888 - root_mean_squared_error: 6.7513 - val_loss: 47.3345 - val_mean_squared_error: 47.3345 - val_mean_absolute_error: 3.0564 - val_root_mean_squared_error: 6.8800
# Epoch 19/150
# 47/47 [==============================] - 60s 1s/step - loss: 43.8155 - mean_squared_error: 43.8155 - mean_absolute_error: 3.1033 - root_mean_squared_error: 6.6193 - val_loss: 46.4032 - val_mean_squared_error: 46.4032 - val_mean_absolute_error: 3.1288 - val_root_mean_squared_error: 6.8120
# Epoch 20/150
# 47/47 [==============================] - ETA: 0s - loss: 44.8620 - mean_squared_error: 44.8620 - mean_absolute_error: 3.1651 - root_mean_squared_error: 6.6979
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 47/47 [==============================] - 59s 1s/step - loss: 44.8620 - mean_squared_error: 44.8620 - mean_absolute_error: 3.1651 - root_mean_squared_error: 6.6979 - val_loss: 48.9721 - val_mean_squared_error: 48.9721 - val_mean_absolute_error: 3.3687 - val_root_mean_squared_error: 6.9980
# Epoch 21/150
# 47/47 [==============================] - 64s 1s/step - loss: 43.5866 - mean_squared_error: 43.5866 - mean_absolute_error: 3.1086 - root_mean_squared_error: 6.6020 - val_loss: 52.9470 - val_mean_squared_error: 52.9470 - val_mean_absolute_error: 3.6010 - val_root_mean_squared_error: 7.2765
# Epoch 22/150
# 47/47 [==============================] - 65s 1s/step - loss: 44.4090 - mean_squared_error: 44.4090 - mean_absolute_error: 3.1743 - root_mean_squared_error: 6.6640 - val_loss: 47.1155 - val_mean_squared_error: 47.1155 - val_mean_absolute_error: 2.9709 - val_root_mean_squared_error: 6.8641
# Epoch 23/150
# 47/47 [==============================] - 65s 1s/step - loss: 44.0196 - mean_squared_error: 44.0196 - mean_absolute_error: 3.1676 - root_mean_squared_error: 6.6347 - val_loss: 47.0302 - val_mean_squared_error: 47.0302 - val_mean_absolute_error: 3.0902 - val_root_mean_squared_error: 6.8579
# Epoch 24/150
# 47/47 [==============================] - 60s 1s/step - loss: 42.2143 - mean_squared_error: 42.2143 - mean_absolute_error: 3.1070 - root_mean_squared_error: 6.4973 - val_loss: 50.1285 - val_mean_squared_error: 50.1285 - val_mean_absolute_error: 3.2736 - val_root_mean_squared_error: 7.0802
# Epoch 25/150
# 47/47 [==============================] - 59s 1s/step - loss: 41.8299 - mean_squared_error: 41.8299 - mean_absolute_error: 3.0584 - root_mean_squared_error: 6.4676 - val_loss: 44.3375 - val_mean_squared_error: 44.3375 - val_mean_absolute_error: 3.0488 - val_root_mean_squared_error: 6.6586
# Epoch 26/150
# 47/47 [==============================] - 61s 1s/step - loss: 46.4268 - mean_squared_error: 46.4268 - mean_absolute_error: 3.2412 - root_mean_squared_error: 6.8137 - val_loss: 49.2136 - val_mean_squared_error: 49.2136 - val_mean_absolute_error: 3.0200 - val_root_mean_squared_error: 7.0152
# Epoch 27/150
# 47/47 [==============================] - 58s 1s/step - loss: 44.7894 - mean_squared_error: 44.7894 - mean_absolute_error: 3.1750 - root_mean_squared_error: 6.6925 - val_loss: 47.3985 - val_mean_squared_error: 47.3985 - val_mean_absolute_error: 3.0162 - val_root_mean_squared_error: 6.8847
# Epoch 28/150
# 47/47 [==============================] - 59s 1s/step - loss: 43.2445 - mean_squared_error: 43.2445 - mean_absolute_error: 3.1167 - root_mean_squared_error: 6.5761 - val_loss: 44.6906 - val_mean_squared_error: 44.6906 - val_mean_absolute_error: 2.9261 - val_root_mean_squared_error: 6.6851
# Epoch 29/150
# 47/47 [==============================] - 64s 1s/step - loss: 43.8166 - mean_squared_error: 43.8166 - mean_absolute_error: 3.1643 - root_mean_squared_error: 6.6194 - val_loss: 46.7102 - val_mean_squared_error: 46.7102 - val_mean_absolute_error: 3.0412 - val_root_mean_squared_error: 6.8345
# Epoch 30/150
# 47/47 [==============================] - 66s 1s/step - loss: 42.5854 - mean_squared_error: 42.5853 - mean_absolute_error: 3.0702 - root_mean_squared_error: 6.5257 - val_loss: 43.5590 - val_mean_squared_error: 43.5590 - val_mean_absolute_error: 2.9989 - val_root_mean_squared_error: 6.5999
# Epoch 31/150
# 47/47 [==============================] - 62s 1s/step - loss: 41.7813 - mean_squared_error: 41.7813 - mean_absolute_error: 3.0505 - root_mean_squared_error: 6.4638 - val_loss: 45.0767 - val_mean_squared_error: 45.0767 - val_mean_absolute_error: 3.0529 - val_root_mean_squared_error: 6.7139
# Epoch 32/150
# 47/47 [==============================] - 59s 1s/step - loss: 40.7571 - mean_squared_error: 40.7571 - mean_absolute_error: 3.0286 - root_mean_squared_error: 6.3841 - val_loss: 45.2901 - val_mean_squared_error: 45.2901 - val_mean_absolute_error: 2.9781 - val_root_mean_squared_error: 6.7298
# Epoch 33/150
# 47/47 [==============================] - 60s 1s/step - loss: 40.8318 - mean_squared_error: 40.8317 - mean_absolute_error: 3.0265 - root_mean_squared_error: 6.3900 - val_loss: 51.6922 - val_mean_squared_error: 51.6922 - val_mean_absolute_error: 3.3946 - val_root_mean_squared_error: 7.1897
# Epoch 34/150
# 47/47 [==============================] - 59s 1s/step - loss: 41.5950 - mean_squared_error: 41.5950 - mean_absolute_error: 3.0664 - root_mean_squared_error: 6.4494 - val_loss: 54.6855 - val_mean_squared_error: 54.6855 - val_mean_absolute_error: 3.3890 - val_root_mean_squared_error: 7.3950
# Epoch 35/150
# 47/47 [==============================] - 59s 1s/step - loss: 41.8941 - mean_squared_error: 41.8941 - mean_absolute_error: 3.0633 - root_mean_squared_error: 6.4726 - val_loss: 46.7221 - val_mean_squared_error: 46.7221 - val_mean_absolute_error: 3.0091 - val_root_mean_squared_error: 6.8354
# Epoch 36/150
# 47/47 [==============================] - 60s 1s/step - loss: 39.1752 - mean_squared_error: 39.1752 - mean_absolute_error: 2.9496 - root_mean_squared_error: 6.2590 - val_loss: 44.3189 - val_mean_squared_error: 44.3189 - val_mean_absolute_error: 2.9630 - val_root_mean_squared_error: 6.6572
# Epoch 37/150
# 47/47 [==============================] - 60s 1s/step - loss: 39.3831 - mean_squared_error: 39.3830 - mean_absolute_error: 2.9880 - root_mean_squared_error: 6.2756 - val_loss: 44.6094 - val_mean_squared_error: 44.6094 - val_mean_absolute_error: 2.9759 - val_root_mean_squared_error: 6.6790
# Epoch 38/150
# 47/47 [==============================] - 59s 1s/step - loss: 39.9426 - mean_squared_error: 39.9426 - mean_absolute_error: 2.9994 - root_mean_squared_error: 6.3200 - val_loss: 46.5377 - val_mean_squared_error: 46.5377 - val_mean_absolute_error: 2.9914 - val_root_mean_squared_error: 6.8219
# Epoch 39/150
# 47/47 [==============================] - 65s 1s/step - loss: 39.4204 - mean_squared_error: 39.4204 - mean_absolute_error: 2.9324 - root_mean_squared_error: 6.2786 - val_loss: 49.1686 - val_mean_squared_error: 49.1686 - val_mean_absolute_error: 3.1636 - val_root_mean_squared_error: 7.0120
# Epoch 40/150
# 47/47 [==============================] - 65s 1s/step - loss: 39.4607 - mean_squared_error: 39.4607 - mean_absolute_error: 3.0107 - root_mean_squared_error: 6.2818 - val_loss: 47.9409 - val_mean_squared_error: 47.9409 - val_mean_absolute_error: 3.0773 - val_root_mean_squared_error: 6.9239
# Epoch 41/150
# 47/47 [==============================] - 66s 1s/step - loss: 40.0290 - mean_squared_error: 40.0290 - mean_absolute_error: 2.9841 - root_mean_squared_error: 6.3268 - val_loss: 43.7934 - val_mean_squared_error: 43.7934 - val_mean_absolute_error: 3.0765 - val_root_mean_squared_error: 6.6177
# Epoch 42/150
# 47/47 [==============================] - 65s 1s/step - loss: 40.1229 - mean_squared_error: 40.1229 - mean_absolute_error: 3.0257 - root_mean_squared_error: 6.3343 - val_loss: 48.7421 - val_mean_squared_error: 48.7421 - val_mean_absolute_error: 3.2720 - val_root_mean_squared_error: 6.9816
# Epoch 43/150
# 47/47 [==============================] - 64s 1s/step - loss: 38.4241 - mean_squared_error: 38.4241 - mean_absolute_error: 2.9172 - root_mean_squared_error: 6.1987 - val_loss: 60.3034 - val_mean_squared_error: 60.3034 - val_mean_absolute_error: 3.7033 - val_root_mean_squared_error: 7.7655
# Epoch 44/150
# 47/47 [==============================] - 66s 1s/step - loss: 37.7533 - mean_squared_error: 37.7533 - mean_absolute_error: 2.9065 - root_mean_squared_error: 6.1444 - val_loss: 43.4590 - val_mean_squared_error: 43.4590 - val_mean_absolute_error: 3.0260 - val_root_mean_squared_error: 6.5923
# Epoch 45/150
# 47/47 [==============================] - 60s 1s/step - loss: 41.3236 - mean_squared_error: 41.3236 - mean_absolute_error: 3.0279 - root_mean_squared_error: 6.4283 - val_loss: 50.1412 - val_mean_squared_error: 50.1412 - val_mean_absolute_error: 3.1566 - val_root_mean_squared_error: 7.0810
# Epoch 46/150
# 47/47 [==============================] - 59s 1s/step - loss: 40.4655 - mean_squared_error: 40.4655 - mean_absolute_error: 3.0048 - root_mean_squared_error: 6.3612 - val_loss: 46.4675 - val_mean_squared_error: 46.4675 - val_mean_absolute_error: 3.0970 - val_root_mean_squared_error: 6.8167
# Epoch 47/150
# 47/47 [==============================] - 60s 1s/step - loss: 39.1347 - mean_squared_error: 39.1347 - mean_absolute_error: 2.9692 - root_mean_squared_error: 6.2558 - val_loss: 44.8346 - val_mean_squared_error: 44.8346 - val_mean_absolute_error: 2.9781 - val_root_mean_squared_error: 6.6959
# Epoch 48/150
# 47/47 [==============================] - 66s 1s/step - loss: 40.3316 - mean_squared_error: 40.3316 - mean_absolute_error: 3.0274 - root_mean_squared_error: 6.3507 - val_loss: 47.6083 - val_mean_squared_error: 47.6083 - val_mean_absolute_error: 3.2402 - val_root_mean_squared_error: 6.8999
# Epoch 49/150
# 47/47 [==============================] - 65s 1s/step - loss: 38.6298 - mean_squared_error: 38.6298 - mean_absolute_error: 2.9161 - root_mean_squared_error: 6.2153 - val_loss: 45.8638 - val_mean_squared_error: 45.8638 - val_mean_absolute_error: 3.0926 - val_root_mean_squared_error: 6.7723
# Epoch 50/150
# 47/47 [==============================] - 65s 1s/step - loss: 39.4882 - mean_squared_error: 39.4882 - mean_absolute_error: 2.9730 - root_mean_squared_error: 6.2840 - val_loss: 53.3386 - val_mean_squared_error: 53.3386 - val_mean_absolute_error: 3.2676 - val_root_mean_squared_error: 7.3033
# Epoch 51/150
# 47/47 [==============================] - 65s 1s/step - loss: 39.4315 - mean_squared_error: 39.4315 - mean_absolute_error: 2.9689 - root_mean_squared_error: 6.2794 - val_loss: 42.9930 - val_mean_squared_error: 42.9930 - val_mean_absolute_error: 2.9190 - val_root_mean_squared_error: 6.5569
# Epoch 52/150
# 47/47 [==============================] - 60s 1s/step - loss: 38.5988 - mean_squared_error: 38.5988 - mean_absolute_error: 2.9366 - root_mean_squared_error: 6.2128 - val_loss: 48.9960 - val_mean_squared_error: 48.9960 - val_mean_absolute_error: 3.0721 - val_root_mean_squared_error: 6.9997
# Epoch 53/150
# 47/47 [==============================] - 60s 1s/step - loss: 39.2489 - mean_squared_error: 39.2489 - mean_absolute_error: 2.9668 - root_mean_squared_error: 6.2649 - val_loss: 43.7870 - val_mean_squared_error: 43.7870 - val_mean_absolute_error: 2.9102 - val_root_mean_squared_error: 6.6172
# Epoch 54/150
# 47/47 [==============================] - 64s 1s/step - loss: 38.2472 - mean_squared_error: 38.2472 - mean_absolute_error: 2.9248 - root_mean_squared_error: 6.1844 - val_loss: 41.0873 - val_mean_squared_error: 41.0874 - val_mean_absolute_error: 2.8683 - val_root_mean_squared_error: 6.4099
# Epoch 55/150
# 47/47 [==============================] - 66s 1s/step - loss: 37.6292 - mean_squared_error: 37.6292 - mean_absolute_error: 2.9080 - root_mean_squared_error: 6.1343 - val_loss: 60.2400 - val_mean_squared_error: 60.2400 - val_mean_absolute_error: 3.6323 - val_root_mean_squared_error: 7.7614
# Epoch 56/150
# 47/47 [==============================] - 59s 1s/step - loss: 37.4093 - mean_squared_error: 37.4093 - mean_absolute_error: 2.9127 - root_mean_squared_error: 6.1163 - val_loss: 45.0131 - val_mean_squared_error: 45.0131 - val_mean_absolute_error: 3.0136 - val_root_mean_squared_error: 6.7092
# Epoch 57/150
# 47/47 [==============================] - 59s 1s/step - loss: 36.6761 - mean_squared_error: 36.6761 - mean_absolute_error: 2.8892 - root_mean_squared_error: 6.0561 - val_loss: 44.6182 - val_mean_squared_error: 44.6182 - val_mean_absolute_error: 3.0377 - val_root_mean_squared_error: 6.6797
# Epoch 58/150
# 47/47 [==============================] - 59s 1s/step - loss: 38.4501 - mean_squared_error: 38.4501 - mean_absolute_error: 2.9613 - root_mean_squared_error: 6.2008 - val_loss: 42.9509 - val_mean_squared_error: 42.9509 - val_mean_absolute_error: 2.9230 - val_root_mean_squared_error: 6.5537
# Epoch 59/150
# 47/47 [==============================] - 65s 1s/step - loss: 37.8181 - mean_squared_error: 37.8181 - mean_absolute_error: 2.9225 - root_mean_squared_error: 6.1496 - val_loss: 54.5547 - val_mean_squared_error: 54.5547 - val_mean_absolute_error: 3.3676 - val_root_mean_squared_error: 7.3861
# Epoch 60/150
# 47/47 [==============================] - 65s 1s/step - loss: 37.6059 - mean_squared_error: 37.6059 - mean_absolute_error: 2.9083 - root_mean_squared_error: 6.1324 - val_loss: 44.2438 - val_mean_squared_error: 44.2438 - val_mean_absolute_error: 2.9081 - val_root_mean_squared_error: 6.6516
# Epoch 61/150
# 47/47 [==============================] - 59s 1s/step - loss: 36.4501 - mean_squared_error: 36.4501 - mean_absolute_error: 2.8706 - root_mean_squared_error: 6.0374 - val_loss: 46.1424 - val_mean_squared_error: 46.1424 - val_mean_absolute_error: 2.9451 - val_root_mean_squared_error: 6.7928
# Epoch 62/150
# 47/47 [==============================] - 60s 1s/step - loss: 36.6883 - mean_squared_error: 36.6883 - mean_absolute_error: 2.8906 - root_mean_squared_error: 6.0571 - val_loss: 51.8928 - val_mean_squared_error: 51.8928 - val_mean_absolute_error: 3.3849 - val_root_mean_squared_error: 7.2037
# Epoch 63/150
# 47/47 [==============================] - 64s 1s/step - loss: 36.9643 - mean_squared_error: 36.9643 - mean_absolute_error: 2.9133 - root_mean_squared_error: 6.0798 - val_loss: 43.5208 - val_mean_squared_error: 43.5208 - val_mean_absolute_error: 2.8686 - val_root_mean_squared_error: 6.5970
# Epoch 64/150
# 47/47 [==============================] - 64s 1s/step - loss: 36.4919 - mean_squared_error: 36.4919 - mean_absolute_error: 2.8706 - root_mean_squared_error: 6.0409 - val_loss: 42.7960 - val_mean_squared_error: 42.7960 - val_mean_absolute_error: 2.8656 - val_root_mean_squared_error: 6.5419
# Epoch 65/150
# 47/47 [==============================] - 64s 1s/step - loss: 35.7406 - mean_squared_error: 35.7406 - mean_absolute_error: 2.8425 - root_mean_squared_error: 5.9783 - val_loss: 47.0672 - val_mean_squared_error: 47.0672 - val_mean_absolute_error: 3.0879 - val_root_mean_squared_error: 6.8606
# Epoch 66/150
# 47/47 [==============================] - 65s 1s/step - loss: 36.0132 - mean_squared_error: 36.0132 - mean_absolute_error: 2.8812 - root_mean_squared_error: 6.0011 - val_loss: 47.4952 - val_mean_squared_error: 47.4952 - val_mean_absolute_error: 2.9819 - val_root_mean_squared_error: 6.8917
# Epoch 67/150
# 47/47 [==============================] - 64s 1s/step - loss: 36.6242 - mean_squared_error: 36.6242 - mean_absolute_error: 2.8678 - root_mean_squared_error: 6.0518 - val_loss: 43.0229 - val_mean_squared_error: 43.0229 - val_mean_absolute_error: 3.0956 - val_root_mean_squared_error: 6.5592
# Epoch 68/150
# 47/47 [==============================] - 65s 1s/step - loss: 36.2798 - mean_squared_error: 36.2798 - mean_absolute_error: 2.8822 - root_mean_squared_error: 6.0233 - val_loss: 46.8416 - val_mean_squared_error: 46.8416 - val_mean_absolute_error: 3.1424 - val_root_mean_squared_error: 6.8441
# Epoch 69/150
# 47/47 [==============================] - 64s 1s/step - loss: 39.1575 - mean_squared_error: 39.1575 - mean_absolute_error: 2.9904 - root_mean_squared_error: 6.2576 - val_loss: 42.2135 - val_mean_squared_error: 42.2135 - val_mean_absolute_error: 2.9607 - val_root_mean_squared_error: 6.4972
# Epoch 70/150
# 47/47 [==============================] - 65s 1s/step - loss: 36.9885 - mean_squared_error: 36.9885 - mean_absolute_error: 2.8588 - root_mean_squared_error: 6.0818 - val_loss: 47.7690 - val_mean_squared_error: 47.7690 - val_mean_absolute_error: 3.1853 - val_root_mean_squared_error: 6.9115
# Epoch 71/150
# 47/47 [==============================] - 65s 1s/step - loss: 36.1833 - mean_squared_error: 36.1833 - mean_absolute_error: 2.8787 - root_mean_squared_error: 6.0153 - val_loss: 48.0471 - val_mean_squared_error: 48.0471 - val_mean_absolute_error: 3.1651 - val_root_mean_squared_error: 6.9316
# Epoch 72/150
# 47/47 [==============================] - 65s 1s/step - loss: 34.7048 - mean_squared_error: 34.7048 - mean_absolute_error: 2.8038 - root_mean_squared_error: 5.8911 - val_loss: 46.2895 - val_mean_squared_error: 46.2895 - val_mean_absolute_error: 3.0090 - val_root_mean_squared_error: 6.8036
# Epoch 73/150
# 47/47 [==============================] - 66s 1s/step - loss: 34.0204 - mean_squared_error: 34.0204 - mean_absolute_error: 2.7821 - root_mean_squared_error: 5.8327 - val_loss: 44.4902 - val_mean_squared_error: 44.4902 - val_mean_absolute_error: 2.9249 - val_root_mean_squared_error: 6.6701
# Epoch 74/150
# 47/47 [==============================] - 65s 1s/step - loss: 34.6287 - mean_squared_error: 34.6287 - mean_absolute_error: 2.7963 - root_mean_squared_error: 5.8846 - val_loss: 45.3667 - val_mean_squared_error: 45.3667 - val_mean_absolute_error: 2.9631 - val_root_mean_squared_error: 6.7355
# Epoch 75/150
# 47/47 [==============================] - 60s 1s/step - loss: 35.3482 - mean_squared_error: 35.3482 - mean_absolute_error: 2.8604 - root_mean_squared_error: 5.9454 - val_loss: 44.3353 - val_mean_squared_error: 44.3353 - val_mean_absolute_error: 2.9172 - val_root_mean_squared_error: 6.6585
# Epoch 76/150
# 47/47 [==============================] - 60s 1s/step - loss: 34.4733 - mean_squared_error: 34.4733 - mean_absolute_error: 2.7969 - root_mean_squared_error: 5.8714 - val_loss: 46.2598 - val_mean_squared_error: 46.2598 - val_mean_absolute_error: 2.9560 - val_root_mean_squared_error: 6.8015
# Epoch 77/150
# 47/47 [==============================] - 60s 1s/step - loss: 33.6260 - mean_squared_error: 33.6260 - mean_absolute_error: 2.7727 - root_mean_squared_error: 5.7988 - val_loss: 46.1742 - val_mean_squared_error: 46.1742 - val_mean_absolute_error: 2.9410 - val_root_mean_squared_error: 6.7952
# Epoch 78/150
# 47/47 [==============================] - 59s 1s/step - loss: 34.6843 - mean_squared_error: 34.6843 - mean_absolute_error: 2.8089 - root_mean_squared_error: 5.8893 - val_loss: 45.6062 - val_mean_squared_error: 45.6062 - val_mean_absolute_error: 3.0872 - val_root_mean_squared_error: 6.7532
# Epoch 79/150
# 47/47 [==============================] - 59s 1s/step - loss: 33.0091 - mean_squared_error: 33.0091 - mean_absolute_error: 2.7550 - root_mean_squared_error: 5.7454 - val_loss: 43.8587 - val_mean_squared_error: 43.8587 - val_mean_absolute_error: 3.0226 - val_root_mean_squared_error: 6.6226
# Epoch 80/150
# 47/47 [==============================] - 59s 1s/step - loss: 34.9542 - mean_squared_error: 34.9542 - mean_absolute_error: 2.8259 - root_mean_squared_error: 5.9122 - val_loss: 41.2354 - val_mean_squared_error: 41.2354 - val_mean_absolute_error: 2.8444 - val_root_mean_squared_error: 6.4215
# Epoch 81/150
# 47/47 [==============================] - 60s 1s/step - loss: 34.5399 - mean_squared_error: 34.5399 - mean_absolute_error: 2.8448 - root_mean_squared_error: 5.8771 - val_loss: 46.9465 - val_mean_squared_error: 46.9465 - val_mean_absolute_error: 2.9540 - val_root_mean_squared_error: 6.8518
# Epoch 82/150
# 47/47 [==============================] - 64s 1s/step - loss: 33.9398 - mean_squared_error: 33.9398 - mean_absolute_error: 2.7772 - root_mean_squared_error: 5.8258 - val_loss: 49.5199 - val_mean_squared_error: 49.5199 - val_mean_absolute_error: 3.1326 - val_root_mean_squared_error: 7.0370
# Epoch 83/150
# 47/47 [==============================] - 59s 1s/step - loss: 33.4845 - mean_squared_error: 33.4845 - mean_absolute_error: 2.7558 - root_mean_squared_error: 5.7866 - val_loss: 51.9755 - val_mean_squared_error: 51.9755 - val_mean_absolute_error: 3.1523 - val_root_mean_squared_error: 7.2094
# Epoch 84/150
# 47/47 [==============================] - 59s 1s/step - loss: 34.9999 - mean_squared_error: 34.9999 - mean_absolute_error: 2.8141 - root_mean_squared_error: 5.9161 - val_loss: 53.6437 - val_mean_squared_error: 53.6437 - val_mean_absolute_error: 3.3281 - val_root_mean_squared_error: 7.3242
# Epoch 85/150
# 47/47 [==============================] - 59s 1s/step - loss: 34.4472 - mean_squared_error: 34.4472 - mean_absolute_error: 2.8156 - root_mean_squared_error: 5.8692 - val_loss: 59.0255 - val_mean_squared_error: 59.0255 - val_mean_absolute_error: 3.4783 - val_root_mean_squared_error: 7.6828
# Epoch 86/150
# 47/47 [==============================] - 59s 1s/step - loss: 37.4361 - mean_squared_error: 37.4361 - mean_absolute_error: 2.9467 - root_mean_squared_error: 6.1185 - val_loss: 43.4754 - val_mean_squared_error: 43.4754 - val_mean_absolute_error: 2.8736 - val_root_mean_squared_error: 6.5936
# Epoch 87/150
# 47/47 [==============================] - 58s 1s/step - loss: 34.8858 - mean_squared_error: 34.8858 - mean_absolute_error: 2.8230 - root_mean_squared_error: 5.9064 - val_loss: 48.2221 - val_mean_squared_error: 48.2221 - val_mean_absolute_error: 3.1969 - val_root_mean_squared_error: 6.9442
# Epoch 88/150
# 47/47 [==============================] - 65s 1s/step - loss: 33.2636 - mean_squared_error: 33.2636 - mean_absolute_error: 2.7536 - root_mean_squared_error: 5.7675 - val_loss: 51.0748 - val_mean_squared_error: 51.0748 - val_mean_absolute_error: 3.2283 - val_root_mean_squared_error: 7.1467
# Epoch 89/150
# 47/47 [==============================] - 59s 1s/step - loss: 33.0444 - mean_squared_error: 33.0444 - mean_absolute_error: 2.7309 - root_mean_squared_error: 5.7484 - val_loss: 41.9590 - val_mean_squared_error: 41.9590 - val_mean_absolute_error: 2.8607 - val_root_mean_squared_error: 6.4776
# Epoch 90/150
# 47/47 [==============================] - 59s 1s/step - loss: 34.3162 - mean_squared_error: 34.3162 - mean_absolute_error: 2.7934 - root_mean_squared_error: 5.8580 - val_loss: 669.8000 - val_mean_squared_error: 669.7999 - val_mean_absolute_error: 22.4794 - val_root_mean_squared_error: 25.8805
# Epoch 91/150
# 47/47 [==============================] - 64s 1s/step - loss: 32.5885 - mean_squared_error: 32.5885 - mean_absolute_error: 2.7286 - root_mean_squared_error: 5.7086 - val_loss: 43.8000 - val_mean_squared_error: 43.8000 - val_mean_absolute_error: 2.9091 - val_root_mean_squared_error: 6.6182
# Epoch 92/150
# 47/47 [==============================] - 65s 1s/step - loss: 32.8661 - mean_squared_error: 32.8661 - mean_absolute_error: 2.7318 - root_mean_squared_error: 5.7329 - val_loss: 40.6280 - val_mean_squared_error: 40.6280 - val_mean_absolute_error: 2.8049 - val_root_mean_squared_error: 6.3740
# Epoch 93/150
# 47/47 [==============================] - 64s 1s/step - loss: 33.1272 - mean_squared_error: 33.1272 - mean_absolute_error: 2.7488 - root_mean_squared_error: 5.7556 - val_loss: 54.4424 - val_mean_squared_error: 54.4424 - val_mean_absolute_error: 3.3680 - val_root_mean_squared_error: 7.3785
# Epoch 94/150
# 47/47 [==============================] - 64s 1s/step - loss: 31.9342 - mean_squared_error: 31.9342 - mean_absolute_error: 2.7158 - root_mean_squared_error: 5.6510 - val_loss: 2230.0579 - val_mean_squared_error: 2230.0576 - val_mean_absolute_error: 39.0980 - val_root_mean_squared_error: 47.2235
# Epoch 95/150
# 47/47 [==============================] - 59s 1s/step - loss: 31.7772 - mean_squared_error: 31.7772 - mean_absolute_error: 2.6937 - root_mean_squared_error: 5.6371 - val_loss: 44.8553 - val_mean_squared_error: 44.8553 - val_mean_absolute_error: 2.9162 - val_root_mean_squared_error: 6.6974
# Epoch 96/150
# 47/47 [==============================] - 61s 1s/step - loss: 32.7100 - mean_squared_error: 32.7100 - mean_absolute_error: 2.7445 - root_mean_squared_error: 5.7193 - val_loss: 43.2039 - val_mean_squared_error: 43.2039 - val_mean_absolute_error: 2.8998 - val_root_mean_squared_error: 6.5730
# Epoch 97/150
# 47/47 [==============================] - 64s 1s/step - loss: 31.5599 - mean_squared_error: 31.5599 - mean_absolute_error: 2.6972 - root_mean_squared_error: 5.6178 - val_loss: 43.5362 - val_mean_squared_error: 43.5362 - val_mean_absolute_error: 3.0250 - val_root_mean_squared_error: 6.5982
# Epoch 98/150
# 47/47 [==============================] - 64s 1s/step - loss: 31.0596 - mean_squared_error: 31.0596 - mean_absolute_error: 2.6713 - root_mean_squared_error: 5.5731 - val_loss: 43.9889 - val_mean_squared_error: 43.9889 - val_mean_absolute_error: 3.0313 - val_root_mean_squared_error: 6.6324
# Epoch 99/150
# 47/47 [==============================] - 59s 1s/step - loss: 31.4354 - mean_squared_error: 31.4354 - mean_absolute_error: 2.6972 - root_mean_squared_error: 5.6067 - val_loss: 44.6597 - val_mean_squared_error: 44.6597 - val_mean_absolute_error: 2.9422 - val_root_mean_squared_error: 6.6828
# Epoch 100/150
# 47/47 [==============================] - 60s 1s/step - loss: 30.8367 - mean_squared_error: 30.8367 - mean_absolute_error: 2.6422 - root_mean_squared_error: 5.5531 - val_loss: 54.3059 - val_mean_squared_error: 54.3059 - val_mean_absolute_error: 3.2650 - val_root_mean_squared_error: 7.3693
# Epoch 101/150
# 47/47 [==============================] - 64s 1s/step - loss: 30.8112 - mean_squared_error: 30.8112 - mean_absolute_error: 2.6735 - root_mean_squared_error: 5.5508 - val_loss: 46.8990 - val_mean_squared_error: 46.8990 - val_mean_absolute_error: 3.0601 - val_root_mean_squared_error: 6.8483
# Epoch 102/150
# 47/47 [==============================] - 59s 1s/step - loss: 31.4137 - mean_squared_error: 31.4137 - mean_absolute_error: 2.6983 - root_mean_squared_error: 5.6048 - val_loss: 49.5458 - val_mean_squared_error: 49.5458 - val_mean_absolute_error: 3.2021 - val_root_mean_squared_error: 7.0389
# Epoch 103/150
# 47/47 [==============================] - 59s 1s/step - loss: 32.6654 - mean_squared_error: 32.6654 - mean_absolute_error: 2.7550 - root_mean_squared_error: 5.7154 - val_loss: 46.6201 - val_mean_squared_error: 46.6201 - val_mean_absolute_error: 3.1932 - val_root_mean_squared_error: 6.8279
# Epoch 104/150
# 47/47 [==============================] - 61s 1s/step - loss: 30.4600 - mean_squared_error: 30.4600 - mean_absolute_error: 2.6401 - root_mean_squared_error: 5.5191 - val_loss: 583.3765 - val_mean_squared_error: 583.3765 - val_mean_absolute_error: 21.2163 - val_root_mean_squared_error: 24.1532
# Epoch 105/150
# 47/47 [==============================] - 60s 1s/step - loss: 29.8835 - mean_squared_error: 29.8835 - mean_absolute_error: 2.6333 - root_mean_squared_error: 5.4666 - val_loss: 45.6812 - val_mean_squared_error: 45.6812 - val_mean_absolute_error: 3.0840 - val_root_mean_squared_error: 6.7588
# Epoch 106/150
# 47/47 [==============================] - 59s 1s/step - loss: 32.8805 - mean_squared_error: 32.8805 - mean_absolute_error: 2.7403 - root_mean_squared_error: 5.7342 - val_loss: 43.5135 - val_mean_squared_error: 43.5135 - val_mean_absolute_error: 2.9701 - val_root_mean_squared_error: 6.5965
# Epoch 107/150
# 47/47 [==============================] - 64s 1s/step - loss: 32.6600 - mean_squared_error: 32.6600 - mean_absolute_error: 2.7467 - root_mean_squared_error: 5.7149 - val_loss: 47.1431 - val_mean_squared_error: 47.1431 - val_mean_absolute_error: 3.0716 - val_root_mean_squared_error: 6.8661
# Epoch 108/150
# 47/47 [==============================] - 64s 1s/step - loss: 31.8550 - mean_squared_error: 31.8550 - mean_absolute_error: 2.7214 - root_mean_squared_error: 5.6440 - val_loss: 48.4964 - val_mean_squared_error: 48.4964 - val_mean_absolute_error: 3.0974 - val_root_mean_squared_error: 6.9639
# Epoch 109/150
# 47/47 [==============================] - 64s 1s/step - loss: 34.6743 - mean_squared_error: 34.6743 - mean_absolute_error: 2.8547 - root_mean_squared_error: 5.8885 - val_loss: 44.4716 - val_mean_squared_error: 44.4716 - val_mean_absolute_error: 3.0161 - val_root_mean_squared_error: 6.6687
# Epoch 110/150
# 47/47 [==============================] - 59s 1s/step - loss: 32.9890 - mean_squared_error: 32.9890 - mean_absolute_error: 2.7593 - root_mean_squared_error: 5.7436 - val_loss: 642.9438 - val_mean_squared_error: 642.9438 - val_mean_absolute_error: 21.5701 - val_root_mean_squared_error: 25.3563
# Epoch 111/150
# 47/47 [==============================] - 60s 1s/step - loss: 31.3430 - mean_squared_error: 31.3430 - mean_absolute_error: 2.6883 - root_mean_squared_error: 5.5985 - val_loss: 44.8579 - val_mean_squared_error: 44.8579 - val_mean_absolute_error: 2.9190 - val_root_mean_squared_error: 6.6976
# Epoch 112/150
# 47/47 [==============================] - 64s 1s/step - loss: 30.7167 - mean_squared_error: 30.7167 - mean_absolute_error: 2.6755 - root_mean_squared_error: 5.5423 - val_loss: 401.2268 - val_mean_squared_error: 401.2267 - val_mean_absolute_error: 17.4131 - val_root_mean_squared_error: 20.0306
# Epoch 113/150
# 47/47 [==============================] - 59s 1s/step - loss: 31.3666 - mean_squared_error: 31.3666 - mean_absolute_error: 2.6716 - root_mean_squared_error: 5.6006 - val_loss: 148.8505 - val_mean_squared_error: 148.8505 - val_mean_absolute_error: 10.6568 - val_root_mean_squared_error: 12.2004
# Epoch 114/150
# 47/47 [==============================] - 59s 1s/step - loss: 30.8850 - mean_squared_error: 30.8850 - mean_absolute_error: 2.6991 - root_mean_squared_error: 5.5574 - val_loss: 44.2650 - val_mean_squared_error: 44.2650 - val_mean_absolute_error: 2.9291 - val_root_mean_squared_error: 6.6532
# Epoch 115/150
# 47/47 [==============================] - 66s 1s/step - loss: 29.6965 - mean_squared_error: 29.6965 - mean_absolute_error: 2.6182 - root_mean_squared_error: 5.4494 - val_loss: 44.0018 - val_mean_squared_error: 44.0018 - val_mean_absolute_error: 3.0285 - val_root_mean_squared_error: 6.6334
# Epoch 116/150
# 47/47 [==============================] - 64s 1s/step - loss: 28.9306 - mean_squared_error: 28.9306 - mean_absolute_error: 2.6031 - root_mean_squared_error: 5.3787 - val_loss: 48.3341 - val_mean_squared_error: 48.3341 - val_mean_absolute_error: 3.1526 - val_root_mean_squared_error: 6.9523
# Epoch 117/150
# 47/47 [==============================] - 64s 1s/step - loss: 30.1494 - mean_squared_error: 30.1494 - mean_absolute_error: 2.6320 - root_mean_squared_error: 5.4908 - val_loss: 59.0248 - val_mean_squared_error: 59.0248 - val_mean_absolute_error: 3.5099 - val_root_mean_squared_error: 7.6828
# Epoch 118/150
# 47/47 [==============================] - 64s 1s/step - loss: 30.5252 - mean_squared_error: 30.5253 - mean_absolute_error: 2.6434 - root_mean_squared_error: 5.5250 - val_loss: 54.9946 - val_mean_squared_error: 54.9946 - val_mean_absolute_error: 3.4812 - val_root_mean_squared_error: 7.4158
# Epoch 119/150
# 47/47 [==============================] - 65s 1s/step - loss: 30.3749 - mean_squared_error: 30.3749 - mean_absolute_error: 2.6533 - root_mean_squared_error: 5.5113 - val_loss: 47.6566 - val_mean_squared_error: 47.6566 - val_mean_absolute_error: 3.0099 - val_root_mean_squared_error: 6.9034
# Epoch 120/150
# 47/47 [==============================] - 64s 1s/step - loss: 28.4843 - mean_squared_error: 28.4843 - mean_absolute_error: 2.5637 - root_mean_squared_error: 5.3371 - val_loss: 43.8479 - val_mean_squared_error: 43.8479 - val_mean_absolute_error: 2.9500 - val_root_mean_squared_error: 6.6218
# Epoch 121/150
# 47/47 [==============================] - 64s 1s/step - loss: 30.7420 - mean_squared_error: 30.7420 - mean_absolute_error: 2.6497 - root_mean_squared_error: 5.5445 - val_loss: 46.1040 - val_mean_squared_error: 46.1040 - val_mean_absolute_error: 3.0501 - val_root_mean_squared_error: 6.7900
# Epoch 122/150
# 47/47 [==============================] - 59s 1s/step - loss: 30.2211 - mean_squared_error: 30.2211 - mean_absolute_error: 2.6582 - root_mean_squared_error: 5.4974 - val_loss: 46.8003 - val_mean_squared_error: 46.8003 - val_mean_absolute_error: 3.0703 - val_root_mean_squared_error: 6.8411
# Epoch 123/150
# 47/47 [==============================] - 60s 1s/step - loss: 31.7347 - mean_squared_error: 31.7347 - mean_absolute_error: 2.7089 - root_mean_squared_error: 5.6334 - val_loss: 47.6625 - val_mean_squared_error: 47.6625 - val_mean_absolute_error: 3.0783 - val_root_mean_squared_error: 6.9038
# Epoch 124/150
# 47/47 [==============================] - 65s 1s/step - loss: 29.8655 - mean_squared_error: 29.8655 - mean_absolute_error: 2.6453 - root_mean_squared_error: 5.4649 - val_loss: 41.9719 - val_mean_squared_error: 41.9719 - val_mean_absolute_error: 2.9107 - val_root_mean_squared_error: 6.4786
# Epoch 125/150
# 47/47 [==============================] - 59s 1s/step - loss: 31.4676 - mean_squared_error: 31.4676 - mean_absolute_error: 2.7155 - root_mean_squared_error: 5.6096 - val_loss: 46.1686 - val_mean_squared_error: 46.1686 - val_mean_absolute_error: 2.9606 - val_root_mean_squared_error: 6.7947
# Epoch 126/150
# 47/47 [==============================] - 59s 1s/step - loss: 29.7745 - mean_squared_error: 29.7745 - mean_absolute_error: 2.6263 - root_mean_squared_error: 5.4566 - val_loss: 458.4834 - val_mean_squared_error: 458.4834 - val_mean_absolute_error: 18.5866 - val_root_mean_squared_error: 21.4122
# Epoch 127/150
# 47/47 [==============================] - 60s 1s/step - loss: 29.8412 - mean_squared_error: 29.8413 - mean_absolute_error: 2.6131 - root_mean_squared_error: 5.4627 - val_loss: 48.4437 - val_mean_squared_error: 48.4437 - val_mean_absolute_error: 3.0898 - val_root_mean_squared_error: 6.9602
# Epoch 128/150
# 47/47 [==============================] - 64s 1s/step - loss: 31.3414 - mean_squared_error: 31.3414 - mean_absolute_error: 2.6970 - root_mean_squared_error: 5.5983 - val_loss: 50.4378 - val_mean_squared_error: 50.4378 - val_mean_absolute_error: 3.2748 - val_root_mean_squared_error: 7.1020
# Epoch 129/150
# 47/47 [==============================] - 65s 1s/step - loss: 29.2566 - mean_squared_error: 29.2566 - mean_absolute_error: 2.6179 - root_mean_squared_error: 5.4089 - val_loss: 45.0571 - val_mean_squared_error: 45.0571 - val_mean_absolute_error: 3.0680 - val_root_mean_squared_error: 6.7125
# Epoch 130/150
# 47/47 [==============================] - 59s 1s/step - loss: 28.9624 - mean_squared_error: 28.9624 - mean_absolute_error: 2.5957 - root_mean_squared_error: 5.3817 - val_loss: 46.1663 - val_mean_squared_error: 46.1663 - val_mean_absolute_error: 3.0678 - val_root_mean_squared_error: 6.7946
# Epoch 131/150
# 47/47 [==============================] - 59s 1s/step - loss: 27.7155 - mean_squared_error: 27.7155 - mean_absolute_error: 2.5424 - root_mean_squared_error: 5.2645 - val_loss: 43.5915 - val_mean_squared_error: 43.5915 - val_mean_absolute_error: 2.9962 - val_root_mean_squared_error: 6.6024
# Epoch 132/150
# 47/47 [==============================] - 64s 1s/step - loss: 27.9111 - mean_squared_error: 27.9111 - mean_absolute_error: 2.5612 - root_mean_squared_error: 5.2831 - val_loss: 44.1698 - val_mean_squared_error: 44.1698 - val_mean_absolute_error: 2.9302 - val_root_mean_squared_error: 6.6460
# Epoch 133/150
# 47/47 [==============================] - 65s 1s/step - loss: 28.0123 - mean_squared_error: 28.0123 - mean_absolute_error: 2.5527 - root_mean_squared_error: 5.2927 - val_loss: 45.4731 - val_mean_squared_error: 45.4731 - val_mean_absolute_error: 2.9978 - val_root_mean_squared_error: 6.7434
# Epoch 134/150
# 47/47 [==============================] - 64s 1s/step - loss: 28.8434 - mean_squared_error: 28.8434 - mean_absolute_error: 2.6027 - root_mean_squared_error: 5.3706 - val_loss: 44.0916 - val_mean_squared_error: 44.0916 - val_mean_absolute_error: 2.8687 - val_root_mean_squared_error: 6.6402
# Epoch 135/150
# 47/47 [==============================] - 66s 1s/step - loss: 27.4472 - mean_squared_error: 27.4472 - mean_absolute_error: 2.5283 - root_mean_squared_error: 5.2390 - val_loss: 2664.9536 - val_mean_squared_error: 2664.9536 - val_mean_absolute_error: 42.4223 - val_root_mean_squared_error: 51.6232
# Epoch 136/150
# 47/47 [==============================] - 65s 1s/step - loss: 27.7297 - mean_squared_error: 27.7297 - mean_absolute_error: 2.5369 - root_mean_squared_error: 5.2659 - val_loss: 2076.3325 - val_mean_squared_error: 2076.3325 - val_mean_absolute_error: 37.6793 - val_root_mean_squared_error: 45.5668
# Epoch 137/150
# 47/47 [==============================] - 65s 1s/step - loss: 27.5252 - mean_squared_error: 27.5252 - mean_absolute_error: 2.5358 - root_mean_squared_error: 5.2464 - val_loss: 47.9613 - val_mean_squared_error: 47.9613 - val_mean_absolute_error: 3.0470 - val_root_mean_squared_error: 6.9254
# Epoch 138/150
# 47/47 [==============================] - 59s 1s/step - loss: 27.7327 - mean_squared_error: 27.7327 - mean_absolute_error: 2.5507 - root_mean_squared_error: 5.2662 - val_loss: 1761.5068 - val_mean_squared_error: 1761.5071 - val_mean_absolute_error: 34.8438 - val_root_mean_squared_error: 41.9703
# Epoch 139/150
# 47/47 [==============================] - 61s 1s/step - loss: 29.0323 - mean_squared_error: 29.0323 - mean_absolute_error: 2.6008 - root_mean_squared_error: 5.3882 - val_loss: 47.8876 - val_mean_squared_error: 47.8876 - val_mean_absolute_error: 3.0399 - val_root_mean_squared_error: 6.9201
# Epoch 140/150
# 47/47 [==============================] - 64s 1s/step - loss: 28.5175 - mean_squared_error: 28.5175 - mean_absolute_error: 2.5814 - root_mean_squared_error: 5.3402 - val_loss: 45.6761 - val_mean_squared_error: 45.6761 - val_mean_absolute_error: 2.9532 - val_root_mean_squared_error: 6.7584
# Epoch 141/150
# 47/47 [==============================] - 65s 1s/step - loss: 27.6740 - mean_squared_error: 27.6740 - mean_absolute_error: 2.5481 - root_mean_squared_error: 5.2606 - val_loss: 49.4625 - val_mean_squared_error: 49.4625 - val_mean_absolute_error: 3.2457 - val_root_mean_squared_error: 7.0330
# Epoch 142/150
# 47/47 [==============================] - 64s 1s/step - loss: 27.6760 - mean_squared_error: 27.6760 - mean_absolute_error: 2.5461 - root_mean_squared_error: 5.2608 - val_loss: 49.4258 - val_mean_squared_error: 49.4258 - val_mean_absolute_error: 3.1110 - val_root_mean_squared_error: 7.0304
# Epoch 143/150
# 47/47 [==============================] - 65s 1s/step - loss: 29.2743 - mean_squared_error: 29.2743 - mean_absolute_error: 2.6017 - root_mean_squared_error: 5.4106 - val_loss: 45.9997 - val_mean_squared_error: 45.9997 - val_mean_absolute_error: 3.0078 - val_root_mean_squared_error: 6.7823
# Epoch 144/150
# 47/47 [==============================] - 59s 1s/step - loss: 27.3132 - mean_squared_error: 27.3132 - mean_absolute_error: 2.5257 - root_mean_squared_error: 5.2262 - val_loss: 46.5628 - val_mean_squared_error: 46.5628 - val_mean_absolute_error: 3.0935 - val_root_mean_squared_error: 6.8237
# Epoch 145/150
# 47/47 [==============================] - 58s 1s/step - loss: 27.8172 - mean_squared_error: 27.8172 - mean_absolute_error: 2.5679 - root_mean_squared_error: 5.2742 - val_loss: 53.8593 - val_mean_squared_error: 53.8593 - val_mean_absolute_error: 3.4222 - val_root_mean_squared_error: 7.3389
# Epoch 146/150
# 47/47 [==============================] - 64s 1s/step - loss: 26.1815 - mean_squared_error: 26.1815 - mean_absolute_error: 2.4857 - root_mean_squared_error: 5.1168 - val_loss: 43.2672 - val_mean_squared_error: 43.2672 - val_mean_absolute_error: 2.9391 - val_root_mean_squared_error: 6.5778
# Epoch 147/150
# 47/47 [==============================] - 65s 1s/step - loss: 27.0870 - mean_squared_error: 27.0870 - mean_absolute_error: 2.5250 - root_mean_squared_error: 5.2045 - val_loss: 50.6765 - val_mean_squared_error: 50.6765 - val_mean_absolute_error: 3.2502 - val_root_mean_squared_error: 7.1187
# Epoch 148/150
# 47/47 [==============================] - 64s 1s/step - loss: 27.0017 - mean_squared_error: 27.0017 - mean_absolute_error: 2.5297 - root_mean_squared_error: 5.1963 - val_loss: 1472.5056 - val_mean_squared_error: 1472.5056 - val_mean_absolute_error: 32.3409 - val_root_mean_squared_error: 38.3732
# Epoch 149/150
# 47/47 [==============================] - 59s 1s/step - loss: 26.5477 - mean_squared_error: 26.5477 - mean_absolute_error: 2.4884 - root_mean_squared_error: 5.1524 - val_loss: 2898.4143 - val_mean_squared_error: 2898.4143 - val_mean_absolute_error: 43.9867 - val_root_mean_squared_error: 53.8369
# Epoch 150/150
# 47/47 [==============================] - 59s 1s/step - loss: 27.4823 - mean_squared_error: 27.4823 - mean_absolute_error: 2.5433 - root_mean_squared_error: 5.2424 - val_loss: 47.0162 - val_mean_squared_error: 47.0162 - val_mean_absolute_error: 3.0457 - val_root_mean_squared_error: 6.8568
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-60671f930151> in <cell line: 28>()
#      46
#      47     # Save the prediction
# ---> 48     y_pred = model.predict([bloodpressure.test_dataset, etCO2.test_dataset, spO2.test_dataset, mac.test_dataset, info.test_dataset], verbose=0)
#      49     with open('download/prediction.pkl', 'wb') as f:
#      50         pickle.dump(y_pred, f)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2440, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2425, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2413, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2381, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 219, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Layer "model" expects 4 input(s), but it received 5 input tensors. Inputs received: [<tf.Tensor 'IteratorGetNext:0' shape=(None, 3744, 3) dtype=float32>, <tf.Tensor 'IteratorGetNext:1' shape=(None, 3744, 1) dtype=float32>, <tf.Tensor 'IteratorGetNext:2' shape=(None, 3744, 1) dtype=float32>, <tf.Tensor 'IteratorGetNext:3' shape=(None, 3744, 1) dtype=float32>, <tf.Tensor 'IteratorGetNext:4' shape=(None, 5) dtype=float32>]

# %% [markdown]
# # Training results

# %%
from utils.plotting import training_loss_plot

plot = training_loss_plot(train_score, filename='download/training_loss.pdf')
plot.show()

# %% [markdown]
# # Testing

# %%
### Predict on the test set
from utils.evaluation import phases_report, phases_report_std

print('Testmetriken:')

report = phases_report(y_pred, bis.test_dataset, mac.test_dataset)
report
# Out:
# Testmetriken:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-d657c53b64e0> in <cell line: 6>()
#       4 print('Testmetriken:')
#       5
# ----> 6 report = phases_report(y_pred, bis.test_dataset, mac.test_dataset)
#       7 report
#
# /content/utils/evaluation.py in phases_report(prediction, groundtruth, propofolrate)
#      49     baseline = np.ones(groundtruth.shape) * 41.0
#      50
# ---> 51     phases = get_anaesthesia_phases(dataset = propofolrate)
#      52
#      53     # Create the three datasets
#
# /content/utils/evaluation.py in get_anaesthesia_phases(dataset, N)
#      26         conv = np.convolve(data[:,0], np.ones(N)/N, mode='valid')
#      27         index1 = np.argmax(conv < 40) + 2 * N
# ---> 28         index2 = np.where(conv > 5)[0][-1] - N
#      29         anesthesia_phases.append([index1, index2])
#      30
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
phases_report_std(report, y_pred, bis.test_dataset, mac.test_dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e02a79d94edc> in <cell line: 1>()
# ----> 1 phases_report_std(report, y_pred, bis.test_dataset, mac.test_dataset)
#
# NameError: name 'report' is not defined

# %%
from utils.plotting import full_histogramm_plot

plot = full_histogramm_plot(groundtruth = bis.test_dataset, prediction = y_pred, filename='download/histogramm.pdf')
plot.show()

# %%
from utils.plotting import single_prediction_plot

for case in test_index:
    single_prediction_plot(
        case = case,
        index = test_index,
        groundtruth = bis.test_dataset,
        prediction = y_pred,
        infusion = mac.test_dataset,
        error = 'Prediction RMSE',
        filename = 'download/' + str(case) + '.pdf')

print('Finished')

# %%
from utils.plotting import full_prediction_plot

full_prediction_plot(index = test_index, groundtruth = bis.test_dataset, prediction = y_pred, infusion = mac.test_dataset)
